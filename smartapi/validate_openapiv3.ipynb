# %% [markdown]
# ---

# %% [markdown]
# [Issue: Support OpenAPI v3.1.0 schema validation](https://github.com/SmartAPI/smartAPI/issues/245)

# %%
# Import necessary libraries
import json

import requests
import yaml
import jsonschema

from jsonschema import validate, Draft7Validator
from deepdiff import DeepDiff

from controller.smartapi import SmartAPI

import warnings
warnings.filterwarnings("ignore")

# %%
def validate_doc(smartapi, schema):
    try:
        # Decode the raw data from bytes to a string
        data_doc = smartapi.raw.decode('utf-8')
        # Load the YAML formatted string into a Python dictionary
        data_dict = yaml.safe_load(data_doc)
        # Now validate the dictionary against the schema
        validate(instance=data_dict, schema=schema)
        print("Validation successful!")
    except yaml.YAMLError as ye:
        print(f"YAML parsing error: {str(ye)}")
    except jsonschema.exceptions.ValidationError as ve:
        print(f"Validation error at {ve.path}: {ve.message}")
    except jsonschema.exceptions.SchemaError as se:
        print(f"Schema error: {se.message}")
    except Exception as e:
        print(f"An unexpected error occurred: {str(e)}")

# %% [markdown]
#  **View our document data to inspect**

# %% [markdown]
# https://smart-api.info/registry?q=beb82e00728d3824591caec8da3e63fc

# %%
test_doc_id = 'beb82e00728d3824591caec8da3e63fc'
test_doc = SmartAPI.get(test_doc_id)
test_data_doc = smartapi.raw.decode()
print(test_doc.raw)
print(type(test_doc.raw))
print(test_data_doc)
# Out:
# b'{"openapi":"3.0.2","info":{"title":"Sri-node-normalizer(Trapi v1.4.0)","version":"2.3.5","x-translator":{"component":"Utility","team":["Standards Reference Implementation Team"],"infores":"infores:sri-node-normalizer"},"x-trapi":{"version":"1.4.0","operations":["annotate_nodes"]},"contact":{"email":"bizon@renci.org","name":"Chris Bizon","x-id":"https://github.com/cbizon","x-role":"responsible developer"},"termsOfService":"https://toss.apps.renci.org/tos?service_long=Node+Normalization&provider_long=the+Translator+Consortium","description":"Node Normalization takes a CURIE, and returns: <ol> <li>The preferred CURIE for this entity <li>All other known equivalent identifiers for the entity <li>Semantic types for the entity as defined by the <a href=\\"https://biolink.github.io/biolink-model/\\">BioLink Model</a> </ol> The data served by Node Normalization is created by <a href=\\"https://github.com/TranslatorSRI/Babel\\">Babel</a>, which attempts to find identifier equivalences, and makes sure that CURIE prefixes are BioLink Model Compliant.  To determine whether Node Normalization is likely to be useful, check /get_semantic_types, which lists the BioLink semantic types for which normalization has been attempted, and /get_curie_prefixes, which lists the number of times each prefix is used for a semantic type."},"paths":{"/query":{"post":{"summary":"Normalizes a TRAPI response object","description":"Returns the response object with a merged knowledge graph and query graph bindings","operationId":"query_query_post","requestBody":{"content":{"application/json":{"schema":{"$ref":"#/components/schemas/Query"}}},"required":true},"responses":{"200":{"description":"Successful Response","content":{"application/json":{"schema":{"$ref":"#/components/schemas/Query"}}}},"422":{"description":"Validation Error","content":{"application/json":{"schema":{"$ref":"#/components/schemas/HTTPValidationError"}}}}}}},"/asyncquery":{"post":{"summary":"Normalizes a TRAPI response object","description":"Returns the response object with a merged knowledge graph and query graph bindings","operationId":"async_query_asyncquery_post","requestBody":{"content":{"application/json":{"schema":{"$ref":"#/components/schemas/AsyncQuery"}}},"required":true},"responses":{"200":{"description":"Successful Response","content":{"application/json":{"schema":{}}}},"422":{"description":"Validation Error","content":{"application/json":{"schema":{"$ref":"#/components/schemas/HTTPValidationError"}}}}}}},"/get_allowed_conflations":{"get":{"summary":"Get the available conflations","description":"The returned strings can be included in an option to /get_normalized_nodes","operationId":"get_conflations_get_allowed_conflations_get","responses":{"200":{"description":"Successful Response","content":{"application/json":{"schema":{}}}}}}},"/get_normalized_nodes":{"get":{"summary":"Get the equivalent identifiers and semantic types for the curie(s) entered.","description":"Returns the equivalent identifiers and semantic types for the curie(s)","operationId":"get_normalized_node_handler_get_normalized_nodes_get","parameters":[{"description":"List of curies to normalize","required":false,"schema":{"title":"Curie","minItems":1,"type":"array","items":{"type":"string"},"description":"List of curies to normalize","default":[]},"example":["MESH:D014867","NCIT:C34373"],"name":"curie","in":"query"},{"description":"Whether to apply gene/protein conflation","required":false,"schema":{"title":"Conflate","type":"boolean","description":"Whether to apply gene/protein conflation","default":true},"name":"conflate","in":"query"},{"description":"Whether to apply drug/chemical conflation","required":false,"schema":{"title":"Drug Chemical Conflate","type":"boolean","description":"Whether to apply drug/chemical conflation","default":false},"name":"drug_chemical_conflate","in":"query"},{"description":"Whether to return curie descriptions when possible","required":false,"schema":{"title":"Description","type":"bool ...
# <class 'bytes'>
# servers:
#   - url: 'https://ramp-api-alpha.ncats.io'
#  # - url: 'http://127.0.0.1:5762/'
# openapi: 3.0.3
# info:
#   description: Relational Database of Metabolic Pathways (RaMP) API
#   title: RaMP API v1.0.1
#   version: 1.0.1
#   contact:
#     name: Timothy Sheils
#     x-role: responsible developer
#     email: timothy.sheils@nih.gov
#     x-id: 'https://github.com/tsheils'
#   termsOfService: https://rampdb.nih.gov
# tags:
# - name: NCATS-API
# paths:
#   /api/source_versions:
#     get:
#       summary: Return source version information
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#           content:
#             application/json:
#               schema:
#                 type: object
#       parameters: []
#   /api/id-types:
#     get:
#       summary: Return analyte ID types
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#           content:
#             application/json:
#               schema:
#                 type: object
#       parameters: []
#   /api/entity_counts:
#     get:
#       summary: Return counts on entities and their associations
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#           content:
#             application/json:
#               schema:
#                 type: object
#       parameters: []
#   /api/analyte_intersects:
#     get:
#       summary: Return analyte source intersects
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#       parameters:
#         - name: analytetype
#           description: >-
#             specifies type of analyte intersects to return, 'metabolites' or
#             'genes'
#           in: query
#           required: true
#           schema:
#             type: string
#         - name: query_scope
#           description: specifies 'global' or 'mapped-to-pathway'
#           in: query
#           required: true
#           schema:
#             type: string
#   /api/ontology-types:
#     get:
#       summary: Return all types of ontologies present in RaMP-DB
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#           content:
#             application/json:
#               schema:
#                 type: object
#       parameters: []
#   /api/chemical-class-type:
#     get:
#       summary: Return available high level chemical class types (from ClassyFire)
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#       parameters:
#         - name: classtype
#           in: query
#           required: false
#           schema:
#             type: string
#   /api/pathways-from-analytes:
#     post:
#       summary: Return pathways from given list of analytes
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Retrieve pathway(s) for a given analyte(s). IDs should be prepended by ID source (e.g. **hmdb**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 analytes:
#                   type: array
#                   items:
#                     type: string
#               example: # Sample object
#                 analytes: ["ensembl:ENSG00000135679", "hmdb:HMDB0000064", "hmdb:HMDB0000148", "ensembl:ENSG00000141510"]
#   /api/analytes-from-pathways:
#     post:
#       summary: Retrieve analytes (genes/proteins, metabolites) by pathway.
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Enter exact pathway name(s). `analyte_type` should be `"gene"`, `"metabolite"`, or `"both"` *(default)*
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 pathway:
#                   type: array
#                   items:
#                     type: string
#                 analyte_type:
#                   type: string
#                   enum: ["gene", "metabolite", "both"]
#                   required: false
#               example:
#                 pathway: [ "De Novo Triacylglycerol Biosynthesis", "sphingolipid metabolism"]
#                 analyte_type: "both"
#   /api/ontologies-from-metabolites:
#     post:
#       summary: Return ontologies from list of metabolites
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Enter a list of metabolites. IDs should be prepended by ID source (e.g. **kegg**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 metabolite:
#                   type: array
#                   items:
#                     type: string
#                 NameOrIds:
#                   type: string
#                   enum: [ "name", "ids"]
#                   required: false
#               example:
#                 metabolite: [ "ensembl:ENSG00000135679", "hmdb:HMDB0000064", "hmdb:HMDB0000148", "ensembl:ENSG00000141510"]
#                 NameOrIds: "ids"
#   /api/metabolites-from-ontologies:
#     post:
#       summary: Return metabolites from ontology
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Enter ontology(ies) and retrieve corresponding analytes (metabolites).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 ontology:
#                   type: array
#                   items:
#                     type: string
#                 format:
#                   type: string
#                   enum: [ "json", "tsv" ]
#                   required: false
#               example:
#                 ontology: ["Colon", "Liver", "Lung"]
#                 format: "json"
#   /api/chemical-classes:
#     post:
#       summary: Return available chemical classes of given metabolites in RaMP-DB
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Retrieve chemical class information (from ClassyFire and LIPID MAPS) for input metabolite IDs. IDs should be prepended by ID source (e.g. **hmdb**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 metabolites:
#                   type: array
#                   items:
#                       type: string
#                 biospecimen:
#                   type: string
#                   enum: ["Blood", "Adipose", "Heart", "Urine", "Brain", "Liver", "Kidney", "Saliva", "Feces"]
#                   required: false
#               example:
#                 metabolites: ["hmdb:HMDB0000056", "hmdb:HMDB0000439", "hmdb:HMDB0000479", "hmdb:HMDB0000532",
#                               "hmdb:HMDB0001015", "hmdb:HMDB0001138", "hmdb:HMDB0029159", "hmdb:HMDB0029412",
#                               "hmdb:HMDB0034365", "hmdb:HMDB0035227", "hmdb:HMDB0007973", "hmdb:HMDB0008057",
#                               "hmdb:HMDB0011211"]
#   /api/chemical-properties:
#     post:
#       summary: Return chemical properties of given metabolites
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Retrieve chemical properties (smiles, inchi_key, inchi_key_prefix, inchi, mw, monoisotop_mass, formula, common_name) from input metabolites. IDs should be prepended by ID source (e.g. **hmdb**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 metabolites:
#                   type: array
#                   items:
#                     type: string
#               example:
#                 metabolites: [ "hmdb:HMDB0000056", "hmdb:HMDB0000439", "hmdb:HMDB0000479", "hmdb:HMDB0000532",
#                                "hmdb:HMDB0001015", "hmdb:HMDB0001138", "hmdb:HMDB0029159", "hmdb:HMDB0029412",
#                                "hmdb:HMDB0034365", "hmdb:HMDB0035227", "hmdb:HMDB0007973", "hmdb:HMDB0008057",
#                                "hmdb:HMDB0011211" ]
#   /api/common-reaction-analytes:
#     post:
#       summary: Return analytes involved in same reaction as given list of analytes
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Retrieve Analytes Involved in the Same Reaction. IDs should be prepended by ID source (e.g. **hmdb**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 analyte:
#                   type: array
#                   items:
#                     type: string
#                 NameOrIds:
#                   type: string
#                   enum: [ "name", "ids" ]
#                   required: false
#               example:
#                 analyte: [ "ensembl:ENSG00000135679", "hmdb:HMDB0000064", "hmdb:HMDB0000148", "ensembl:ENSG00000141510"]
#   /api/combined-fisher-test:
#     post:
#       summary: Return combined Fisher's test results from given list of analytes query results
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Perform Pathway Enrichment. IDs should be prepended by ID source (e.g. **hmdb**:C00412). Input analyte IDs can be a mix of genes/proteins or metabolites.
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 analytes:
#                   type: array
#                   items:
#                     type: string
#                 biospecimen:
#                   type: string
#                   enum: [ "Blood", "Adipose", "Heart", "Urine", "Brain", "Liver", "Kidney", "Saliva", "Feces" ]
#                   required: false
#               example: # Sample object
#                 analytes: ["hmdb:HMDB0000033", "hmdb:HMDB0000052", "hmdb:HMDB0000094", "hmdb:HMDB0000161",
#                            "hmdb:HMDB0000168", "hmdb:HMDB0000191", "hmdb:HMDB0000201", "chemspider:10026",
#                            "hmdb:HMDB0006059", "Chemspider:6405", "CAS:5657-19-2", "hmdb:HMDB0002511",
#                            "chemspider:20171375", "CAS:133-32-4", "CAS:5746-90-7", "CAS:477251-67-5", "hmdb:HMDB0000695",
#                            "chebi:15934", "CAS:838-07-3", "hmdb:HMDBP00789", "hmdb:HMDBP00283", "hmdb:HMDBP00284",
#                            "hmdb:HMDBP00850"]
#   /api/filter-fisher-test-results:
#     post:
#       summary: >-
#         Return filtered Fisher's test results from given list of Fisher's test
#         results
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Filter Pathway Enrichment. This is primarily used after running `combined-fisher-test` as the required input is the output from that call.
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 fishers_results:
#                   type: array
#                   items:
#                     type: object
#                 pval_type:
#                   type: string
#                   enum: ["fdr", "holm", "pval"]
#                   required: false
#                 pval_cutoff:
#                   type: number
#                   required: false
#               example: # Sample object
#                 fishers_results:
#                   analyte_type: ["both"]
#                   result_type: ["pathway_enrichment"]
#                   fishresults: [
#                     {
#                       "pathwayName": "beta-Alanine metabolism",
#                       "pathwayId": "map00410",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.032104,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 29,
#                       "Pval_combined": 0.032104,
#                       "Pval_combined_FDR": 0.059322,
#                       "Pval_combined_Holm": 1,
#                       "analytes": "CARN; Carnosine;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Methionine Metabolism",
#                       "pathwayId": "map00270",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000044,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 55,
#                       "Pval_combined": 0.000044,
#                       "Pval_combined_FDR": 0.000164,
#                       "Pval_combined_Holm": 0.002797,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Tyrosine metabolism",
#                       "pathwayId": "map00350",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.518364,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 69,
#                       "Pval_Gene": 0.00003,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 45,
#                       "Pval_combined": 0.000015,
#                       "Pval_combined_FDR": 0.000065,
#                       "Pval_combined_Holm": 0.001013,
#                       "analytes": "L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Arginine and proline metabolism",
#                       "pathwayId": "map00330",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.011701,
#                       "Num_In_Path_Metab": 3,
#                       "Total_In_Path_Metab": 51,
#                       "Pval_Gene": 1.132259e-7,
#                       "Num_In_Path_Gene": 3,
#                       "Total_In_Path_Gene": 62,
#                       "Pval_combined": 1.324894e-9,
#                       "Pval_combined_FDR": 2.8154e-8,
#                       "Pval_combined_Holm": 1.086413e-7,
#                       "analytes": "Argininosuccinic acid;L-Alanine;L-Aspartic acid;GOT1;GOT2;GPT"
#                     },
#                     {
#                       "pathwayName": "Phenylalanine and Tyrosine Metabolism",
#                       "pathwayId": "map00360",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Alanine, aspartate and glutamate metabolism",
#                       "pathwayId": "map00250",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.001954,
#                       "Num_In_Path_Metab": 4,
#                       "Total_In_Path_Metab": 61,
#                       "Pval_Gene": 5.11736e-11,
#                       "Num_In_Path_Gene": 4,
#                       "Total_In_Path_Gene": 55,
#                       "Pval_combined": 9.99901e-14,
#                       "Pval_combined_FDR": 4.249579e-12,
#                       "Pval_combined_Holm": 8.399168e-12,
#                       "analytes": "Argininosuccinic acid;L-Alanine;L-Asparagine;L-Aspartic acid;GOT1;GOT2;AGXT;GPT"
#                     },
#                     {
#                       "pathwayName": "Nitrogen metabolism",
#                       "pathwayId": "map00910",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.02611,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 26,
#                       "Pval_combined": 0.02611,
#                       "Pval_combined_FDR": 0.05044,
#                       "Pval_combined_Holm": 1,
#                       "analytes": "L-Asparagine;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "2-Oxocarboxylic acid metabolism",
#                       "pathwayId": "map01210",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000003147428,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 15,
#                       "Pval_combined": 0.000003147428,
#                       "Pval_combined_FDR": 0.000024,
#                       "Pval_combined_Holm": 0.000236,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Phenylalanine, tyrosine and tryptophan biosynthesis",
#                       "pathwayId": "map00400",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000005693446,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 20,
#                       "Pval_combined": 0.000005693446,
#                       "Pval_combined_FDR": 0.00004,
#                       "Pval_combined_Holm": 0.000421,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glyoxylate metabolism and glycine degradation",
#                       "pathwayId": "R-HSA-389661",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000014,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 31,
#                       "Pval_combined": 0.000014,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000947,
#                       "analytes": "GOT2;AGXT"
#                     },
#                     {
#                       "pathwayName": "Sulfur amino acid metabolism",
#                       "pathwayId": "R-HSA-1614635",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Gluconeogenesis",
#                       "pathwayId": "R-HSA-70263",
#                       "pathwaySource": "reactome",
#                       "Pval_Metab": 0.122185,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 32,
#                       "Pval_Gene": 0.000017,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 34,
#                       "Pval_combined": 0.000002052088,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000156,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glucose metabolism",
#                       "pathwayId": "R-HSA-70326",
#                       "pathwaySource": "reactome",
#                       "Pval_Metab": 0.157544,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 42,
#                       "Pval_Gene": 0.000125,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 92,
#                       "Pval_combined": 0.00002,
#                       "Pval_combined_FDR": 0.00008,
#                       "Pval_combined_Holm": 0.001278,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Aspartate and asparagine metabolism",
#                       "pathwayId": "R-HSA-8963693",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000001649093,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 11,
#                       "Pval_combined": 0.000001649093,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.00013,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Amino acid metabolism pathway excerpt: histidine catabolism extension",
#                       "pathwayId": "WP4661",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.00079,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 17,
#                       "Pval_combined": 0.00079,
#                       "Pval_combined_FDR": 0.002684,
#                       "Pval_combined_Holm": 0.04816,
#                       "analytes": "Citric acid;L-Alanine"
#                     },
#                     {
#                       "pathwayName": "Sulfur amino acid metabolism",
#                       "pathwayId": "WP3574",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glycolysis and gluconeogenesis",
#                       "pathwayId": "WP534",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.045562,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 18,
#                       "Pval_Gene": 0.000031,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 46,
#                       "Pval_combined": 0.000001410614,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000113,
#                       "analytes": "L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Amino acid metabolism",
#                       "pathwayId": "WP3925",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.000003106941,
#                       "Num_In_Path_Metab": 5,
#                       "Total_In_Path_Metab": 109,
#                       "Pval_Gene": 0.00013,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 94,
#                       "Pval_combined": 4.049386e-10,
#                       "Pval_combined_FDR": 1.147326e-8,
#                       "Pval_combined_Holm": 3.360991e-8,
#                       "analytes": "Argininosuccinic acid;Citric acid;L-Alanine;L-Asparagine;L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Biomarkers for urea cycle disorders",
#                       "pathwayId": "WP4583",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000001978779,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 12,
#                       "Pval_combined": 0.000001978779,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000152,
#                       "analytes": "GOT1;GPT"
#                     },
#                     {
#                       "pathwayName": "Urea cycle and metabolism of amino groups",
#                       "pathwayId": "WP497",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.002822,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 32,
#                       "Pval_combined": 0.002822,
#                       "Pval_combined_FDR": 0.007055,
#                       "Pval_combined_Holm": 0.15385,
#                       "analytes": "Argininosuccinic acid;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Glucose metabolism",
#                       "pathwayId": "WP4093",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.103437,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 42,
#                       "Pval_Gene": 0.000125,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 92,
#                       "Pval_combined": 0.000013,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000891,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Metabolic reprogramming in colon cancer",
#                       "pathwayId": "WP4290",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.004177,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 39,
#                       "Pval_Gene": 0.008374,
#                       "Num_In_Path_Gene": 1,
#                       "Total_In_Path_Gene": 42,
#                       "Pval_combined": 0.000035,
#                       "Pval_combined_FDR": 0.000135,
#                       "Pval_combined_Holm": 0.002238,
#                       "analytes": "Citric acid;L-Asparagine;GOT2"
#                     },
#                     {
#                       "pathwayName": "Aspartate and asparagine metabolism",
#                       "pathwayId": "WP4979",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000001649093,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 11,
#                       "Pval_combined": 0.000001649093,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.00013,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Urea cycle and associated pathways",
#                       "pathwayId": "WP4595",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 6.068128e-9,
#                       "Num_In_Path_Gene": 3,
#                       "Total_In_Path_Gene": 24,
#                       "Pval_combined": 6.068128e-9,
#                       "Pval_combined_FDR": 1.031582e-7,
#                       "Pval_combined_Holm": 4.915183e-7,
#                       "analytes": "GOT1;GOT2;GPT"
#                     },
#                     {
#                       "pathwayName": "NAD metabolism in oncogene-induced senescence and mitochondrial dysfunction-associated senescence",
#                       "pathwayId": "WP5046",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000009734892,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 26,
#                       "Pval_combined": 0.000009734892,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000711,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Metabolism overview",
#                       "pathwayId": "WP3602",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.002603,
#                       "Num_In_Path_Metab": 3,
#                       "Total_In_Path_Metab": 116,
#                       "Pval_combined": 0.002603,
#                       "Pval_combined_FDR": 0.007055,
#                       "Pval_combined_Holm": 0.145751,
#                       "analytes": "Argininosuccinic acid;Citric acid;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Glyoxylate metabolism and glycine degradation",
#                       "pathwayId": "WP3562",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000014,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 31,
#                       "Pval_combined": 0.000014,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000947,
#                       "analytes": "GOT2;AGXT"
#                     },
#                     {
#                       "pathwayName": "Alanine and aspartate metabolism",
#                       "pathwayId": "WP106",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 7.081563e-15,
#                       "Num_In_Path_Metab": 7,
#                       "Total_In_Path_Metab": 23,
#                       "Pval_Gene": 1.371261e-11,
#                       "Num_In_Path_Gene": 4,
#                       "Total_In_Path_Gene": 40,
#                       "Pval_combined": 9.710673e-26,
#                       "Pval_combined_FDR": 8.254072e-24,
#                       "Pval_combined_Holm": 8.254072e-24,
#                       "analytes": "CARN; Carnosine;Argininosuccinic acid;Citric acid;L-Alanine;L-Asparagine;L-Aspartic acid;(3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate; L-Acetylcarnitine; O-Acetylcarnitine;GOT1;GOT2;AGXT;GPT"
#                     },
#                     {
#                       "pathwayName": "mRNA, protein, and metabolite inducation pathway by cyclosporin A",
#                       "pathwayId": "WP3953",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.00053,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 14,
#                       "Pval_combined": 0.00053,
#                       "Pval_combined_FDR": 0.001879,
#                       "Pval_combined_Holm": 0.032885,
#                       "analytes": "L-Alanine;L-Asparagine"
#                     }
#                   ]
#   /api/cluster-fisher-test-results:
#     post:
#       summary: >-
#         Return clustered Fisher's test results from given list of Fisher's test
#         results
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Cluster Pathway Enrichment. This is primarily used after running `combined-fisher-test` or `filter-fisher-test` as the required input is the output from that call.
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 min_pathway_tocluster:
#                   type: number
#                   required: false
#                 perc_analyte_overlap:
#                   type: number
#                   required: false
#                 perc_pathway_overlap:
#                   type: number
#                   required: false
#                 fishers_results:
#                   type: array
#                   items:
#                     type: object
#                 pval_type:
#                   type: string
#                   enum: [ "fdr", "holm", "pval" ]
#                   required: false
#                 pval_cutoff:
#                   type: number
#                   required: false
#               example: # Sample object
#                 min_pathway_tocluster: 2
#                 perc_analyte_overlap: 0.2
#                 perc_pathway_overlap: 0.2
#                 fishers_results:
#                   analyte_type: [ "both" ]
#                   result_type: [ "pathway_enrichment" ]
#                   fishresults: [
#                     {
#                       "pathwayName": "beta-Alanine metabolism",
#                       "pathwayId": "map00410",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.032104,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 29,
#                       "Pval_combined": 0.032104,
#                       "Pval_combined_FDR": 0.059322,
#                       "Pval_combined_Holm": 1,
#                       "analytes": "CARN; Carnosine;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Methionine Metabolism",
#                       "pathwayId": "map00270",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000044,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 55,
#                       "Pval_combined": 0.000044,
#                       "Pval_combined_FDR": 0.000164,
#                       "Pval_combined_Holm": 0.002797,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Tyrosine metabolism",
#                       "pathwayId": "map00350",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.518364,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 69,
#                       "Pval_Gene": 0.00003,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 45,
#                       "Pval_combined": 0.000015,
#                       "Pval_combined_FDR": 0.000065,
#                       "Pval_combined_Holm": 0.001013,
#                       "analytes": "L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Arginine and proline metabolism",
#                       "pathwayId": "map00330",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.011701,
#                       "Num_In_Path_Metab": 3,
#                       "Total_In_Path_Metab": 51,
#                       "Pval_Gene": 1.132259e-7,
#                       "Num_In_Path_Gene": 3,
#                       "Total_In_Path_Gene": 62,
#                       "Pval_combined": 1.324894e-9,
#                       "Pval_combined_FDR": 2.8154e-8,
#                       "Pval_combined_Holm": 1.086413e-7,
#                       "analytes": "Argininosuccinic acid;L-Alanine;L-Aspartic acid;GOT1;GOT2;GPT"
#                     },
#                     {
#                       "pathwayName": "Phenylalanine and Tyrosine Metabolism",
#                       "pathwayId": "map00360",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Alanine, aspartate and glutamate metabolism",
#                       "pathwayId": "map00250",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.001954,
#                       "Num_In_Path_Metab": 4,
#                       "Total_In_Path_Metab": 61,
#                       "Pval_Gene": 5.11736e-11,
#                       "Num_In_Path_Gene": 4,
#                       "Total_In_Path_Gene": 55,
#                       "Pval_combined": 9.99901e-14,
#                       "Pval_combined_FDR": 4.249579e-12,
#                       "Pval_combined_Holm": 8.399168e-12,
#                       "analytes": "Argininosuccinic acid;L-Alanine;L-Asparagine;L-Aspartic acid;GOT1;GOT2;AGXT;GPT"
#                     },
#                     {
#                       "pathwayName": "Nitrogen metabolism",
#                       "pathwayId": "map00910",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.02611,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 26,
#                       "Pval_combined": 0.02611,
#                       "Pval_combined_FDR": 0.05044,
#                       "Pval_combined_Holm": 1,
#                       "analytes": "L-Asparagine;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "2-Oxocarboxylic acid metabolism",
#                       "pathwayId": "map01210",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000003147428,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 15,
#                       "Pval_combined": 0.000003147428,
#                       "Pval_combined_FDR": 0.000024,
#                       "Pval_combined_Holm": 0.000236,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Phenylalanine, tyrosine and tryptophan biosynthesis",
#                       "pathwayId": "map00400",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000005693446,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 20,
#                       "Pval_combined": 0.000005693446,
#                       "Pval_combined_FDR": 0.00004,
#                       "Pval_combined_Holm": 0.000421,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glyoxylate metabolism and glycine degradation",
#                       "pathwayId": "R-HSA-389661",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000014,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 31,
#                       "Pval_combined": 0.000014,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000947,
#                       "analytes": "GOT2;AGXT"
#                     },
#                     {
#                       "pathwayName": "Sulfur amino acid metabolism",
#                       "pathwayId": "R-HSA-1614635",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Gluconeogenesis",
#                       "pathwayId": "R-HSA-70263",
#                       "pathwaySource": "reactome",
#                       "Pval_Metab": 0.122185,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 32,
#                       "Pval_Gene": 0.000017,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 34,
#                       "Pval_combined": 0.000002052088,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000156,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glucose metabolism",
#                       "pathwayId": "R-HSA-70326",
#                       "pathwaySource": "reactome",
#                       "Pval_Metab": 0.157544,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 42,
#                       "Pval_Gene": 0.000125,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 92,
#                       "Pval_combined": 0.00002,
#                       "Pval_combined_FDR": 0.00008,
#                       "Pval_combined_Holm": 0.001278,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Aspartate and asparagine metabolism",
#                       "pathwayId": "R-HSA-8963693",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000001649093,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 11,
#                       "Pval_combined": 0.000001649093,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.00013,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Amino acid metabolism pathway excerpt: histidine catabolism extension",
#                       "pathwayId": "WP4661",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.00079,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 17,
#                       "Pval_combined": 0.00079,
#                       "Pval_combined_FDR": 0.002684,
#                       "Pval_combined_Holm": 0.04816,
#                       "analytes": "Citric acid;L-Alanine"
#                     },
#                     {
#                       "pathwayName": "Sulfur amino acid metabolism",
#                       "pathwayId": "WP3574",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glycolysis and gluconeogenesis",
#                       "pathwayId": "WP534",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.045562,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 18,
#                       "Pval_Gene": 0.000031,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 46,
#                       "Pval_combined": 0.000001410614,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000113,
#                       "analytes": "L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Amino acid metabolism",
#                       "pathwayId": "WP3925",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.000003106941,
#                       "Num_In_Path_Metab": 5,
#                       "Total_In_Path_Metab": 109,
#                       "Pval_Gene": 0.00013,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 94,
#                       "Pval_combined": 4.049386e-10,
#                       "Pval_combined_FDR": 1.147326e-8,
#                       "Pval_combined_Holm": 3.360991e-8,
#                       "analytes": "Argininosuccinic acid;Citric acid;L-Alanine;L-Asparagine;L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Biomarkers for urea cycle disorders",
#                       "pathwayId": "WP4583",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000001978779,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 12,
#                       "Pval_combined": 0.000001978779,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000152,
#                       "analytes": "GOT1;GPT"
#                     },
#                     {
#                       "pathwayName": "Urea cycle and metabolism of amino groups",
#                       "pathwayId": "WP497",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.002822,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 32,
#                       "Pval_combined": 0.002822,
#                       "Pval_combined_FDR": 0.007055,
#                       "Pval_combined_Holm": 0.15385,
#                       "analytes": "Argininosuccinic acid;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Glucose metabolism",
#                       "pathwayId": "WP4093",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.103437,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 42,
#                       "Pval_Gene": 0.000125,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 92,
#                       "Pval_combined": 0.000013,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000891,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Metabolic reprogramming in colon cancer",
#                       "pathwayId": "WP4290",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.004177,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 39,
#                       "Pval_Gene": 0.008374,
#                       "Num_In_Path_Gene": 1,
#                       "Total_In_Path_Gene": 42,
#                       "Pval_combined": 0.000035,
#                       "Pval_combined_FDR": 0.000135,
#                       "Pval_combined_Holm": 0.002238,
#                       "analytes": "Citric acid;L-Asparagine;GOT2"
#                     },
#                     {
#                       "pathwayName": "Aspartate and asparagine metabolism",
#                       "pathwayId": "WP4979",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000001649093,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 11,
#                       "Pval_combined": 0.000001649093,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.00013,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Urea cycle and associated pathways",
#                       "pathwayId": "WP4595",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 6.068128e-9,
#                       "Num_In_Path_Gene": 3,
#                       "Total_In_Path_Gene": 24,
#                       "Pval_combined": 6.068128e-9,
#                       "Pval_combined_FDR": 1.031582e-7,
#                       "Pval_combined_Holm": 4.915183e-7,
#                       "analytes": "GOT1;GOT2;GPT"
#                     },
#                     {
#                       "pathwayName": "NAD metabolism in oncogene-induced senescence and mitochondrial dysfunction-associated senescence",
#                       "pathwayId": "WP5046",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000009734892,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 26,
#                       "Pval_combined": 0.000009734892,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000711,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Metabolism overview",
#                       "pathwayId": "WP3602",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.002603,
#                       "Num_In_Path_Metab": 3,
#                       "Total_In_Path_Metab": 116,
#                       "Pval_combined": 0.002603,
#                       "Pval_combined_FDR": 0.007055,
#                       "Pval_combined_Holm": 0.145751,
#                       "analytes": "Argininosuccinic acid;Citric acid;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Glyoxylate metabolism and glycine degradation",
#                       "pathwayId": "WP3562",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000014,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 31,
#                       "Pval_combined": 0.000014,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000947,
#                       "analytes": "GOT2;AGXT"
#                     },
#                     {
#                       "pathwayName": "Alanine and aspartate metabolism",
#                       "pathwayId": "WP106",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 7.081563e-15,
#                       "Num_In_Path_Metab": 7,
#                       "Total_In_Path_Metab": 23,
#                       "Pval_Gene": 1.371261e-11,
#                       "Num_In_Path_Gene": 4,
#                       "Total_In_Path_Gene": 40,
#                       "Pval_combined": 9.710673e-26,
#                       "Pval_combined_FDR": 8.254072e-24,
#                       "Pval_combined_Holm": 8.254072e-24,
#                       "analytes": "CARN; Carnosine;Argininosuccinic acid;Citric acid;L-Alanine;L-Asparagine;L-Aspartic acid;(3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate; L-Acetylcarnitine; O-Acetylcarnitine;GOT1;GOT2;AGXT;GPT"
#                     },
#                     {
#                       "pathwayName": "mRNA, protein, and metabolite inducation pathway by cyclosporin A",
#                       "pathwayId": "WP3953",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.00053,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 14,
#                       "Pval_combined": 0.00053,
#                       "Pval_combined_FDR": 0.001879,
#                       "Pval_combined_Holm": 0.032885,
#                       "analytes": "L-Alanine;L-Asparagine"
#                     }
#                   ]
#   /api/chemical-enrichment:
#     post:
#       summary: Perform chemical enrichment on given metabolites
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Perform chemical class enrichment on ClassyFire and LIPIDMAPS classes. IDs should be prepended by ID source (e.g. **hmdb**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 metabolites:
#                   type: array
#                   items:
#                     type: string
#                 biospecimen:
#                   type: string
#                   enum: [ "Blood", "Adipose", "Heart", "Urine", "Brain", "Liver", "Kidney", "Saliva", "Feces" ]
#                   required: false
#               example:
#                 metabolites: [ "hmdb:HMDB0000056", "hmdb:HMDB0000439", "hmdb:HMDB0000479", "hmdb:HMDB0000532",
#                                "hmdb:HMDB0001015", "hmdb:HMDB0001138", "hmdb:HMDB0029159", "hmdb:HMDB0029412",
#                                "hmdb:HMDB0034365", "hmdb:HMDB0035227", "hmdb:HMDB0007973", "hmdb:HMDB0008057",
#                                "hmdb:HMDB0011211" ]

# %%
trapi_doc_31="/Users/nacosta/Documents/smartAPI/trapi-openapi31.0"

# %%
# Load the schema from a JSON file
with open(trapi_doc_31, 'r') as doc_:
    trapi_doc  = json.load(doc_)

# %%
type(trapi_doc)
# Out:
# dict

# %%
for smartapi in SmartAPI.get_all(1):
    # print(dir(smartapi._doc))
    #smartapi.url # confirm with the API
    # print(smartapi.url)
    data_doc = smartapi.raw.decode()
    print(smartapi.raw)
    print(type(smartapi.raw))
    print(type(data_doc))
    print(data_doc)
    break  # Print the directory of the first object to get all possible callable methods and attributes
# Out:
# b'servers:\n  - url: \'https://ramp-api-alpha.ncats.io\'\n # - url: \'http://127.0.0.1:5762/\'\nopenapi: 3.0.3\ninfo:\n  description: Relational Database of Metabolic Pathways (RaMP) API\n  title: RaMP API v1.0.1\n  version: 1.0.1\n  contact:\n    name: Timothy Sheils\n    x-role: responsible developer\n    email: timothy.sheils@nih.gov\n    x-id: \'https://github.com/tsheils\'\n  termsOfService: https://rampdb.nih.gov\ntags:\n- name: NCATS-API\npaths:\n  /api/source_versions:\n    get:\n      summary: Return source version information\n      responses:\n        \'200\':\n          description: OK\n          content:\n            application/json:\n              schema:\n                type: object\n        \'500\':\n          description: Internal Server Error\n          content:\n            application/json:\n              schema:\n                type: string\n        default:\n          description: Default response.\n          content:\n            application/json:\n              schema:\n                type: object\n      parameters: []\n  /api/id-types:\n    get:\n      summary: Return analyte ID types\n      responses:\n        \'200\':\n          description: OK\n          content:\n            application/json:\n              schema:\n                type: object\n        \'500\':\n          description: Internal Server Error\n          content:\n            application/json:\n              schema:\n                type: string\n        default:\n          description: Default response.\n          content:\n            application/json:\n              schema:\n                type: object\n      parameters: []\n  /api/entity_counts:\n    get:\n      summary: Return counts on entities and their associations\n      responses:\n        \'200\':\n          description: OK\n          content:\n            application/json:\n              schema:\n                type: object\n        \'500\':\n          description: Internal Server Error\n          content:\n            application/json:\n              schema:\n                type: string\n        default:\n          description: Default response.\n          content:\n            application/json:\n              schema:\n                type: object\n      parameters: []\n  /api/analyte_intersects:\n    get:\n      summary: Return analyte source intersects\n      responses:\n        \'200\':\n          description: OK\n        \'500\':\n          description: Internal Server Error\n          content:\n            application/json:\n              schema:\n                type: string\n        default:\n          description: Default response.\n      parameters:\n        - name: analytetype\n          description: >-\n            specifies type of analyte intersects to return, \'metabolites\' or\n            \'genes\'\n          in: query\n          required: true\n          schema:\n            type: string\n        - name: query_scope\n          description: specifies \'global\' or \'mapped-to-pathway\'\n          in: query\n          required: true\n          schema:\n            type: string\n  /api/ontology-types:\n    get:\n      summary: Return all types of ontologies present in RaMP-DB\n      responses:\n        \'200\':\n          description: OK\n          content:\n            application/json:\n              schema:\n                type: object\n        \'500\':\n          description: Internal Server Error\n          content:\n            application/json:\n              schema:\n                type: string\n        default:\n          description: Default response.\n          content:\n            application/json:\n              schema:\n                type: object\n      parameters: []\n  /api/chemical-class-type:\n    get:\n      summary: Return available high level chemical class types (from ClassyFire)\n      responses:\n        \'200\':\n          description: OK\n        \'500\':\n          description: Internal Server Error\n          content:\ ...
# <class 'bytes'>
# <class 'str'>
# servers:
#   - url: 'https://ramp-api-alpha.ncats.io'
#  # - url: 'http://127.0.0.1:5762/'
# openapi: 3.0.3
# info:
#   description: Relational Database of Metabolic Pathways (RaMP) API
#   title: RaMP API v1.0.1
#   version: 1.0.1
#   contact:
#     name: Timothy Sheils
#     x-role: responsible developer
#     email: timothy.sheils@nih.gov
#     x-id: 'https://github.com/tsheils'
#   termsOfService: https://rampdb.nih.gov
# tags:
# - name: NCATS-API
# paths:
#   /api/source_versions:
#     get:
#       summary: Return source version information
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#           content:
#             application/json:
#               schema:
#                 type: object
#       parameters: []
#   /api/id-types:
#     get:
#       summary: Return analyte ID types
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#           content:
#             application/json:
#               schema:
#                 type: object
#       parameters: []
#   /api/entity_counts:
#     get:
#       summary: Return counts on entities and their associations
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#           content:
#             application/json:
#               schema:
#                 type: object
#       parameters: []
#   /api/analyte_intersects:
#     get:
#       summary: Return analyte source intersects
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#       parameters:
#         - name: analytetype
#           description: >-
#             specifies type of analyte intersects to return, 'metabolites' or
#             'genes'
#           in: query
#           required: true
#           schema:
#             type: string
#         - name: query_scope
#           description: specifies 'global' or 'mapped-to-pathway'
#           in: query
#           required: true
#           schema:
#             type: string
#   /api/ontology-types:
#     get:
#       summary: Return all types of ontologies present in RaMP-DB
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#           content:
#             application/json:
#               schema:
#                 type: object
#       parameters: []
#   /api/chemical-class-type:
#     get:
#       summary: Return available high level chemical class types (from ClassyFire)
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#           content:
#             application/json:
#               schema:
#                 type: string
#         default:
#           description: Default response.
#       parameters:
#         - name: classtype
#           in: query
#           required: false
#           schema:
#             type: string
#   /api/pathways-from-analytes:
#     post:
#       summary: Return pathways from given list of analytes
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Retrieve pathway(s) for a given analyte(s). IDs should be prepended by ID source (e.g. **hmdb**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 analytes:
#                   type: array
#                   items:
#                     type: string
#               example: # Sample object
#                 analytes: ["ensembl:ENSG00000135679", "hmdb:HMDB0000064", "hmdb:HMDB0000148", "ensembl:ENSG00000141510"]
#   /api/analytes-from-pathways:
#     post:
#       summary: Retrieve analytes (genes/proteins, metabolites) by pathway.
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Enter exact pathway name(s). `analyte_type` should be `"gene"`, `"metabolite"`, or `"both"` *(default)*
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 pathway:
#                   type: array
#                   items:
#                     type: string
#                 analyte_type:
#                   type: string
#                   enum: ["gene", "metabolite", "both"]
#                   required: false
#               example:
#                 pathway: [ "De Novo Triacylglycerol Biosynthesis", "sphingolipid metabolism"]
#                 analyte_type: "both"
#   /api/ontologies-from-metabolites:
#     post:
#       summary: Return ontologies from list of metabolites
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Enter a list of metabolites. IDs should be prepended by ID source (e.g. **kegg**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 metabolite:
#                   type: array
#                   items:
#                     type: string
#                 NameOrIds:
#                   type: string
#                   enum: [ "name", "ids"]
#                   required: false
#               example:
#                 metabolite: [ "ensembl:ENSG00000135679", "hmdb:HMDB0000064", "hmdb:HMDB0000148", "ensembl:ENSG00000141510"]
#                 NameOrIds: "ids"
#   /api/metabolites-from-ontologies:
#     post:
#       summary: Return metabolites from ontology
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Enter ontology(ies) and retrieve corresponding analytes (metabolites).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 ontology:
#                   type: array
#                   items:
#                     type: string
#                 format:
#                   type: string
#                   enum: [ "json", "tsv" ]
#                   required: false
#               example:
#                 ontology: ["Colon", "Liver", "Lung"]
#                 format: "json"
#   /api/chemical-classes:
#     post:
#       summary: Return available chemical classes of given metabolites in RaMP-DB
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Retrieve chemical class information (from ClassyFire and LIPID MAPS) for input metabolite IDs. IDs should be prepended by ID source (e.g. **hmdb**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 metabolites:
#                   type: array
#                   items:
#                       type: string
#                 biospecimen:
#                   type: string
#                   enum: ["Blood", "Adipose", "Heart", "Urine", "Brain", "Liver", "Kidney", "Saliva", "Feces"]
#                   required: false
#               example:
#                 metabolites: ["hmdb:HMDB0000056", "hmdb:HMDB0000439", "hmdb:HMDB0000479", "hmdb:HMDB0000532",
#                               "hmdb:HMDB0001015", "hmdb:HMDB0001138", "hmdb:HMDB0029159", "hmdb:HMDB0029412",
#                               "hmdb:HMDB0034365", "hmdb:HMDB0035227", "hmdb:HMDB0007973", "hmdb:HMDB0008057",
#                               "hmdb:HMDB0011211"]
#   /api/chemical-properties:
#     post:
#       summary: Return chemical properties of given metabolites
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Retrieve chemical properties (smiles, inchi_key, inchi_key_prefix, inchi, mw, monoisotop_mass, formula, common_name) from input metabolites. IDs should be prepended by ID source (e.g. **hmdb**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 metabolites:
#                   type: array
#                   items:
#                     type: string
#               example:
#                 metabolites: [ "hmdb:HMDB0000056", "hmdb:HMDB0000439", "hmdb:HMDB0000479", "hmdb:HMDB0000532",
#                                "hmdb:HMDB0001015", "hmdb:HMDB0001138", "hmdb:HMDB0029159", "hmdb:HMDB0029412",
#                                "hmdb:HMDB0034365", "hmdb:HMDB0035227", "hmdb:HMDB0007973", "hmdb:HMDB0008057",
#                                "hmdb:HMDB0011211" ]
#   /api/common-reaction-analytes:
#     post:
#       summary: Return analytes involved in same reaction as given list of analytes
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Retrieve Analytes Involved in the Same Reaction. IDs should be prepended by ID source (e.g. **hmdb**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 analyte:
#                   type: array
#                   items:
#                     type: string
#                 NameOrIds:
#                   type: string
#                   enum: [ "name", "ids" ]
#                   required: false
#               example:
#                 analyte: [ "ensembl:ENSG00000135679", "hmdb:HMDB0000064", "hmdb:HMDB0000148", "ensembl:ENSG00000141510"]
#   /api/combined-fisher-test:
#     post:
#       summary: Return combined Fisher's test results from given list of analytes query results
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Perform Pathway Enrichment. IDs should be prepended by ID source (e.g. **hmdb**:C00412). Input analyte IDs can be a mix of genes/proteins or metabolites.
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 analytes:
#                   type: array
#                   items:
#                     type: string
#                 biospecimen:
#                   type: string
#                   enum: [ "Blood", "Adipose", "Heart", "Urine", "Brain", "Liver", "Kidney", "Saliva", "Feces" ]
#                   required: false
#               example: # Sample object
#                 analytes: ["hmdb:HMDB0000033", "hmdb:HMDB0000052", "hmdb:HMDB0000094", "hmdb:HMDB0000161",
#                            "hmdb:HMDB0000168", "hmdb:HMDB0000191", "hmdb:HMDB0000201", "chemspider:10026",
#                            "hmdb:HMDB0006059", "Chemspider:6405", "CAS:5657-19-2", "hmdb:HMDB0002511",
#                            "chemspider:20171375", "CAS:133-32-4", "CAS:5746-90-7", "CAS:477251-67-5", "hmdb:HMDB0000695",
#                            "chebi:15934", "CAS:838-07-3", "hmdb:HMDBP00789", "hmdb:HMDBP00283", "hmdb:HMDBP00284",
#                            "hmdb:HMDBP00850"]
#   /api/filter-fisher-test-results:
#     post:
#       summary: >-
#         Return filtered Fisher's test results from given list of Fisher's test
#         results
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Filter Pathway Enrichment. This is primarily used after running `combined-fisher-test` as the required input is the output from that call.
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 fishers_results:
#                   type: array
#                   items:
#                     type: object
#                 pval_type:
#                   type: string
#                   enum: ["fdr", "holm", "pval"]
#                   required: false
#                 pval_cutoff:
#                   type: number
#                   required: false
#               example: # Sample object
#                 fishers_results:
#                   analyte_type: ["both"]
#                   result_type: ["pathway_enrichment"]
#                   fishresults: [
#                     {
#                       "pathwayName": "beta-Alanine metabolism",
#                       "pathwayId": "map00410",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.032104,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 29,
#                       "Pval_combined": 0.032104,
#                       "Pval_combined_FDR": 0.059322,
#                       "Pval_combined_Holm": 1,
#                       "analytes": "CARN; Carnosine;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Methionine Metabolism",
#                       "pathwayId": "map00270",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000044,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 55,
#                       "Pval_combined": 0.000044,
#                       "Pval_combined_FDR": 0.000164,
#                       "Pval_combined_Holm": 0.002797,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Tyrosine metabolism",
#                       "pathwayId": "map00350",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.518364,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 69,
#                       "Pval_Gene": 0.00003,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 45,
#                       "Pval_combined": 0.000015,
#                       "Pval_combined_FDR": 0.000065,
#                       "Pval_combined_Holm": 0.001013,
#                       "analytes": "L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Arginine and proline metabolism",
#                       "pathwayId": "map00330",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.011701,
#                       "Num_In_Path_Metab": 3,
#                       "Total_In_Path_Metab": 51,
#                       "Pval_Gene": 1.132259e-7,
#                       "Num_In_Path_Gene": 3,
#                       "Total_In_Path_Gene": 62,
#                       "Pval_combined": 1.324894e-9,
#                       "Pval_combined_FDR": 2.8154e-8,
#                       "Pval_combined_Holm": 1.086413e-7,
#                       "analytes": "Argininosuccinic acid;L-Alanine;L-Aspartic acid;GOT1;GOT2;GPT"
#                     },
#                     {
#                       "pathwayName": "Phenylalanine and Tyrosine Metabolism",
#                       "pathwayId": "map00360",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Alanine, aspartate and glutamate metabolism",
#                       "pathwayId": "map00250",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.001954,
#                       "Num_In_Path_Metab": 4,
#                       "Total_In_Path_Metab": 61,
#                       "Pval_Gene": 5.11736e-11,
#                       "Num_In_Path_Gene": 4,
#                       "Total_In_Path_Gene": 55,
#                       "Pval_combined": 9.99901e-14,
#                       "Pval_combined_FDR": 4.249579e-12,
#                       "Pval_combined_Holm": 8.399168e-12,
#                       "analytes": "Argininosuccinic acid;L-Alanine;L-Asparagine;L-Aspartic acid;GOT1;GOT2;AGXT;GPT"
#                     },
#                     {
#                       "pathwayName": "Nitrogen metabolism",
#                       "pathwayId": "map00910",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.02611,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 26,
#                       "Pval_combined": 0.02611,
#                       "Pval_combined_FDR": 0.05044,
#                       "Pval_combined_Holm": 1,
#                       "analytes": "L-Asparagine;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "2-Oxocarboxylic acid metabolism",
#                       "pathwayId": "map01210",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000003147428,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 15,
#                       "Pval_combined": 0.000003147428,
#                       "Pval_combined_FDR": 0.000024,
#                       "Pval_combined_Holm": 0.000236,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Phenylalanine, tyrosine and tryptophan biosynthesis",
#                       "pathwayId": "map00400",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000005693446,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 20,
#                       "Pval_combined": 0.000005693446,
#                       "Pval_combined_FDR": 0.00004,
#                       "Pval_combined_Holm": 0.000421,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glyoxylate metabolism and glycine degradation",
#                       "pathwayId": "R-HSA-389661",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000014,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 31,
#                       "Pval_combined": 0.000014,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000947,
#                       "analytes": "GOT2;AGXT"
#                     },
#                     {
#                       "pathwayName": "Sulfur amino acid metabolism",
#                       "pathwayId": "R-HSA-1614635",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Gluconeogenesis",
#                       "pathwayId": "R-HSA-70263",
#                       "pathwaySource": "reactome",
#                       "Pval_Metab": 0.122185,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 32,
#                       "Pval_Gene": 0.000017,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 34,
#                       "Pval_combined": 0.000002052088,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000156,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glucose metabolism",
#                       "pathwayId": "R-HSA-70326",
#                       "pathwaySource": "reactome",
#                       "Pval_Metab": 0.157544,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 42,
#                       "Pval_Gene": 0.000125,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 92,
#                       "Pval_combined": 0.00002,
#                       "Pval_combined_FDR": 0.00008,
#                       "Pval_combined_Holm": 0.001278,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Aspartate and asparagine metabolism",
#                       "pathwayId": "R-HSA-8963693",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000001649093,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 11,
#                       "Pval_combined": 0.000001649093,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.00013,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Amino acid metabolism pathway excerpt: histidine catabolism extension",
#                       "pathwayId": "WP4661",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.00079,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 17,
#                       "Pval_combined": 0.00079,
#                       "Pval_combined_FDR": 0.002684,
#                       "Pval_combined_Holm": 0.04816,
#                       "analytes": "Citric acid;L-Alanine"
#                     },
#                     {
#                       "pathwayName": "Sulfur amino acid metabolism",
#                       "pathwayId": "WP3574",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glycolysis and gluconeogenesis",
#                       "pathwayId": "WP534",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.045562,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 18,
#                       "Pval_Gene": 0.000031,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 46,
#                       "Pval_combined": 0.000001410614,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000113,
#                       "analytes": "L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Amino acid metabolism",
#                       "pathwayId": "WP3925",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.000003106941,
#                       "Num_In_Path_Metab": 5,
#                       "Total_In_Path_Metab": 109,
#                       "Pval_Gene": 0.00013,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 94,
#                       "Pval_combined": 4.049386e-10,
#                       "Pval_combined_FDR": 1.147326e-8,
#                       "Pval_combined_Holm": 3.360991e-8,
#                       "analytes": "Argininosuccinic acid;Citric acid;L-Alanine;L-Asparagine;L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Biomarkers for urea cycle disorders",
#                       "pathwayId": "WP4583",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000001978779,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 12,
#                       "Pval_combined": 0.000001978779,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000152,
#                       "analytes": "GOT1;GPT"
#                     },
#                     {
#                       "pathwayName": "Urea cycle and metabolism of amino groups",
#                       "pathwayId": "WP497",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.002822,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 32,
#                       "Pval_combined": 0.002822,
#                       "Pval_combined_FDR": 0.007055,
#                       "Pval_combined_Holm": 0.15385,
#                       "analytes": "Argininosuccinic acid;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Glucose metabolism",
#                       "pathwayId": "WP4093",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.103437,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 42,
#                       "Pval_Gene": 0.000125,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 92,
#                       "Pval_combined": 0.000013,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000891,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Metabolic reprogramming in colon cancer",
#                       "pathwayId": "WP4290",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.004177,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 39,
#                       "Pval_Gene": 0.008374,
#                       "Num_In_Path_Gene": 1,
#                       "Total_In_Path_Gene": 42,
#                       "Pval_combined": 0.000035,
#                       "Pval_combined_FDR": 0.000135,
#                       "Pval_combined_Holm": 0.002238,
#                       "analytes": "Citric acid;L-Asparagine;GOT2"
#                     },
#                     {
#                       "pathwayName": "Aspartate and asparagine metabolism",
#                       "pathwayId": "WP4979",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000001649093,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 11,
#                       "Pval_combined": 0.000001649093,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.00013,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Urea cycle and associated pathways",
#                       "pathwayId": "WP4595",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 6.068128e-9,
#                       "Num_In_Path_Gene": 3,
#                       "Total_In_Path_Gene": 24,
#                       "Pval_combined": 6.068128e-9,
#                       "Pval_combined_FDR": 1.031582e-7,
#                       "Pval_combined_Holm": 4.915183e-7,
#                       "analytes": "GOT1;GOT2;GPT"
#                     },
#                     {
#                       "pathwayName": "NAD metabolism in oncogene-induced senescence and mitochondrial dysfunction-associated senescence",
#                       "pathwayId": "WP5046",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000009734892,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 26,
#                       "Pval_combined": 0.000009734892,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000711,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Metabolism overview",
#                       "pathwayId": "WP3602",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.002603,
#                       "Num_In_Path_Metab": 3,
#                       "Total_In_Path_Metab": 116,
#                       "Pval_combined": 0.002603,
#                       "Pval_combined_FDR": 0.007055,
#                       "Pval_combined_Holm": 0.145751,
#                       "analytes": "Argininosuccinic acid;Citric acid;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Glyoxylate metabolism and glycine degradation",
#                       "pathwayId": "WP3562",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000014,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 31,
#                       "Pval_combined": 0.000014,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000947,
#                       "analytes": "GOT2;AGXT"
#                     },
#                     {
#                       "pathwayName": "Alanine and aspartate metabolism",
#                       "pathwayId": "WP106",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 7.081563e-15,
#                       "Num_In_Path_Metab": 7,
#                       "Total_In_Path_Metab": 23,
#                       "Pval_Gene": 1.371261e-11,
#                       "Num_In_Path_Gene": 4,
#                       "Total_In_Path_Gene": 40,
#                       "Pval_combined": 9.710673e-26,
#                       "Pval_combined_FDR": 8.254072e-24,
#                       "Pval_combined_Holm": 8.254072e-24,
#                       "analytes": "CARN; Carnosine;Argininosuccinic acid;Citric acid;L-Alanine;L-Asparagine;L-Aspartic acid;(3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate; L-Acetylcarnitine; O-Acetylcarnitine;GOT1;GOT2;AGXT;GPT"
#                     },
#                     {
#                       "pathwayName": "mRNA, protein, and metabolite inducation pathway by cyclosporin A",
#                       "pathwayId": "WP3953",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.00053,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 14,
#                       "Pval_combined": 0.00053,
#                       "Pval_combined_FDR": 0.001879,
#                       "Pval_combined_Holm": 0.032885,
#                       "analytes": "L-Alanine;L-Asparagine"
#                     }
#                   ]
#   /api/cluster-fisher-test-results:
#     post:
#       summary: >-
#         Return clustered Fisher's test results from given list of Fisher's test
#         results
#       responses:
#         '200':
#           description: OK
#           content:
#             application/json:
#               schema:
#                 type: object
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Cluster Pathway Enrichment. This is primarily used after running `combined-fisher-test` or `filter-fisher-test` as the required input is the output from that call.
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 min_pathway_tocluster:
#                   type: number
#                   required: false
#                 perc_analyte_overlap:
#                   type: number
#                   required: false
#                 perc_pathway_overlap:
#                   type: number
#                   required: false
#                 fishers_results:
#                   type: array
#                   items:
#                     type: object
#                 pval_type:
#                   type: string
#                   enum: [ "fdr", "holm", "pval" ]
#                   required: false
#                 pval_cutoff:
#                   type: number
#                   required: false
#               example: # Sample object
#                 min_pathway_tocluster: 2
#                 perc_analyte_overlap: 0.2
#                 perc_pathway_overlap: 0.2
#                 fishers_results:
#                   analyte_type: [ "both" ]
#                   result_type: [ "pathway_enrichment" ]
#                   fishresults: [
#                     {
#                       "pathwayName": "beta-Alanine metabolism",
#                       "pathwayId": "map00410",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.032104,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 29,
#                       "Pval_combined": 0.032104,
#                       "Pval_combined_FDR": 0.059322,
#                       "Pval_combined_Holm": 1,
#                       "analytes": "CARN; Carnosine;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Methionine Metabolism",
#                       "pathwayId": "map00270",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000044,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 55,
#                       "Pval_combined": 0.000044,
#                       "Pval_combined_FDR": 0.000164,
#                       "Pval_combined_Holm": 0.002797,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Tyrosine metabolism",
#                       "pathwayId": "map00350",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.518364,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 69,
#                       "Pval_Gene": 0.00003,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 45,
#                       "Pval_combined": 0.000015,
#                       "Pval_combined_FDR": 0.000065,
#                       "Pval_combined_Holm": 0.001013,
#                       "analytes": "L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Arginine and proline metabolism",
#                       "pathwayId": "map00330",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.011701,
#                       "Num_In_Path_Metab": 3,
#                       "Total_In_Path_Metab": 51,
#                       "Pval_Gene": 1.132259e-7,
#                       "Num_In_Path_Gene": 3,
#                       "Total_In_Path_Gene": 62,
#                       "Pval_combined": 1.324894e-9,
#                       "Pval_combined_FDR": 2.8154e-8,
#                       "Pval_combined_Holm": 1.086413e-7,
#                       "analytes": "Argininosuccinic acid;L-Alanine;L-Aspartic acid;GOT1;GOT2;GPT"
#                     },
#                     {
#                       "pathwayName": "Phenylalanine and Tyrosine Metabolism",
#                       "pathwayId": "map00360",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Alanine, aspartate and glutamate metabolism",
#                       "pathwayId": "map00250",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.001954,
#                       "Num_In_Path_Metab": 4,
#                       "Total_In_Path_Metab": 61,
#                       "Pval_Gene": 5.11736e-11,
#                       "Num_In_Path_Gene": 4,
#                       "Total_In_Path_Gene": 55,
#                       "Pval_combined": 9.99901e-14,
#                       "Pval_combined_FDR": 4.249579e-12,
#                       "Pval_combined_Holm": 8.399168e-12,
#                       "analytes": "Argininosuccinic acid;L-Alanine;L-Asparagine;L-Aspartic acid;GOT1;GOT2;AGXT;GPT"
#                     },
#                     {
#                       "pathwayName": "Nitrogen metabolism",
#                       "pathwayId": "map00910",
#                       "pathwaySource": "kegg",
#                       "Pval_Metab": 0.02611,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 26,
#                       "Pval_combined": 0.02611,
#                       "Pval_combined_FDR": 0.05044,
#                       "Pval_combined_Holm": 1,
#                       "analytes": "L-Asparagine;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "2-Oxocarboxylic acid metabolism",
#                       "pathwayId": "map01210",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000003147428,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 15,
#                       "Pval_combined": 0.000003147428,
#                       "Pval_combined_FDR": 0.000024,
#                       "Pval_combined_Holm": 0.000236,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Phenylalanine, tyrosine and tryptophan biosynthesis",
#                       "pathwayId": "map00400",
#                       "pathwaySource": "kegg",
#                       "Pval_Gene": 0.000005693446,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 20,
#                       "Pval_combined": 0.000005693446,
#                       "Pval_combined_FDR": 0.00004,
#                       "Pval_combined_Holm": 0.000421,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glyoxylate metabolism and glycine degradation",
#                       "pathwayId": "R-HSA-389661",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000014,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 31,
#                       "Pval_combined": 0.000014,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000947,
#                       "analytes": "GOT2;AGXT"
#                     },
#                     {
#                       "pathwayName": "Sulfur amino acid metabolism",
#                       "pathwayId": "R-HSA-1614635",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Gluconeogenesis",
#                       "pathwayId": "R-HSA-70263",
#                       "pathwaySource": "reactome",
#                       "Pval_Metab": 0.122185,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 32,
#                       "Pval_Gene": 0.000017,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 34,
#                       "Pval_combined": 0.000002052088,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000156,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glucose metabolism",
#                       "pathwayId": "R-HSA-70326",
#                       "pathwaySource": "reactome",
#                       "Pval_Metab": 0.157544,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 42,
#                       "Pval_Gene": 0.000125,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 92,
#                       "Pval_combined": 0.00002,
#                       "Pval_combined_FDR": 0.00008,
#                       "Pval_combined_Holm": 0.001278,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Aspartate and asparagine metabolism",
#                       "pathwayId": "R-HSA-8963693",
#                       "pathwaySource": "reactome",
#                       "Pval_Gene": 0.000001649093,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 11,
#                       "Pval_combined": 0.000001649093,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.00013,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Amino acid metabolism pathway excerpt: histidine catabolism extension",
#                       "pathwayId": "WP4661",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.00079,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 17,
#                       "Pval_combined": 0.00079,
#                       "Pval_combined_FDR": 0.002684,
#                       "Pval_combined_Holm": 0.04816,
#                       "analytes": "Citric acid;L-Alanine"
#                     },
#                     {
#                       "pathwayName": "Sulfur amino acid metabolism",
#                       "pathwayId": "WP3574",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000011,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 27,
#                       "Pval_combined": 0.000011,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000757,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Glycolysis and gluconeogenesis",
#                       "pathwayId": "WP534",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.045562,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 18,
#                       "Pval_Gene": 0.000031,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 46,
#                       "Pval_combined": 0.000001410614,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000113,
#                       "analytes": "L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Amino acid metabolism",
#                       "pathwayId": "WP3925",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.000003106941,
#                       "Num_In_Path_Metab": 5,
#                       "Total_In_Path_Metab": 109,
#                       "Pval_Gene": 0.00013,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 94,
#                       "Pval_combined": 4.049386e-10,
#                       "Pval_combined_FDR": 1.147326e-8,
#                       "Pval_combined_Holm": 3.360991e-8,
#                       "analytes": "Argininosuccinic acid;Citric acid;L-Alanine;L-Asparagine;L-Aspartic acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Biomarkers for urea cycle disorders",
#                       "pathwayId": "WP4583",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000001978779,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 12,
#                       "Pval_combined": 0.000001978779,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.000152,
#                       "analytes": "GOT1;GPT"
#                     },
#                     {
#                       "pathwayName": "Urea cycle and metabolism of amino groups",
#                       "pathwayId": "WP497",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.002822,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 32,
#                       "Pval_combined": 0.002822,
#                       "Pval_combined_FDR": 0.007055,
#                       "Pval_combined_Holm": 0.15385,
#                       "analytes": "Argininosuccinic acid;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Glucose metabolism",
#                       "pathwayId": "WP4093",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.103437,
#                       "Num_In_Path_Metab": 1,
#                       "Total_In_Path_Metab": 42,
#                       "Pval_Gene": 0.000125,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 92,
#                       "Pval_combined": 0.000013,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000891,
#                       "analytes": "Citric acid;GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Metabolic reprogramming in colon cancer",
#                       "pathwayId": "WP4290",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.004177,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 39,
#                       "Pval_Gene": 0.008374,
#                       "Num_In_Path_Gene": 1,
#                       "Total_In_Path_Gene": 42,
#                       "Pval_combined": 0.000035,
#                       "Pval_combined_FDR": 0.000135,
#                       "Pval_combined_Holm": 0.002238,
#                       "analytes": "Citric acid;L-Asparagine;GOT2"
#                     },
#                     {
#                       "pathwayName": "Aspartate and asparagine metabolism",
#                       "pathwayId": "WP4979",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000001649093,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 11,
#                       "Pval_combined": 0.000001649093,
#                       "Pval_combined_FDR": 0.000017,
#                       "Pval_combined_Holm": 0.00013,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Urea cycle and associated pathways",
#                       "pathwayId": "WP4595",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 6.068128e-9,
#                       "Num_In_Path_Gene": 3,
#                       "Total_In_Path_Gene": 24,
#                       "Pval_combined": 6.068128e-9,
#                       "Pval_combined_FDR": 1.031582e-7,
#                       "Pval_combined_Holm": 4.915183e-7,
#                       "analytes": "GOT1;GOT2;GPT"
#                     },
#                     {
#                       "pathwayName": "NAD metabolism in oncogene-induced senescence and mitochondrial dysfunction-associated senescence",
#                       "pathwayId": "WP5046",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000009734892,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 26,
#                       "Pval_combined": 0.000009734892,
#                       "Pval_combined_FDR": 0.000056,
#                       "Pval_combined_Holm": 0.000711,
#                       "analytes": "GOT1;GOT2"
#                     },
#                     {
#                       "pathwayName": "Metabolism overview",
#                       "pathwayId": "WP3602",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.002603,
#                       "Num_In_Path_Metab": 3,
#                       "Total_In_Path_Metab": 116,
#                       "Pval_combined": 0.002603,
#                       "Pval_combined_FDR": 0.007055,
#                       "Pval_combined_Holm": 0.145751,
#                       "analytes": "Argininosuccinic acid;Citric acid;L-Aspartic acid"
#                     },
#                     {
#                       "pathwayName": "Glyoxylate metabolism and glycine degradation",
#                       "pathwayId": "WP3562",
#                       "pathwaySource": "wiki",
#                       "Pval_Gene": 0.000014,
#                       "Num_In_Path_Gene": 2,
#                       "Total_In_Path_Gene": 31,
#                       "Pval_combined": 0.000014,
#                       "Pval_combined_FDR": 0.000062,
#                       "Pval_combined_Holm": 0.000947,
#                       "analytes": "GOT2;AGXT"
#                     },
#                     {
#                       "pathwayName": "Alanine and aspartate metabolism",
#                       "pathwayId": "WP106",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 7.081563e-15,
#                       "Num_In_Path_Metab": 7,
#                       "Total_In_Path_Metab": 23,
#                       "Pval_Gene": 1.371261e-11,
#                       "Num_In_Path_Gene": 4,
#                       "Total_In_Path_Gene": 40,
#                       "Pval_combined": 9.710673e-26,
#                       "Pval_combined_FDR": 8.254072e-24,
#                       "Pval_combined_Holm": 8.254072e-24,
#                       "analytes": "CARN; Carnosine;Argininosuccinic acid;Citric acid;L-Alanine;L-Asparagine;L-Aspartic acid;(3R)-3-acetyloxy-4-(trimethylazaniumyl)butanoate; L-Acetylcarnitine; O-Acetylcarnitine;GOT1;GOT2;AGXT;GPT"
#                     },
#                     {
#                       "pathwayName": "mRNA, protein, and metabolite inducation pathway by cyclosporin A",
#                       "pathwayId": "WP3953",
#                       "pathwaySource": "wiki",
#                       "Pval_Metab": 0.00053,
#                       "Num_In_Path_Metab": 2,
#                       "Total_In_Path_Metab": 14,
#                       "Pval_combined": 0.00053,
#                       "Pval_combined_FDR": 0.001879,
#                       "Pval_combined_Holm": 0.032885,
#                       "analytes": "L-Alanine;L-Asparagine"
#                     }
#                   ]
#   /api/chemical-enrichment:
#     post:
#       summary: Perform chemical enrichment on given metabolites
#       responses:
#         '200':
#           description: OK
#         '500':
#           description: Internal Server Error
#       requestBody:
#         description: Perform chemical class enrichment on ClassyFire and LIPIDMAPS classes. IDs should be prepended by ID source (e.g. **hmdb**:C00412).
#         required: true
#         content:
#           application/json:
#             schema:
#               type: object
#               properties:
#                 metabolites:
#                   type: array
#                   items:
#                     type: string
#                 biospecimen:
#                   type: string
#                   enum: [ "Blood", "Adipose", "Heart", "Urine", "Brain", "Liver", "Kidney", "Saliva", "Feces" ]
#                   required: false
#               example:
#                 metabolites: [ "hmdb:HMDB0000056", "hmdb:HMDB0000439", "hmdb:HMDB0000479", "hmdb:HMDB0000532",
#                                "hmdb:HMDB0001015", "hmdb:HMDB0001138", "hmdb:HMDB0029159", "hmdb:HMDB0029412",
#                                "hmdb:HMDB0034365", "hmdb:HMDB0035227", "hmdb:HMDB0007973", "hmdb:HMDB0008057",
#                                "hmdb:HMDB0011211" ]

# %% [markdown]
# **Starting with the two main `schema.json` files from our two suggested validation sources from swagger:**
# - Load Files

# %%
schemajson_vb_31= "/Users/nacosta/Documents/smartAPI/openapi-schema-validator-badge-31.json"

# %%
# Load the schema from a JSON file
with open(schemajson_vb_31, 'r') as schema_file:
    schema_vb = json.load(schema_file)

# %%
validate_doc(trapi_doc, schema_vb)
# Out:
# An unexpected error occurred: 'dict' object has no attribute 'raw'

# %%
try:
    validate(trapi_doc, schema_vb)
    print("Validation successful!")
except yaml.YAMLError as ye:
    print(f"YAML parsing error: {str(ye)}")
except jsonschema.exceptions.ValidationError as ve:
    print(f"Validation error at {ve.path}: {ve.message}")
except jsonschema.exceptions.SchemaError as se:
    print(f"Schema error: {se.message}")
except Exception as e:
    print(f"An unexpected error occurred: {str(e)}")
# Out:
# Validation successful!

# %%
# print(test_data_doc)
validate_doc(test_doc, schema_vb)
# Out:
# Validation error at deque([]): Unevaluated properties are not allowed ('openapi' was unexpected)

# %%
for smartapi in SmartAPI.get_all(1):
    # print("Raw data preview:", smartapi.raw[:100])  # Preview of the raw byte data

    try:
        # Decode the raw data from bytes to a string
        data_doc = smartapi.raw.decode('utf-8')
        # print("Decoded data preview:", data_doc[:500])
        # Load the YAML formatted string into a Python dictionary
        data_dict = yaml.safe_load(data_doc)
        # Now validate the dictionary against the schema
        validate(instance=data_dict, schema=schema_vb)
        print("Validation successful!")# Preview of the decoded data
    except yaml.YAMLError as ye:
        print("YAML parsing error:", ye)
    except jsonschema.exceptions.ValidationError as ve:
        print("Validation error:", ve)
    except jsonschema.exceptions.SchemaError as se:
        print("Schema error:", se)
    except Exception as e:
        print("An unexpected error occurred:", e)
# Out:
# Validation error: Unevaluated properties are not allowed ('openapi' was unexpected)
#
# Failed validating 'unevaluatedProperties' in schema:
#     {'$defs': {'callbacks': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#callback-object',
#                              '$ref': '#/$defs/specification-extensions',
#                              'additionalProperties': {'$ref': '#/$defs/path-item-or-reference'},
#                              'type': 'object'},
#                'callbacks-or-reference': {'else': {'$ref': '#/$defs/callbacks'},
#                                           'if': {'required': ['$ref'],
#                                                  'type': 'object'},
#                                           'then': {'$ref': '#/$defs/reference'}},
#                'components': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#components-object',
#                               '$ref': '#/$defs/specification-extensions',
#                               'patternProperties': {'^(schemas|responses|parameters|examples|requestBodies|headers|securitySchemes|links|callbacks|pathItems)$': {'$comment': 'Enumerating '
#                                                                                                                                                                               'all '
#                                                                                                                                                                               'of '
#                                                                                                                                                                               'the '
#                                                                                                                                                                               'property '
#                                                                                                                                                                               'names '
#                                                                                                                                                                               'in '
#                                                                                                                                                                               'the '
#                                                                                                                                                                               'regex '
#                                                                                                                                                                               'above '
#                                                                                                                                                                               'is '
#                                                                                                                                                                               'necessary '
#                                                                                                                                                                               'for '
#                                                                                                                                                                               'unevaluatedProperties '
#                                                                                                                                                                               'to '
#                                                                                                                                                                               'work '
#                                                                                                                                                                               'as '
#                                                                                                                                                                               'expected',
#                                                                                                                                                                   'propertyNames': {'pattern': '^[a-zA-Z0-9._-]+$'}}},
#                               'properties': {'callbacks': {'additionalProperties': {'$ref': '#/$defs/callbacks-or-reference'},
#                                                            'type': 'object'},
#                                              'examples': {'additionalProperties': {'$ref': '#/$defs/example-or-reference'},
#                                                           'type': 'object'},
#                                              'headers': {'additionalProperties': {'$ref': '#/$defs/header-or-reference'},
#                                                          'type': 'object'},
#                                              'links': {'additionalProperties': {'$ref': '#/$defs/link-or-reference'},
#                                                        'type': 'object'},
#                                              'parameters': {'additionalProperties': {'$ref': '#/$defs/parameter-or-reference'},
#                                                             'type': 'object'},
#                                              'pathItems': {'additionalProperties': {'$ref': '#/$defs/path-item-or-reference'},
#                                                            'type': 'object'},
#                                              'requestBodies': {'additionalProperties': {'$ref': '#/$defs/request-body-or-reference'},
#                                                                'type': 'object'},
#                                              'responses': {'additionalProperties': {'$ref': '#/$defs/response-or-reference'},
#                                                            'type': 'object'},
#                                              'schemas': {'additionalProperties': {'$dynamicRef': '#meta'},
#                                                          'type': 'object'},
#                                              'securitySchemes': {'additionalProperties': {'$ref': '#/$defs/security-scheme-or-reference'},
#                                                                  'type': 'object'}},
#                               'type': 'object',
#                               'unevaluatedProperties': False},
#                'contact': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#contact-object',
#                            '$ref': '#/$defs/specification-extensions',
#                            'properties': {'email': {'format': 'email',
#                                                     'type': 'string'},
#                                           'name': {'type': 'string'},
#                                           'url': {'format': 'uri',
#                                                   'type': 'string'}},
#                            'type': 'object',
#                            'unevaluatedProperties': False},
#                'content': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#fixed-fields-10',
#                            'additionalProperties': {'$ref': '#/$defs/media-type'},
#                            'propertyNames': {'format': 'media-range'},
#                            'type': 'object'},
#                'encoding': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#encoding-object',
#                             '$defs': {'explode-default': {'else': {'properties': {'explode': {'default': False}}},
#                                                           'if': {'properties': {'style': {'const': 'form'}},
#                                                                  'required': ['style']},
#                                                           'then': {'properties': {'explode': {'default': True}}}}},
#                             'allOf': [{'$ref': '#/$defs/specification-extensions'},
#                                       {'$ref': '#/$defs/encoding/$defs/explode-default'}],
#                             'properties': {'allowReserved': {'default': False,
#                                                              'type': 'boolean'},
#                                            'contentType': {'format': 'media-range',
#                                                            'type': 'string'},
#                                            'explode': {'type': 'boolean'},
#                                            'headers': {'additionalProperties': {'$ref': '#/$defs/header-or-reference'},
#                                                        'type': 'object'},
#                                            'style': {'default': 'form',
#                                                      'enum': ['form',
#                                                               'spaceDelimited',
#                                                               'pipeDelimited',
#                                                               'deepObject']}},
#                             'type': 'object',
#                             'unevaluatedProperties': False},
#                'example': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#example-object',
#                            '$ref': '#/$defs/specification-extensions',
#                            'not': {'required': ['value', 'externalValue']},
#                            'properties': {'description': {'type': 'string'},
#                                           'externalValue': {'format': 'uri',
#                                                             'type': 'string'},
#                                           'summary': {'type': 'string'},
#                                           'value': True},
#                            'type': 'object',
#                            'unevaluatedProperties': False},
#                'example-or-reference': {'else': {'$ref': '#/$defs/example'},
#                                         'if': {'required': ['$ref'],
#                                                'type': 'object'},
#                                         'then': {'$ref': '#/$defs/reference'}},
#                'examples': {'properties': {'example': True,
#                                            'examples': {'additionalProperties': {'$ref': '#/$defs/example-or-reference'},
#                                                         'type': 'object'}}},
#                'external-documentation': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#external-documentation-object',
#                                           '$ref': '#/$defs/specification-extensions',
#                                           'properties': {'description': {'type': 'string'},
#                                                          'url': {'format': 'uri',
#                                                                  'type': 'string'}},
#                                           'required': ['url'],
#                                           'type': 'object',
#                                           'unevaluatedProperties': False},
#                'header': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#header-object',
#                           '$ref': '#/$defs/specification-extensions',
#                           'dependentSchemas': {'schema': {'$ref': '#/$defs/examples',
#                                                           'properties': {'explode': {'default': False,
#                                                                                      'type': 'boolean'},
#                                                                          'style': {'const': 'simple',
#                                                                                    'default': 'simple'}}}},
#                           'oneOf': [{'required': ['schema']},
#                                     {'required': ['content']}],
#                           'properties': {'content': {'$ref': '#/$defs/content',
#                                                      'maxProperties': 1,
#                                                      'minProperties': 1},
#                                          'deprecated': {'default': False,
#                                                         'type': 'boolean'},
#                                          'description': {'type': 'string'},
#                                          'required': {'default': False,
#                                                       'type': 'boolean'},
#                                          'schema': {'$dynamicRef': '#meta'}},
#                           'type': 'object',
#                           'unevaluatedProperties': False},
#                'header-or-reference': {'else': {'$ref': '#/$defs/header'},
#                                        'if': {'required': ['$ref'],
#                                               'type': 'object'},
#                                        'then': {'$ref': '#/$defs/reference'}},
#                'info': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#info-object',
#                         '$ref': '#/$defs/specification-extensions',
#                         'properties': {'contact': {'$ref': '#/$defs/contact'},
#                                        'description': {'type': 'string'},
#                                        'license': {'$ref': '#/$defs/license'},
#                                        'summary': {'type': 'string'},
#                                        'termsOfService': {'format': 'uri',
#                                                           'type': 'string'},
#                                        'title': {'type': 'string'},
#                                        'version': {'type': 'string'}},
#                         'required': ['title', 'version'],
#                         'type': 'object',
#                         'unevaluatedProperties': False},
#                'license': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#license-object',
#                            '$ref': '#/$defs/specification-extensions',
#                            'dependentSchemas': {'identifier': {'not': {'required': ['url']}}},
#                            'properties': {'identifier': {'type': 'string'},
#                                           'name': {'type': 'string'},
#                                           'url': {'format': 'uri',
#                                                   'type': 'string'}},
#                            'required': ['name'],
#                            'type': 'object',
#                            'unevaluatedProperties': False},
#                'link': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#link-object',
#                         '$ref': '#/$defs/specification-extensions',
#                         'oneOf': [{'required': ['operationRef']},
#                                   {'required': ['operationId']}],
#                         'properties': {'body': {'$ref': '#/$defs/server'},
#                                        'description': {'type': 'string'},
#                                        'operationId': {'type': 'string'},
#                                        'operationRef': {'format': 'uri-reference',
#                                                         'type': 'string'},
#                                        'parameters': {'$ref': '#/$defs/map-of-strings'},
#                                        'requestBody': True},
#                         'type': 'object',
#                         'unevaluatedProperties': False},
#                'link-or-reference': {'else': {'$ref': '#/$defs/link'},
#                                      'if': {'required': ['$ref'],
#                                             'type': 'object'},
#                                      'then': {'$ref': '#/$defs/reference'}},
#                'map-of-strings': {'additionalProperties': {'type': 'string'},
#                                   'type': 'object'},
#                'media-type': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#media-type-object',
#                               'allOf': [{'$ref': '#/$defs/specification-extensions'},
#                                         {'$ref': '#/$defs/examples'}],
#                               'properties': {'encoding': {'additionalProperties': {'$ref': '#/$defs/encoding'},
#                                                           'type': 'object'},
#                                              'schema': {'$dynamicRef': '#meta'}},
#                               'type': 'object',
#                               'unevaluatedProperties': False},
#                'oauth-flows': {'$defs': {'authorization-code': {'$ref': '#/$defs/specification-extensions',
#                                                                 'properties': {'authorizationUrl': {'format': 'uri',
#                                                                                                     'type': 'string'},
#                                                                                'refreshUrl': {'format': 'uri',
#                                                                                               'type': 'string'},
#                                                                                'scopes': {'$ref': '#/$defs/map-of-strings'},
#                                                                                'tokenUrl': {'format': 'uri',
#                                                                                             'type': 'string'}},
#                                                                 'required': ['authorizationUrl',
#                                                                              'tokenUrl',
#                                                                              'scopes'],
#                                                                 'type': 'object',
#                                                                 'unevaluatedProperties': False},
#                                          'client-credentials': {'$ref': '#/$defs/specification-extensions',
#                                                                 'properties': {'refreshUrl': {'format': 'uri',
#                                                                                               'type': 'string'},
#                                                                                'scopes': {'$ref': '#/$defs/map-of-strings'},
#                                                                                'tokenUrl': {'format': 'uri',
#                                                                                             'type': 'string'}},
#                                                                 'required': ['tokenUrl',
#                                                                              'scopes'],
#                                                                 'type': 'object',
#                                                                 'unevaluatedProperties': False},
#                                          'implicit': {'$ref': '#/$defs/specification-extensions',
#                                                       'properties': {'authorizationUrl': {'format': 'uri',
#                                                                                           'type': 'string'},
#                                                                      'refreshUrl': {'format': 'uri',
#                                                                                     'type': 'string'},
#                                                                      'scopes': {'$ref': '#/$defs/map-of-strings'}},
#                                                       'required': ['authorizationUrl',
#                                                                    'scopes'],
#                                                       'type': 'object',
#                                                       'unevaluatedProperties': False},
#                                          'password': {'$ref': '#/$defs/specification-extensions',
#                                                       'properties': {'refreshUrl': {'format': 'uri',
#                                                                                     'type': 'string'},
#                                                                      'scopes': {'$ref': '#/$defs/map-of-strings'},
#                                                                      'tokenUrl': {'format': 'uri',
#                                                                                   'type': 'string'}},
#                                                       'required': ['tokenUrl',
#                                                                    'scopes'],
#                                                       'type': 'object',
#                                                       'unevaluatedProperties': False}},
#                                '$ref': '#/$defs/specification-extensions',
#                                'properties': {'authorizationCode': {'$ref': '#/$defs/oauth-flows/$defs/authorization-code'},
#                                               'clientCredentials': {'$ref': '#/$defs/oauth-flows/$defs/client-credentials'},
#                                               'implicit': {'$ref': '#/$defs/oauth-flows/$defs/implicit'},
#                                               'password': {'$ref': '#/$defs/oauth-flows/$defs/password'}},
#                                'type': 'object',
#                                'unevaluatedProperties': False},
#                'operation': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#operation-object',
#                              '$ref': '#/$defs/specification-extensions',
#                              'properties': {'callbacks': {'additionalProperties': {'$ref': '#/$defs/callbacks-or-reference'},
#                                                           'type': 'object'},
#                                             'deprecated': {'default': False,
#                                                            'type': 'boolean'},
#                                             'description': {'type': 'string'},
#                                             'externalDocs': {'$ref': '#/$defs/external-documentation'},
#                                             'operationId': {'type': 'string'},
#                                             'parameters': {'items': {'$ref': '#/$defs/parameter-or-reference'},
#                                                            'type': 'array'},
#                                             'requestBody': {'$ref': '#/$defs/request-body-or-reference'},
#                                             'responses': {'$ref': '#/$defs/responses'},
#                                             'security': {'items': {'$ref': '#/$defs/security-requirement'},
#                                                          'type': 'array'},
#                                             'servers': {'items': {'$ref': '#/$defs/server'},
#                                                         'type': 'array'},
#                                             'summary': {'type': 'string'},
#                                             'tags': {'items': {'type': 'string'},
#                                                      'type': 'array'}},
#                              'type': 'object',
#                              'unevaluatedProperties': False},
#                'parameter': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#parameter-object',
#                              '$ref': '#/$defs/specification-extensions',
#                              'dependentSchemas': {'schema': {'$defs': {'styles-for-cookie': {'if': {'properties': {'in': {'const': 'cookie'}},
#                                                                                                     'required': ['in']},
#                                                                                              'then': {'properties': {'style': {'const': 'form',
#                                                                                                                                'default': 'form'}}}},
#                                                                        'styles-for-form': {'else': {'properties': {'explode': {'default': False}}},
#                                                                                            'if': {'properties': {'style': {'const': 'form'}},
#                                                                                                   'required': ['style']},
#                                                                                            'then': {'properties': {'explode': {'default': True}}}},
#                                                                        'styles-for-header': {'if': {'properties': {'in': {'const': 'header'}},
#                                                                                                     'required': ['in']},
#                                                                                              'then': {'properties': {'style': {'const': 'simple',
#                                                                                                                                'default': 'simple'}}}},
#                                                                        'styles-for-path': {'if': {'properties': {'in': {'const': 'path'}},
#                                                                                                   'required': ['in']},
#                                                                                            'then': {'properties': {'name': {'pattern': '[^/#?]+$'},
#                                                                                                                    'required': {'const': True},
#                                                                                                                    'style': {'default': 'simple',
#                                                                                                                              'enum': ['matrix',
#                                                                                                                                       'label',
#                                                                                                                                       'simple']}},
#                                                                                                     'required': ['required']}},
#                                                                        'styles-for-query': {'if': {'properties': {'in': {'const': 'query'}},
#                                                                                                    'required': ['in']},
#                                                                                             'then': {'properties': {'allowReserved': {'default': False,
#                                                                                                                                       'type': 'boolean'},
#                                                                                                                     'style': {'default': 'form',
#                                                                                                                               'enum': ['form',
#                                                                                                                                        'spaceDelimited',
#                                                                                                                                        'pipeDelimited',
#                                                                                                                                        'deepObject']}}}}},
#                                                              'allOf': [{'$ref': '#/$defs/examples'},
#                                                                        {'$ref': '#/$defs/parameter/dependentSchemas/schema/$defs/styles-for-path'},
#                                                                        {'$ref': '#/$defs/parameter/dependentSchemas/schema/$defs/styles-for-header'},
#                                                                        {'$ref': '#/$defs/parameter/dependentSchemas/schema/$defs/styles-for-query'},
#                                                                        {'$ref': '#/$defs/parameter/dependentSchemas/schema/$defs/styles-for-cookie'},
#                                                                        {'$ref': '#/$defs/parameter/dependentSchemas/schema/$defs/styles-for-form'}],
#                                                              'properties': {'explode': {'type': 'boolean'},
#                                                                             'style': {'type': 'string'}}}},
#                              'if': {'properties': {'in': {'const': 'query'}},
#                                     'required': ['in']},
#                              'oneOf': [{'required': ['schema']},
#                                        {'required': ['content']}],
#                              'properties': {'content': {'$ref': '#/$defs/content',
#                                                         'maxProperties': 1,
#                                                         'minProperties': 1},
#                                             'deprecated': {'default': False,
#                                                            'type': 'boolean'},
#                                             'description': {'type': 'string'},
#                                             'in': {'enum': ['query',
#                                                             'header',
#                                                             'path',
#                                                             'cookie']},
#                                             'name': {'type': 'string'},
#                                             'required': {'default': False,
#                                                          'type': 'boolean'},
#                                             'schema': {'$dynamicRef': '#meta'}},
#                              'required': ['name', 'in'],
#                              'then': {'properties': {'allowEmptyValue': {'default': False,
#                                                                          'type': 'boolean'}}},
#                              'type': 'object',
#                              'unevaluatedProperties': False},
#                'parameter-or-reference': {'else': {'$ref': '#/$defs/parameter'},
#                                           'if': {'required': ['$ref'],
#                                                  'type': 'object'},
#                                           'then': {'$ref': '#/$defs/reference'}},
#                'path-item': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#path-item-object',
#                              '$ref': '#/$defs/specification-extensions',
#                              'properties': {'delete': {'$ref': '#/$defs/operation'},
#                                             'description': {'type': 'string'},
#                                             'get': {'$ref': '#/$defs/operation'},
#                                             'head': {'$ref': '#/$defs/operation'},
#                                             'options': {'$ref': '#/$defs/operation'},
#                                             'parameters': {'items': {'$ref': '#/$defs/parameter-or-reference'},
#                                                            'type': 'array'},
#                                             'patch': {'$ref': '#/$defs/operation'},
#                                             'post': {'$ref': '#/$defs/operation'},
#                                             'put': {'$ref': '#/$defs/operation'},
#                                             'servers': {'items': {'$ref': '#/$defs/server'},
#                                                         'type': 'array'},
#                                             'summary': {'type': 'string'},
#                                             'trace': {'$ref': '#/$defs/operation'}},
#                              'type': 'object',
#                              'unevaluatedProperties': False},
#                'path-item-or-reference': {'else': {'$ref': '#/$defs/path-item'},
#                                           'if': {'required': ['$ref'],
#                                                  'type': 'object'},
#                                           'then': {'$ref': '#/$defs/reference'}},
#                'paths': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#paths-object',
#                          '$ref': '#/$defs/specification-extensions',
#                          'patternProperties': {'^/': {'$ref': '#/$defs/path-item'}},
#                          'type': 'object',
#                          'unevaluatedProperties': False},
#                'reference': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#reference-object',
#                              'properties': {'$ref': {'format': 'uri-reference',
#                                                      'type': 'string'},
#                                             'description': {'type': 'string'},
#                                             'summary': {'type': 'string'}},
#                              'type': 'object',
#                              'unevaluatedProperties': False},
#                'request-body': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#request-body-object',
#                                 '$ref': '#/$defs/specification-extensions',
#                                 'properties': {'content': {'$ref': '#/$defs/content'},
#                                                'description': {'type': 'string'},
#                                                'required': {'default': False,
#                                                             'type': 'boolean'}},
#                                 'required': ['content'],
#                                 'type': 'object',
#                                 'unevaluatedProperties': False},
#                'request-body-or-reference': {'else': {'$ref': '#/$defs/request-body'},
#                                              'if': {'required': ['$ref'],
#                                                     'type': 'object'},
#                                              'then': {'$ref': '#/$defs/reference'}},
#                'response': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#response-object',
#                             '$ref': '#/$defs/specification-extensions',
#                             'properties': {'content': {'$ref': '#/$defs/content'},
#                                            'description': {'type': 'string'},
#                                            'headers': {'additionalProperties': {'$ref': '#/$defs/header-or-reference'},
#                                                        'type': 'object'},
#                                            'links': {'additionalProperties': {'$ref': '#/$defs/link-or-reference'},
#                                                      'type': 'object'}},
#                             'required': ['description'],
#                             'type': 'object',
#                             'unevaluatedProperties': False},
#                'response-or-reference': {'else': {'$ref': '#/$defs/response'},
#                                          'if': {'required': ['$ref'],
#                                                 'type': 'object'},
#                                          'then': {'$ref': '#/$defs/reference'}},
#                'responses': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#responses-object',
#                              '$ref': '#/$defs/specification-extensions',
#                              'minProperties': 1,
#                              'patternProperties': {'^[1-5](?:[0-9]{2}|XX)$': {'$ref': '#/$defs/response-or-reference'}},
#                              'properties': {'default': {'$ref': '#/$defs/response-or-reference'}},
#                              'type': 'object',
#                              'unevaluatedProperties': False},
#                'schema': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#schema-object',
#                           '$dynamicAnchor': 'meta',
#                           'type': ['object', 'boolean']},
#                'security-requirement': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#security-requirement-object',
#                                         'additionalProperties': {'items': {'type': 'string'},
#                                                                  'type': 'array'},
#                                         'type': 'object'},
#                'security-scheme': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#security-scheme-object',
#                                    '$defs': {'type-apikey': {'if': {'properties': {'type': {'const': 'apiKey'}},
#                                                                     'required': ['type']},
#                                                              'then': {'properties': {'in': {'enum': ['query',
#                                                                                                      'header',
#                                                                                                      'cookie']},
#                                                                                      'name': {'type': 'string'}},
#                                                                       'required': ['name',
#                                                                                    'in']}},
#                                              'type-http': {'if': {'properties': {'type': {'const': 'http'}},
#                                                                   'required': ['type']},
#                                                            'then': {'properties': {'scheme': {'type': 'string'}},
#                                                                     'required': ['scheme']}},
#                                              'type-http-bearer': {'if': {'properties': {'scheme': {'pattern': '^[Bb][Ee][Aa][Rr][Ee][Rr]$',
#                                                                                                    'type': 'string'},
#                                                                                         'type': {'const': 'http'}},
#                                                                          'required': ['type',
#                                                                                       'scheme']},
#                                                                   'then': {'properties': {'bearerFormat': {'type': 'string'}}}},
#                                              'type-oauth2': {'if': {'properties': {'type': {'const': 'oauth2'}},
#                                                                     'required': ['type']},
#                                                              'then': {'properties': {'flows': {'$ref': '#/$defs/oauth-flows'}},
#                                                                       'required': ['flows']}},
#                                              'type-oidc': {'if': {'properties': {'type': {'const': 'openIdConnect'}},
#                                                                   'required': ['type']},
#                                                            'then': {'properties': {'openIdConnectUrl': {'format': 'uri',
#                                                                                                         'type': 'string'}},
#                                                                     'required': ['openIdConnectUrl']}}},
#                                    'allOf': [{'$ref': '#/$defs/specification-extensions'},
#                                              {'$ref': '#/$defs/security-scheme/$defs/type-apikey'},
#                                              {'$ref': '#/$defs/security-scheme/$defs/type-http'},
#                                              {'$ref': '#/$defs/security-scheme/$defs/type-http-bearer'},
#                                              {'$ref': '#/$defs/security-scheme/$defs/type-oauth2'},
#                                              {'$ref': '#/$defs/security-scheme/$defs/type-oidc'}],
#                                    'properties': {'description': {'type': 'string'},
#                                                   'type': {'enum': ['apiKey',
#                                                                     'http',
#                                                                     'mutualTLS',
#                                                                     'oauth2',
#                                                                     'openIdConnect']}},
#                                    'required': ['type'],
#                                    'type': 'object',
#                                    'unevaluatedProperties': False},
#                'security-scheme-or-reference': {'else': {'$ref': '#/$defs/security-scheme'},
#                                                 'if': {'required': ['$ref'],
#                                                        'type': 'object'},
#                                                 'then': {'$ref': '#/$defs/reference'}},
#                'server': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#server-object',
#                           '$ref': '#/$defs/specification-extensions',
#                           'properties': {'description': {'type': 'string'},
#                                          'url': {'format': 'uri-reference',
#                                                  'type': 'string'},
#                                          'variables': {'additionalProperties': {'$ref': '#/$defs/server-variable'},
#                                                        'type': 'object'}},
#                           'required': ['url'],
#                           'type': 'object',
#                           'unevaluatedProperties': False},
#                'server-variable': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#server-variable-object',
#                                    '$ref': '#/$defs/specification-extensions',
#                                    'properties': {'default': {'type': 'string'},
#                                                   'description': {'type': 'string'},
#                                                   'enum': {'items': {'type': 'string'},
#                                                            'minItems': 1,
#                                                            'type': 'array'}},
#                                    'required': ['default'],
#                                    'type': 'object',
#                                    'unevaluatedProperties': False},
#                'specification-extensions': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#specification-extensions',
#                                             'patternProperties': {'^x-': True}},
#                'tag': {'$comment': 'https://spec.openapis.org/oas/v3.1.0#tag-object',
#                        '$ref': '#/$defs/specification-extensions',
#                        'properties': {'description': {'type': 'string'},
#                                       'externalDocs': {'$ref': '#/$defs/external-documentation'},
#                                       'name': {'type': 'string'}},
#                        'required': ['name'],
#                        'type': 'object',
#                        'unevaluatedProperties': False}},
#      '$id': 'https://spec.openapis.org/oas/3.1/schema/2022-10-07',
#      '$ref': '#/$defs/specification-extensions',
#      '$schema': 'https://json-schema.org/draft/2020-12/schema',
#      'anyOf': [{'required': ['paths']},
#                {'required': ['components']},
#                {'required': ['webhooks']}],
#      'description': 'The description of OpenAPI v3.1.x documents without '
#                     'schema validation, as defined by '
#                     'https://spec.openapis.org/oas/v3.1.0',
#      'properties': {'components': {'$ref': '#/$defs/components'},
#                     'externalDocs': {'$ref': '#/$defs/external-documentation'},
#                     'info': {'$ref': '#/$defs/info'},
#                     'jsonSchemaDialect': {'default': 'https://spec.openapis.org/oas/3.1/dialect/base',
#                                           'format': 'uri',
#                                           'type': 'string'},
#                     'openapi': {'pattern': '^3\\.1\\.\\d+(-.+)?$',
#                                 'type': 'string'},
#                     'paths': {'$ref': '#/$defs/paths'},
#                     'security': {'items': {'$ref': '#/$defs/security-requirement'},
#                                  'type': 'array'},
#                     'servers': {'default': [{'url': '/'}],
#                                 'items': {'$ref': '#/$defs/server'},
#                                 'type': 'array'},
#                     'tags': {'items': {'$ref': '#/$defs/tag'},
#                              'type': 'array'},
#                     'webhooks': {'additionalProperties': {'$ref': '#/$defs/path-item-or-reference'},
#                                  'type': 'object'}},
#      'required': ['openapi', 'info'],
#      'type': 'object',
#      'unevaluatedProperties': False}
#
# On instance:
#     {'info': {'contact': {'email': 'timothy.sheils@nih.gov',
#                           'name': 'Timothy Sheils',
#                           'x-id': 'https://github.com/tsheils',
#                           'x-role': 'responsible developer'},
#               'description': 'Relational Database of Metabolic Pathways '
#                              '(RaMP) API',
#               'termsOfService': 'https://rampdb.nih.gov',
#               'title': 'RaMP API v1.0.1',
#               'version': '1.0.1'},
#      'openapi': '3.0.3',
#      'paths': {'/api/analyte_intersects': {'get': {'parameters': [{'description': 'specifies '
#                                                                                   'type '
#                                                                                   'of '
#                                                                                   'analyte '
#                                                                                   'intersects '
#                                                                                   'to '
#                                                                                   'return, '
#                                                                                   "'metabolites' "
#                                                                                   'or '
#                                                                                   "'genes'",
#                                                                    'in': 'query',
#                                                                    'name': 'analytetype',
#                                                                    'required': True,
#                                                                    'schema': {'type': 'string'}},
#                                                                   {'description': 'specifies '
#                                                                                   "'global' "
#                                                                                   'or '
#                                                                                   "'mapped-to-pathway'",
#                                                                    'in': 'query',
#                                                                    'name': 'query_scope',
#                                                                    'required': True,
#                                                                    'schema': {'type': 'string'}}],
# ...
#                                                                        'results '
#                                                                        'from '
#                                                                        'given '
#                                                                        'list '
#                                                                        'of '
#                                                                        "Fisher's "
#                                                                        'test '
#                                                                        'results'}},
#                '/api/id-types': {'get': {'parameters': [],
#                                          'responses': {'200': {'content': {'application/json': {'schema': {'type': 'object'}}},
#                                                                'description': 'OK'},
#                                                        '500': {'content': {'application/json': {'schema': {'type': 'string'}}},
#                                                                'description': 'Internal '
#                                                                               'Server '
#                                                                               'Error'},
#                                                        'default': {'content': {'application/json': {'schema': {'type': 'object'}}},
#                                                                    'description': 'Default '
#                                                                                   'response.'}},
#                                          'summary': 'Return analyte ID '
#                                                     'types'}},
#                '/api/metabolites-from-ontologies': {'post': {'requestBody': {'content': {'application/json': {'schema': {'example': {'format': 'json',
#                                                                                                                                      'ontology': ['Colon',
#                                                                                                                                                   'Liver',
#                                                                                                                                                   'Lung']},
#                                                                                                                          'properties': {'format': {'enum': ['json',
#                                                                                                                                                             'tsv'],
#                                                                                                                                                    'required': False,
#                                                                                                                                                    'type': 'string'},
#                                                                                                                                         'ontology': {'items': {'type': 'string'},
#                                                                                                                                                      'type': 'array'}},
#                                                                                                                          'type': 'object'}}},
#                                                                              'description': 'Enter '
#                                                                                             'ontology(ies) '
#                                                                                             'and '
#                                                                                             'retrieve '
#                                                                                             'corresponding '
#                                                                                             'analytes '
#                                                                                             '(metabolites).',
#                                                                              'required': True},
#                                                              'responses': {'200': {'description': 'OK'},
#                                                                            '500': {'description': 'Internal '
#                                                                                                   'Server '
#                                                                                                   'Error'}},
#                                                              'summary': 'Return '
#                                                                         'metabolites '
#                                                                         'from '
#                                                                         'ontology'}},
#                '/api/ontologies-from-metabolites': {'post': {'requestBody': {'content': {'application/json': {'schema': {'example': {'NameOrIds': 'ids',
#                                                                                                                                      'metabolite': ['ensembl:ENSG00000135679',
#                                                                                                                                                     'hmdb:HMDB0000064',
#                                                                                                                                                     'hmdb:HMDB0000148',
#                                                                                                                                                     'ensembl:ENSG00000141510']},
#                                                                                                                          'properties': {'NameOrIds': {'enum': ['name',
#                                                                                                                                                                'ids'],
#                                                                                                                                                       'required': False,
#                                                                                                                                                       'type': 'string'},
#                                                                                                                                         'metabolite': {'items': {'type': 'string'},
#                                                                                                                                                        'type': 'array'}},
#                                                                                                                          'type': 'object'}}},
#                                                                              'description': 'Enter '
#                                                                                             'a '
#                                                                                             'list '
#                                                                                             'of '
#                                                                                             'metabolites. '
#                                                                                             'IDs '
#                                                                                             'should '
#                                                                                             'be '
#                                                                                             'prepended '
#                                                                                             'by '
#                                                                                             'ID '
#                                                                                             'source '
#                                                                                             '(e.g. '
#                                                                                             '**kegg**:C00412).',
#                                                                              'required': True},
#                                                              'responses': {'200': {'description': 'OK'},
#                                                                            '500': {'description': 'Internal '
#                                                                                                   'Server '
#                                                                                                   'Error'}},
#                                                              'summary': 'Return '
#                                                                         'ontologies '
#                                                                         'from '
#                                                                         'list '
#                                                                         'of '
#                                                                         'metabolites'}},
#                '/api/ontology-types': {'get': {'parameters': [],
#                                                'responses': {'200': {'content': {'application/json': {'schema': {'type': 'object'}}},
#                                                                      'description': 'OK'},
#                                                              '500': {'content': {'application/json': {'schema': {'type': 'string'}}},
#                                                                      'description': 'Internal '
#                                                                                     'Server '
#                                                                                     'Error'},
#                                                              'default': {'content': {'application/json': {'schema': {'type': 'object'}}},
#                                                                          'description': 'Default '
#                                                                                         'response.'}},
#                                                'summary': 'Return all '
#                                                           'types of '
#                                                           'ontologies '
#                                                           'present in '
#                                                           'RaMP-DB'}},
#                '/api/pathways-from-analytes': {'post': {'requestBody': {'content': {'application/json': {'schema': {'example': {'analytes': ['ensembl:ENSG00000135679',
#                                                                                                                                              'hmdb:HMDB0000064',
#                                                                                                                                              'hmdb:HMDB0000148',
#                                                                                                                                              'ensembl:ENSG00000141510']},
#                                                                                                                     'properties': {'analytes': {'items': {'type': 'string'},
#                                                                                                                                                 'type': 'array'}},
#                                                                                                                     'type': 'object'}}},
#                                                                         'description': 'Retrieve '
#                                                                                        'pathway(s) '
#                                                                                        'for '
#                                                                                        'a '
#                                                                                        'given '
#                                                                                        'analyte(s). '
#                                                                                        'IDs '
#                                                                                        'should '
#                                                                                        'be '
#                                                                                        'prepended '
#                                                                                        'by '
#                                                                                        'ID '
#                                                                                        'source '
#                                                                                        '(e.g. '
#                                                                                        '**hmdb**:C00412).',
#                                                                         'required': True},
#                                                         'responses': {'200': {'description': 'OK'},
#                                                                       '500': {'description': 'Internal '
#                                                                                              'Server '
#                                                                                              'Error'}},
#                                                         'summary': 'Return '
#                                                                    'pathways '
#                                                                    'from '
#                                                                    'given '
#                                                                    'list '
#                                                                    'of '
#                                                                    'analytes'}},
#                '/api/source_versions': {'get': {'parameters': [],
#                                                 'responses': {'200': {'content': {'application/json': {'schema': {'type': 'object'}}},
#                                                                       'description': 'OK'},
#                                                               '500': {'content': {'application/json': {'schema': {'type': 'string'}}},
#                                                                       'description': 'Internal '
#                                                                                      'Server '
#                                                                                      'Error'},
#                                                               'default': {'content': {'application/json': {'schema': {'type': 'object'}}},
#                                                                           'description': 'Default '
#                                                                                          'response.'}},
#                                                 'summary': 'Return source '
#                                                            'version '
#                                                            'information'}}},
#      'servers': [{'url': 'https://ramp-api-alpha.ncats.io'}],
#      'tags': [{'name': 'NCATS-API'}]}

# %%
for smartapi in SmartAPI.get_all(1):
    try:
        # Decode the raw data from bytes to a string
        data_doc = smartapi.raw.decode('utf-8')
        # Load the YAML formatted string into a Python dictionary
        data_dict = yaml.safe_load(data_doc)
        # Now validate the dictionary against the schema
        validate(instance=data_dict, schema=schema_vb)
        print("Validation successful!")
    except yaml.YAMLError as ye:
        print(f"YAML parsing error: {str(ye)}")
    except jsonschema.exceptions.ValidationError as ve:
        print(f"Validation error at {ve.path}: {ve.message}")
    except jsonschema.exceptions.SchemaError as se:
        print(f"Schema error: {se.message}")
    except Exception as e:
        print(f"An unexpected error occurred: {str(e)}")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/elasticsearch_dsl/_sync/search.py:77: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   es.search(index=self._index, body=self.to_dict(), **self._params)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/elasticsearch_dsl/_sync/document.py:106: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   doc = es.get(index=cls._default_index(index), id=id, **kwargs)
# Validation error at deque([]): Unevaluated properties are not allowed ('openapi' was unexpected)

# %%
schemajson_ap_31="/Users/nacosta/Documents/smartAPI/openapi-schema-apidom-31.json"
schemajson_ap_31_ajv="/Users/nacosta/Documents/smartAPI/openapi-schema-apidiom-31-ajv.json"

# %%
# Load the schema from a JSON file
with open(schemajson_ap_31, 'r') as schema_file:
    schema_ap = json.load(schema_file)

# %%
# Load the schema from a JSON file
with open(schemajson_ap_31_ajv, 'r') as schema_file:
    schema_ap_ajv = json.load(schema_file)

# %%
official_schema="/Users/nacosta/Documents/smartAPI/official.json"
# Load the schema from a JSON file
with open(official_schema, 'r') as official_schema:
    schema_official = json.load(official_schema)

# %%
try:
    validate(trapi_doc, schema_official)
    print("Validation successful!")
except yaml.YAMLError as ye:
    print(f"YAML parsing error: {str(ye)}")
except jsonschema.exceptions.ValidationError as ve:
    print(f"Validation error at {ve.path}: {ve.message}")
except jsonschema.exceptions.SchemaError as se:
    print(f"Schema error: {se.message}")
except Exception as e:
    print(f"An unexpected error occurred: {str(e)}")
# Out:
# Validation successful!

# %%
validate_doc(test_doc, schema_ap_ajv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/nacosta/Documents/smartAPI/WORKING_BRANCH/add-validation/smartAPI/src/validate_openapiv3.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/WORKING_BRANCH/add-validation/smartAPI/src/validate_openapiv3.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> validate_doc(test_doc, schema_ap_ajv)
#
# NameError: name 'validate_doc' is not defined

# %%
for smartapi in SmartAPI.get_all(1):
    try:
        # Decode the raw data from bytes to a string
        data_doc = smartapi.raw.decode('utf-8')
        # Load the YAML formatted string into a Python dictionary
        data_dict = yaml.safe_load(data_doc)
        # Now validate the dictionary against the schema
        validate(instance=data_dict, schema=schema_ap)
        print("Validation successful!")
    except yaml.YAMLError as ye:
        print(f"YAML parsing error: {str(ye)}")
    except jsonschema.exceptions.ValidationError as ve:
        print(f"Validation error at {ve.path}: {ve.message}")
    except jsonschema.exceptions.SchemaError as se:
        print(f"Schema error: {se.message}")
    except Exception as e:
        print(f"An unexpected error occurred: {str(e)}")
# Out:
# Validation error at deque([]): Unevaluated properties are not allowed ('openapi' was unexpected)

# %%
import json
from deepdiff import DeepDiff

# Load the first JSON file
with open(schemajson_ap_31, 'r') as file:
    schema_ap_31 = json.load(file)

# Load the second JSON file
with open(schemajson_vb_31, 'r') as file:
    schema_vb_31 = json.load(file)

# Compare the two JSON files
diff = DeepDiff(schema_vb_31, schema_ap_31)

for change_type, changes in diff.items():
    print(f"{change_type}:")
    for change in changes:
        print(f"  {change}")
# Out:
# type_changes:
#   root['$defs']['link']['properties']['operationId']
# dictionary_item_added:
#   root['$defs']['license']['oneOf']
#   root['$defs']['server-variable']['properties']['descriptions']
#   root['$defs']['path-item']['patternProperties']
#   root['$defs']['parameter']['properties']['allowEmptyValue']
#   root['$defs']['parameter']['dependentSchemas']['schema']['properties']['allowReserved']
# dictionary_item_removed:
#   root['description']
#   root['properties']['servers']['default']
#   root['$defs']['info']['$comment']
#   root['$defs']['info']['properties']['termsOfService']['format']
#   root['$defs']['contact']['$comment']
#   root['$defs']['contact']['properties']['url']['format']
#   root['$defs']['contact']['properties']['email']['format']
#   root['$defs']['license']['$comment']
#   root['$defs']['license']['dependentSchemas']
#   root['$defs']['server']['$comment']
#   root['$defs']['server-variable']['$comment']
#   root['$defs']['server-variable']['properties']['description']
#   root['$defs']['components']['$comment']
#   root['$defs']['paths']['$comment']
#   root['$defs']['path-item']['$comment']
#   root['$defs']['path-item']['properties']['get']
#   root['$defs']['path-item']['properties']['put']
#   root['$defs']['path-item']['properties']['post']
#   root['$defs']['path-item']['properties']['delete']
#   root['$defs']['path-item']['properties']['options']
#   root['$defs']['path-item']['properties']['head']
#   root['$defs']['path-item']['properties']['patch']
#   root['$defs']['path-item']['properties']['trace']
#   root['$defs']['operation']['$comment']
#   root['$defs']['external-documentation']['$comment']
#   root['$defs']['parameter']['$comment']
#   root['$defs']['parameter']['if']
#   root['$defs']['parameter']['then']
#   root['$defs']['parameter']['properties']['content']['minProperties']
#   root['$defs']['parameter']['properties']['content']['maxProperties']
#   root['$defs']['parameter']['dependentSchemas']['schema']['$defs']['styles-for-query']['then']['properties']['allowReserved']
#   root['$defs']['request-body']['$comment']
#   root['$defs']['content']['$comment']
#   root['$defs']['media-type']['$comment']
#   root['$defs']['encoding']['$comment']
#   root['$defs']['responses']['$comment']
#   root['$defs']['responses']['minProperties']
#   root['$defs']['response']['$comment']
#   root['$defs']['callbacks']['$comment']
#   root['$defs']['example']['$comment']
#   root['$defs']['example']['not']
#   root['$defs']['link']['$comment']
#   root['$defs']['header']['$comment']
#   root['$defs']['header']['properties']['content']['minProperties']
#   root['$defs']['header']['properties']['content']['maxProperties']
#   root['$defs']['tag']['$comment']
#   root['$defs']['reference']['$comment']
#   root['$defs']['schema']['$comment']
#   root['$defs']['security-scheme']['$comment']
#   root['$defs']['oauth-flows']['$defs']['implicit']['properties']['authorizationUrl']['format']
#   root['$defs']['oauth-flows']['$defs']['implicit']['properties']['refreshUrl']['format']
#   root['$defs']['oauth-flows']['$defs']['password']['properties']['tokenUrl']['format']
#   root['$defs']['oauth-flows']['$defs']['password']['properties']['refreshUrl']['format']
#   root['$defs']['oauth-flows']['$defs']['client-credentials']['properties']['tokenUrl']['format']
#   root['$defs']['oauth-flows']['$defs']['client-credentials']['properties']['refreshUrl']['format']
#   root['$defs']['oauth-flows']['$defs']['authorization-code']['properties']['authorizationUrl']['format']
#   root['$defs']['oauth-flows']['$defs']['authorization-code']['properties']['tokenUrl']['format']
#   root['$defs']['oauth-flows']['$defs']['authorization-code']['properties']['refreshUrl']['format']
#   root['$defs']['security-requirement']['$comment']
#   root['$defs']['specification-extensions']['$comment']
# values_changed:
#   root['$id']
# iterable_item_removed:
#   root['$defs']['parameter']['required'][0]

# %%
# !ls
# Out:
# ADMIN.md                 migrate.py               tests
# __pycache__              model                    utils
# admin.py                 pipeline.py              validate_openapiv3.ipynb
# config.py                pyproject.toml           validate_schemas.ipynb
# config_key.py            schemas copy.ini         validate_x-bte.ipynb
# controller               schemas.ini              validation_report.txt
# handlers                 smartapi_schema.json     x-bte_schema.json
# index.py                 templates

# %%
raw_file="smartapi_schema.json"
# Load the schema from a JSON file
with open(raw_file, 'r') as schema_file:
    schema_original_3 = json.load(schema_file)

# %%
# Compare the two JSON files
diff = DeepDiff(schema_original_3, schema_vb_31)

for change_type, changes in diff.items():
    print(f"{change_type}:")
    for change in changes:
        print(f"  {change}")
# Out:
# dictionary_item_added:
#   root['$id']
#   root['required']
#   root['anyOf']
#   root['$ref']
#   root['unevaluatedProperties']
#   root['$defs']
#   root['properties']['openapi']
#   root['properties']['jsonSchemaDialect']
#   root['properties']['webhooks']
#   root['properties']['components']
#   root['properties']['security']
#   root['properties']['externalDocs']
#   root['properties']['servers']['default']
#   root['properties']['paths']['$ref']
# dictionary_item_removed:
#   root['title']
#   root['definitions']
#   root['properties']['x-externalResources']
#   root['properties']['paths']['type']
#   root['properties']['paths']['patternProperties']
# values_changed:
#   root['$schema']
#   root['description']
#   root['properties']['info']['$ref']
#   root['properties']['servers']['items']['$ref']
#   root['properties']['tags']['items']['$ref']

# %%
# Compare the two JSON files
diff = DeepDiff(schema_original_3, schema_ap_31)

for change_type, changes in diff.items():
    print(f"{change_type}:")
    if isinstance(changes, dict):
        for change, details in changes.items():
            print(f"  {change}")
            if isinstance(details, dict):
                for key, value in details.items():
                    print(f"    {key}: {value}")
    elif isinstance(changes, list):
        for change in changes:
            print(f"  {change}")
# Out:
# dictionary_item_added:
# dictionary_item_removed:
# values_changed:
#   root['$schema']
#     new_value: https://json-schema.org/draft/2020-12/schema
#     old_value: http://json-schema.org/draft-04/schema#
#   root['properties']['info']['$ref']
#     new_value: #/$defs/info
#     old_value: #/definitions/info
#   root['properties']['servers']['items']['$ref']
#     new_value: #/$defs/server
#     old_value: #/definitions/server
#   root['properties']['tags']['items']['$ref']
#     new_value: #/$defs/tag
#     old_value: #/definitions/tag

# %%
# Compare the two JSON files
diff = DeepDiff(schema_original_3, schema_vb_31)

for change_type, changes in diff.items():
    print(f"{change_type}:")
    if isinstance(changes, dict):
        for change, details in changes.items():
            print(f"  {change}")
            if isinstance(details, dict):
                for key, value in details.items():
                    print(f"    {key}: {value}")
    elif isinstance(changes, list):
        for change in changes:
            print(f"  {change}")
# Out:
# dictionary_item_added:
# dictionary_item_removed:
# values_changed:
#   root['$schema']
#     new_value: https://json-schema.org/draft/2020-12/schema
#     old_value: http://json-schema.org/draft-04/schema#
#   root['description']
#     new_value: The description of OpenAPI v3.1.x documents without schema validation, as defined by https://spec.openapis.org/oas/v3.1.0
#     old_value: This is the root document object of the smartAPI definition file.
#   root['properties']['info']['$ref']
#     new_value: #/$defs/info
#     old_value: #/definitions/info
#   root['properties']['servers']['items']['$ref']
#     new_value: #/$defs/server
#     old_value: #/definitions/server
#   root['properties']['tags']['items']['$ref']
#     new_value: #/$defs/tag
#     old_value: #/definitions/tag

# %%
import pprint

# Compare the two JSON files
diff = DeepDiff(schema_vb_31, schema_ap_31)

pp = pprint.PrettyPrinter(indent=4)

for change_type, changes in diff.items():
    print(f"{change_type}:")
    if isinstance(changes, dict):
        for change, details in changes.items():
            print(f"  {change}")
            if isinstance(details, dict):
                for key, value in details.items():
                    print(f"    {key}: ", end="")
                    pp.pprint(value)
            elif isinstance(details, list):
                print(f"    ", end="")
                pp.pprint(details)
            else:
                print(f"    {details}")
    elif isinstance(changes, list):
        for change in changes:
            print(f"  {change}")
    else:
        print(f"  {changes}")
# Out:
# type_changes:
#   root['$defs']['link']['properties']['operationId']
#     old_type: <class 'dict'>
#     new_type: <class 'bool'>
#     old_value: {'type': 'string'}
#     new_value: True
# dictionary_item_added:
#   [root['$defs']['license']['oneOf'], root['$defs']['server-variable']['properties']['descriptions'], root['$defs']['path-item']['patternProperties'], root['$defs']['parameter']['properties']['allowEmptyValue'], root['$defs']['parameter']['dependentSchemas']['schema']['properties']['allowReserved']]
# dictionary_item_removed:
#   [root['description'], root['properties']['servers']['default'], root['$defs']['info']['$comment'], root['$defs']['info']['properties']['termsOfService']['format'], root['$defs']['contact']['$comment'], root['$defs']['contact']['properties']['url']['format'], root['$defs']['contact']['properties']['email']['format'], root['$defs']['license']['$comment'], root['$defs']['license']['dependentSchemas'], root['$defs']['server']['$comment'], root['$defs']['server-variable']['$comment'], root['$defs']['server-variable']['properties']['description'], root['$defs']['components']['$comment'], root['$defs']['paths']['$comment'], root['$defs']['path-item']['$comment'], root['$defs']['path-item']['properties']['get'], root['$defs']['path-item']['properties']['put'], root['$defs']['path-item']['properties']['post'], root['$defs']['path-item']['properties']['delete'], root['$defs']['path-item']['properties']['options'], root['$defs']['path-item']['properties']['head'], root['$defs']['path-item']['properties']['patch'], root['$defs']['path-item']['properties']['trace'], root['$defs']['operation']['$comment'], root['$defs']['external-documentation']['$comment'], root['$defs']['parameter']['$comment'], root['$defs']['parameter']['if'], root['$defs']['parameter']['then'], root['$defs']['parameter']['properties']['content']['minProperties'], root['$defs']['parameter']['properties']['content']['maxProperties'], root['$defs']['parameter']['dependentSchemas']['schema']['$defs']['styles-for-query']['then']['properties']['allowReserved'], root['$defs']['request-body']['$comment'], root['$defs']['content']['$comment'], root['$defs']['media-type']['$comment'], root['$defs']['encoding']['$comment'], root['$defs']['responses']['$comment'], root['$defs']['responses']['minProperties'], root['$defs']['response']['$comment'], root['$defs']['callbacks']['$comment'], root['$defs']['example']['$comment'], root['$defs']['example']['not'], root['$defs']['link']['$comment'], root['$defs']['header']['$comment'], root['$defs']['header']['properties']['content']['minProperties'], root['$defs']['header']['properties']['content']['maxProperties'], root['$defs']['tag']['$comment'], root['$defs']['reference']['$comment'], root['$defs']['schema']['$comment'], root['$defs']['security-scheme']['$comment'], root['$defs']['oauth-flows']['$defs']['implicit']['properties']['authorizationUrl']['format'], root['$defs']['oauth-flows']['$defs']['implicit']['properties']['refreshUrl']['format'], root['$defs']['oauth-flows']['$defs']['password']['properties']['tokenUrl']['format'], root['$defs']['oauth-flows']['$defs']['password']['properties']['refreshUrl']['format'], root['$defs']['oauth-flows']['$defs']['client-credentials']['properties']['tokenUrl']['format'], root['$defs']['oauth-flows']['$defs']['client-credentials']['properties']['refreshUrl']['format'], root['$defs']['oauth-flows']['$defs']['authorization-code']['properties']['authorizationUrl']['format'], root['$defs']['oauth-flows']['$defs']['authorization-code']['properties']['tokenUrl']['format'], root['$defs']['oauth-flows']['$defs']['authorization-code']['properties']['refreshUrl']['format'], root['$defs']['security-requirement']['$comment'], root['$defs']['specification-extensions']['$comment']]
# values_changed:
#   root['$id']
#     new_value: 'https://spec.openapis.org/oas/3.1/schema/2021-09-28'
#     old_value: 'https://spec.openapis.org/oas/3.1/schema/2022-10-07'
# iterable_item_removed:
#   root['$defs']['parameter']['required'][0]
#     name

# %%
import pprint

# Compare the two JSON files
diff = DeepDiff(schema_vb_31, schema_ap_31)

pp = pprint.PrettyPrinter(indent=4)

for change_type, changes in diff.items():
    print(f"{change_type}:")
    if isinstance(changes, dict):
        for change, details in changes.items():
            print(f"  {change}")
            if isinstance(details, dict):
                for key, value in details.items():
                    print(f"    {key}: ", end="")
                    pp.pprint(value)
            elif isinstance(details, list):
                print("\n".join(f"    - {item}" for item in details))
            else:
                print(f"    {details}")
    elif isinstance(changes, list):
        print("\n".join(f"  - {change}" for change in changes))
    else:
        print(f"  {changes}")
# Out:
# type_changes:
#   root['$defs']['link']['properties']['operationId']
#     old_type: <class 'dict'>
#     new_type: <class 'bool'>
#     old_value: {'type': 'string'}
#     new_value: True
# dictionary_item_added:
#   [root['$defs']['license']['oneOf'], root['$defs']['server-variable']['properties']['descriptions'], root['$defs']['path-item']['patternProperties'], root['$defs']['parameter']['properties']['allowEmptyValue'], root['$defs']['parameter']['dependentSchemas']['schema']['properties']['allowReserved']]
# dictionary_item_removed:
#   [root['description'], root['properties']['servers']['default'], root['$defs']['info']['$comment'], root['$defs']['info']['properties']['termsOfService']['format'], root['$defs']['contact']['$comment'], root['$defs']['contact']['properties']['url']['format'], root['$defs']['contact']['properties']['email']['format'], root['$defs']['license']['$comment'], root['$defs']['license']['dependentSchemas'], root['$defs']['server']['$comment'], root['$defs']['server-variable']['$comment'], root['$defs']['server-variable']['properties']['description'], root['$defs']['components']['$comment'], root['$defs']['paths']['$comment'], root['$defs']['path-item']['$comment'], root['$defs']['path-item']['properties']['get'], root['$defs']['path-item']['properties']['put'], root['$defs']['path-item']['properties']['post'], root['$defs']['path-item']['properties']['delete'], root['$defs']['path-item']['properties']['options'], root['$defs']['path-item']['properties']['head'], root['$defs']['path-item']['properties']['patch'], root['$defs']['path-item']['properties']['trace'], root['$defs']['operation']['$comment'], root['$defs']['external-documentation']['$comment'], root['$defs']['parameter']['$comment'], root['$defs']['parameter']['if'], root['$defs']['parameter']['then'], root['$defs']['parameter']['properties']['content']['minProperties'], root['$defs']['parameter']['properties']['content']['maxProperties'], root['$defs']['parameter']['dependentSchemas']['schema']['$defs']['styles-for-query']['then']['properties']['allowReserved'], root['$defs']['request-body']['$comment'], root['$defs']['content']['$comment'], root['$defs']['media-type']['$comment'], root['$defs']['encoding']['$comment'], root['$defs']['responses']['$comment'], root['$defs']['responses']['minProperties'], root['$defs']['response']['$comment'], root['$defs']['callbacks']['$comment'], root['$defs']['example']['$comment'], root['$defs']['example']['not'], root['$defs']['link']['$comment'], root['$defs']['header']['$comment'], root['$defs']['header']['properties']['content']['minProperties'], root['$defs']['header']['properties']['content']['maxProperties'], root['$defs']['tag']['$comment'], root['$defs']['reference']['$comment'], root['$defs']['schema']['$comment'], root['$defs']['security-scheme']['$comment'], root['$defs']['oauth-flows']['$defs']['implicit']['properties']['authorizationUrl']['format'], root['$defs']['oauth-flows']['$defs']['implicit']['properties']['refreshUrl']['format'], root['$defs']['oauth-flows']['$defs']['password']['properties']['tokenUrl']['format'], root['$defs']['oauth-flows']['$defs']['password']['properties']['refreshUrl']['format'], root['$defs']['oauth-flows']['$defs']['client-credentials']['properties']['tokenUrl']['format'], root['$defs']['oauth-flows']['$defs']['client-credentials']['properties']['refreshUrl']['format'], root['$defs']['oauth-flows']['$defs']['authorization-code']['properties']['authorizationUrl']['format'], root['$defs']['oauth-flows']['$defs']['authorization-code']['properties']['tokenUrl']['format'], root['$defs']['oauth-flows']['$defs']['authorization-code']['properties']['refreshUrl']['format'], root['$defs']['security-requirement']['$comment'], root['$defs']['specification-extensions']['$comment']]
# values_changed:
#   root['$id']
#     new_value: 'https://spec.openapis.org/oas/3.1/schema/2021-09-28'
#     old_value: 'https://spec.openapis.org/oas/3.1/schema/2022-10-07'
# iterable_item_removed:
#   root['$defs']['parameter']['required'][0]
#     name

# %%
# Compare the two JSON files
diff = DeepDiff(schema_vb_31, schema_ap_31)

for change_type, changes in diff.items():
    print(f"{change_type}:")
    if isinstance(changes, dict):
        for change, details in changes.items():
            print(f"  {change}")
            if isinstance(details, dict):
                for key, value in details.items():
                    print(f"    {key}: {value}")
    elif isinstance(changes, list):
        for change in changes:
            print(f"  {change}")
# Out:
# type_changes:
#   root['$defs']['link']['properties']['operationId']
#     old_type: <class 'dict'>
#     new_type: <class 'bool'>
#     old_value: {'type': 'string'}
#     new_value: True
# dictionary_item_added:
# dictionary_item_removed:
# values_changed:
#   root['$id']
#     new_value: https://spec.openapis.org/oas/3.1/schema/2021-09-28
#     old_value: https://spec.openapis.org/oas/3.1/schema/2022-10-07
# iterable_item_removed:
#   root['$defs']['parameter']['required'][0]

# %% [markdown]
# ---
