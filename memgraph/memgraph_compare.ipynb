# %%
import mgclient # memgraph client

# %% [markdown]
# ```
# docker run -p 7687:7687 -p 7444:7444 -p 3000:3000 --name memgraph -e MEMGRAPH="--query-execution-timeout-sec=3600 --memory-limit=30720" memgraph/memgraph-platform
# ```

# %% [markdown]
# # Data Comparisons

# %% [markdown]
# ## `Memgraph`

# %% [markdown]
# **Connect to `memgraph` host**

# %%
conn = mgclient.connect(host="localhost", port=7687)   # connect to memgraph
conn.autocommit = True  # autocommit mode is required for DDL queries
cursor = conn.cursor() # cursor is used to execute queries

# %% [markdown]
# ---

# %%
from controller.metakg import MetaKG
from model import ConsolidatedMetaKGDoc

# %%
index = ConsolidatedMetaKGDoc.Index.name

# %%
# Index on the name property of the Entity node
q="""
CREATE INDEX ON :Entity(name);
"""

cursor.execute(q) # execute query

# %% [markdown]
# This graph database reflects the `ConsolidatedMetaKG` Index with node enitities reflecting the `subject` and `object`, and the paths reflecting the pairs corresponding `predicate`.
#
# This database would be built once.

# %%
for edge in MetaKG.get_all_via_scan(size=1000, index=index):
    subject = edge['_source']['subject']
    object = edge['_source']['object']
    predicate = edge['_source']['predicate']
    api_data = edge['_source']['api']  # Additional data as properties

    # Construct a unique identifier for each relationship
    # This is just an example - modify it according to your data structure
    unique_id = f"{subject}-{predicate}-{object}"
    
    # Cypher query to create nodes with a static relationship
    query = """
    MERGE (s:Entity {name: $subject})
    MERGE (o:Entity {name: $object})
    MERGE (s)-[r:RELATED_TO {id: $unique_id}]->(o)
    SET r.predicate = $predicate, r.api = $api_data
    """
    params = {'subject': subject, 'object': object, 'unique_id': unique_id, 'predicate': predicate, 'api_data': api_data}
    cursor.execute(query, params)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb Cell 12 line 1
#      <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> query = """
#      <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> MERGE (s:Entity {name: $subject})
#      <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a> MERGE (o:Entity {name: $object})
#      <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a> MERGE (s)-[r:RELATED_TO {id: $unique_id}]->(o)
#      <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb#X13sZmlsZQ%3D%3D?line=15'>16</a> SET r.predicate = $predicate, r.api = $api_data
#      <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb#X13sZmlsZQ%3D%3D?line=16'>17</a> """
#      <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb#X13sZmlsZQ%3D%3D?line=17'>18</a> params = {'subject': subject, 'object': object, 'unique_id': unique_id, 'predicate': predicate, 'api_data': api_data}
# ---> <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb#X13sZmlsZQ%3D%3D?line=18'>19</a> cursor.execute(query, params)
#
# KeyboardInterrupt:

# %% [markdown]
# ---

# %%
query="""
MATCH p=(start:Entity {name: 'InformationResource'})-[:RELATED_TO*..1]-(end:Entity {name: 'Publication'})
RETURN p;
"""

# %%
cursor.execute(query)

# Display the results
results = cursor.fetchall()
print(len(results))
# Out:
# 1

# %%
query="""
MATCH p=(start:Entity {name: 'InformationResource'})-[:RELATED_TO*..2]-(end:Entity {name: 'Publication'})
RETURN p;
"""

# %%
cursor.execute(query)

# Display the results
results = cursor.fetchall()
print(len(results))
# Out:
# 593

# %%
query="""
MATCH p=(start:Entity {name: 'InformationResource'})-[:RELATED_TO*..2]->(end:Entity {name: 'Publication'})
UNWIND relationships(p) AS r
WITH start, end, collect(r.predicate) AS predicates
RETURN start, end, predicates;
"""

# %%
cursor.execute(query)

# Display the results
results = cursor.fetchall()
print(len(results))
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> cursor.execute(query)
#       <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> # Display the results
#       <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/memgraph_compare.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> results = cursor.fetchall()
#
# DatabaseError: Transaction was asked to abort because of transaction timeout.

# %% [markdown]
# `PROFILE MATCH` query

# %%
q="""
PROFILE MATCH p=(start:Entity {name: 'InformationResource'})-[:RELATED_TO*..3]->(end:Entity {name: 'Publication'})
RETURN p
LIMIT 100;
"""

# %%
cursor.execute(q)

# Fetch and display the results
results = cursor.fetchall()

# Printing each result
for result in results:
    print(result)
# Out:
# ('* Limit', 101, '  0.003494 %', '  0.020170 ms')
# ('* Produce {p}', 100, '  0.037991 %', '  0.219289 ms')
# ('* ConstructNamedPath', 100, '  0.027923 %', '  0.161174 ms')
# ('* Filter (start :Entity), {start.name}', 100, ' 67.900171 %', ' 391.930952 ms')
# ('* ExpandVariable (end)<-[anon1:RELATED_TO]-(start)', 1548889, ' 32.029290 %', ' 184.878330 ms')
# ('* ScanAllByLabelPropertyValue (end :Entity {name})', 1, '  0.001127 %', '  0.006506 ms')
# ('* Once', 1, '  0.000003 %', '  0.000019 ms')

# %% [markdown]
# The provided Cypher query is performing the following operations in a Neo4j graph database:
# ```
# MATCH p=(start:Entity {name: 'InformationResource'})-[:RELATED_TO*..3]->(end:Entity {name: 'Publication'})
# RETURN p
# LIMIT 100;
# ```
# 1. **MATCH Clause**:
#    - `MATCH p=(start:Entity {name: 'InformationResource'})-[:RELATED_TO*..3]->(end:Entity {name: 'Publication'})`
#    - This part of the query is looking for a specific pattern in the graph. It defines a variable `p` that represents a path between two nodes (labeled as `Entity`).
#    - The first node (`start`) is an `Entity` with a `name` property equal to `'InformationResource'`.
#    - The last node (`end`) is an `Entity` with a `name` property equal to `'Publication'`.
#    - The `[:RELATED_TO*..3]->` segment specifies the type of relationships to follow (`RELATED_TO`) and the depth of the path. It indicates that the query should find paths where `start` and `end` are connected by a sequence of up to 3 `RELATED_TO` relationships. The `->` indicates the direction of the relationship is from `start` to `end`.
#
# 2. **RETURN Clause**:
#    - `RETURN p`
#    - This clause specifies that the query should return the paths that it finds. Each path `p` includes the start node, the end node, and all nodes and relationships between them that match the specified pattern.
#
# 3. **LIMIT Clause**:
#    - `LIMIT 100`
#    - This part of the query limits the number of paths returned to 100. Without this limit, the query could potentially return a very large number of paths, especially in a large or densely connected graph, which might be more data than is needed and could impact performance.
#
# In summary, the query is searching for up to 100 instances of a path in the graph where nodes of type `Entity` and with specific `name` properties are connected by a chain of up to 3 `RELATED_TO` relationships. The query is particularly useful for finding specific connections and relationships in a graph, especially when looking for indirect relationships (connections not immediately obvious) between two entities.

# %%
path_query="""
MATCH p=(start:Entity {name: 'InformationResource'})-[:RELATED_TO*..3]->(end:Entity {name: 'Publication'})
RETURN p
LIMIT 100;
"""

cursor.execute(path_query)

# Fetch and display the results
results = cursor.fetchall()

# Printing each result
for result in results:
    print(result)
# Out:
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10cab9590>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10cabb390>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10c940ed0>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10c942a30>], relationships=[<mgclient.Relationship(start_id=226, end_id=121, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-subclass_of-Publication', 'predicate': 'subclass_of'}) at 0x10c8377f0>, <mgclient.Relationship(start_id=121, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6bb25982762d', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-icees-kg/1.3.0', 'ui': 'https://smart-api.info/ui/44e7a1147ca8657f50af6bb25982762d'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Exposures Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Exploring Agent']}}], 'id': 'Publication-correlated_with-SmallMolecule', 'predicate': 'correlated_with'}) at 0x10c836bf0>, <mgclient.Relationship(start_id=114, end_id=121, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6 ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10cad6490>, <mgclient.Node(id=132, labels={'Entity'}, properties={'name': 'InformationContentEntity'}) at 0x10cad5920>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10cad5230>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10cad5fe0>], relationships=[<mgclient.Relationship(start_id=226, end_id=132, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-subclass_of-InformationContentEntity', 'predicate': 'subclass_of'}) at 0x1046362b0>, <mgclient.Relationship(start_id=132, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6bb25982762d', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-icees-kg/1.3.0', 'ui': 'https://smart-api.info/ui/44e7a1147ca8657f50af6bb25982762d'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Exposures Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https:// ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10cad5ad0>, <mgclient.Node(id=132, labels={'Entity'}, properties={'name': 'InformationContentEntity'}) at 0x10cb44ab0>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10cb47150>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10cb45f50>], relationships=[<mgclient.Relationship(start_id=226, end_id=132, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-related_to-InformationContentEntity', 'predicate': 'related_to'}) at 0x10c80a4f0>, <mgclient.Relationship(start_id=132, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6bb25982762d', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-icees-kg/1.3.0', 'ui': 'https://smart-api.info/ui/44e7a1147ca8657f50af6bb25982762d'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Exposures Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://sm ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10cb44c60>, <mgclient.Node(id=128, labels={'Entity'}, properties={'name': 'PhenotypicFeature'}) at 0x10cb44960>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10cb44510>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10caa7f30>], relationships=[<mgclient.Relationship(start_id=226, end_id=128, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-PhenotypicFeature', 'predicate': 'associated_with'}) at 0x10c81ecf0>, <mgclient.Relationship(start_id=128, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://molepro-trapi.transltr.io/molepro/trapi/v1.3', 'support_batch': True}}, 'name': 'MolePro', 'smartapi': {'id': '940677a65cae38c9a482e54e5c6794f7', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/molecular_data_provider/MolePro-TRAPI-1.3.yaml', 'ui': 'https://smart-api.info/ui/940677a65cae38c9a482e54e5c6794f7'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Molecular Data Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTransl ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10caa5ef0>, <mgclient.Node(id=145, labels={'Entity'}, properties={'name': 'DiseaseOrPhenotypicFeature'}) at 0x10caa7480>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10caa7d20>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10caa4420>], relationships=[<mgclient.Relationship(start_id=226, end_id=145, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-DiseaseOrPhenotypicFeature', 'predicate': 'associated_with'}) at 0x10cc217f0>, <mgclient.Relationship(start_id=145, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://molepro-trapi.transltr.io/molepro/trapi/v1.3', 'support_batch': True}}, 'name': 'MolePro', 'smartapi': {'id': '940677a65cae38c9a482e54e5c6794f7', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/molecular_data_provider/MolePro-TRAPI-1.3.yaml', 'ui': 'https://smart-api.info/ui/940677a65cae38c9a482e54e5c6794f7'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Molecular Data Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubuserconte ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10caa5830>, <mgclient.Node(id=145, labels={'Entity'}, properties={'name': 'DiseaseOrPhenotypicFeature'}) at 0x10caa5d40>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10caa46c0>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10ca44690>], relationships=[<mgclient.Relationship(start_id=226, end_id=145, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-DiseaseOrPhenotypicFeature', 'predicate': 'associated_with'}) at 0x10c8182f0>, <mgclient.Relationship(start_id=145, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://molepro-trapi.transltr.io/molepro/trapi/v1.3', 'support_batch': True}}, 'name': 'MolePro', 'smartapi': {'id': '940677a65cae38c9a482e54e5c6794f7', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/molecular_data_provider/MolePro-TRAPI-1.3.yaml', 'ui': 'https://smart-api.info/ui/940677a65cae38c9a482e54e5c6794f7'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Molecular Data Provider']}}], 'id': 'DiseaseOrPhenotypicFeature-is_side_effect_of-SmallMolecule', 'predicate': 'is_side_effect_of'}) at 0x10cc4e1f0>, <mgclient.Relationship(start_id=114, end_id=121, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, ' ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10cb297a0>, <mgclient.Node(id=128, labels={'Entity'}, properties={'name': 'PhenotypicFeature'}) at 0x10cb5a7f0>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10cb5bab0>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10cad5740>], relationships=[<mgclient.Relationship(start_id=226, end_id=128, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-PhenotypicFeature', 'predicate': 'associated_with'}) at 0x10cc2f7f0>, <mgclient.Relationship(start_id=128, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://molepro-trapi.transltr.io/molepro/trapi/v1.3', 'support_batch': True}}, 'name': 'MolePro', 'smartapi': {'id': '940677a65cae38c9a482e54e5c6794f7', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/molecular_data_provider/MolePro-TRAPI-1.3.yaml', 'ui': 'https://smart-api.info/ui/940677a65cae38c9a482e54e5c6794f7'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Molecular Data Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTransl ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10cb010e0>, <mgclient.Node(id=127, labels={'Entity'}, properties={'name': 'Disease'}) at 0x10cb039c0>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10cb018f0>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10cb03030>], relationships=[<mgclient.Relationship(start_id=226, end_id=127, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-Disease', 'predicate': 'associated_with'}) at 0x10c823d70>, <mgclient.Relationship(start_id=127, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://molepro-trapi.transltr.io/molepro/trapi/v1.3', 'support_batch': True}}, 'name': 'MolePro', 'smartapi': {'id': '940677a65cae38c9a482e54e5c6794f7', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/molecular_data_provider/MolePro-TRAPI-1.3.yaml', 'ui': 'https://smart-api.info/ui/940677a65cae38c9a482e54e5c6794f7'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Molecular Data Provider']}}], 'id': 'Disease-is_side_effect_of-SmallMolecule', 'predicate': 'is_side_effect_of'}) at 0x10c823070>, <mgclient.Relationship(start_id=114, end_id=121, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'sup ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10cae96e0>, <mgclient.Node(id=127, labels={'Entity'}, properties={'name': 'Disease'}) at 0x10caeb8d0>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10cab9860>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10cabb420>], relationships=[<mgclient.Relationship(start_id=226, end_id=127, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-Disease', 'predicate': 'associated_with'}) at 0x10cc4a270>, <mgclient.Relationship(start_id=127, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://molepro-trapi.transltr.io/molepro/trapi/v1.3', 'support_batch': True}}, 'name': 'MolePro', 'smartapi': {'id': '940677a65cae38c9a482e54e5c6794f7', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/molecular_data_provider/MolePro-TRAPI-1.3.yaml', 'ui': 'https://smart-api.info/ui/940677a65cae38c9a482e54e5c6794f7'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Molecular Data Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Age ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10caa48d0>, <mgclient.Node(id=127, labels={'Entity'}, properties={'name': 'Disease'}) at 0x10caa4a50>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10caa6100>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x104623570>], relationships=[<mgclient.Relationship(start_id=226, end_id=127, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-Disease', 'predicate': 'associated_with'}) at 0x10ccc01b0>, <mgclient.Relationship(start_id=127, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://molepro-trapi.transltr.io/molepro/trapi/v1.3', 'support_batch': True}}, 'name': 'MolePro', 'smartapi': {'id': '940677a65cae38c9a482e54e5c6794f7', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/molecular_data_provider/MolePro-TRAPI-1.3.yaml', 'ui': 'https://smart-api.info/ui/940677a65cae38c9a482e54e5c6794f7'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Molecular Data Provider']}}], 'id': 'Disease-location of-SmallMolecule', 'predicate': 'location of'}) at 0x10ccc0d70>, <mgclient.Relationship(start_id=114, end_id=121, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x104623fc0>, <mgclient.Node(id=152, labels={'Entity'}, properties={'name': 'Pathway'}) at 0x1046238a0>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x1046ee760>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x1046ec4b0>], relationships=[<mgclient.Relationship(start_id=226, end_id=152, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-Pathway', 'predicate': 'associated_with'}) at 0x10ccc39f0>, <mgclient.Relationship(start_id=152, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://molepro-trapi.transltr.io/molepro/trapi/v1.3', 'support_batch': True}}, 'name': 'MolePro', 'smartapi': {'id': '940677a65cae38c9a482e54e5c6794f7', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/molecular_data_provider/MolePro-TRAPI-1.3.yaml', 'ui': 'https://smart-api.info/ui/940677a65cae38c9a482e54e5c6794f7'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Molecular Data Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Pathway-treated_by-SmallMolecule', 'predicate': 'treated_by'}) at 0x10ccc4ef0>, <mgclient.Relationship(start_id=114, end_id=121, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Tr ...
# ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10c917510>, <mgclient.Node(id=152, labels={'Entity'}, properties={'name': 'Pathway'}) at 0x10c917540>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10c917570>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10c9175a0>], relationships=[<mgclient.Relationship(start_id=226, end_id=152, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-Pathway', 'predicate': 'associated_with'}) at 0x10d4893f0>, <mgclient.Relationship(start_id=152, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Pathway-affected_by-SmallMolecule', 'predicate': 'affected_by'}) at 0x10d489ff0>, <mgclient.Relationship(start_id=114, end_id=121, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6bb25982762d', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-icees-kg/1.3.0', 'ui': 'https://smart-api.info/ui/44e7a1147ca8657f50af6bb25982762d'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Exposures Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.gi ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10c917660>, <mgclient.Node(id=152, labels={'Entity'}, properties={'name': 'Pathway'}) at 0x10c917690>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10c9176c0>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10c9176f0>], relationships=[<mgclient.Relationship(start_id=226, end_id=152, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-Pathway', 'predicate': 'associated_with'}) at 0x10d490cb0>, <mgclient.Relationship(start_id=152, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Pathway-has_substrate-SmallMolecule', 'predicate': 'has_substrate'}) at 0x10d4918b0>, <mgclient.Relationship(start_id=114, end_id=121, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6bb25982762d', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-icees-kg/1.3.0', 'ui': 'https://smart-api.info/ui/44e7a1147ca8657f50af6bb25982762d'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Exposures Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://ra ...
# (<mgclient.Path(nodes=[<mgclient.Node(id=226, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10c9177b0>, <mgclient.Node(id=128, labels={'Entity'}, properties={'name': 'PhenotypicFeature'}) at 0x10c9177e0>, <mgclient.Node(id=114, labels={'Entity'}, properties={'name': 'SmallMolecule'}) at 0x10c917810>, <mgclient.Node(id=121, labels={'Entity'}, properties={'name': 'Publication'}) at 0x10c917840>], relationships=[<mgclient.Relationship(start_id=226, end_id=128, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-PhenotypicFeature', 'predicate': 'associated_with'}) at 0x10d494eb0>, <mgclient.Relationship(start_id=128, end_id=114, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'PhenotypicFeature-increased_likelihood_associated_with-SmallMolecule', 'predicate': 'increased_likelihood_associated_with'}) at 0x10d495a70>, <mgclient.Relationship(start_id=114, end_id=121, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server ...

# %%
# returns clean rows of nodes and relationships (paths) -- very slow at >= 3 hops ...maybe clean rows post process?
q="""
MATCH p=(start:Entity {name: 'InformationResource'})-[:RELATED_TO*..3]->(end:Entity {name: 'Publication'})
UNWIND relationships(p) AS r
WITH p, collect(r.predicate) AS predicates
RETURN reduce(names = [], n IN nodes(p) | names + n.name) AS nodeNames, predicates
LIMIT 10;
"""

# %%
q="""
MATCH p=(start:Entity {name: 'InformationResource'})-[:RELATED_TO*..3]->(end:Entity {name: 'Publication'})
RETURN p
LIMIT 100;
"""

cursor.execute(q)

# Fetch and display the results
results = cursor.fetchall()

# Printing each result
for result in results:
    path = result[0]  # Assuming each result is a path
    nodes = path.nodes
    relationships = path.relationships

    # Iterating through the nodes and relationships
    for i in range(len(nodes)):
        # Print the node's name
        print(nodes[i].properties['name'], end='')

        if i < len(relationships):
            # Print the relationship's predicate
            print(' - ' + relationships[i].properties['predicate'] + ' -> ', end='')

    print()  # New line after each path
    print()  # New line after each path
# Out:
# InformationResource - subclass_of -> Publication - correlated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - subclass_of -> InformationContentEntity - correlated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - related_to -> InformationContentEntity - correlated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - ameliorates -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> DiseaseOrPhenotypicFeature - related_to -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> DiseaseOrPhenotypicFeature - is_side_effect_of -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - treated_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - is_side_effect_of -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - treated_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - location of -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - treated_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - is_assessed_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - related_to -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> DiseaseOrPhenotypicFeature - ameliorates -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - is_side_effect_of -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> DiseaseOrPhenotypicFeature - treated_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - occurs_together_in_literature_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> NamedThing - occurs_together_in_literature_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - subclass_of -> NamedThing - occurs_together_in_literature_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - occurs_together_in_literature_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - occurs_together_in_literature_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - caused_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - has_biomarker -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - affected_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - causes -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - has_contraindication -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - contribution_from -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - has_contraindication -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - entity_positively_regulated_by_entity -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - has_real_world_evidence_of_association_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - affected_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - has_biomarker -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - related_to -> Behavior - related_to -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - contribution_from -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - is_ameliorated_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - is_ameliorated_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - decreases_abundance_of -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - increased_likelihood_associated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - has_predisposing_factor -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - disrupted_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - associated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - associated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - has_part -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - decreased_likelihood_associated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - produces -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - interacts_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - treats -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - is_ameliorated_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - regulates -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - causes -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - has_participant -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - related_to -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - related_to -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - caused_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - positively_correlated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - negatively_correlated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - positively_correlated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - negatively_correlated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - correlated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - response_increased_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - part_of -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - has_capability -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - participates_in -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - contributes_to -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - caused_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - enabled_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - increases_abundance_of -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - decreased_likelihood_associated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - has_catalyst -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - decreases_response_to -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - associated_with -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - increases_abundance_of -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - has_participant -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - has_part -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - is_exacerbated_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - ameliorates -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - disrupted_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - actively_involves -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - adverse_event_caused_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - has_upstream_actor -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - exacerbates -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - has_active_ingredient -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - increases_response_to -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - primarily_composed_of -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - regulated_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - response_affected_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - affects -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - similar_to -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - overlaps -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - affects_response_to -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - composed_primarily_of -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - has_predisposing_factor -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - has_output -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - response_decreased_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - disrupts -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - adverse_event_caused_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Disease - is_exacerbated_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - affected_by -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> Pathway - has_substrate -> SmallMolecule - correlated_with -> Publication
#
# InformationResource - associated_with -> PhenotypicFeature - increased_likelihood_associated_with -> SmallMolecule - correlated_with -> Publication

# %%
q="""
MATCH p=(start:Entity {name: 'InformationResource'})-[:RELATED_TO*..3]->(end:Entity {name: 'Publication'})
RETURN count(p) AS total;
"""

cursor.execute(q)
results = cursor.fetchall()

print(results)
# Out:
# [(346364,)]

# %% [markdown]
# ---

# %% [markdown]
# ## NetworkX

# %%
from utils.metakg.path_finder import MetaKGPathFinder
import networkx.classes.digraph as nx_digraph
import networkx as nx

# %%
subject='InformationResource'
object='Publication'

# %%
query_data = {
    'q': '*'
}
pf = MetaKGPathFinder(query_data)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/elasticsearch/connection/base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)

# %%
G = pf.G

cutoff=3

paths = pf.get_paths(subject=subject, object=object, cutoff=cutoff)

# %%
len(paths)
# Out:
# 448

# %%
for p in paths:
    print(f"PATH: {'->'.join(p['path'])}")
    for e in p['edges']:
        print(f"{e['subject']} - { {e['predicate']} } -> {e['object']}")
    print("\n")
# Out:
# PATH: InformationResource->NamedThing->AnatomicalEntity->Publication
# InformationResource - {'associated_with'} -> NamedThing
# InformationResource - {'subclass_of'} -> NamedThing
# NamedThing - {'occurs_together_in_literature_with'} -> AnatomicalEntity
# NamedThing - {'subclass_of'} -> AnatomicalEntity
# NamedThing - {'active_in'} -> AnatomicalEntity
# NamedThing - {'actively_involved_in'} -> AnatomicalEntity
# NamedThing - {'actively_involves'} -> AnatomicalEntity
# NamedThing - {'acts_upstream_of'} -> AnatomicalEntity
# NamedThing - {'acts_upstream_of_negative_effect'} -> AnatomicalEntity
# NamedThing - {'acts_upstream_of_or_within'} -> AnatomicalEntity
# NamedThing - {'acts_upstream_of_or_within_negative_effect'} -> AnatomicalEntity
# NamedThing - {'acts_upstream_of_or_within_positive_effect'} -> AnatomicalEntity
# NamedThing - {'acts_upstream_of_positive_effect'} -> AnatomicalEntity
# NamedThing - {'affects_activity_of'} -> AnatomicalEntity
# NamedThing - {'affects'} -> AnatomicalEntity
# NamedThing - {'affects_transport_of'} -> AnatomicalEntity
# NamedThing - {'capable_of'} -> AnatomicalEntity
# NamedThing - {'caused_by'} -> AnatomicalEntity
# NamedThing - {'causes'} -> AnatomicalEntity
# NamedThing - {'coexists_with'} -> AnatomicalEntity
# NamedThing - {'contributes_to'} -> AnatomicalEntity
# NamedThing - {'derives_from'} -> AnatomicalEntity
# NamedThing - {'derives_into'} -> AnatomicalEntity
# NamedThing - {'enabled_by'} -> AnatomicalEntity
# NamedThing - {'enables'} -> AnatomicalEntity
# NamedThing - {'entity_negatively_regulates_entity'} -> AnatomicalEntity
# NamedThing - {'entity_positively_regulates_entity'} -> AnatomicalEntity
# NamedThing - {'entity_regulates_entity'} -> AnatomicalEntity
# NamedThing - {'has_input'} -> AnatomicalEntity
# NamedThing - {'has_output'} -> AnatomicalEntity
# NamedThing - {'has_part'} -> AnatomicalEntity
# NamedThing - {'has_participant'} -> AnatomicalEntity
# NamedThing - {'interacts_with'} -> AnatomicalEntity
# NamedThing - {'located_in'} -> AnatomicalEntity
# NamedThing - {'location_of'} -> AnatomicalEntity
# NamedThing - {'molecularly_interacts_with'} -> AnatomicalEntity
# NamedThing - {'negatively_regulates'} -> AnatomicalEntity
# NamedThing - {'occurs_in'} -> AnatomicalEntity
# NamedThing - {'overlaps'} -> AnatomicalEntity
# NamedThing - {'participates_in'} -> AnatomicalEntity
# NamedThing - {'part_of'} -> AnatomicalEntity
# NamedThing - {'physically_interacts_with'} -> AnatomicalEntity
# NamedThing - {'positively_regulates'} -> AnatomicalEntity
# NamedThing - {'preceded_by'} -> AnatomicalEntity
# NamedThing - {'precedes'} -> AnatomicalEntity
# NamedThing - {'process_negatively_regulates_process'} -> AnatomicalEntity
# NamedThing - {'process_positively_regulates_process'} -> AnatomicalEntity
# NamedThing - {'process_regulates_process'} -> AnatomicalEntity
# NamedThing - {'produced_by'} -> AnatomicalEntity
# NamedThing - {'regulates'} -> AnatomicalEntity
# NamedThing - {'related_to'} -> AnatomicalEntity
# NamedThing - {'temporally_related_to'} -> AnatomicalEntity
# NamedThing - {'composed_primarily_of'} -> AnatomicalEntity
# NamedThing - {'has_upstream_actor'} -> AnatomicalEntity
# NamedThing - {'exacerbates'} -> AnatomicalEntity
# NamedThing - {'increases_response_to'} -> AnatomicalEntity
# NamedThing - {'disrupts'} -> AnatomicalEntity
# NamedThing - {'affected_by'} -> AnatomicalEntity
# NamedThing - {'treats'} -> AnatomicalEntity
# NamedThing - {'is_substrate_of'} -> AnatomicalEntity
# NamedThing - {'has_capability'} -> AnatomicalEntity
# NamedThing - {'is_input_of'} -> AnatomicalEntity
# NamedThing - {'decreases_response_to'} -> AnatomicalEntity
# NamedThing - {'expresses'} -> AnatomicalEntity
# NamedThing - {'has_substrate'} -> AnatomicalEntity
# NamedThing - {'ameliorates'} -> AnatomicalEntity
# NamedThing - {'has_metabolite'} -> AnatomicalEntity
# NamedThing - {'genetically_interacts_with'} -> AnatomicalEntity
# NamedThing - {'has_active_ingredient'} -> AnatomicalEntity
# NamedThing - {'has_catalyst'} -> AnatomicalEntity
# NamedThing - {'primarily_composed_of'} -> AnatomicalEntity
# NamedThing - {'expressed_in'} -> AnatomicalEntity
# NamedThing - {'associated_with'} -> AnatomicalEntity
# NamedThing - {'similar_to'} -> AnatomicalEntity
# NamedThing - {'catalyzes'} -> AnatomicalEntity
# NamedThing - {'is_output_of'} -> AnatomicalEntity
# NamedThing - {'affects_response_to'} -> AnatomicalEntity
# NamedThing - {'gene_product_of'} -> AnatomicalEntity
# NamedThing - {'is_sequence_variant_of'} -> AnatomicalEntity
# NamedThing - {'gene_associated_with_condition'} -> AnatomicalEntity
# NamedThing - {'has_phenotype'} -> AnatomicalEntity
# NamedThing - {'binds'} -> AnatomicalEntity
# NamedThing - {'biomarker_for'} -> AnatomicalEntity
# NamedThing - {'prevents'} -> AnatomicalEntity
# NamedThing - {'colocalizes_with'} -> AnatomicalEntity
# NamedThing - {'disease_has_basis_in'} -> AnatomicalEntity
# NamedThing - {'produces'} -> AnatomicalEntity
# NamedThing - {'predisposes'} -> AnatomicalEntity
# NamedThing - {'diagnoses'} -> AnatomicalEntity
# NamedThing - {'close_match'} -> AnatomicalEntity
# NamedThing - {'manifestation_of'} -> AnatomicalEntity
# NamedThing - {'develops_from'} -> AnatomicalEntity
# NamedThing - {'contraindicated_for'} -> AnatomicalEntity
# NamedThing - {'disease_has_location'} -> AnatomicalEntity
# NamedThing - {'directly_physically_interacts_with'} -> AnatomicalEntity
# AnatomicalEntity - {'develops_from'} -> Publication
# AnatomicalEntity - {'interacts_with'} -> Publication
# AnatomicalEntity - {'produces'} -> Publication
# AnatomicalEntity - {'has_part'} -> Publication
# AnatomicalEntity - {'diagnoses'} -> Publication
# AnatomicalEntity - {'related_to'} -> Publication
# AnatomicalEntity - {'affects'} -> Publication
# AnatomicalEntity - {'manifestation_of'} -> Publication
# AnatomicalEntity - {'has_input'} -> Publication
# AnatomicalEntity - {'occurs_in'} -> Publication
# AnatomicalEntity - {'coexists_with'} -> Publication
# AnatomicalEntity - {'close_match'} -> Publication
# AnatomicalEntity - {'disrupts'} -> Publication
# AnatomicalEntity - {'located_in'} -> Publication
# AnatomicalEntity - {'regulates'} -> Publication
# AnatomicalEntity - {'treats'} -> Publication
# AnatomicalEntity - {'causes'} -> Publication
# AnatomicalEntity - {'associated_with'} -> Publication
# AnatomicalEntity - {'gene_associated_with_condition'} -> Publication
# AnatomicalEntity - {'subclass_of'} -> Publication
#
#
# PATH: InformationResource->NamedThing->BiologicalProcess->Publication
# InformationResource - {'associated_with'} -> NamedThing
# InformationResource - {'subclass_of'} -> NamedThing
# NamedThing - {'occurs_together_in_literature_with'} -> BiologicalProcess
# NamedThing - {'subclass_of'} -> BiologicalProcess
# NamedThing - {'active_in'} -> BiologicalProcess
# NamedThing - {'actively_involved_in'} -> BiologicalProcess
# NamedThing - {'actively_involves'} -> BiologicalProcess
# NamedThing - {'acts_upstream_of'} -> BiologicalProcess
# NamedThing - {'acts_upstream_of_negative_effect'} -> BiologicalProcess
# NamedThing - {'acts_upstream_of_or_within'} -> BiologicalProcess
# NamedThing - {'acts_upstream_of_or_within_negative_effect'} -> BiologicalProcess
# NamedThing - {'acts_upstream_of_or_within_positive_effect'} -> BiologicalProcess
# NamedThing - {'acts_upstream_of_positive_effect'} -> BiologicalProcess
# NamedThing - {'affects'} -> BiologicalProcess
# NamedThing - {'capable_of'} -> BiologicalProcess
# NamedThing - {'caused_by'} -> BiologicalProcess
# NamedThing - {'causes'} -> BiologicalProcess
# NamedThing - {'contributes_to'} -> BiologicalProcess
# NamedThing - {'derives_from'} -> BiologicalProcess
# NamedThing - {'derives_into'} -> BiologicalProcess
# NamedThing - {'enabled_by'} -> BiologicalProcess
# NamedThing - {'enables'} -> BiologicalProcess
# NamedThing - {'has_input'} -> BiologicalProcess
# NamedThing - {'has_output'} -> BiologicalProcess
# NamedThing - {'has_part'} -> BiologicalProcess
# NamedThing - {'has_participant'} -> BiologicalProcess
# NamedThing - {'negatively_regulates'} -> BiologicalProcess
# NamedThing - {'occurs_in'} -> BiologicalProcess
# NamedThing - {'overlaps'} -> BiologicalProcess
# NamedThing - {'participates_in'} -> BiologicalProcess
# NamedThing - {'part_of'} -> BiologicalProcess
# NamedThing - {'positively_regulates'} -> BiologicalProcess
# NamedThing - {'preceded_by'} -> BiologicalProcess
# NamedThing - {'precedes'} -> BiologicalProcess
# NamedThing - {'process_negatively_regulates_process'} -> BiologicalProcess
# NamedThing - {'process_positively_regulates_process'} -> BiologicalProcess
# NamedThing - {'process_regulates_process'} -> BiologicalProcess
# NamedThing - {'regulates'} -> BiologicalProcess
# NamedThing - {'related_to'} -> BiologicalProcess
# NamedThing - {'temporally_related_to'} -> BiologicalProcess
# NamedThing - {'is_input_of'} -> BiologicalProcess
# NamedThing - {'decreases_response_to'} -> BiologicalProcess
# NamedThing - {'has_substrate'} -> BiologicalProcess
# NamedThing - {'interacts_with'} -> BiologicalProcess
# NamedThing - {'ameliorates'} -> BiologicalProcess
# NamedThing - {'is_substrate_of'} -> BiologicalProcess
# NamedThing - {'has_capability'} -> BiologicalProcess
# NamedThing - {'has_catalyst'} -> BiologicalProcess
# NamedThing - {'associated_with'} -> BiologicalProcess
# NamedThing - {'catalyzes'} -> BiologicalProcess
# NamedThing - {'affects_response_to'} -> BiologicalProcess
# NamedThing - {'entity_positively_regulates_entity'} -> BiologicalProcess
# NamedThing - {'has_metabolite'} -> BiologicalProcess
# NamedThing - {'composed_primarily_of'} -> BiologicalProcess
# NamedThing - {'has_upstream_actor'} -> BiologicalProcess
# NamedThing - {'affects_transport_of'} -> BiologicalProcess
# NamedThing - {'exacerbates'} -> BiologicalProcess
# NamedThing - {'has_active_ingredient'} -> BiologicalProcess
# NamedThing - {'increases_response_to'} -> BiologicalProcess
# NamedThing - {'primarily_composed_of'} -> BiologicalProcess
# NamedThing - {'disrupts'} -> BiologicalProcess
# NamedThing - {'similar_to'} -> BiologicalProcess
# NamedThing - {'is_output_of'} -> BiologicalProcess
# NamedThing - {'affected_by'} -> BiologicalProcess
# NamedThing - {'treats'} -> BiologicalProcess
# NamedThing - {'close_match'} -> BiologicalProcess
# NamedThing - {'manifestation_of'} -> BiologicalProcess
# NamedThing - {'coexists_with'} -> BiologicalProcess
# NamedThing - {'contraindicated_for'} -> BiologicalProcess
# NamedThing - {'physically_interacts_with'} -> BiologicalProcess
# NamedThing - {'gene_product_of'} -> BiologicalProcess
# NamedThing - {'directly_physically_interacts_with'} -> BiologicalProcess
# NamedThing - {'has_phenotype'} -> BiologicalProcess
# NamedThing - {'binds'} -> BiologicalProcess
# NamedThing - {'is_sequence_variant_of'} -> BiologicalProcess
# NamedThing - {'gene_associated_with_condition'} -> BiologicalProcess
# NamedThing - {'located_in'} -> BiologicalProcess
# NamedThing - {'colocalizes_with'} -> BiologicalProcess
# NamedThing - {'produces'} -> BiologicalProcess
# NamedThing - {'prevents'} -> BiologicalProcess
# NamedThing - {'diagnoses'} -> BiologicalProcess
# NamedThing - {'predisposes'} -> BiologicalProcess
# BiologicalProcess - {'correlated_with'} -> Publication
# BiologicalProcess - {'disrupts'} -> Publication
# BiologicalProcess - {'gene_associated_with_condition'} -> Publication
# BiologicalProcess - {'regulates'} -> Publication
# BiologicalProcess - {'biomarker_for'} -> Publication
# BiologicalProcess - {'has_part'} -> Publication
# BiologicalProcess - {'located_in'} -> Publication
# BiologicalProcess - {'predisposes'} -> Publication
# BiologicalProcess - {'precedes'} -> Publication
# BiologicalProcess - {'prevents'} -> Publication
# BiologicalProcess - {'causes'} -> Publication
# BiologicalProcess - {'close_match'} -> Publication
# BiologicalProcess - {'associated_with'} -> Publication
# BiologicalProcess - {'produces'} -> Publication
# BiologicalProcess - {'has_participant'} -> Publication
# BiologicalProcess - {'subclass_of'} -> Publication
# BiologicalProcess - {'related_to'} -> Publication
# BiologicalProcess - {'affects'} -> Publication
# BiologicalProcess - {'treats'} -> Publication
# BiologicalProcess - {'manifestation_of'} -> Publication
# BiologicalProcess - {'has_input'} -> Publication
# BiologicalProcess - {'has_output'} -> Publication
# BiologicalProcess - {'occurs_in'} -> Publication
# BiologicalProcess - {'coexists_with'} -> Publication
#
#
# PATH: InformationResource->NamedThing->Cell->Publication
# InformationResource - {'associated_with'} -> NamedThing
# InformationResource - {'subclass_of'} -> NamedThing
# NamedThing - {'occurs_together_in_literature_with'} -> Cell
# NamedThing - {'subclass_of'} -> Cell
# NamedThing - {'active_in'} -> Cell
# NamedThing - {'actively_involved_in'} -> Cell
# NamedThing - {'actively_involves'} -> Cell
# NamedThing - {'acts_upstream_of'} -> Cell
# NamedThing - {'acts_upstream_of_or_within_positive_effect'} -> Cell
# NamedThing - {'affects'} -> Cell
# NamedThing - {'capable_of'} -> Cell
# NamedThing - {'causes'} -> Cell
# NamedThing - {'coexists_with'} -> Cell
# NamedThing - {'contributes_to'} -> Cell
# NamedThing - {'derives_from'} -> Cell
# NamedThing - {'derives_into'} -> Cell
# NamedThing - {'has_input'} -> Cell
# NamedThing - {'has_output'} -> Cell
# NamedThing - {'has_part'} -> Cell
# NamedThing - {'has_participant'} -> Cell
# NamedThing - {'occurs_in'} -> Cell
# NamedThing - {'overlaps'} -> Cell
# NamedThing - {'participates_in'} -> Cell
# NamedThing - {'part_of'} -> Cell
# NamedThing - {'produced_by'} -> Cell
# NamedThing - {'regulates'} -> Cell
# NamedThing - {'related_to'} -> Cell
# NamedThing - {'is_output_of'} -> Cell
# NamedThing - {'acts_upstream_of_positive_effect'} -> Cell
# NamedThing - {'affects_response_to'} -> Cell
# NamedThing - {'location_of'} -> Cell
# NamedThing - {'entity_positively_regulates_entity'} -> Cell
# NamedThing - {'located_in'} -> Cell
# NamedThing - {'composed_primarily_of'} -> Cell
# NamedThing - {'preceded_by'} -> Cell
# NamedThing - {'disrupts'} -> Cell
# NamedThing - {'acts_upstream_of_negative_effect'} -> Cell
# NamedThing - {'acts_upstream_of_or_within'} -> Cell
# NamedThing - {'affected_by'} -> Cell
# NamedThing - {'has_substrate'} -> Cell
# NamedThing - {'interacts_with'} -> Cell
# NamedThing - {'ameliorates'} -> Cell
# NamedThing - {'treats'} -> Cell
# NamedThing - {'is_substrate_of'} -> Cell
# NamedThing - {'has_capability'} -> Cell
# NamedThing - {'acts_upstream_of_or_within_negative_effect'} -> Cell
# NamedThing - {'caused_by'} -> Cell
# NamedThing - {'enabled_by'} -> Cell
# NamedThing - {'has_catalyst'} -> Cell
# NamedThing - {'is_input_of'} -> Cell
# NamedThing - {'decreases_response_to'} -> Cell
# NamedThing - {'associated_with'} -> Cell
# NamedThing - {'enables'} -> Cell
# NamedThing - {'physically_interacts_with'} -> Cell
# NamedThing - {'catalyzes'} -> Cell
# NamedThing - {'expresses'} -> Cell
# NamedThing - {'precedes'} -> Cell
# NamedThing - {'has_metabolite'} -> Cell
# NamedThing - {'genetically_interacts_with'} -> Cell
# NamedThing - {'has_upstream_actor'} -> Cell
# NamedThing - {'exacerbates'} -> Cell
# NamedThing - {'has_active_ingredient'} -> Cell
# NamedThing - {'increases_response_to'} -> Cell
# NamedThing - {'primarily_composed_of'} -> Cell
# NamedThing - {'expressed_in'} -> Cell
# NamedThing - {'temporally_related_to'} -> Cell
# NamedThing - {'similar_to'} -> Cell
# NamedThing - {'disease_has_location'} -> Cell
# NamedThing - {'correlated_with'} -> Cell
# NamedThing - {'gene_associated_with_condition'} -> Cell
# NamedThing - {'has_phenotype'} -> Cell
# NamedThing - {'biomarker_for'} -> Cell
# NamedThing - {'prevents'} -> Cell
# NamedThing - {'produces'} -> Cell
# NamedThing - {'predisposes'} -> Cell
# NamedThing - {'diagnoses'} -> Cell
# NamedThing - {'close_match'} -> Cell
# NamedThing - {'manifestation_of'} -> Cell
# Cell - {'subclass_of'} -> Publication
# Cell - {'has_part'} -> Publication
# Cell - {'produces'} -> Publication
# Cell - {'related_to'} -> Publication
# Cell - {'occurs_in'} -> Publication
# Cell - {'affects'} -> Publication
# Cell - {'coexists_with'} -> Publication
# Cell - {'close_match'} -> Publication
# Cell - {'located_in'} -> Publication
# Cell - {'treats'} -> Publication
#
#
# PATH: InformationResource->NamedThing->CellularComponent->Publication
# InformationResource - {'associated_with'} -> NamedThing
# InformationResource - {'subclass_of'} -> NamedThing
# NamedThing - {'occurs_together_in_literature_with'} -> CellularComponent
# NamedThing - {'subclass_of'} -> CellularComponent
# NamedThing - {'active_in'} -> CellularComponent
# NamedThing - {'actively_involved_in'} -> CellularComponent
# NamedThing - {'actively_involves'} -> CellularComponent
# NamedThing - {'acts_upstream_of'} -> CellularComponent
# NamedThing - {'acts_upstream_of_negative_effect'} -> CellularComponent
# NamedThing - {'acts_upstream_of_or_within'} -> CellularComponent
# NamedThing - {'acts_upstream_of_or_within_negative_effect'} -> CellularComponent
# NamedThing - {'acts_upstream_of_or_within_positive_effect'} -> CellularComponent
# NamedThing - {'acts_upstream_of_positive_effect'} -> CellularComponent
# NamedThing - {'affects_activity_of'} -> CellularComponent
# NamedThing - {'affects'} -> CellularComponent
# NamedThing - {'affects_transport_of'} -> CellularComponent
# NamedThing - {'capable_of'} -> CellularComponent
# NamedThing - {'caused_by'} -> CellularComponent
# NamedThing - {'coexists_with'} -> CellularComponent
# NamedThing - {'enabled_by'} -> CellularComponent
# NamedThing - {'enables'} -> CellularComponent
# NamedThing - {'entity_negatively_regulates_entity'} -> CellularComponent
# NamedThing - {'entity_positively_regulates_entity'} -> CellularComponent
# NamedThing - {'entity_regulates_entity'} -> CellularComponent
# NamedThing - {'has_input'} -> CellularComponent
# NamedThing - {'has_output'} -> CellularComponent
# NamedThing - {'has_part'} -> CellularComponent
# NamedThing - {'has_participant'} -> CellularComponent
# NamedThing - {'interacts_with'} -> CellularComponent
# NamedThing - {'located_in'} -> CellularComponent
# NamedThing - {'molecularly_interacts_with'} -> CellularComponent
# NamedThing - {'negatively_regulates'} -> CellularComponent
# NamedThing - {'occurs_in'} -> CellularComponent
# NamedThing - {'overlaps'} -> CellularComponent
# NamedThing - {'participates_in'} -> CellularComponent
# NamedThing - {'part_of'} -> CellularComponent
# NamedThing - {'physically_interacts_with'} -> CellularComponent
# NamedThing - {'positively_regulates'} -> CellularComponent
# NamedThing - {'preceded_by'} -> CellularComponent
# NamedThing - {'precedes'} -> CellularComponent
# NamedThing - {'process_negatively_regulates_process'} -> CellularComponent
# NamedThing - {'process_positively_regulates_process'} -> CellularComponent
# NamedThing - {'process_regulates_process'} -> CellularComponent
# NamedThing - {'regulates'} -> CellularComponent
# NamedThing - {'related_to'} -> CellularComponent
# NamedThing - {'temporally_related_to'} -> CellularComponent
# NamedThing - {'is_output_of'} -> CellularComponent
# NamedThing - {'affects_response_to'} -> CellularComponent
# NamedThing - {'composed_primarily_of'} -> CellularComponent
# NamedThing - {'has_upstream_actor'} -> CellularComponent
# NamedThing - {'exacerbates'} -> CellularComponent
# NamedThing - {'increases_response_to'} -> CellularComponent
# NamedThing - {'disrupts'} -> CellularComponent
# NamedThing - {'affected_by'} -> CellularComponent
# NamedThing - {'treats'} -> CellularComponent
# NamedThing - {'causes'} -> CellularComponent
# NamedThing - {'is_substrate_of'} -> CellularComponent
# NamedThing - {'has_capability'} -> CellularComponent
# NamedThing - {'contributes_to'} -> CellularComponent
# NamedThing - {'is_input_of'} -> CellularComponent
# NamedThing - {'decreases_response_to'} -> CellularComponent
# NamedThing - {'has_substrate'} -> CellularComponent
# NamedThing - {'ameliorates'} -> CellularComponent
# NamedThing - {'genetically_interacts_with'} -> CellularComponent
# NamedThing - {'has_active_ingredient'} -> CellularComponent
# NamedThing - {'has_catalyst'} -> CellularComponent
# NamedThing - {'primarily_composed_of'} -> CellularComponent
# NamedThing - {'expressed_in'} -> CellularComponent
# NamedThing - {'associated_with'} -> CellularComponent
# NamedThing - {'similar_to'} -> CellularComponent
# NamedThing - {'catalyzes'} -> CellularComponent
# NamedThing - {'manifestation_of'} -> CellularComponent
# NamedThing - {'close_match'} -> CellularComponent
# NamedThing - {'derives_from'} -> CellularComponent
# NamedThing - {'disease_has_location'} -> CellularComponent
# NamedThing - {'gene_associated_with_condition'} -> CellularComponent
# NamedThing - {'produces'} -> CellularComponent
# NamedThing - {'prevents'} -> CellularComponent
# NamedThing - {'diagnoses'} -> CellularComponent
# NamedThing - {'colocalizes_with'} -> CellularComponent
# NamedThing - {'predisposes'} -> CellularComponent
# CellularComponent - {'subclass_of'} -> Publication
# CellularComponent - {'produces'} -> Publication
# CellularComponent - {'has_part'} -> Publication
# CellularComponent - {'related_to'} -> Publication
# CellularComponent - {'occurs_in'} -> Publication
# CellularComponent - {'affects'} -> Publication
# CellularComponent - {'regulates'} -> Publication
# CellularComponent - {'disrupts'} -> Publication
# CellularComponent - {'located_in'} -> Publication
# CellularComponent - {'associated_with'} -> Publication
# CellularComponent - {'close_match'} -> Publication
#
#
# PATH: InformationResource->NamedThing->ChemicalEntity->Publication
# InformationResource - {'associated_with'} -> NamedThing
# InformationResource - {'subclass_of'} -> NamedThing
# NamedThing - {'occurs_together_in_literature_with'} -> ChemicalEntity
# NamedThing - {'is_input_of'} -> ChemicalEntity
# NamedThing - {'subclass_of'} -> ChemicalEntity
# NamedThing - {'has_capability'} -> ChemicalEntity
# NamedThing - {'contributes_to'} -> ChemicalEntity
# NamedThing - {'decreases_response_to'} -> ChemicalEntity
# NamedThing - {'associated_with'} -> ChemicalEntity
# NamedThing - {'expresses'} -> ChemicalEntity
# NamedThing - {'has_substrate'} -> ChemicalEntity
# NamedThing - {'ameliorates'} -> ChemicalEntity
# NamedThing - {'genetically_interacts_with'} -> ChemicalEntity
# NamedThing - {'actively_involves'} -> ChemicalEntity
# NamedThing - {'has_active_ingredient'} -> ChemicalEntity
# NamedThing - {'has_catalyst'} -> ChemicalEntity
# NamedThing - {'primarily_composed_of'} -> ChemicalEntity
# NamedThing - {'similar_to'} -> ChemicalEntity
# NamedThing - {'catalyzes'} -> ChemicalEntity
# NamedThing - {'is_output_of'} -> ChemicalEntity
# NamedThing - {'affects_response_to'} -> ChemicalEntity
# NamedThing - {'composed_primarily_of'} -> ChemicalEntity
# NamedThing - {'has_upstream_actor'} -> ChemicalEntity
# NamedThing - {'exacerbates'} -> ChemicalEntity
# NamedThing - {'increases_response_to'} -> ChemicalEntity
# NamedThing - {'disrupts'} -> ChemicalEntity
# NamedThing - {'affected_by'} -> ChemicalEntity
# NamedThing - {'treats'} -> ChemicalEntity
# NamedThing - {'causes'} -> ChemicalEntity
# NamedThing - {'is_substrate_of'} -> ChemicalEntity
# NamedThing - {'active_in'} -> ChemicalEntity
# NamedThing - {'actively_involved_in'} -> ChemicalEntity
# NamedThing - {'acts_upstream_of'} -> ChemicalEntity
# NamedThing - {'acts_upstream_of_negative_effect'} -> ChemicalEntity
# NamedThing - {'acts_upstream_of_or_within'} -> ChemicalEntity
# NamedThing - {'acts_upstream_of_or_within_negative_effect'} -> ChemicalEntity
# NamedThing - {'acts_upstream_of_or_within_positive_effect'} -> ChemicalEntity
# NamedThing - {'acts_upstream_of_positive_effect'} -> ChemicalEntity
# NamedThing - {'affects_activity_of'} -> ChemicalEntity
# NamedThing - {'affects'} -> ChemicalEntity
# NamedThing - {'affects_transport_of'} -> ChemicalEntity
# NamedThing - {'capable_of'} -> ChemicalEntity
# NamedThing - {'caused_by'} -> ChemicalEntity
# NamedThing - {'enabled_by'} -> ChemicalEntity
# NamedThing - {'enables'} -> ChemicalEntity
# NamedThing - {'entity_negatively_regulates_entity'} -> ChemicalEntity
# NamedThing - {'entity_positively_regulates_entity'} -> ChemicalEntity
# NamedThing - {'entity_regulates_entity'} -> ChemicalEntity
# NamedThing - {'has_input'} -> ChemicalEntity
# NamedThing - {'has_output'} -> ChemicalEntity
# NamedThing - {'has_part'} -> ChemicalEntity
# NamedThing - {'has_participant'} -> ChemicalEntity
# NamedThing - {'interacts_with'} -> ChemicalEntity
# NamedThing - {'location_of'} -> ChemicalEntity
# NamedThing - {'molecularly_interacts_with'} -> ChemicalEntity
# NamedThing - {'negatively_regulates'} -> ChemicalEntity
# NamedThing - {'occurs_in'} -> ChemicalEntity
# NamedThing - {'overlaps'} -> ChemicalEntity
# NamedThing - {'participates_in'} -> ChemicalEntity
# NamedThing - {'part_of'} -> ChemicalEntity
# NamedThing - {'physically_interacts_with'} -> ChemicalEntity
# NamedThing - {'positively_regulates'} -> ChemicalEntity
# NamedThing - {'preceded_by'} -> ChemicalEntity
# NamedThing - {'precedes'} -> ChemicalEntity
# NamedThing - {'process_negatively_regulates_process'} -> ChemicalEntity
# NamedThing - {'process_positively_regulates_process'} -> ChemicalEntity
# NamedThing - {'process_regulates_process'} -> ChemicalEntity
# NamedThing - {'regulates'} -> ChemicalEntity
# NamedThing - {'related_to'} -> ChemicalEntity
# NamedThing - {'temporally_related_to'} -> ChemicalEntity
# NamedThing - {'manifestation_of'} -> ChemicalEntity
# NamedThing - {'coexists_with'} -> ChemicalEntity
# NamedThing - {'has_metabolite'} -> ChemicalEntity
# NamedThing - {'contraindicated_for'} -> ChemicalEntity
# NamedThing - {'chemically_similar_to'} -> ChemicalEntity
# NamedThing - {'derives_from'} -> ChemicalEntity
# NamedThing - {'in_taxon'} -> ChemicalEntity
# NamedThing - {'disease_has_location'} -> ChemicalEntity
# NamedThing - {'gene_product_of'} -> ChemicalEntity
# NamedThing - {'directly_physically_interacts_with'} -> ChemicalEntity
# NamedThing - {'has_phenotype'} -> ChemicalEntity
# NamedThing - {'binds'} -> ChemicalEntity
# NamedThing - {'is_sequence_variant_of'} -> ChemicalEntity
# NamedThing - {'biomarker_for'} -> ChemicalEntity
# NamedThing - {'correlated_with'} -> ChemicalEntity
# NamedThing - {'gene_associated_with_condition'} -> ChemicalEntity
# NamedThing - {'located_in'} -> ChemicalEntity
# NamedThing - {'colocalizes_with'} -> ChemicalEntity
# NamedThing - {'produces'} -> ChemicalEntity
# NamedThing - {'expressed_in'} -> ChemicalEntity
# NamedThing - {'prevents'} -> ChemicalEntity
# NamedThing - {'diagnoses'} -> ChemicalEntity
# NamedThing - {'predisposes'} -> ChemicalEntity
# NamedThing - {'same_as'} -> ChemicalEntity
# NamedThing - {'close_match'} -> ChemicalEntity
# ChemicalEntity - {'correlated_with'} -> Publication
# ChemicalEntity - {'disrupts'} -> Publication
# ChemicalEntity - {'associated_with'} -> Publication
# ChemicalEntity - {'directly_physically_interacts_with'} -> Publication
# ChemicalEntity - {'gene_associated_with_condition'} -> Publication
# ChemicalEntity - {'regulates'} -> Publication
# ChemicalEntity - {'located_in'} -> Publication
# ChemicalEntity - {'predisposes'} -> Publication
# ChemicalEntity - {'related_to'} -> Publication
# ChemicalEntity - {'has_part'} -> Publication
# ChemicalEntity - {'prevents'} -> Publication
# ChemicalEntity - {'affects'} -> Publication
# ChemicalEntity - {'precedes'} -> Publication
# ChemicalEntity - {'occurs_in'} -> Publication
# ChemicalEntity - {'has_metabolite'} -> Publication
# ChemicalEntity - {'close_match'} -> Publication
# ChemicalEntity - {'subclass_of'} -> Publication
# ChemicalEntity - {'interacts_with'} -> Publication
# ChemicalEntity - {'treats'} -> Publication
# ChemicalEntity - {'physically_interacts_with'} -> Publication
# ChemicalEntity - {'has_input'} -> Publication
# ChemicalEntity - {'causes'} -> Publication
# ChemicalEntity - {'coexists_with'} -> Publication
#
#
# PATH: InformationResource->NamedThing->ChemicalMixture->Publication
# InformationResource - {'associated_with'} -> NamedThing
# InformationResource - {'subclass_of'} -> NamedThing
# NamedThing - {'occurs_together_in_literature_with'} -> ChemicalMixture
# NamedThing - {'subclass_of'} -> ChemicalMixture
# NamedThing - {'has_input'} -> ChemicalMixture
# NamedThing - {'has_output'} -> ChemicalMixture
# NamedThing - {'has_participant'} -> ChemicalMixture
# NamedThing - {'preceded_by'} -> ChemicalMixture
# NamedThing - {'related_to'} -> ChemicalMixture
# NamedThing - {'temporally_related_to'} -> ChemicalMixture
# NamedThing - {'increases_response_to'} -> ChemicalMixture
# NamedThing - {'has_capability'} -> ChemicalMixture
# NamedThing - {'participates_in'} -> ChemicalMixture
# NamedThing - {'enabled_by'} -> ChemicalMixture
# NamedThing - {'is_input_of'} -> ChemicalMixture
# NamedThing - {'decreases_response_to'} -> ChemicalMixture
# NamedThing - {'enables'} -> ChemicalMixture
# NamedThing - {'has_part'} -> ChemicalMixture
# NamedThing - {'has_substrate'} -> ChemicalMixture
# NamedThing - {'precedes'} -> ChemicalMixture
# NamedThing - {'interacts_with'} -> ChemicalMixture
# NamedThing - {'ameliorates'} -> ChemicalMixture
# NamedThing - {'capable_of'} -> ChemicalMixture
# NamedThing - {'actively_involves'} -> ChemicalMixture
# NamedThing - {'has_active_ingredient'} -> ChemicalMixture
# NamedThing - {'has_catalyst'} -> ChemicalMixture
# NamedThing - {'primarily_composed_of'} -> ChemicalMixture
# NamedThing - {'actively_involved_in'} -> ChemicalMixture
# NamedThing - {'associated_with'} -> ChemicalMixture
# NamedThing - {'affects'} -> ChemicalMixture
# NamedThing - {'similar_to'} -> ChemicalMixture
# NamedThing - {'catalyzes'} -> ChemicalMixture
# NamedThing - {'is_output_of'} -> ChemicalMixture
# NamedThing - {'overlaps'} -> ChemicalMixture
# NamedThing - {'affects_response_to'} -> ChemicalMixture
# NamedThing - {'composed_primarily_of'} -> ChemicalMixture
# NamedThing - {'has_upstream_actor'} -> ChemicalMixture
# NamedThing - {'exacerbates'} -> ChemicalMixture
# NamedThing - {'disrupts'} -> ChemicalMixture
# NamedThing - {'affected_by'} -> ChemicalMixture
# NamedThing - {'treats'} -> ChemicalMixture
# NamedThing - {'regulates'} -> ChemicalMixture
# NamedThing - {'is_substrate_of'} -> ChemicalMixture
# NamedThing - {'part_of'} -> ChemicalMixture
# NamedThing - {'produces'} -> ChemicalMixture
# NamedThing - {'coexists_with'} -> ChemicalMixture
# NamedThing - {'close_match'} -> ChemicalMixture
# NamedThing - {'derives_from'} -> ChemicalMixture
# ChemicalMixture - {'related_to'} -> Publication
# ChemicalMixture - {'affects'} -> Publication
# ChemicalMixture - {'subclass_of'} -> Publication
# ChemicalMixture - {'treats'} -> Publication
#
#
# PATH: InformationResource->NamedThing->ComplexMolecularMixture->Publication
# InformationResource - {'associated_with'} -> NamedThing
# InformationResource - {'subclass_of'} -> NamedThing
# NamedThing - {'occurs_together_in_literature_with'} -> ComplexMolecularMixture
# NamedThing - {'affects_response_to'} -> ComplexMolecularMixture
# NamedThing - {'composed_primarily_of'} -> ComplexMolecularMixture
# NamedThing - {'affected_by'} -> ComplexMolecularMixture
# NamedThing - {'interacts_with'} -> ComplexMolecularMixture
# NamedThing - {'part_of'} -> ComplexMolecularMixture
# NamedThing - {'participates_in'} -> ComplexMolecularMixture
# NamedThing - {'has_participant'} -> ComplexMolecularMixture
# NamedThing - {'decreases_response_to'} -> ComplexMolecularMixture
# NamedThing - {'associated_with'} -> ComplexMolecularMixture
# NamedThing - {'has_part'} -> ComplexMolecularMixture
# NamedThing - {'has_upstream_actor'} -> ComplexMolecularMixture
# NamedThing - {'has_active_ingredient'} -> ComplexMolecularMixture
# NamedThing - {'increases_response_to'} -> ComplexMolecularMixture
# NamedThing - {'primarily_composed_of'} -> ComplexMolecularMixture
# NamedThing - {'affects'} -> ComplexMolecularMixture
# NamedThing - {'similar_to'} -> ComplexMolecularMixture
# NamedThing - {'related_to'} -> ComplexMolecularMixture
# NamedThing - {'overlaps'} -> ComplexMolecularMixture
# NamedThing - {'regulates'} -> ComplexMolecularMixture
# NamedThing - {'subclass_of'} -> ComplexMolecularMixture
# NamedThing - {'coexists_with'} -> ComplexMolecularMixture
# NamedThing - {'close_match'} -> ComplexMolecularMixture
# ComplexMolecularMixture - {'correlated_with'} -> Publication
# ComplexMolecularMixture - {'subclass_of'} -> Publication
# ComplexMolecularMixture - {'treats'} -> Publication
# ComplexMolecularMixture - {'related_to'} -> Publication
#
#
# PATH: InformationResource->NamedThing->Disease->Publication
# InformationResource - {'associated_with'} -> NamedThing
# InformationResource - {'subclass_of'} -> NamedThing
# NamedThing - {'occurs_together_in_literature_with'} -> Disease
# NamedThing - {'subclass_of'} -> Disease
# NamedThing - {'related_to'} -> Disease
# NamedThing - {'location_of'} -> Disease
# NamedThing - {'entity_positively_regulates_entity'} -> Disease
# NamedThing - {'process_positively_regulates_process'} -> Disease
# NamedThing - {'has_upstream_actor'} -> Disease
# NamedThing - {'process_negatively_regulates_process'} -> Disease
# NamedThing - {'exacerbates'} -> Disease
# NamedThing - {'has_active_ingredient'} -> Disease
# NamedThing - {'increases_response_to'} -> Disease
# NamedThing - {'primarily_composed_of'} -> Disease
# NamedThing - {'temporally_related_to'} -> Disease
# NamedThing - {'actively_involved_in'} -> Disease
# NamedThing - {'has_output'} -> Disease
# NamedThing - {'affects'} -> Disease
# NamedThing - {'process_regulates_process'} -> Disease
# NamedThing - {'disrupts'} -> Disease
# NamedThing - {'similar_to'} -> Disease
# NamedThing - {'is_output_of'} -> Disease
# NamedThing - {'affects_response_to'} -> Disease
# NamedThing - {'treats'} -> Disease
# NamedThing - {'causes'} -> Disease
# NamedThing - {'composed_primarily_of'} -> Disease
# NamedThing - {'enabled_by'} -> Disease
# NamedThing - {'has_participant'} -> Disease
# NamedThing - {'is_input_of'} -> Disease
# NamedThing - {'expresses'} -> Disease
# NamedThing - {'affected_by'} -> Disease
# NamedThing - {'has_substrate'} -> Disease
# NamedThing - {'interacts_with'} -> Disease
# NamedThing - {'ameliorates'} -> Disease
# NamedThing - {'regulates'} -> Disease
# NamedThing - {'is_substrate_of'} -> Disease
# NamedThing - {'part_of'} -> Disease
# NamedThing - {'has_capability'} -> Disease
# NamedThing - {'participates_in'} -> Disease
# NamedThing - {'capable_of'} -> Disease
# NamedThing - {'contributes_to'} -> Disease
# NamedThing - {'caused_by'} -> Disease
# NamedThing - {'actively_involves'} -> Disease
# NamedThing - {'has_input'} -> Disease
# NamedThing - {'has_catalyst'} -> Disease
# NamedThing - {'decreases_response_to'} -> Disease
# NamedThing - {'associated_with'} -> Disease
# NamedThing - {'enables'} -> Disease
# NamedThing - {'has_part'} -> Disease
# NamedThing - {'catalyzes'} -> Disease
# NamedThing - {'precedes'} -> Disease
# NamedThing - {'overlaps'} -> Disease
# NamedThing - {'gene_product_of'} -> Disease
# NamedThing - {'directly_physically_interacts_with'} -> Disease
# NamedThing - {'has_phenotype'} -> Disease
# NamedThing - {'binds'} -> Disease
# NamedThing - {'is_sequence_variant_of'} -> Disease
# NamedThing - {'biomarker_for'} -> Disease
# NamedThing - {'correlated_with'} -> Disease
# NamedThing - {'gene_associated_with_condition'} -> Disease
# NamedThing - {'located_in'} -> Disease
# NamedThing - {'colocalizes_with'} -> Disease
# NamedThing - {'produces'} -> Disease
# NamedThing - {'expressed_in'} -> Disease
# NamedThing - {'prevents'} -> Disease
# NamedThing - {'diagnoses'} -> Disease
# NamedThing - {'predisposes'} -> Disease
# NamedThing - {'occurs_in'} -> Disease
# NamedThing - {'manifestation_of'} -> Disease
# NamedThing - {'coexists_with'} -> Disease
# NamedThing - {'close_match'} -> Disease
# NamedThing - {'contraindicated_for'} -> Disease
# NamedThing - {'chemically_similar_to'} -> Disease
# NamedThing - {'physically_interacts_with'} -> Disease
# NamedThing - {'derives_from'} -> Disease
# NamedThing - {'disease_has_location'} -> Disease
# Disease - {'correlated_with'} -> Publication
# Disease - {'associated_with'} -> Publication
# Disease - {'gene_associated_with_condition'} -> Publication
# Disease - {'subclass_of'} -> Publication
# Disease - {'has_part'} -> Publication
# Disease - {'interacts_with'} -> Publication
# Disease - {'produces'} -> Publication
# Disease - {'predisposes'} -> Publication
# Disease - {'related_to'} -> Publication
# Disease - {'prevents'} -> Publication
# Disease - {'diagnoses'} -> Publication
# Disease - {'contributes_to'} -> Publication
# Disease - {'manifestation_of'} -> Publication
# Disease - {'occurs_in'} -> Publication
# Disease - {'affects'} -> Publication
# Disease - {'has_input'} -> Publication
# Disease - {'exacerbates'} -> Publication
# Disease - {'coexists_with'} -> Publication
# Disease - {'close_match'} -> Publication
# Disease - {'disrupts'} -> Publication
# Disease - {'regulates'} -> Publication
# Disease - {'biomarker_for'} -> Publication
# Disease - {'located_in'} -> Publication
# Disease - {'treats'} -> Publication
# Disease - {'causes'} -> Publication
# Disease - {'disease_has_location'} -> Publication
# Disease - {'precedes'} -> Publication
#
#
# PATH: InformationResource->NamedThing->GrossAnatomicalStructure->Publication
# InformationResource - {'associated_with'} -> NamedThing
# InformationResource - {'subclass_of'} -> NamedThing
# NamedThing - {'occurs_together_in_literature_with'} -> GrossAnatomicalStructure
# NamedThing - {'subclass_of'} -> GrossAnatomicalStructure
# NamedThing - {'active_in'} -> GrossAnatomicalStructure
# NamedThing - {'actively_involved_in'} -> GrossAnatomicalStructure
# NamedThing - {'actively_involves'} -> GrossAnatomicalStructure
# NamedThing - {'acts_upstream_of'} -> GrossAnatomicalStructure
# NamedThing - {'acts_upstream_of_or_within_positive_effect'} -> GrossAnatomicalStructure
# NamedThing - {'affects'} -> GrossAnatomicalStructure
# NamedThing - {'capable_of'} -> GrossAnatomicalStructure
# NamedThing - {'coexists_with'} -> GrossAnatomicalStructure
# NamedThing - {'has_output'} -> GrossAnatomicalStructure
# NamedThing - {'has_part'} -> GrossAnatomicalStructure
# NamedThing - {'has_participant'} -> GrossAnatomicalStructure
# NamedThing - {'located_in'} -> GrossAnatomicalStructure
# NamedThing - {'occurs_in'} -> GrossAnatomicalStructure
# NamedThing - {'overlaps'} -> GrossAnatomicalStructure
# NamedThing - {'participates_in'} -> GrossAnatomicalStructure
# NamedThing - {'part_of'} -> GrossAnatomicalStructure
# NamedThing - {'regulates'} -> GrossAnatomicalStructure
# NamedThing - {'related_to'} -> GrossAnatomicalStructure
# NamedThing - {'disrupts'} -> GrossAnatomicalStructure
# NamedThing - {'acts_upstream_of_or_within'} -> GrossAnatomicalStructure
# NamedThing - {'affected_by'} -> GrossAnatomicalStructure
# NamedThing - {'acts_upstream_of_positive_effect'} -> GrossAnatomicalStructure
# NamedThing - {'produced_by'} -> GrossAnatomicalStructure
# NamedThing - {'treats'} -> GrossAnatomicalStructure
# NamedThing - {'causes'} -> GrossAnatomicalStructure
# NamedThing - {'is_substrate_of'} -> GrossAnatomicalStructure
# NamedThing - {'has_capability'} -> GrossAnatomicalStructure
# NamedThing - {'acts_upstream_of_or_within_negative_effect'} -> GrossAnatomicalStructure
# NamedThing - {'contributes_to'} -> GrossAnatomicalStructure
# NamedThing - {'has_input'} -> GrossAnatomicalStructure
# NamedThing - {'preceded_by'} -> GrossAnatomicalStructure
# NamedThing - {'enabled_by'} -> GrossAnatomicalStructure
# NamedThing - {'is_input_of'} -> GrossAnatomicalStructure
# NamedThing - {'decreases_response_to'} -> GrossAnatomicalStructure
# NamedThing - {'acts_upstream_of_negative_effect'} -> GrossAnatomicalStructure
# NamedThing - {'enables'} -> GrossAnatomicalStructure
# NamedThing - {'expresses'} -> GrossAnatomicalStructure
# NamedThing - {'has_substrate'} -> GrossAnatomicalStructure
# NamedThing - {'precedes'} -> GrossAnatomicalStructure
# NamedThing - {'interacts_with'} -> GrossAnatomicalStructure
# NamedThing - {'ameliorates'} -> GrossAnatomicalStructure
# NamedThing - {'caused_by'} -> GrossAnatomicalStructure
# NamedThing - {'has_active_ingredient'} -> GrossAnatomicalStructure
# NamedThing - {'has_catalyst'} -> GrossAnatomicalStructure
# NamedThing - {'primarily_composed_of'} -> GrossAnatomicalStructure
# NamedThing - {'expressed_in'} -> GrossAnatomicalStructure
# NamedThing - {'temporally_related_to'} -> GrossAnatomicalStructure
# NamedThing - {'associated_with'} -> GrossAnatomicalStructure
# NamedThing - {'similar_to'} -> GrossAnatomicalStructure
# NamedThing - {'catalyzes'} -> GrossAnatomicalStructure
# NamedThing - {'is_output_of'} -> GrossAnatomicalStructure
# NamedThing - {'affects_response_to'} -> GrossAnatomicalStructure
# NamedThing - {'location_of'} -> GrossAnatomicalStructure
# NamedThing - {'entity_positively_regulates_entity'} -> GrossAnatomicalStructure
# NamedThing - {'composed_primarily_of'} -> GrossAnatomicalStructure
# NamedThing - {'has_upstream_actor'} -> GrossAnatomicalStructure
# NamedThing - {'exacerbates'} -> GrossAnatomicalStructure
# NamedThing - {'increases_response_to'} -> GrossAnatomicalStructure
# NamedThing - {'disease_has_basis_in'} -> GrossAnatomicalStructure
# NamedThing - {'predisposes'} -> GrossAnatomicalStructure
# NamedThing - {'close_match'} -> GrossAnatomicalStructure
# NamedThing - {'manifestation_of'} -> GrossAnatomicalStructure
# NamedThing - {'develops_from'} -> GrossAnatomicalStructure
# NamedThing - {'contraindicated_for'} -> GrossAnatomicalStructure
# NamedThing - {'physically_interacts_with'} -> GrossAnatomicalStructure
# NamedThing - {'derives_from'} -> GrossAnatomicalStructure
# NamedThing - {'disease_has_location'} -> GrossAnatomicalStructure
# NamedThing - {'directly_physically_interacts_with'} -> GrossAnatomicalStructure
# NamedThing - {'has_phenotype'} -> GrossAnatomicalStructure
# NamedThing - {'is_sequence_variant_of'} -> GrossAnatomicalStructure
# NamedThing - {'biomarker_for'} -> GrossAnatomicalStructure
# NamedThing - {'gene_associated_with_condition'} -> GrossAnatomicalStructure
# NamedThing - {'colocalizes_with'} -> GrossAnatomicalStructure
# NamedThing - {'produces'} -> GrossAnatomicalStructure
# NamedThing - {'prevents'} -> GrossAnatomicalStructure
# NamedThing - {'diagnoses'} -> GrossAnatomicalStructure
# GrossAnatomicalStructure - {'affects'} -> Publication
# GrossAnatomicalStructure - {'coexists_with'} -> Publication
# GrossAnatomicalStructure - {'close_match'} -> Publication
# GrossAnatomicalStructure - {'develops_from'} -> Publication
# GrossAnatomicalStructure - {'regulates'} -> Publication
# GrossAnatomicalStructure - {'has_input'} -> Publication
# GrossAnatomicalStructure - {'associated_with'} -> Publication
# GrossAnatomicalStructure - {'located_in'} -> Publication
# GrossAnatomicalStructure - {'subclass_of'} -> Publication
# GrossAnatomicalStructure - {'has_part'} -> Publication
# GrossAnatomicalStructure - {'produces'} -> Publication
# GrossAnatomicalStructure - {'related_to'} -> Publication
# GrossAnatomicalStructure - {'occurs_in'} -> Publication
#
#
# PATH: InformationResource->NamedThing->MolecularActivity->Publication
# InformationResource - {'associated_with'} -> NamedThing
# InformationResource - {'subclass_of'} -> NamedThing
# NamedThing - {'occurs_together_in_literature_with'} -> MolecularActivity
# NamedThing - {'subclass_of'} -> MolecularActivity
# NamedThing - {'active_in'} -> MolecularActivity
# NamedThing - {'actively_involved_in'} -> MolecularActivity
# NamedThing - {'actively_involves'} -> MolecularActivity
# NamedThing - {'acts_upstream_of'} -> MolecularActivity
# NamedThing - {'acts_upstream_of_negative_effect'} -> MolecularActivity
# NamedThing - {'acts_upstream_of_or_within'} -> MolecularActivity
# NamedThing - {'acts_upstream_of_or_within_negative_effect'} -> MolecularActivity
# NamedThing - {'acts_upstream_of_or_within_positive_effect'} -> MolecularActivity
# NamedThing - {'acts_upstream_of_positive_effect'} -> MolecularActivity
# NamedThing - {'affects_activity_of'} -> MolecularActivity
# NamedThing - {'affects'} -> MolecularActivity
# NamedThing - {'affects_transport_of'} -> MolecularActivity
# NamedThing - {'capable_of'} -> MolecularActivity
# NamedThing - {'caused_by'} -> MolecularActivity
# NamedThing - {'contributes_to'} -> MolecularActivity
# NamedThing - {'enabled_by'} -> MolecularActivity
# NamedThing - {'enables'} -> MolecularActivity
# NamedThing - {'entity_positively_regulates_entity'} -> MolecularActivity
# NamedThing - {'entity_regulates_entity'} -> MolecularActivity
# NamedThing - {'has_input'} -> MolecularActivity
# NamedThing - {'has_participant'} -> MolecularActivity
# NamedThing - {'has_part'} -> MolecularActivity
# NamedThing - {'interacts_with'} -> MolecularActivity
# NamedThing - {'molecularly_interacts_with'} -> MolecularActivity
# NamedThing - {'negatively_regulates'} -> MolecularActivity
# NamedThing - {'occurs_in'} -> MolecularActivity
# NamedThing - {'overlaps'} -> MolecularActivity
# NamedThing - {'participates_in'} -> MolecularActivity
# NamedThing - {'part_of'} -> MolecularActivity
# NamedThing - {'physically_interacts_with'} -> MolecularActivity
# NamedThing - {'positively_regulates'} -> MolecularActivity
# NamedThing - {'preceded_by'} -> MolecularActivity
# NamedThing - {'precedes'} -> MolecularActivity
# NamedThing - {'process_negatively_regulates_process'} -> MolecularActivity
# NamedThing - {'process_positively_regulates_process'} -> MolecularActivity
# NamedThing - {'process_regulates_process'} -> MolecularActivity
# NamedThing - {'produces'} -> MolecularActivity
# NamedThing - {'regulates'} -> MolecularActivity
# NamedThing - {'related_to'} -> MolecularActivity
# NamedThing - {'temporally_related_to'} -> MolecularActivity
# NamedThing - {'is_input_of'} -> MolecularActivity
# NamedThing - {'decreases_response_to'} -> MolecularActivity
# NamedThing - {'has_substrate'} -> MolecularActivity
# NamedThing - {'ameliorates'} -> MolecularActivity
# NamedThing - {'is_substrate_of'} -> MolecularActivity
# NamedThing - {'has_capability'} -> MolecularActivity
# NamedThing - {'has_catalyst'} -> MolecularActivity
# NamedThing - {'associated_with'} -> MolecularActivity
# NamedThing - {'similar_to'} -> MolecularActivity
# NamedThing - {'catalyzes'} -> MolecularActivity
# NamedThing - {'affects_response_to'} -> MolecularActivity
# NamedThing - {'composed_primarily_of'} -> MolecularActivity
# NamedThing - {'genetically_interacts_with'} -> MolecularActivity
# NamedThing - {'has_upstream_actor'} -> MolecularActivity
# NamedThing - {'exacerbates'} -> MolecularActivity
# NamedThing - {'has_active_ingredient'} -> MolecularActivity
# NamedThing - {'increases_response_to'} -> MolecularActivity
# NamedThing - {'primarily_composed_of'} -> MolecularActivity
# NamedThing - {'has_output'} -> MolecularActivity
# NamedThing - {'disrupts'} -> MolecularActivity
# NamedThing - {'is_output_of'} -> MolecularActivity
# NamedThing - {'affected_by'} -> MolecularActivity
# NamedThing - {'treats'} -> MolecularActivity
# NamedThing - {'causes'} -> MolecularActivity
# NamedThing - {'directly_physically_interacts_with'} -> MolecularActivity
# NamedThing - {'is_sequence_variant_of'} -> MolecularActivity
# NamedThing - {'gene_associated_with_condition'} -> MolecularActivity
# NamedThing - {'has_phenotype'} -> MolecularActivity
# NamedThing - {'located_in'} -> MolecularActivity
# NamedThing - {'colocalizes_with'} -> MolecularActivity
# NamedThing - {'manifestation_of'} -> MolecularActivity
# NamedThing - {'coexists_with'} -> MolecularActivity
# NamedThing - {'close_match'} -> MolecularActivity
# NamedThing - {'derives_from'} -> MolecularActivity
# MolecularActivity - {'occurs_in'} -> Publication
# MolecularActivity - {'treats'} -> Publication
# MolecularActivity - {'has_input'} -> Publication
# MolecularActivity - {'has_output'} -> Publication
# MolecularActivity - {'coexists_with'} -> Publication
# MolecularActivity - {'regulates'} -> Publication
# MolecularActivity - {'disrupts'} -> Publication
# MolecularActivity - {'associated_with'} -> Publication
# MolecularActivity - {'gene_associated_with_condition'} -> Publication
# MolecularActivity - {'located_in'} -> Publication
# MolecularActivity - {'produces'} -> Publication
# MolecularActivity - {'related_to'} -> Publication
# MolecularActivity - {'affects'} -> Publication
# MolecularActivity - {'has_participant'} -> Publication
# MolecularActivity - {'subclass_of'} -> Publication
#
#
# PATH: InformationResource->NamedThing->MolecularMixture->Publication
# InformationResource - {'associated_with'} -> NamedThing
# InformationResource - {'subclass_of'} -> NamedThing
# NamedThing - {'occurs_together_in_literature_with'} -> MolecularMixture
# NamedThing - {'subclass_of'} -> MolecularMixture
# NamedThing - {'has_input'} -> MolecularMixture
# NamedThing - {'has_output'} -> MolecularMixture
# NamedThing - {'has_participant'} -> MolecularMixture
# NamedThing - {'preceded_by'} -> MolecularMixture
# NamedThing - {'related_to'} -> MolecularMixture
# NamedThing - {'temporally_related_to'} -> MolecularMixture
# NamedThing - {'composed_primarily_of'} -> MolecularMixture
# NamedThing - {'has_upstream_actor'} -> MolecularMixture
# NamedThing - {'affects_transport_of'} -> MolecularMixture
# NamedThing - {'exacerbates'} -> MolecularMixture
# NamedThing - {'increases_response_to'} -> MolecularMixture
# NamedThing - {'disrupts'} -> MolecularMixture
# NamedThing - {'affected_by'} -> MolecularMixture
# NamedThing - {'interacts_with'} -> MolecularMixture
# ...
# Disease - {'related_to'} -> IndividualOrganism
# Disease - {'overlaps'} -> IndividualOrganism
# Disease - {'composed_primarily_of'} -> IndividualOrganism
# Disease - {'has_upstream_actor'} -> IndividualOrganism
# Disease - {'primarily_composed_of'} -> IndividualOrganism
# Disease - {'has_output'} -> IndividualOrganism
# Disease - {'affected_by'} -> IndividualOrganism
# Disease - {'has_part'} -> IndividualOrganism
# Disease - {'occurs_in'} -> IndividualOrganism
# Disease - {'close_match'} -> IndividualOrganism
# Disease - {'disrupts'} -> IndividualOrganism
# Disease - {'regulates'} -> IndividualOrganism
# Disease - {'located_in'} -> IndividualOrganism
# Disease - {'causes'} -> IndividualOrganism
# Disease - {'subclass_of'} -> IndividualOrganism
# IndividualOrganism - {'close_match'} -> Publication
# IndividualOrganism - {'subclass_of'} -> Publication
# IndividualOrganism - {'occurs_in'} -> Publication
# IndividualOrganism - {'located_in'} -> Publication
# IndividualOrganism - {'related_to'} -> Publication
# IndividualOrganism - {'affects'} -> Publication
#
#
# PATH: InformationResource->Disease->CellLine->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'ameliorates'} -> CellLine
# Disease - {'affects'} -> CellLine
# Disease - {'related_to'} -> CellLine
# Disease - {'treats'} -> CellLine
# Disease - {'close_match'} -> CellLine
# Disease - {'has_participant'} -> CellLine
# Disease - {'coexists_with'} -> CellLine
# Disease - {'regulates'} -> CellLine
# Disease - {'disrupts'} -> CellLine
# Disease - {'expressed_in'} -> CellLine
# Disease - {'located_in'} -> CellLine
# Disease - {'derives_from'} -> CellLine
# Disease - {'disease_has_location'} -> CellLine
# Disease - {'associated_with'} -> CellLine
# Disease - {'subclass_of'} -> CellLine
# Disease - {'has_part'} -> CellLine
# Disease - {'interacts_with'} -> CellLine
# Disease - {'produces'} -> CellLine
# Disease - {'diagnoses'} -> CellLine
# Disease - {'occurs_in'} -> CellLine
# Disease - {'has_input'} -> CellLine
# CellLine - {'gene_associated_with_condition'} -> Publication
# CellLine - {'located_in'} -> Publication
# CellLine - {'produces'} -> Publication
# CellLine - {'related_to'} -> Publication
# CellLine - {'affects'} -> Publication
# CellLine - {'close_match'} -> Publication
# CellLine - {'subclass_of'} -> Publication
# CellLine - {'treats'} -> Publication
#
#
# PATH: InformationResource->Disease->BehavioralFeature->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'contributes_to'} -> BehavioralFeature
# Disease - {'manifestation_of'} -> BehavioralFeature
# Disease - {'has_input'} -> BehavioralFeature
# Disease - {'occurs_in'} -> BehavioralFeature
# Disease - {'affects'} -> BehavioralFeature
# Disease - {'close_match'} -> BehavioralFeature
# Disease - {'exacerbates'} -> BehavioralFeature
# Disease - {'coexists_with'} -> BehavioralFeature
# Disease - {'has_phenotype'} -> BehavioralFeature
# Disease - {'disrupts'} -> BehavioralFeature
# Disease - {'regulates'} -> BehavioralFeature
# Disease - {'contraindicated_for'} -> BehavioralFeature
# Disease - {'treats'} -> BehavioralFeature
# Disease - {'causes'} -> BehavioralFeature
# Disease - {'precedes'} -> BehavioralFeature
# Disease - {'associated_with'} -> BehavioralFeature
# Disease - {'subclass_of'} -> BehavioralFeature
# Disease - {'gene_associated_with_condition'} -> BehavioralFeature
# Disease - {'has_part'} -> BehavioralFeature
# Disease - {'interacts_with'} -> BehavioralFeature
# Disease - {'predisposes'} -> BehavioralFeature
# Disease - {'related_to'} -> BehavioralFeature
# Disease - {'prevents'} -> BehavioralFeature
# Disease - {'diagnoses'} -> BehavioralFeature
# BehavioralFeature - {'subclass_of'} -> Publication
# BehavioralFeature - {'produces'} -> Publication
# BehavioralFeature - {'related_to'} -> Publication
# BehavioralFeature - {'occurs_in'} -> Publication
# BehavioralFeature - {'affects'} -> Publication
# BehavioralFeature - {'manifestation_of'} -> Publication
# BehavioralFeature - {'coexists_with'} -> Publication
# BehavioralFeature - {'disrupts'} -> Publication
# BehavioralFeature - {'located_in'} -> Publication
# BehavioralFeature - {'predisposes'} -> Publication
# BehavioralFeature - {'causes'} -> Publication
#
#
# PATH: InformationResource->Disease->Cohort->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'has_input'} -> Cohort
# Disease - {'coexists_with'} -> Cohort
# Disease - {'close_match'} -> Cohort
# Disease - {'has_participant'} -> Cohort
# Disease - {'located_in'} -> Cohort
# Disease - {'treats'} -> Cohort
# Disease - {'associated_with'} -> Cohort
# Disease - {'subclass_of'} -> Cohort
# Disease - {'interacts_with'} -> Cohort
# Disease - {'produces'} -> Cohort
# Disease - {'predisposes'} -> Cohort
# Disease - {'related_to'} -> Cohort
# Disease - {'occurs_in'} -> Cohort
# Disease - {'affects'} -> Cohort
# Disease - {'diagnoses'} -> Cohort
# Cohort - {'diagnoses'} -> Publication
# Cohort - {'related_to'} -> Publication
# Cohort - {'treats'} -> Publication
# Cohort - {'has_input'} -> Publication
# Cohort - {'occurs_in'} -> Publication
# Cohort - {'has_part'} -> Publication
# Cohort - {'close_match'} -> Publication
# Cohort - {'subclass_of'} -> Publication
# Cohort - {'interacts_with'} -> Publication
# Cohort - {'produces'} -> Publication
#
#
# PATH: InformationResource->Disease->GeographicLocation->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'has_input'} -> GeographicLocation
# Disease - {'affects'} -> GeographicLocation
# Disease - {'close_match'} -> GeographicLocation
# Disease - {'has_participant'} -> GeographicLocation
# Disease - {'coexists_with'} -> GeographicLocation
# Disease - {'located_in'} -> GeographicLocation
# Disease - {'associated_with'} -> GeographicLocation
# Disease - {'subclass_of'} -> GeographicLocation
# Disease - {'has_part'} -> GeographicLocation
# Disease - {'interacts_with'} -> GeographicLocation
# Disease - {'produces'} -> GeographicLocation
# Disease - {'related_to'} -> GeographicLocation
# Disease - {'occurs_in'} -> GeographicLocation
# GeographicLocation - {'subclass_of'} -> Publication
# GeographicLocation - {'related_to'} -> Publication
# GeographicLocation - {'gene_associated_with_condition'} -> Publication
# GeographicLocation - {'located_in'} -> Publication
# GeographicLocation - {'close_match'} -> Publication
#
#
# PATH: InformationResource->Disease->MaterialSample->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'affects'} -> MaterialSample
# Disease - {'coexists_with'} -> MaterialSample
# Disease - {'close_match'} -> MaterialSample
# Disease - {'regulates'} -> MaterialSample
# Disease - {'disrupts'} -> MaterialSample
# Disease - {'located_in'} -> MaterialSample
# Disease - {'treats'} -> MaterialSample
# Disease - {'causes'} -> MaterialSample
# Disease - {'precedes'} -> MaterialSample
# Disease - {'associated_with'} -> MaterialSample
# Disease - {'subclass_of'} -> MaterialSample
# Disease - {'has_part'} -> MaterialSample
# Disease - {'interacts_with'} -> MaterialSample
# Disease - {'produces'} -> MaterialSample
# Disease - {'predisposes'} -> MaterialSample
# Disease - {'related_to'} -> MaterialSample
# Disease - {'diagnoses'} -> MaterialSample
# Disease - {'occurs_in'} -> MaterialSample
# Disease - {'manifestation_of'} -> MaterialSample
# Disease - {'exacerbates'} -> MaterialSample
# MaterialSample - {'located_in'} -> Publication
# MaterialSample - {'associated_with'} -> Publication
# MaterialSample - {'subclass_of'} -> Publication
# MaterialSample - {'has_part'} -> Publication
# MaterialSample - {'related_to'} -> Publication
# MaterialSample - {'occurs_in'} -> Publication
# MaterialSample - {'affects'} -> Publication
# MaterialSample - {'close_match'} -> Publication
#
#
# PATH: InformationResource->Disease->ProteinFamily->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'interacts_with'} -> ProteinFamily
# Disease - {'produces'} -> ProteinFamily
# Disease - {'related_to'} -> ProteinFamily
# Disease - {'occurs_in'} -> ProteinFamily
# Disease - {'affects'} -> ProteinFamily
# Disease - {'close_match'} -> ProteinFamily
# Disease - {'coexists_with'} -> ProteinFamily
# Disease - {'has_participant'} -> ProteinFamily
# Disease - {'regulates'} -> ProteinFamily
# Disease - {'located_in'} -> ProteinFamily
# Disease - {'associated_with'} -> ProteinFamily
# Disease - {'has_part'} -> ProteinFamily
# ProteinFamily - {'associated_with'} -> Publication
# ProteinFamily - {'subclass_of'} -> Publication
# ProteinFamily - {'gene_associated_with_condition'} -> Publication
# ProteinFamily - {'predisposes'} -> Publication
# ProteinFamily - {'related_to'} -> Publication
# ProteinFamily - {'affects'} -> Publication
# ProteinFamily - {'disrupts'} -> Publication
# ProteinFamily - {'located_in'} -> Publication
# ProteinFamily - {'regulates'} -> Publication
# ProteinFamily - {'treats'} -> Publication
#
#
# PATH: InformationResource->Disease->Agent->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'located_in'} -> Agent
# Disease - {'biomarker_for'} -> Agent
# Disease - {'treats'} -> Agent
# Disease - {'causes'} -> Agent
# Disease - {'precedes'} -> Agent
# Disease - {'associated_with'} -> Agent
# Disease - {'gene_associated_with_condition'} -> Agent
# Disease - {'subclass_of'} -> Agent
# Disease - {'has_part'} -> Agent
# Disease - {'prevents'} -> Agent
# Disease - {'interacts_with'} -> Agent
# Disease - {'produces'} -> Agent
# Disease - {'predisposes'} -> Agent
# Disease - {'related_to'} -> Agent
# Disease - {'diagnoses'} -> Agent
# Disease - {'occurs_in'} -> Agent
# Disease - {'manifestation_of'} -> Agent
# Disease - {'has_input'} -> Agent
# Disease - {'exacerbates'} -> Agent
# Disease - {'affects'} -> Agent
# Disease - {'coexists_with'} -> Agent
# Disease - {'close_match'} -> Agent
# Disease - {'has_phenotype'} -> Agent
# Disease - {'regulates'} -> Agent
# Disease - {'disrupts'} -> Agent
# Agent - {'has_part'} -> Publication
# Agent - {'interacts_with'} -> Publication
# Agent - {'produces'} -> Publication
# Agent - {'predisposes'} -> Publication
# Agent - {'related_to'} -> Publication
# Agent - {'prevents'} -> Publication
# Agent - {'precedes'} -> Publication
# Agent - {'occurs_in'} -> Publication
# Agent - {'affects'} -> Publication
# Agent - {'exacerbates'} -> Publication
# Agent - {'coexists_with'} -> Publication
# Agent - {'close_match'} -> Publication
# Agent - {'subclass_of'} -> Publication
# Agent - {'regulates'} -> Publication
# Agent - {'diagnoses'} -> Publication
# Agent - {'treats'} -> Publication
# Agent - {'has_input'} -> Publication
# Agent - {'causes'} -> Publication
# Agent - {'located_in'} -> Publication
# Agent - {'disrupts'} -> Publication
#
#
# PATH: InformationResource->Disease->MicroRNA->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'located_in'} -> MicroRNA
# Disease - {'associated_with'} -> MicroRNA
# Disease - {'has_part'} -> MicroRNA
# Disease - {'interacts_with'} -> MicroRNA
# Disease - {'produces'} -> MicroRNA
# Disease - {'related_to'} -> MicroRNA
# Disease - {'occurs_in'} -> MicroRNA
# Disease - {'affects'} -> MicroRNA
# Disease - {'coexists_with'} -> MicroRNA
# MicroRNA - {'causes'} -> Publication
# MicroRNA - {'disrupts'} -> Publication
# MicroRNA - {'associated_with'} -> Publication
# MicroRNA - {'gene_associated_with_condition'} -> Publication
# MicroRNA - {'subclass_of'} -> Publication
# MicroRNA - {'predisposes'} -> Publication
# MicroRNA - {'located_in'} -> Publication
# MicroRNA - {'regulates'} -> Publication
#
#
# PATH: InformationResource->Disease->PhysicalEntity->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'associated_with'} -> PhysicalEntity
# Disease - {'subclass_of'} -> PhysicalEntity
# Disease - {'gene_associated_with_condition'} -> PhysicalEntity
# Disease - {'has_part'} -> PhysicalEntity
# Disease - {'interacts_with'} -> PhysicalEntity
# Disease - {'produces'} -> PhysicalEntity
# Disease - {'predisposes'} -> PhysicalEntity
# Disease - {'related_to'} -> PhysicalEntity
# Disease - {'prevents'} -> PhysicalEntity
# Disease - {'diagnoses'} -> PhysicalEntity
# Disease - {'manifestation_of'} -> PhysicalEntity
# Disease - {'has_input'} -> PhysicalEntity
# Disease - {'occurs_in'} -> PhysicalEntity
# Disease - {'affects'} -> PhysicalEntity
# Disease - {'close_match'} -> PhysicalEntity
# Disease - {'exacerbates'} -> PhysicalEntity
# Disease - {'coexists_with'} -> PhysicalEntity
# Disease - {'has_participant'} -> PhysicalEntity
# Disease - {'has_phenotype'} -> PhysicalEntity
# Disease - {'disrupts'} -> PhysicalEntity
# Disease - {'located_in'} -> PhysicalEntity
# Disease - {'regulates'} -> PhysicalEntity
# Disease - {'contraindicated_for'} -> PhysicalEntity
# Disease - {'treats'} -> PhysicalEntity
# Disease - {'derives_from'} -> PhysicalEntity
# Disease - {'causes'} -> PhysicalEntity
# Disease - {'precedes'} -> PhysicalEntity
# PhysicalEntity - {'subclass_of'} -> Publication
# PhysicalEntity - {'has_part'} -> Publication
# PhysicalEntity - {'interacts_with'} -> Publication
# PhysicalEntity - {'produces'} -> Publication
# PhysicalEntity - {'predisposes'} -> Publication
# PhysicalEntity - {'related_to'} -> Publication
# PhysicalEntity - {'occurs_in'} -> Publication
# PhysicalEntity - {'affects'} -> Publication
# PhysicalEntity - {'close_match'} -> Publication
# PhysicalEntity - {'coexists_with'} -> Publication
# PhysicalEntity - {'regulates'} -> Publication
# PhysicalEntity - {'located_in'} -> Publication
# PhysicalEntity - {'treats'} -> Publication
# PhysicalEntity - {'has_input'} -> Publication
# PhysicalEntity - {'causes'} -> Publication
# PhysicalEntity - {'disrupts'} -> Publication
# PhysicalEntity - {'associated_with'} -> Publication
#
#
# PATH: InformationResource->Disease->Vitamin->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'associated_with'} -> Vitamin
# Disease - {'interacts_with'} -> Vitamin
# Disease - {'produces'} -> Vitamin
# Disease - {'related_to'} -> Vitamin
# Disease - {'has_part'} -> Vitamin
# Disease - {'has_input'} -> Vitamin
# Disease - {'coexists_with'} -> Vitamin
# Disease - {'close_match'} -> Vitamin
# Disease - {'has_participant'} -> Vitamin
# Disease - {'regulates'} -> Vitamin
# Vitamin - {'regulates'} -> Publication
# Vitamin - {'treats'} -> Publication
# Vitamin - {'disrupts'} -> Publication
# Vitamin - {'subclass_of'} -> Publication
# Vitamin - {'related_to'} -> Publication
# Vitamin - {'affects'} -> Publication
#
#
# PATH: InformationResource->Disease->LifeStage->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'subclass_of'} -> LifeStage
# Disease - {'produces'} -> LifeStage
# Disease - {'related_to'} -> LifeStage
# Disease - {'occurs_in'} -> LifeStage
# Disease - {'affects'} -> LifeStage
# Disease - {'close_match'} -> LifeStage
# Disease - {'located_in'} -> LifeStage
# Disease - {'treats'} -> LifeStage
# LifeStage - {'subclass_of'} -> Publication
# LifeStage - {'has_part'} -> Publication
# LifeStage - {'interacts_with'} -> Publication
# LifeStage - {'produces'} -> Publication
# LifeStage - {'has_input'} -> Publication
#
#
# PATH: InformationResource->Disease->ProteinDomain->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'associated_with'} -> ProteinDomain
# Disease - {'interacts_with'} -> ProteinDomain
# Disease - {'produces'} -> ProteinDomain
# Disease - {'related_to'} -> ProteinDomain
# Disease - {'has_part'} -> ProteinDomain
# Disease - {'occurs_in'} -> ProteinDomain
# Disease - {'affects'} -> ProteinDomain
# Disease - {'coexists_with'} -> ProteinDomain
# Disease - {'disrupts'} -> ProteinDomain
# Disease - {'regulates'} -> ProteinDomain
# Disease - {'located_in'} -> ProteinDomain
# ProteinDomain - {'associated_with'} -> Publication
# ProteinDomain - {'located_in'} -> Publication
# ProteinDomain - {'related_to'} -> Publication
# ProteinDomain - {'occurs_in'} -> Publication
# ProteinDomain - {'affects'} -> Publication
# ProteinDomain - {'subclass_of'} -> Publication
#
#
# PATH: InformationResource->Disease->Event->Publication
# InformationResource - {'associated_with'} -> Disease
# Disease - {'subclass_of'} -> Event
# Disease - {'related_to'} -> Event
# Disease - {'diagnoses'} -> Event
# Disease - {'manifestation_of'} -> Event
# Disease - {'has_input'} -> Event
# Disease - {'exacerbates'} -> Event
# Disease - {'coexists_with'} -> Event
# Disease - {'close_match'} -> Event
# Event - {'occurs_in'} -> Publication
# Event - {'subclass_of'} -> Publication
#
#
# PATH: InformationResource->Publication
# InformationResource - {'subclass_of'} -> Publication

# %%
if nx.has_path(G, subject, object):
    raw_paths = list(nx.all_simple_paths(G, source=subject, target=object, cutoff=cutoff))
    for path in raw_paths:
        print(path)
# Out:
# ['InformationResource', 'NamedThing', 'AnatomicalEntity', 'Publication']
# ['InformationResource', 'NamedThing', 'BiologicalProcess', 'Publication']
# ['InformationResource', 'NamedThing', 'Cell', 'Publication']
# ['InformationResource', 'NamedThing', 'CellularComponent', 'Publication']
# ['InformationResource', 'NamedThing', 'ChemicalEntity', 'Publication']
# ['InformationResource', 'NamedThing', 'ChemicalMixture', 'Publication']
# ['InformationResource', 'NamedThing', 'ComplexMolecularMixture', 'Publication']
# ['InformationResource', 'NamedThing', 'Disease', 'Publication']
# ['InformationResource', 'NamedThing', 'GrossAnatomicalStructure', 'Publication']
# ['InformationResource', 'NamedThing', 'MolecularActivity', 'Publication']
# ['InformationResource', 'NamedThing', 'MolecularMixture', 'Publication']
# ['InformationResource', 'NamedThing', 'OrganismTaxon', 'Publication']
# ['InformationResource', 'NamedThing', 'Pathway', 'Publication']
# ['InformationResource', 'NamedThing', 'PhenotypicFeature', 'Publication']
# ['InformationResource', 'NamedThing', 'Polypeptide', 'Publication']
# ['InformationResource', 'NamedThing', 'Protein', 'Publication']
# ['InformationResource', 'NamedThing', 'SmallMolecule', 'Publication']
# ['InformationResource', 'NamedThing', 'CellLine', 'Publication']
# ['InformationResource', 'NamedThing', 'Entity', 'Publication']
# ['InformationResource', 'NamedThing', 'InformationContentEntity', 'Publication']
# ['InformationResource', 'NamedThing', 'NoncodingRNAProduct', 'Publication']
# ['InformationResource', 'NamedThing', 'Drug', 'Publication']
# ['InformationResource', 'NamedThing', 'EnvironmentalProcess', 'Publication']
# ['InformationResource', 'NamedThing', 'Transcript', 'Publication']
# ['InformationResource', 'NamedThing', 'Behavior', 'Publication']
# ['InformationResource', 'NamedThing', 'BiologicalProcessOrActivity', 'Publication']
# ['InformationResource', 'NamedThing', 'MicroRNA', 'Publication']
# ['InformationResource', 'NamedThing', 'PathologicalProcess', 'Publication']
# ['InformationResource', 'NamedThing', 'RNAProduct', 'Publication']
# ['InformationResource', 'NamedThing', 'Exon', 'Publication']
# ['InformationResource', 'NamedThing', 'NucleicAcidEntity', 'Publication']
# ['InformationResource', 'NamedThing', 'LifeStage', 'Publication']
# ['InformationResource', 'NamedThing', 'DiseaseOrPhenotypicFeature', 'Publication']
# ['InformationResource', 'NamedThing', 'Gene', 'Publication']
# ['InformationResource', 'NamedThing', 'MaterialSample', 'Publication']
# ['InformationResource', 'NamedThing', 'PopulationOfIndividualOrganisms', 'Publication']
# ['InformationResource', 'NamedThing', 'Publication']
# ['InformationResource', 'NamedThing', 'MolecularEntity', 'Publication']
# ['InformationResource', 'NamedThing', 'OrganismalEntity', 'Publication']
# ['InformationResource', 'NamedThing', 'BiologicalEntity', 'Publication']
# ['InformationResource', 'NamedThing', 'OrganismAttribute', 'Publication']
# ['InformationResource', 'NamedThing', 'PhysicalEntity', 'Publication']
# ['InformationResource', 'NamedThing', 'GenomicEntity', 'Publication']
# ['InformationResource', 'NamedThing', 'Annotation', 'Publication']
# ['InformationResource', 'NamedThing', 'IndividualOrganism', 'Publication']
# ['InformationResource', 'NamedThing', 'ClinicalAttribute', 'Publication']
# ['InformationResource', 'NamedThing', 'PhysiologicalProcess', 'Publication']
# ['InformationResource', 'NamedThing', 'Phenomenon', 'Publication']
# ['InformationResource', 'NamedThing', 'Procedure', 'Publication']
# ['InformationResource', 'NamedThing', 'GeneFamily', 'Publication']
# ['InformationResource', 'NamedThing', 'Activity', 'Publication']
# ['InformationResource', 'NamedThing', 'Device', 'Publication']
# ['InformationResource', 'NamedThing', 'ProteinFamily', 'Publication']
# ['InformationResource', 'NamedThing', 'BehavioralFeature', 'Publication']
# ['InformationResource', 'NamedThing', 'Vitamin', 'Publication']
# ['InformationResource', 'NamedThing', 'ClinicalIntervention', 'Publication']
# ['InformationResource', 'NamedThing', 'Food', 'Publication']
# ['InformationResource', 'NamedThing', 'Cohort', 'Publication']
# ['InformationResource', 'NamedThing', 'GeographicLocation', 'Publication']
# ['InformationResource', 'NamedThing', 'Agent', 'Publication']
# ['InformationResource', 'NamedThing', 'ProteinDomain', 'Publication']
# ['InformationResource', 'NamedThing', 'Event', 'Publication']
# ['InformationResource', 'NamedThing', 'Treatment', 'Publication']
# ['InformationResource', 'NamedThing', 'GeneticInheritance', 'Publication']
# ['InformationResource', 'Pathway', 'SmallMolecule', 'Publication']
# ['InformationResource', 'Pathway', 'Disease', 'Publication']
# ['InformationResource', 'Pathway', 'PhenotypicFeature', 'Publication']
# ['InformationResource', 'Pathway', 'AnatomicalEntity', 'Publication']
# ['InformationResource', 'Pathway', 'BiologicalProcess', 'Publication']
# ['InformationResource', 'Pathway', 'Cell', 'Publication']
# ['InformationResource', 'Pathway', 'CellularComponent', 'Publication']
# ['InformationResource', 'Pathway', 'ChemicalEntity', 'Publication']
# ['InformationResource', 'Pathway', 'ChemicalMixture', 'Publication']
# ['InformationResource', 'Pathway', 'ComplexMolecularMixture', 'Publication']
# ['InformationResource', 'Pathway', 'GrossAnatomicalStructure', 'Publication']
# ['InformationResource', 'Pathway', 'MolecularActivity', 'Publication']
# ['InformationResource', 'Pathway', 'MolecularMixture', 'Publication']
# ['InformationResource', 'Pathway', 'NamedThing', 'Publication']
# ['InformationResource', 'Pathway', 'OrganismTaxon', 'Publication']
# ['InformationResource', 'Pathway', 'Polypeptide', 'Publication']
# ['InformationResource', 'Pathway', 'Protein', 'Publication']
# ['InformationResource', 'Pathway', 'Transcript', 'Publication']
# ['InformationResource', 'Pathway', 'PhysiologicalProcess', 'Publication']
# ['InformationResource', 'Pathway', 'Procedure', 'Publication']
# ['InformationResource', 'Pathway', 'Drug', 'Publication']
# ['InformationResource', 'Pathway', 'GeneFamily', 'Publication']
# ['InformationResource', 'Pathway', 'Gene', 'Publication']
# ['InformationResource', 'Pathway', 'MolecularEntity', 'Publication']
# ['InformationResource', 'Pathway', 'BiologicalProcessOrActivity', 'Publication']
# ['InformationResource', 'Pathway', 'BiologicalEntity', 'Publication']
# ['InformationResource', 'Pathway', 'Entity', 'Publication']
# ['InformationResource', 'Pathway', 'EnvironmentalProcess', 'Publication']
# ['InformationResource', 'Pathway', 'OrganismalEntity', 'Publication']
# ['InformationResource', 'Pathway', 'Behavior', 'Publication']
# ['InformationResource', 'Pathway', 'Annotation', 'Publication']
# ['InformationResource', 'Pathway', 'DiseaseOrPhenotypicFeature', 'Publication']
# ['InformationResource', 'Pathway', 'OrganismAttribute', 'Publication']
# ['InformationResource', 'Pathway', 'GenomicEntity', 'Publication']
# ['InformationResource', 'Pathway', 'NucleicAcidEntity', 'Publication']
# ['InformationResource', 'Pathway', 'RNAProduct', 'Publication']
# ['InformationResource', 'Pathway', 'ClinicalAttribute', 'Publication']
# ['InformationResource', 'Pathway', 'NoncodingRNAProduct', 'Publication']
# ['InformationResource', 'Pathway', 'Device', 'Publication']
# ['InformationResource', 'Pathway', 'InformationContentEntity', 'Publication']
# ['InformationResource', 'Pathway', 'Phenomenon', 'Publication']
# ['InformationResource', 'Pathway', 'IndividualOrganism', 'Publication']
# ['InformationResource', 'Pathway', 'Treatment', 'Publication']
# ['InformationResource', 'Pathway', 'PathologicalProcess', 'Publication']
# ['InformationResource', 'Pathway', 'CellLine', 'Publication']
# ['InformationResource', 'Pathway', 'Activity', 'Publication']
# ['InformationResource', 'Pathway', 'Food', 'Publication']
# ['InformationResource', 'Pathway', 'Agent', 'Publication']
# ['InformationResource', 'Pathway', 'LifeStage', 'Publication']
# ['InformationResource', 'Pathway', 'MicroRNA', 'Publication']
# ['InformationResource', 'Pathway', 'Vitamin', 'Publication']
# ['InformationResource', 'Pathway', 'Publication']
# ['InformationResource', 'Pathway', 'ClinicalIntervention', 'Publication']
# ['InformationResource', 'Pathway', 'BehavioralFeature', 'Publication']
# ['InformationResource', 'Pathway', 'ProteinFamily', 'Publication']
# ['InformationResource', 'Pathway', 'PhysicalEntity', 'Publication']
# ['InformationResource', 'Pathway', 'Cohort', 'Publication']
# ['InformationResource', 'Pathway', 'PopulationOfIndividualOrganisms', 'Publication']
# ['InformationResource', 'Pathway', 'MaterialSample', 'Publication']
# ['InformationResource', 'Pathway', 'ProteinDomain', 'Publication']
# ['InformationResource', 'Pathway', 'GeographicLocation', 'Publication']
# ['InformationResource', 'Pathway', 'Event', 'Publication']
# ['InformationResource', 'Pathway', 'GeneticInheritance', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'SmallMolecule', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Protein', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'ChemicalEntity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'MolecularEntity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Disease', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'PhenotypicFeature', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'OrganismAttribute', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'BiologicalEntity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Annotation', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'NamedThing', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Entity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'AnatomicalEntity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Gene', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'GenomicEntity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'NucleicAcidEntity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'OrganismalEntity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Polypeptide', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'BiologicalProcess', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'BiologicalProcessOrActivity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'MolecularActivity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Pathway', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'CellularComponent', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'CellLine', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Transcript', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'ClinicalAttribute', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'PhysiologicalProcess', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'ComplexMolecularMixture', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'NoncodingRNAProduct', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'RNAProduct', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'EnvironmentalProcess', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'InformationContentEntity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Phenomenon', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Procedure', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'IndividualOrganism', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Behavior', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'GrossAnatomicalStructure', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'PathologicalProcess', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'OrganismTaxon', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'MolecularMixture', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'GeneFamily', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Cell', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'ChemicalMixture', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Activity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Drug', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'PhysicalEntity', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Agent', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Device', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Vitamin', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'PopulationOfIndividualOrganisms', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'ClinicalIntervention', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'LifeStage', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'MaterialSample', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'ProteinFamily', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'BehavioralFeature', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'ProteinDomain', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Cohort', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Food', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'MicroRNA', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Treatment', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'GeographicLocation', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'Event', 'Publication']
# ['InformationResource', 'DiseaseOrPhenotypicFeature', 'GeneticInheritance', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'SmallMolecule', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Drug', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'ChemicalExposure', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Disease', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'PhenotypicFeature', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'EnvironmentalExposure', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Activity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'ClinicalIntervention', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'PopulationOfIndividualOrganisms', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'ChemicalEntity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'ComplexMolecularMixture', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'BiologicalProcess', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'PhysiologicalProcess', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Protein', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Device', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Gene', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Procedure', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'ClinicalAttribute', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Annotation', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'MolecularMixture', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'NamedThing', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Entity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'MolecularActivity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Behavior', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'CellularComponent', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'MolecularEntity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'GrossAnatomicalStructure', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'PathologicalProcess', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'GenomicEntity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'CellLine', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'ChemicalMixture', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'NucleicAcidEntity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Pathway', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'DiseaseOrPhenotypicFeature', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'AnatomicalEntity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Polypeptide', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'EnvironmentalProcess', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'BiologicalProcessOrActivity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'OrganismalEntity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'BiologicalEntity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'OrganismTaxon', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Cell', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'OrganismAttribute', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Phenomenon', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'BehavioralFeature', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Agent', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'MaterialSample', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'MicroRNA', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'PhysicalEntity', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Vitamin', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'ProteinFamily', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Event', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'RNAProduct', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'GeographicLocation', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'LifeStage', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'GeneFamily', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'IndividualOrganism', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Treatment', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Food', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'NoncodingRNAProduct', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'ProteinDomain', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Transcript', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Cohort', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'Exon', 'Publication']
# ['InformationResource', 'InformationContentEntity', 'GeneticInheritance', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Disease', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Drug', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Procedure', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'SmallMolecule', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'ChemicalEntity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Cell', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Protein', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'MolecularEntity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Gene', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Pathway', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'AnatomicalEntity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'BiologicalProcess', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'CellularComponent', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'ChemicalMixture', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'ComplexMolecularMixture', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'GrossAnatomicalStructure', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'MolecularActivity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'MolecularMixture', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'NamedThing', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'OrganismTaxon', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Polypeptide', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'PhysiologicalProcess', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'PathologicalProcess', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'GeneticInheritance', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'DiseaseOrPhenotypicFeature', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'BiologicalEntity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Entity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'PopulationOfIndividualOrganisms', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'ChemicalExposure', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'EnvironmentalExposure', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'InformationContentEntity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'ClinicalIntervention', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Device', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'ClinicalAttribute', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Annotation', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Activity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'GenomicEntity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'NucleicAcidEntity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'OrganismalEntity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'OrganismAttribute', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'BiologicalProcessOrActivity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Food', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'NoncodingRNAProduct', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'RNAProduct', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'EnvironmentalProcess', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Transcript', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Phenomenon', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'IndividualOrganism', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Treatment', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Behavior', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'GeneFamily', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'CellLine', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'BehavioralFeature', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Agent', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'LifeStage', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Vitamin', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'ProteinDomain', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Cohort', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'PhysicalEntity', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'MaterialSample', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'MicroRNA', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'GeographicLocation', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'ProteinFamily', 'Publication']
# ['InformationResource', 'PhenotypicFeature', 'Event', 'Publication']
# ['InformationResource', 'Behavior', 'BiologicalEntity', 'Publication']
# ['InformationResource', 'Behavior', 'SmallMolecule', 'Publication']
# ['InformationResource', 'Behavior', 'MolecularMixture', 'Publication']
# ['InformationResource', 'Behavior', 'BiologicalProcess', 'Publication']
# ['InformationResource', 'Behavior', 'BiologicalProcessOrActivity', 'Publication']
# ['InformationResource', 'Behavior', 'NamedThing', 'Publication']
# ['InformationResource', 'Behavior', 'Entity', 'Publication']
# ['InformationResource', 'Behavior', 'Protein', 'Publication']
# ['InformationResource', 'Behavior', 'AnatomicalEntity', 'Publication']
# ['InformationResource', 'Behavior', 'ChemicalEntity', 'Publication']
# ['InformationResource', 'Behavior', 'OrganismalEntity', 'Publication']
# ['InformationResource', 'Behavior', 'MolecularActivity', 'Publication']
# ['InformationResource', 'Behavior', 'Pathway', 'Publication']
# ['InformationResource', 'Behavior', 'Gene', 'Publication']
# ['InformationResource', 'Behavior', 'DiseaseOrPhenotypicFeature', 'Publication']
# ['InformationResource', 'Behavior', 'Transcript', 'Publication']
# ['InformationResource', 'Behavior', 'Disease', 'Publication']
# ['InformationResource', 'Behavior', 'ClinicalAttribute', 'Publication']
# ['InformationResource', 'Behavior', 'InformationContentEntity', 'Publication']
# ['InformationResource', 'Behavior', 'PhysiologicalProcess', 'Publication']
# ['InformationResource', 'Behavior', 'Polypeptide', 'Publication']
# ['InformationResource', 'Behavior', 'RNAProduct', 'Publication']
# ['InformationResource', 'Behavior', 'EnvironmentalProcess', 'Publication']
# ['InformationResource', 'Behavior', 'Device', 'Publication']
# ['InformationResource', 'Behavior', 'OrganismTaxon', 'Publication']
# ['InformationResource', 'Behavior', 'Cell', 'Publication']
# ['InformationResource', 'Behavior', 'Activity', 'Publication']
# ['InformationResource', 'Behavior', 'Annotation', 'Publication']
# ['InformationResource', 'Behavior', 'OrganismAttribute', 'Publication']
# ['InformationResource', 'Behavior', 'Drug', 'Publication']
# ['InformationResource', 'Behavior', 'Phenomenon', 'Publication']
# ['InformationResource', 'Behavior', 'Procedure', 'Publication']
# ['InformationResource', 'Behavior', 'PhenotypicFeature', 'Publication']
# ['InformationResource', 'Behavior', 'IndividualOrganism', 'Publication']
# ['InformationResource', 'Behavior', 'CellularComponent', 'Publication']
# ['InformationResource', 'Behavior', 'MolecularEntity', 'Publication']
# ['InformationResource', 'Behavior', 'GrossAnatomicalStructure', 'Publication']
# ['InformationResource', 'Behavior', 'PathologicalProcess', 'Publication']
# ['InformationResource', 'Behavior', 'GeneFamily', 'Publication']
# ['InformationResource', 'Behavior', 'GenomicEntity', 'Publication']
# ['InformationResource', 'Behavior', 'CellLine', 'Publication']
# ['InformationResource', 'Behavior', 'ChemicalMixture', 'Publication']
# ['InformationResource', 'Behavior', 'NucleicAcidEntity', 'Publication']
# ['InformationResource', 'Behavior', 'ComplexMolecularMixture', 'Publication']
# ['InformationResource', 'Behavior', 'NoncodingRNAProduct', 'Publication']
# ['InformationResource', 'Behavior', 'Food', 'Publication']
# ['InformationResource', 'Behavior', 'ProteinDomain', 'Publication']
# ['InformationResource', 'Behavior', 'PhysicalEntity', 'Publication']
# ['InformationResource', 'Behavior', 'Agent', 'Publication']
# ['InformationResource', 'Behavior', 'Event', 'Publication']
# ['InformationResource', 'Behavior', 'LifeStage', 'Publication']
# ['InformationResource', 'Behavior', 'BehavioralFeature', 'Publication']
# ['InformationResource', 'Behavior', 'PopulationOfIndividualOrganisms', 'Publication']
# ['InformationResource', 'Behavior', 'ProteinFamily', 'Publication']
# ['InformationResource', 'Behavior', 'ClinicalIntervention', 'Publication']
# ['InformationResource', 'Behavior', 'Cohort', 'Publication']
# ['InformationResource', 'Behavior', 'Publication']
# ['InformationResource', 'Behavior', 'GeographicLocation', 'Publication']
# ['InformationResource', 'Behavior', 'Vitamin', 'Publication']
# ['InformationResource', 'Behavior', 'MaterialSample', 'Publication']
# ['InformationResource', 'Behavior', 'GeneticInheritance', 'Publication']
# ['InformationResource', 'Disease', 'PopulationOfIndividualOrganisms', 'Publication']
# ['InformationResource', 'Disease', 'EnvironmentalExposure', 'Publication']
# ['InformationResource', 'Disease', 'Drug', 'Publication']
# ['InformationResource', 'Disease', 'ChemicalExposure', 'Publication']
# ['InformationResource', 'Disease', 'Activity', 'Publication']
# ['InformationResource', 'Disease', 'ClinicalAttribute', 'Publication']
# ['InformationResource', 'Disease', 'Annotation', 'Publication']
# ['InformationResource', 'Disease', 'PhysiologicalProcess', 'Publication']
# ['InformationResource', 'Disease', 'InformationContentEntity', 'Publication']
# ['InformationResource', 'Disease', 'Procedure', 'Publication']
# ['InformationResource', 'Disease', 'Publication']
# ['InformationResource', 'Disease', 'ComplexMolecularMixture', 'Publication']
# ['InformationResource', 'Disease', 'ClinicalIntervention', 'Publication']
# ['InformationResource', 'Disease', 'BiologicalProcess', 'Publication']
# ['InformationResource', 'Disease', 'Protein', 'Publication']
# ['InformationResource', 'Disease', 'Gene', 'Publication']
# ['InformationResource', 'Disease', 'Device', 'Publication']
# ['InformationResource', 'Disease', 'PhenotypicFeature', 'Publication']
# ['InformationResource', 'Disease', 'SmallMolecule', 'Publication']
# ['InformationResource', 'Disease', 'Cell', 'Publication']
# ['InformationResource', 'Disease', 'MolecularEntity', 'Publication']
# ['InformationResource', 'Disease', 'ChemicalEntity', 'Publication']
# ['InformationResource', 'Disease', 'Pathway', 'Publication']
# ['InformationResource', 'Disease', 'AnatomicalEntity', 'Publication']
# ['InformationResource', 'Disease', 'CellularComponent', 'Publication']
# ['InformationResource', 'Disease', 'ChemicalMixture', 'Publication']
# ['InformationResource', 'Disease', 'GrossAnatomicalStructure', 'Publication']
# ['InformationResource', 'Disease', 'MolecularActivity', 'Publication']
# ['InformationResource', 'Disease', 'MolecularMixture', 'Publication']
# ['InformationResource', 'Disease', 'NamedThing', 'Publication']
# ['InformationResource', 'Disease', 'OrganismTaxon', 'Publication']
# ['InformationResource', 'Disease', 'Polypeptide', 'Publication']
# ['InformationResource', 'Disease', 'BiologicalEntity', 'Publication']
# ['InformationResource', 'Disease', 'Treatment', 'Publication']
# ['InformationResource', 'Disease', 'NucleicAcidEntity', 'Publication']
# ['InformationResource', 'Disease', 'Transcript', 'Publication']
# ['InformationResource', 'Disease', 'PathologicalProcess', 'Publication']
# ['InformationResource', 'Disease', 'GeneticInheritance', 'Publication']
# ['InformationResource', 'Disease', 'DiseaseOrPhenotypicFeature', 'Publication']
# ['InformationResource', 'Disease', 'OrganismAttribute', 'Publication']
# ['InformationResource', 'Disease', 'Entity', 'Publication']
# ['InformationResource', 'Disease', 'Food', 'Publication']
# ['InformationResource', 'Disease', 'NoncodingRNAProduct', 'Publication']
# ['InformationResource', 'Disease', 'RNAProduct', 'Publication']
# ['InformationResource', 'Disease', 'EnvironmentalProcess', 'Publication']
# ['InformationResource', 'Disease', 'OrganismalEntity', 'Publication']
# ['InformationResource', 'Disease', 'Phenomenon', 'Publication']
# ['InformationResource', 'Disease', 'Behavior', 'Publication']
# ['InformationResource', 'Disease', 'BiologicalProcessOrActivity', 'Publication']
# ['InformationResource', 'Disease', 'GeneFamily', 'Publication']
# ['InformationResource', 'Disease', 'GenomicEntity', 'Publication']
# ['InformationResource', 'Disease', 'IndividualOrganism', 'Publication']
# ['InformationResource', 'Disease', 'CellLine', 'Publication']
# ['InformationResource', 'Disease', 'BehavioralFeature', 'Publication']
# ['InformationResource', 'Disease', 'Cohort', 'Publication']
# ['InformationResource', 'Disease', 'GeographicLocation', 'Publication']
# ['InformationResource', 'Disease', 'MaterialSample', 'Publication']
# ['InformationResource', 'Disease', 'ProteinFamily', 'Publication']
# ['InformationResource', 'Disease', 'Agent', 'Publication']
# ['InformationResource', 'Disease', 'MicroRNA', 'Publication']
# ['InformationResource', 'Disease', 'PhysicalEntity', 'Publication']
# ['InformationResource', 'Disease', 'Vitamin', 'Publication']
# ['InformationResource', 'Disease', 'LifeStage', 'Publication']
# ['InformationResource', 'Disease', 'ProteinDomain', 'Publication']
# ['InformationResource', 'Disease', 'Event', 'Publication']
# ['InformationResource', 'Publication']

# %% [markdown]
# ---

# %% [markdown]
# For the relations(predicates), if `node X` is connected to node Z through node Y, i.e X->Y->Z , will every relation(predicate) that connects Y->Z , or X->Y, will those relations all connect X->Z?

# %% [markdown]
# ---
