# %% [markdown]
# # Using the API: Practical Use Cases and Best Practices

# %% [markdown]
# ## SmartAPI

# %% [markdown]
# Load our packages:
# ...

# %%
import requests, os
import pandas as pd
from IPython.display import display

# %%
# Base URL for the SmartAPI
BASE_URL = "https://smart-api.info/api"

# %% [markdown]
# ### Catch all API query
#
# **Endpoint:** https://smart-api.info/api/query
# **Example:**

# %%
# Fetch the list of APIs (equivalent to indices in Elasticsearch)
response = requests.get(f"{BASE_URL}/query")
response.raise_for_status()

# %%
if response.status_code == 200:
    apis = response.json()
    df = pd.DataFrame(apis['hits'])  # Convert results to a DataFrame
    display(df[['info', 'servers', 'tags']].head())
else:
    print("Error fetching APIs:", response.status_code)
# Out:
#                                                 info
# 0  {'contact': {'email': 'help@biothings.io', 'na...  \
# 1  {'termsOfService': 'https://creativecommons.or...
# 2  {'contact': {'name': 'Elsevier', 'url': 'https...
# 3  {'contact': {'email': 'cdis@uchicago.edu'}, 'd...
# 4  {'contact': {'email': 'help@biothings.io', 'na...
#
#                                              servers
# 0  [{'description': 'Production server', 'url': '...  \
# 1  [{'description': 'NIAID Test server', 'url': '...
# 2  [{'url': 'http://nih-guid-broker-elb-181302043...
# 3               [{'url': 'https://example.domain/'}]
# 4  [{'description': 'Encrypted Production server'...
#
#                                                 tags
# 0  [{'name': 'disease'}, {'name': 'phenotype'}, {...
# 1  [{'description': 'Query based on ID for DICOM ...
# 2  [{'description': 'DataCite Broker', 'name': 'D...
# 3  [{'description': 'Authorization and token mana...
# 4  [{'name': 'chemical'}, {'name': 'disease'}, {'...

# %%
# SmartAPI endpoint to list all APIs
url = os.path.join(BASE_URL, "query")

# Make the GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    apis_metadata = response.json()
    # Print the keys of the returned JSON for inspection
    print("-"*100)
    print("Keys in the response:", apis_metadata.keys())
    print("Keys in the an example smartapi document:", apis_metadata["hits"][0].keys())
    print(f"components keys: {apis_metadata['hits'][0]['components'].keys()}")
    print(f"info keys: {apis_metadata['hits'][0]['info'].keys()}")
    print(f"paths keys: {apis_metadata['hits'][0]['paths'].keys()}")
    print(f"tags: {apis_metadata['hits'][0]['tags']}")
    print("-"*100)
    print("\nSample API Metadata:")
    sample_smartapi_doc=apis_metadata["hits"][0]
sample_smartapi_doc
# Out:
# ----------------------------------------------------------------------------------------------------
# Keys in the response: dict_keys(['took', 'total', 'max_score', 'hits'])
# Keys in the an example smartapi document: dict_keys(['components', 'info', 'openapi', 'paths', 'servers', 'tags'])
# components keys: dict_keys(['parameters', 'x-bte-kgs-operations', 'x-bte-response-mapping'])
# info keys: dict_keys(['contact', 'description', 'termsOfService', 'title', 'version', 'x-translator'])
# paths keys: dict_keys(['/association/{id}', '/association', '/metadata', '/metadata/fields', '/query/ngd', '/query'])
# tags: [{'name': 'disease'}, {'name': 'phenotype'}, {'name': 'gene'}, {'name': 'chemical'}, {'name': 'association'}, {'name': 'query'}, {'name': 'translator'}, {'name': 'biothings'}, {'name': 'ngd'}]
# ----------------------------------------------------------------------------------------------------
#
# Sample API Metadata:
# {'components': {'parameters': {'callback': {'description': 'Optional, you can pass a "callback" parameter to make a JSONP call.',
#     'in': 'query',
#     'name': 'callback',
#     'required': False,
#     'schema': {'type': 'string'}},
#    'dotfield': {'description': 'Optional, can be used to control the format of the returned object.  If "dotfield" is true, the returned data object is returned flattened (no nested objects)  using dotfield notation for key names. Default: false.',
#     'in': 'query',
#     'name': 'dotfield',
#     'required': False,
#     'schema': {'default': False, 'type': 'boolean'}},
#    'email': {'description': 'Optional, if you are regular users of our services, we encourage you to provide us an email,  so that we can better track the usage or follow up with you.',
#     'in': 'query',
#     'name': 'email',
#     'required': False,
#     'schema': {'type': 'string'}},
#    'facet_size': {'description': 'Optional, an integer (1 <= facet_size <= 1000) that specifies how many buckets to return in a  [faceted query](https://docs.mychem.info/en/latest/doc/chem_query_service.html?highlight=from#faceted-queries).',
#     'in': 'query',
#     'name': 'facet_size',
#     'required': False,
#     'schema': {'default': 10, 'type': 'integer'}},
#    'facets': {'description': 'Optional, a single field or comma-separated fields to return facets, can only be used on non-free text fields.  E.g. “facets=chembl.molecule_properties.full_mwt”. See [examples of faceted queries for a core BioThings  API](https://docs.mychem.info/en/latest/doc/chem_query_service.html?highlight=from#faceted-queries).',
#     'in': 'query',
#     'name': 'facets',
#     'required': False,
#     'schema': {'items': {'type': 'string'}, 'type': 'array'}},
#    'fetch_all': {'description': 'Optional, a boolean, which when TRUE, allows fast retrieval of all unsorted query hits.  The return object contains a _scroll_id field, which when passed as a parameter to the query endpoint  (see the scroll_id parameter), returns the next 1000 query results. Setting fetch_all = TRUE causes  the results to be inherently unsorted, therefore the sort parameter is ignored. For more information,  see [examples using fetch_all for a core BioThings  API](https://docs.mychem.info/en/latest/doc/chem_query_service.html?highlight=from#scrolling-queries).  Default: FALSE.',
#     'in': 'query',
#     'name': 'fetch_all',
#     'required': False,
#     'schema': {'default': False, 'type': 'boolean'}},
#    'fields': {'description': 'Optional, can be a comma-separated list to limit the fields returned from the object.  If "fields=all", all available fields will be returned.\n\nNote that it supports dot notation as well, e.g., you can pass "chebi.name".  Default: "fields=all".  The parameter "filter" is an alias for this parameter.',
#     'in': 'query',
#     'name': 'fields',
#     'required': False,
#     'schema': {'default': 'all', 'type': 'string'}},
#    'from': {'description': 'Optional, the number of matching hits to skip, starting from 0. Default: 0. ',
#     'in': 'query',
#     'name': 'from',
#     'required': False,
#     'schema': {'default': 0, 'type': 'integer'}},
#    'scroll_id': {'description': 'Optional, a string containing the _scroll_id returned from a query request with fetch_all = TRUE.  Supplying a valid scroll_id will return the next 1000 unordered results. If the next results are  not obtained within 1 minute of the previous set of results, the scroll_id becomes stale, and a  new one must be obtained with another query request with fetch_all = TRUE. All other parameters are  ignored when the scroll_id parameter is supplied. For more information see [examples using scroll_id  for a core BioThings  API](https://docs.mychem.info/en/latest/doc/chem_query_service.html?highlight=from#scrolling-queries).',
#     'in': 'query',
#     'name': 'scroll_id',
#     'required': False,
#     'schema': {'type': 'string'}},
#    'size': {'description': 'Optional, the maximum number of matching hits to return (with a cap of 1000 at the moment). Default: 10. The combination of "size" and "from" parameters can be used to get paging for a large query.',
#     'in': 'query',
#     'name': 'size',
#     'required': False,
#     'schema': {'default': 10, 'type': 'integer'}},
#    'sort': {'description': 'Optional, the comma-separated fields to sort on. Prefix with "-" for descending order, otherwise in ascending order.  Default: sort by matching scores in descending order.',
#     'in': 'query',
#     'name': 'sort',
#     'required': False,
#     'schema': {'items': {'type': 'string'}, 'type': 'array'}}},
#   'x-bte-kgs-operations': {'aapp-ADMINISTERED_TO-cell': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ADMINISTERED_TO AND object.semantic_type_abbreviation:cell AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-ADMINISTERED_TO-cell-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ADMINISTERED_TO AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-acab': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:acab AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-anab': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:anab AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-anst': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'AnatomicalEntity'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:anst AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-anst-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'AnatomicalEntity'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-biof': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:biof AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-biof-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-bpoc': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:bpoc AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-bpoc-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-celc': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'CellularComponent'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:celc AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-celc-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'CellularComponent'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-celf': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:celf AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-celf-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-cell': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:cell AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-cell-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-cgab': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:cgab AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-comd': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:comd AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-dsyn': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:dsyn AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-dsyn-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-emod': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'BiologicalEntity'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:emod AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-emod-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'BiologicalEntity'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-emst': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:emst AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-fndg': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'DiseaseOrPhenotypicFeature'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:fndg AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-fndg-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'DiseaseOrPhenotypicFeature'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-inpo': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:inpo AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-mobd': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:mobd AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-moft': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'MolecularActivity'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:moft AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-moft-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'MolecularActivity'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-neop': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:neop AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-orgf': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:orgf AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-ortf': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:ortf AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-patf': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:patf AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-patf-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-phsf': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:phsf AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-sosy': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:sosy AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-sosy-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AFFECTS-tisu': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:tisu AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-ASSOCIATED_WITH-comd': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:comd AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-ASSOCIATED_WITH-dsyn': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:dsyn AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-ASSOCIATED_WITH-dsyn-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ASSOCIATED_WITH AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-ASSOCIATED_WITH-inpo': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:inpo AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-ASSOCIATED_WITH-mobd': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:mobd AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-ASSOCIATED_WITH-neop': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:neop AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-ASSOCIATED_WITH-patf': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:patf AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-ASSOCIATED_WITH-patf-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ASSOCIATED_WITH AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-ASSOCIATED_WITH-sosy': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:sosy AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-ASSOCIATED_WITH-sosy-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:ASSOCIATED_WITH AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'related_to',
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AUGMENTS-acab': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:acab AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#       'object_direction_qualifier': 'increased',
#       'qualified_predicate': 'causes'},
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AUGMENTS-anab': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:anab AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#       'object_direction_qualifier': 'increased',
#       'qualified_predicate': 'causes'},
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AUGMENTS-biof': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:biof AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#       'object_direction_qualifier': 'increased',
#       'qualified_predicate': 'causes'},
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AUGMENTS-biof-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AUGMENTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affected_by',
#      'qualifiers': {'qualified_predicate': 'caused_by',
#       'subject_aspect_qualifier': 'activity_or_abundance',
#       'subject_direction_qualifier': 'increased'},
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'object.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AUGMENTS-bpoc': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#      'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#       'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:bpoc AND _exists_:object.umls AND pmid_count:>3',
#       'size': 1000},
#      'predicate': 'affects',
#      'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#       'object_direction_qualifier': 'increased',
#       'qualified_predicate': 'causes'},
#      'requestBody': {'body': {'q': '{{ queryInputs }}',
#        'scopes': 'subject.umls'}},
#      'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#      'source': 'infores:semmeddb',
#      'supportBatch': True,
#      'useTemplating': True}],
#    'aapp-AUGMENTS-bpoc-rev': [{'agent_type': 'text_mining_agent',
#      'inputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#      'knowledge_level': 'not_provided',
#      'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
# ...
#      {'$ref': '#/components/x-bte-kgs-operations/fndg-PREDISPOSES-fndg-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/nusq-PART_OF-virs'},
#      {'$ref': '#/components/x-bte-kgs-operations/nusq-PART_OF-virs-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/patf-AFFECTS-dsyn'},
#      {'$ref': '#/components/x-bte-kgs-operations/patf-AFFECTS-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/nusq-COEXISTS_WITH-gngm'},
#      {'$ref': '#/components/x-bte-kgs-operations/nusq-COEXISTS_WITH-gngm-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-CAUSES-mobd'},
#      {'$ref': '#/components/x-bte-kgs-operations/celc-PART_OF-virs'},
#      {'$ref': '#/components/x-bte-kgs-operations/celc-PART_OF-virs-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/celf-AFFECTS-patf'},
#      {'$ref': '#/components/x-bte-kgs-operations/celf-AFFECTS-patf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/sosy-COEXISTS_WITH-sosy'},
#      {'$ref': '#/components/x-bte-kgs-operations/sosy-COEXISTS_WITH-sosy-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-INTERACTS_WITH-nsba'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-AFFECTS-biof'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-AFFECTS-biof-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bpoc-PRODUCES-aapp'},
#      {'$ref': '#/components/x-bte-kgs-operations/bpoc-PRODUCES-aapp-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/celc-LOCATION_OF-bsoj'},
#      {'$ref': '#/components/x-bte-kgs-operations/celc-LOCATION_OF-bsoj-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/phsu-AUGMENTS-moft'},
#      {'$ref': '#/components/x-bte-kgs-operations/phsu-AUGMENTS-moft-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs_umls-INHIBITS-gngm_ncbigene'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs_umls-INHIBITS-gngm_ncbigene-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bact-PRODUCES-bacs'},
#      {'$ref': '#/components/x-bte-kgs-operations/bact-PRODUCES-bacs-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-DISRUPTS-orgf'},
#      {'$ref': '#/components/x-bte-kgs-operations/orgf-AFFECTS-orga'},
#      {'$ref': '#/components/x-bte-kgs-operations/orgf-AFFECTS-orga-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-PREVENTS-patf'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-PREVENTS-patf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-INTERACTS_WITH-carb'},
#      {'$ref': '#/components/x-bte-kgs-operations/emst_umls-LOCATION_OF-aapp_ncbigene-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/horm-INTERACTS_WITH-horm'},
#      {'$ref': '#/components/x-bte-kgs-operations/horm-INTERACTS_WITH-horm-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/lipd-PART_OF-bpoc-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-PREDISPOSES-dsyn'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-PREDISPOSES-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/celf-AFFECTS-bacs'},
#      {'$ref': '#/components/x-bte-kgs-operations/celf-AFFECTS-bacs-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/lipd-CAUSES-patf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-AFFECTS-bpoc'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-AFFECTS-bpoc-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-INTERACTS_WITH-nnon'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm-AFFECTS-orgf'},
#      {'$ref': '#/components/x-bte-kgs-operations/bsoj-LOCATION_OF-celc'},
#      {'$ref': '#/components/x-bte-kgs-operations/bsoj-LOCATION_OF-celc-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-AUGMENTS-celf_umls-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/phsu-CAUSES-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/hops-ASSOCIATED_WITH-neop-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/topp-PREVENTS-inpo'},
#      {'$ref': '#/components/x-bte-kgs-operations/fngs-LOCATION_OF-bacs'},
#      {'$ref': '#/components/x-bte-kgs-operations/fngs-LOCATION_OF-bacs-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/cell-LOCATION_OF-diap'},
#      {'$ref': '#/components/x-bte-kgs-operations/cell-LOCATION_OF-diap-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/nusq-ASSOCIATED_WITH-neop'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-AFFECTS-patf'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-AFFECTS-patf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-DISRUPTS-celf_umls'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-DISRUPTS-celf_umls-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-AFFECTS-cell'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-AFFECTS-cell-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-INTERACTS_WITH-imft'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-INTERACTS_WITH-imft-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/diap-DIAGNOSES-mobd'},
#      {'$ref': '#/components/x-bte-kgs-operations/neop-CAUSES-neop'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-AUGMENTS-phsf'},
#      {'$ref': '#/components/x-bte-kgs-operations/carb-CAUSES-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/medd-TREATS-neop'},
#      {'$ref': '#/components/x-bte-kgs-operations/imft-ASSOCIATED_WITH-neop'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-INTERACTS_WITH-lipd'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-DISRUPTS-cell'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-DISRUPTS-cell-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/fndg-PREDISPOSES-neop'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm-DISRUPTS-celf'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm-DISRUPTS-celf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-PREVENTS-dsyn'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-PREVENTS-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm-INTERACTS_WITH-gngm'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm-INTERACTS_WITH-gngm-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/diap-DIAGNOSES-sosy'},
#      {'$ref': '#/components/x-bte-kgs-operations/acab-COEXISTS_WITH-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/celf-AFFECTS-neop'},
#      {'$ref': '#/components/x-bte-kgs-operations/celf-AFFECTS-neop-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-AFFECTS-dsyn'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-AFFECTS-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-CAUSES-comd'},
#      {'$ref': '#/components/x-bte-kgs-operations/cell-LOCATION_OF-bact'},
#      {'$ref': '#/components/x-bte-kgs-operations/cell-LOCATION_OF-bact-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-PRODUCES-inch'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-PRODUCES-inch-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-AFFECTS-phsf'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-COEXISTS_WITH-orch'},
#      {'$ref': '#/components/x-bte-kgs-operations/acab-PART_OF-neop'},
#      {'$ref': '#/components/x-bte-kgs-operations/acab-PART_OF-neop-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs_umls-INTERACTS_WITH-aapp_ncbigene'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs_umls-INTERACTS_WITH-aapp_ncbigene-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp_ncbigene-COEXISTS_WITH-gngm_ncbigene'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp_ncbigene-COEXISTS_WITH-gngm_ncbigene-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/celc-PART_OF-neop'},
#      {'$ref': '#/components/x-bte-kgs-operations/celc-PART_OF-neop-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/topp-USES-orch'},
#      {'$ref': '#/components/x-bte-kgs-operations/nnon-INTERACTS_WITH-aapp-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-PRODUCES-aapp_umls'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-PRODUCES-aapp_umls-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/lipd-AUGMENTS-celf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/moft-CAUSES-celf'},
#      {'$ref': '#/components/x-bte-kgs-operations/moft-CAUSES-celf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/horm-CAUSES-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-TREATS-dsyn'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-TREATS-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-AFFECTS-moft_umls-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/phsu-PREVENTS-patf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/phsu-INHIBITS-ortf'},
#      {'$ref': '#/components/x-bte-kgs-operations/phsu-INHIBITS-ortf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/nusq-PART_OF-celc'},
#      {'$ref': '#/components/x-bte-kgs-operations/nusq-PART_OF-celc-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp_ncbigene-DISRUPTS-celf_umls-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/imft-PART_OF-bact'},
#      {'$ref': '#/components/x-bte-kgs-operations/imft-PART_OF-bact-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs-COEXISTS_WITH-orch'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-INTERACTS_WITH-gngm_umls'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-INTERACTS_WITH-gngm_umls-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/hops-INHIBITS-gngm-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/fngs_umls-LOCATION_OF-aapp_ncbigene'},
#      {'$ref': '#/components/x-bte-kgs-operations/fngs_umls-LOCATION_OF-aapp_ncbigene-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/orga-PREDISPOSES-dsyn'},
#      {'$ref': '#/components/x-bte-kgs-operations/orga-PREDISPOSES-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bsoj-LOCATION_OF-acab'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm-INTERACTS_WITH-bacs'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm-INTERACTS_WITH-bacs-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/tisu-LOCATION_OF-gngm-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-INHIBITS-ortf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs_ncbigene-PART_OF-aapp_ncbigene'},
#      {'$ref': '#/components/x-bte-kgs-operations/bacs_ncbigene-PART_OF-aapp_ncbigene-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-ASSOCIATED_WITH-sosy'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-ASSOCIATED_WITH-sosy-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-AFFECTS-bpoc'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-AFFECTS-bpoc-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/inch-CAUSES-inpo-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm-AFFECTS-moft'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm-AFFECTS-moft-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/nsba-PART_OF-celc-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/virs-COEXISTS_WITH-dsyn'},
#      {'$ref': '#/components/x-bte-kgs-operations/virs-COEXISTS_WITH-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bpoc-LOCATION_OF-nsba'},
#      {'$ref': '#/components/x-bte-kgs-operations/dsyn-COEXISTS_WITH-sosy'},
#      {'$ref': '#/components/x-bte-kgs-operations/dsyn-COEXISTS_WITH-sosy-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/tisu-LOCATION_OF-bact-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/strd-ASSOCIATED_WITH-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm-PART_OF-fngs'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm-PART_OF-fngs-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-AUGMENTS-ortf'},
#      {'$ref': '#/components/x-bte-kgs-operations/imft-PART_OF-celc'},
#      {'$ref': '#/components/x-bte-kgs-operations/imft-PART_OF-celc-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/nnon-ADMINISTERED_TO-cell'},
#      {'$ref': '#/components/x-bte-kgs-operations/nnon-ADMINISTERED_TO-cell-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bsoj-LOCATION_OF-sosy'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-COEXISTS_WITH-aapp'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-COEXISTS_WITH-aapp-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/bact-LOCATION_OF-carb'},
#      {'$ref': '#/components/x-bte-kgs-operations/inch-CAUSES-comd-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/patf-AFFECTS-orgf'},
#      {'$ref': '#/components/x-bte-kgs-operations/patf-AFFECTS-orgf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/tisu-LOCATION_OF-virs-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/antb-CAUSES-inpo-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-STIMULATES-horm'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-STIMULATES-horm-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-AUGMENTS-tisu'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-INTERACTS_WITH-elii'},
#      {'$ref': '#/components/x-bte-kgs-operations/virs-LOCATION_OF-aapp'},
#      {'$ref': '#/components/x-bte-kgs-operations/virs-LOCATION_OF-aapp-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/orgf-ASSOCIATED_WITH-sosy'},
#      {'$ref': '#/components/x-bte-kgs-operations/orgf-ASSOCIATED_WITH-sosy-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/elii-AUGMENTS-celf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/topp-AFFECTS-celf'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_umls-PRODUCES-aapp_ncbigene'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_umls-PRODUCES-aapp_ncbigene-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-PRODUCES-aapp'},
#      {'$ref': '#/components/x-bte-kgs-operations/aapp-PRODUCES-aapp-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/dsyn-COEXISTS_WITH-cgab'},
#      {'$ref': '#/components/x-bte-kgs-operations/tisu-LOCATION_OF-bsoj-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/phsu-AFFECTS-orgf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/lipd_umls-STIMULATES-gngm_ncbigene-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-PART_OF-fngs_umls'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-PART_OF-fngs_umls-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/horm_ncbigene-TREATS-dsyn_umls'},
#      {'$ref': '#/components/x-bte-kgs-operations/horm_ncbigene-TREATS-dsyn_umls-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/cgab-COEXISTS_WITH-dsyn-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-COEXISTS_WITH-aapp'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-COEXISTS_WITH-aapp-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-INHIBITS-aapp'},
#      {'$ref': '#/components/x-bte-kgs-operations/orch-INHIBITS-aapp-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/inpo-PRECEDES-celf'},
#      {'$ref': '#/components/x-bte-kgs-operations/inpo-PRECEDES-celf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-CAUSES-dsyn_umls'},
#      {'$ref': '#/components/x-bte-kgs-operations/gngm_ncbigene-CAUSES-dsyn_umls-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/plnt-LOCATION_OF-strd'},
#      {'$ref': '#/components/x-bte-kgs-operations/carb-AUGMENTS-celf-rev'},
#      {'$ref': '#/components/x-bte-kgs-operations/cell-LOCATION_OF-bacs'},
#      ...]}}},
#  'servers': [{'description': 'Production server',
#    'url': 'https://biothings.ncats.io/semmeddb',
#    'x-maturity': 'production'},
#   {'description': 'ITRB Test server',
#    'url': 'https://biothings.test.transltr.io/semmeddb',
#    'x-maturity': 'testing'},
#   {'description': 'ITRB CI server',
#    'url': 'https://biothings.ci.transltr.io/semmeddb',
#    'x-maturity': 'staging'}],
#  'tags': [{'name': 'disease'},
#   {'name': 'phenotype'},
#   {'name': 'gene'},
#   {'name': 'chemical'},
#   {'name': 'association'},
#   {'name': 'query'},
#   {'name': 'translator'},
#   {'name': 'biothings'},
#   {'name': 'ngd'}]}

# %%
sample_smartapi_doc["components"]
# Out:
# {'parameters': {'callback': {'description': 'Optional, you can pass a "callback" parameter to make a JSONP call.',
#    'in': 'query',
#    'name': 'callback',
#    'required': False,
#    'schema': {'type': 'string'}},
#   'dotfield': {'description': 'Optional, can be used to control the format of the returned object.  If "dotfield" is true, the returned data object is returned flattened (no nested objects)  using dotfield notation for key names. Default: false.',
#    'in': 'query',
#    'name': 'dotfield',
#    'required': False,
#    'schema': {'default': False, 'type': 'boolean'}},
#   'email': {'description': 'Optional, if you are regular users of our services, we encourage you to provide us an email,  so that we can better track the usage or follow up with you.',
#    'in': 'query',
#    'name': 'email',
#    'required': False,
#    'schema': {'type': 'string'}},
#   'facet_size': {'description': 'Optional, an integer (1 <= facet_size <= 1000) that specifies how many buckets to return in a  [faceted query](https://docs.mychem.info/en/latest/doc/chem_query_service.html?highlight=from#faceted-queries).',
#    'in': 'query',
#    'name': 'facet_size',
#    'required': False,
#    'schema': {'default': 10, 'type': 'integer'}},
#   'facets': {'description': 'Optional, a single field or comma-separated fields to return facets, can only be used on non-free text fields.  E.g. “facets=chembl.molecule_properties.full_mwt”. See [examples of faceted queries for a core BioThings  API](https://docs.mychem.info/en/latest/doc/chem_query_service.html?highlight=from#faceted-queries).',
#    'in': 'query',
#    'name': 'facets',
#    'required': False,
#    'schema': {'items': {'type': 'string'}, 'type': 'array'}},
#   'fetch_all': {'description': 'Optional, a boolean, which when TRUE, allows fast retrieval of all unsorted query hits.  The return object contains a _scroll_id field, which when passed as a parameter to the query endpoint  (see the scroll_id parameter), returns the next 1000 query results. Setting fetch_all = TRUE causes  the results to be inherently unsorted, therefore the sort parameter is ignored. For more information,  see [examples using fetch_all for a core BioThings  API](https://docs.mychem.info/en/latest/doc/chem_query_service.html?highlight=from#scrolling-queries).  Default: FALSE.',
#    'in': 'query',
#    'name': 'fetch_all',
#    'required': False,
#    'schema': {'default': False, 'type': 'boolean'}},
#   'fields': {'description': 'Optional, can be a comma-separated list to limit the fields returned from the object.  If "fields=all", all available fields will be returned.\n\nNote that it supports dot notation as well, e.g., you can pass "chebi.name".  Default: "fields=all".  The parameter "filter" is an alias for this parameter.',
#    'in': 'query',
#    'name': 'fields',
#    'required': False,
#    'schema': {'default': 'all', 'type': 'string'}},
#   'from': {'description': 'Optional, the number of matching hits to skip, starting from 0. Default: 0. ',
#    'in': 'query',
#    'name': 'from',
#    'required': False,
#    'schema': {'default': 0, 'type': 'integer'}},
#   'scroll_id': {'description': 'Optional, a string containing the _scroll_id returned from a query request with fetch_all = TRUE.  Supplying a valid scroll_id will return the next 1000 unordered results. If the next results are  not obtained within 1 minute of the previous set of results, the scroll_id becomes stale, and a  new one must be obtained with another query request with fetch_all = TRUE. All other parameters are  ignored when the scroll_id parameter is supplied. For more information see [examples using scroll_id  for a core BioThings  API](https://docs.mychem.info/en/latest/doc/chem_query_service.html?highlight=from#scrolling-queries).',
#    'in': 'query',
#    'name': 'scroll_id',
#    'required': False,
#    'schema': {'type': 'string'}},
#   'size': {'description': 'Optional, the maximum number of matching hits to return (with a cap of 1000 at the moment). Default: 10. The combination of "size" and "from" parameters can be used to get paging for a large query.',
#    'in': 'query',
#    'name': 'size',
#    'required': False,
#    'schema': {'default': 10, 'type': 'integer'}},
#   'sort': {'description': 'Optional, the comma-separated fields to sort on. Prefix with "-" for descending order, otherwise in ascending order.  Default: sort by matching scores in descending order.',
#    'in': 'query',
#    'name': 'sort',
#    'required': False,
#    'schema': {'items': {'type': 'string'}, 'type': 'array'}}},
#  'x-bte-kgs-operations': {'aapp-ADMINISTERED_TO-cell': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ADMINISTERED_TO AND object.semantic_type_abbreviation:cell AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-ADMINISTERED_TO-cell-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ADMINISTERED_TO AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-acab': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:acab AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-anab': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:anab AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-anst': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'AnatomicalEntity'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:anst AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-anst-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'AnatomicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-biof': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:biof AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-biof-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-bpoc': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:bpoc AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-bpoc-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-celc': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'CellularComponent'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:celc AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-celc-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'CellularComponent'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-celf': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:celf AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-celf-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-cell': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:cell AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-cell-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-cgab': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:cgab AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-comd': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:comd AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-dsyn': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:dsyn AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-dsyn-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-emod': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'BiologicalEntity'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:emod AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-emod-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'BiologicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-emst': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:emst AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-fndg': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'DiseaseOrPhenotypicFeature'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:fndg AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-fndg-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'DiseaseOrPhenotypicFeature'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-inpo': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:inpo AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-mobd': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:mobd AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-moft': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'MolecularActivity'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:moft AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-moft-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'MolecularActivity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-neop': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:neop AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-orgf': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:orgf AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-ortf': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:ortf AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-patf': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:patf AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-patf-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-phsf': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:phsf AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-sosy': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:sosy AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-sosy-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AFFECTS-tisu': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:tisu AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-ASSOCIATED_WITH-comd': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:comd AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-ASSOCIATED_WITH-dsyn': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:dsyn AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-ASSOCIATED_WITH-dsyn-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ASSOCIATED_WITH AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-ASSOCIATED_WITH-inpo': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:inpo AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-ASSOCIATED_WITH-mobd': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:mobd AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-ASSOCIATED_WITH-neop': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:neop AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-ASSOCIATED_WITH-patf': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:patf AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-ASSOCIATED_WITH-patf-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ASSOCIATED_WITH AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-ASSOCIATED_WITH-sosy': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:sosy AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-ASSOCIATED_WITH-sosy-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:ASSOCIATED_WITH AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'related_to',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AUGMENTS-acab': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:acab AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#      'object_direction_qualifier': 'increased',
#      'qualified_predicate': 'causes'},
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AUGMENTS-anab': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:anab AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#      'object_direction_qualifier': 'increased',
#      'qualified_predicate': 'causes'},
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AUGMENTS-biof': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:biof AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#      'object_direction_qualifier': 'increased',
#      'qualified_predicate': 'causes'},
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AUGMENTS-biof-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AUGMENTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'qualifiers': {'qualified_predicate': 'caused_by',
#      'subject_aspect_qualifier': 'activity_or_abundance',
#      'subject_direction_qualifier': 'increased'},
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AUGMENTS-bpoc': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:bpoc AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#      'object_direction_qualifier': 'increased',
#      'qualified_predicate': 'causes'},
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AUGMENTS-bpoc-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AUGMENTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'qualifiers': {'qualified_predicate': 'caused_by',
#      'subject_aspect_qualifier': 'activity_or_abundance',
#      'subject_direction_qualifier': 'increased'},
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AUGMENTS-celc': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'CellularComponent'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:celc AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#      'object_direction_qualifier': 'increased',
#      'qualified_predicate': 'causes'},
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'aapp-AUGMENTS-celc-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'CellularComponent'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
# ...
#      'filter': 'predicate:INHIBITS AND object.semantic_type_abbreviation:ortf AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#      'object_direction_qualifier': 'decreased',
#      'qualified_predicate': 'causes'},
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INHIBITS-ortf-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INHIBITS AND subject.semantic_type_abbreviation:bacs AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affected_by',
#     'qualifiers': {'qualified_predicate': 'caused_by',
#      'subject_aspect_qualifier': 'activity_or_abundance',
#      'subject_direction_qualifier': 'decreased'},
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INHIBITS-phsu': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INHIBITS AND object.semantic_type_abbreviation:phsu AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#      'object_direction_qualifier': 'decreased',
#      'qualified_predicate': 'causes'},
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INHIBITS-strd': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INHIBITS AND object.semantic_type_abbreviation:strd AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'affects',
#     'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#      'object_direction_qualifier': 'decreased',
#      'qualified_predicate': 'causes'},
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-aapp': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:aapp AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-aapp-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND subject.semantic_type_abbreviation:bacs AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-antb': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:antb AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-bacs': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:bacs AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-bacs-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND subject.semantic_type_abbreviation:bacs AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-carb': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:carb AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-cell': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:cell AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-cell-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND subject.semantic_type_abbreviation:bacs AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-eico': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:eico AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-elii': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:elii AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-enzy': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Protein'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:enzy AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-gngm': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:gngm AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-gngm-rev': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND subject.semantic_type_abbreviation:bacs AND _exists_:subject.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'object.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-horm': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:horm AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   'bacs-INTERACTS_WITH-imft': [{'agent_type': 'text_mining_agent',
#     'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#     'knowledge_level': 'not_provided',
#     'outputs': [{'id': 'UMLS', 'semantic': 'BiologicalEntity'}],
#     'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#      'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:imft AND _exists_:object.umls AND pmid_count:>3',
#      'size': 1000},
#     'predicate': 'interacts_with',
#     'requestBody': {'body': {'q': '{{ queryInputs }}',
#       'scopes': 'subject.umls'}},
#     'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#     'source': 'infores:semmeddb',
#     'supportBatch': True,
#     'useTemplating': True}],
#   ...},
#  'x-bte-response-mapping': {'ncbigene-obj': {'NCBIGene': 'object.ncbigene',
#    'biolink:supporting_text': 'predication.sentence',
#    'input_name': 'subject.name',
#    'output_name': 'object.name',
#    'ref_pmid': 'predication.pmid'},
#   'ncbigene-subj': {'NCBIGene': 'subject.ncbigene',
#    'biolink:supporting_text': 'predication.sentence',
#    'input_name': 'object.name',
#    'output_name': 'subject.name',
#    'ref_pmid': 'predication.pmid'},
#   'umls-obj': {'UMLS': 'object.umls',
#    'biolink:supporting_text': 'predication.sentence',
#    'input_name': 'subject.name',
#    'output_name': 'object.name',
#    'ref_pmid': 'predication.pmid'},
#   'umls-subj': {'UMLS': 'subject.umls',
#    'biolink:supporting_text': 'predication.sentence',
#    'input_name': 'object.name',
#    'output_name': 'subject.name',
#    'ref_pmid': 'predication.pmid'}}}

# %%
sample_smartapi_doc["components"]["x-bte-kgs-operations"]
# Out:
# {'aapp-ADMINISTERED_TO-cell': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ADMINISTERED_TO AND object.semantic_type_abbreviation:cell AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-ADMINISTERED_TO-cell-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ADMINISTERED_TO AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-acab': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:acab AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-anab': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:anab AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-anst': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'AnatomicalEntity'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:anst AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-anst-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'AnatomicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-biof': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:biof AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-biof-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-bpoc': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:bpoc AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-bpoc-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-celc': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'CellularComponent'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:celc AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-celc-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'CellularComponent'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-celf': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:celf AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-celf-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-cell': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:cell AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-cell-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-cgab': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:cgab AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-comd': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:comd AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-dsyn': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:dsyn AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-dsyn-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-emod': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'BiologicalEntity'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:emod AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-emod-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'BiologicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-emst': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:emst AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-fndg': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'DiseaseOrPhenotypicFeature'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:fndg AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-fndg-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'DiseaseOrPhenotypicFeature'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-inpo': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:inpo AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-mobd': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:mobd AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-moft': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'MolecularActivity'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:moft AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-moft-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'MolecularActivity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-neop': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:neop AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-orgf': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:orgf AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-ortf': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:ortf AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-patf': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:patf AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-patf-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-phsf': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:phsf AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-sosy': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:sosy AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-sosy-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AFFECTS-tisu': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AFFECTS AND object.semantic_type_abbreviation:tisu AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-ASSOCIATED_WITH-comd': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:comd AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-ASSOCIATED_WITH-dsyn': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:dsyn AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-ASSOCIATED_WITH-dsyn-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ASSOCIATED_WITH AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-ASSOCIATED_WITH-inpo': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:inpo AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-ASSOCIATED_WITH-mobd': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:mobd AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-ASSOCIATED_WITH-neop': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:neop AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-ASSOCIATED_WITH-patf': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:patf AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-ASSOCIATED_WITH-patf-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'PathologicalProcess'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ASSOCIATED_WITH AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-ASSOCIATED_WITH-sosy': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ASSOCIATED_WITH AND object.semantic_type_abbreviation:sosy AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-ASSOCIATED_WITH-sosy-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:ASSOCIATED_WITH AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'related_to',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-acab': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:acab AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#     'object_direction_qualifier': 'increased',
#     'qualified_predicate': 'causes'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-anab': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PhenotypicFeature'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:anab AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#     'object_direction_qualifier': 'increased',
#     'qualified_predicate': 'causes'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-biof': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:biof AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#     'object_direction_qualifier': 'increased',
#     'qualified_predicate': 'causes'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-biof-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Phenomenon'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'qualifiers': {'qualified_predicate': 'caused_by',
#     'subject_aspect_qualifier': 'activity_or_abundance',
#     'subject_direction_qualifier': 'increased'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-bpoc': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:bpoc AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#     'object_direction_qualifier': 'increased',
#     'qualified_predicate': 'causes'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-bpoc-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'GrossAnatomicalStructure'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'qualifiers': {'qualified_predicate': 'caused_by',
#     'subject_aspect_qualifier': 'activity_or_abundance',
#     'subject_direction_qualifier': 'increased'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-celc': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'CellularComponent'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:celc AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#     'object_direction_qualifier': 'increased',
#     'qualified_predicate': 'causes'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-celc-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'CellularComponent'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'qualifiers': {'qualified_predicate': 'caused_by',
#     'subject_aspect_qualifier': 'activity_or_abundance',
#     'subject_direction_qualifier': 'increased'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-celf': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:celf AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#     'object_direction_qualifier': 'increased',
#     'qualified_predicate': 'causes'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-celf-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'qualifiers': {'qualified_predicate': 'caused_by',
#     'subject_aspect_qualifier': 'activity_or_abundance',
#     'subject_direction_qualifier': 'increased'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-cell': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:cell AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#     'object_direction_qualifier': 'increased',
#     'qualified_predicate': 'causes'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-cell-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND subject.semantic_type_abbreviation:aapp AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'qualifiers': {'qualified_predicate': 'caused_by',
#     'subject_aspect_qualifier': 'activity_or_abundance',
#     'subject_direction_qualifier': 'increased'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-comd': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:AUGMENTS AND object.semantic_type_abbreviation:comd AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#     'object_direction_qualifier': 'increased',
#     'qualified_predicate': 'causes'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'aapp-AUGMENTS-dsyn': [{'agent_type': 'text_mining_agent',
# ...
#    'inputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INHIBITS AND subject.semantic_type_abbreviation:bacs AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'qualifiers': {'qualified_predicate': 'caused_by',
#     'subject_aspect_qualifier': 'activity_or_abundance',
#     'subject_direction_qualifier': 'decreased'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INHIBITS-ortf': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INHIBITS AND object.semantic_type_abbreviation:ortf AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#     'object_direction_qualifier': 'decreased',
#     'qualified_predicate': 'causes'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INHIBITS-ortf-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'PhysiologicalProcess'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INHIBITS AND subject.semantic_type_abbreviation:bacs AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affected_by',
#    'qualifiers': {'qualified_predicate': 'caused_by',
#     'subject_aspect_qualifier': 'activity_or_abundance',
#     'subject_direction_qualifier': 'decreased'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INHIBITS-phsu': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INHIBITS AND object.semantic_type_abbreviation:phsu AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#     'object_direction_qualifier': 'decreased',
#     'qualified_predicate': 'causes'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INHIBITS-strd': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INHIBITS AND object.semantic_type_abbreviation:strd AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'affects',
#    'qualifiers': {'object_aspect_qualifier': 'activity_or_abundance',
#     'object_direction_qualifier': 'decreased',
#     'qualified_predicate': 'causes'},
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-aapp': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:aapp AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-aapp-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Polypeptide'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND subject.semantic_type_abbreviation:bacs AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-antb': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:antb AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-bacs': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:bacs AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-bacs-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND subject.semantic_type_abbreviation:bacs AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-carb': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:carb AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-cell': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:cell AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-cell-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND subject.semantic_type_abbreviation:bacs AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-eico': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:eico AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-elii': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:elii AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-enzy': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Protein'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:enzy AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-gngm': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:gngm AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-gngm-rev': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'Gene'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'parameters': {'fields': 'subject.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND subject.semantic_type_abbreviation:bacs AND _exists_:subject.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'object.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-subj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-horm': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'SmallMolecule'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:horm AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  'bacs-INTERACTS_WITH-imft': [{'agent_type': 'text_mining_agent',
#    'inputs': [{'id': 'UMLS', 'semantic': 'ChemicalEntity'}],
#    'knowledge_level': 'not_provided',
#    'outputs': [{'id': 'UMLS', 'semantic': 'BiologicalEntity'}],
#    'parameters': {'fields': 'object.umls,predication.pmid,predication.sentence,subject.name,object.name',
#     'filter': 'predicate:INTERACTS_WITH AND object.semantic_type_abbreviation:imft AND _exists_:object.umls AND pmid_count:>3',
#     'size': 1000},
#    'predicate': 'interacts_with',
#    'requestBody': {'body': {'q': '{{ queryInputs }}',
#      'scopes': 'subject.umls'}},
#    'response_mapping': {'$ref': '#/components/x-bte-response-mapping/umls-obj'},
#    'source': 'infores:semmeddb',
#    'supportBatch': True,
#    'useTemplating': True}],
#  ...}

# %%
sample_smartapi_doc["components"]["x-bte-response-mapping"]
# Out:
# {'ncbigene-obj': {'NCBIGene': 'object.ncbigene',
#   'biolink:supporting_text': 'predication.sentence',
#   'input_name': 'subject.name',
#   'output_name': 'object.name',
#   'ref_pmid': 'predication.pmid'},
#  'ncbigene-subj': {'NCBIGene': 'subject.ncbigene',
#   'biolink:supporting_text': 'predication.sentence',
#   'input_name': 'object.name',
#   'output_name': 'subject.name',
#   'ref_pmid': 'predication.pmid'},
#  'umls-obj': {'UMLS': 'object.umls',
#   'biolink:supporting_text': 'predication.sentence',
#   'input_name': 'subject.name',
#   'output_name': 'object.name',
#   'ref_pmid': 'predication.pmid'},
#  'umls-subj': {'UMLS': 'subject.umls',
#   'biolink:supporting_text': 'predication.sentence',
#   'input_name': 'object.name',
#   'output_name': 'subject.name',
#   'ref_pmid': 'predication.pmid'}}

# %% [markdown]
# ### Get Specific API Metadata
#
# **Endpoint:** https://smart-api.info/api/query?q=mygene
# https://smart-api.info/api/query?q=info.title:%22MyGene.info%20API%22
#
# **Example:**

# %%
# Fetch the list of APIs (equivalent to indices in Elasticsearch)
response = requests.get(f"{BASE_URL}/query?q=mygene")
response.raise_for_status()

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    mygene_apis = response.json()
    # Print the keys of the returned JSON for inspection
    print("-"*100)
    for api in mygene_apis['hits']:
        print(api['info']['title'])
        print(api['tags'])
# Out:
# ----------------------------------------------------------------------------------------------------
# MyGene.info API
# [{'name': 'gene'}, {'name': 'annotation'}, {'name': 'query'}, {'name': 'translator'}, {'name': 'biothings'}]
# SmartAPI API
# [{'name': 'api'}, {'name': 'metadata'}, {'name': 'openapi'}, {'name': 'translator'}, {'name': 'metakg'}]
# MyGene.info API (for test)
# [{'name': 'Genes', 'x-id': 'http://purl.bioontology.org/ontology/MESH/D005796'}]

# %%
# Fetch the list of APIs (equivalent to indices in Elasticsearch)
response = requests.get(f'{BASE_URL}/query?q=info.title:"MyGene.info%20API"')
response.raise_for_status()

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    mygene_apis = response.json()
    # Print the keys of the returned JSON for inspection
    print("-"*100)
    for api in mygene_apis['hits']:
        print(api['info']['title'])
        print(api['tags'])
# Out:
# ----------------------------------------------------------------------------------------------------
# MyGene.info API
# [{'name': 'gene'}, {'name': 'annotation'}, {'name': 'query'}, {'name': 'translator'}, {'name': 'biothings'}]
# MyGene.info API (for test)
# [{'name': 'Genes', 'x-id': 'http://purl.bioontology.org/ontology/MESH/D005796'}]

# %% [markdown]
# ### Get TRAPI APIs
# Endpoint: https://smart-api.info/api/query?q=trapi
#             https://smart-api.info/api/query?q=tags.name:trapi
#
# Registry: https://smart-api.info/registry?q=trapi

# %%
# Fetch the list of APIs (equivalent to indices in Elasticsearch)
response = requests.get(f'{BASE_URL}/query?q=tags.name:trapi')
response.raise_for_status()

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    trapi_apis = response.json()
    print(f"Total APIs: {trapi_apis['total']}")
    # Print the keys of the returned JSON for inspection
    for api in trapi_apis['hits']:
        print(api['info']['title'])
        print(api['tags'])
# Out:
# Total APIs: 55
# ICEES COVID Instance API - production
# [{'name': 'metadata'}, {'name': 'trapi'}]
# ICEES DILI Instance API - production
# [{'name': 'metadata'}, {'name': 'trapi'}]
# ICEES PCD Instance API - production
# [{'name': 'metadata'}, {'name': 'trapi'}]
# ICEES Asthma Instance API - production
# [{'name': 'metadata'}, {'name': 'trapi'}]
# Sri-answer-appraiser(Trapi v1.5.0)
# [{'name': 'translator'}, {'name': 'trapi'}]
# Workflow-runner(Trapi v1.5.0)
# [{'name': 'translator'}, {'name': 'trapi'}]
# Automat-monarchinitiative(Trapi v1.5.0)
# [{'name': 'translator'}, {'name': 'trapi'}]
# Cqs(Trapi v1.5.0)
# [{'name': 'translator'}, {'name': 'trapi'}]
# mediKanren
# [{'description': 'Initiate a query and wait to receive the response', 'name': 'query'}, {'description': 'Required for SmartAPI validation of x-translator', 'name': 'translator'}, {'description': 'Required for SmartAPI validation of x-trapi', 'name': 'trapi'}]
# Automat-panther(Trapi v1.5.0)
# [{'name': 'translator'}, {'name': 'automat'}, {'name': 'trapi'}]

# %% [markdown]
# ### Get Biothings APIs
#
# Endpoint: https://smart-api.info/api/query?q=tags.name:biothings

# %%
size=100

# %%
# Function to search APIs by query
def search_apis(query):
    response = requests.get(f"{BASE_URL}/query?q={query}&size={size}")
    if response.status_code == 200:
        apis = response.json()
        print(f"Total APIs: {apis['total']}")
        df = pd.DataFrame(apis['hits'])  # Convert results to a DataFrame
        display(df[['info', 'tags']].head())
    else:
        print("Error searching APIs:", response.status_code)

print("\n### Search APIs by Query: 'disease' ###")
search_apis('disease')
# Out:
# ### Search APIs by Query: 'disease' ###
# Total APIs: 35
#                                                 info
# 0  {'contact': {'email': 'lschriml@som.umaryland....  \
# 1  {'contact': {'email': 'help@biothings.io', 'na...
# 2  {'contact': {'email': 'help@biothings.io', 'na...
# 3  {'contact': {'email': 'cl3720@cumc.columbia.ed...
# 4  {'contact': {'email': 'cl3720@cumc.columbia.ed...
#
#                                                 tags
# 0  [{'name': 'disease'}, {'name': 'ontology'}, {'...
# 1  [{'name': 'association'}, {'name': 'pathway'},...
# 2  [{'name': 'disease'}, {'name': 'annotation'}, ...
# 3  [{'description': 'OARD metadata', 'name': 'Met...
# 4  [{'description': 'OARD metadata', 'name': 'Met...

# %% [markdown]
# ## SmartAPI MetaKG
