# %%
from admin import backup, _restore, restore_from_file

# %%
backup_file='/Users/nacosta/Documents/smartAPI/files_backup/smartapi_20240725.json'

# %%
restore_from_file(backup_file)
# Out:
# INFO:elastic_transport.transport:HEAD http://localhost:9200/smartapi_docs [status:404 duration:0.005s]
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/elasticsearch_dsl/_sync/index.py:274: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   return self._get_connection(using).indices.exists(index=self._name, **kwargs)
# INFO:elastic_transport.transport:HEAD http://localhost:9200/smartapi_docs [status:404 duration:0.001s]
# INFO:elastic_transport.transport:HEAD http://localhost:9200/smartapi_docs [status:404 duration:0.001s]
# INFO:elastic_transport.transport:HEAD http://localhost:9200/smartapi_docs [status:404 duration:0.001s]
# INFO:elastic_transport.transport:PUT http://localhost:9200/smartapi_docs [status:200 duration:0.645s]
# ...

# %%
from admin import refresh_document

# %%
refresh_document()
# Out:
# INFO:elastic_transport.transport:POST http://localhost:9200/smartapi_docs/_search [status:200 duration:0.038s]
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/elasticsearch_dsl/_sync/search.py:77: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.17/security-minimal-setup.html to enable security.
#   es.search(index=self._index, body=self.to_dict(), **self._params)
# INFO:elastic_transport.transport:GET http://localhost:9200/smartapi_docs/_doc/1dad992a6ce8f680e59a5ea09d90670d [status:200 duration:0.002s]
# ...
