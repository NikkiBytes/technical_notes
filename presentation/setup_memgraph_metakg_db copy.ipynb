# %% [markdown]
# # Building a `Memgraph` database with the `MetaKG` index

# %%
import pprint as pp 
import mgclient # memgraph client

from controller.metakg import MetaKG
from model import ConsolidatedMetaKGDoc

# %%
conn = mgclient.connect(host="localhost", port=7687)   # connect to memgraph
conn.autocommit = True  # autocommit mode is required for DDL queries
cursor = conn.cursor() # cursor is used to execute queries

# %%
# load all 
cursor.execute("CALL mg.load_all();")

# %%
# Load only the specific module
cursor.execute("CALL mg.load('algo');")

# %%
cursor.execute("CALL mg.procedures() YIELD *")

# %%
print("Available Procedures:")
results = cursor.fetchall()
for result in results:
    print(result)
# Out:
# Available Procedures:
# (True, False, 'algo.all_simple_paths', '/usr/lib/memgraph/query_modules/algo.so', 'algo.all_simple_paths(start_node :: NODE, end_node :: NODE, relationship_types :: LIST OF STRING, max_length :: INTEGER) :: (path :: PATH)')
# (True, False, 'algo.astar', '/usr/lib/memgraph/query_modules/algo.so', 'algo.astar(start :: NODE, target :: NODE, config :: MAP) :: (path :: PATH, weight :: FLOAT)')
# (True, False, 'algo.cover', '/usr/lib/memgraph/query_modules/algo.so', 'algo.cover(nodes :: LIST OF NODE) :: (rel :: RELATIONSHIP)')
# (True, False, 'betweenness_centrality.get', '/usr/lib/memgraph/query_modules/betweenness_centrality.so', 'betweenness_centrality.get(directed = true :: BOOLEAN, normalized = true :: BOOLEAN, threads = 8 :: INTEGER) :: (betweenness_centrality :: FLOAT, node :: NODE)')
# (True, False, 'betweenness_centrality_online.get', '/usr/lib/memgraph/query_modules/betweenness_centrality_online.so', 'betweenness_centrality_online.get(normalize = true :: BOOLEAN) :: (betweenness_centrality :: FLOAT, node :: NODE)')
# (True, False, 'betweenness_centrality_online.reset', '/usr/lib/memgraph/query_modules/betweenness_centrality_online.so', 'betweenness_centrality_online.reset() :: (message :: STRING)')
# (True, False, 'betweenness_centrality_online.set', '/usr/lib/memgraph/query_modules/betweenness_centrality_online.so', 'betweenness_centrality_online.set(normalize = true :: BOOLEAN, threads = 8 :: INTEGER) :: (betweenness_centrality :: FLOAT, node :: NODE)')
# (True, False, 'betweenness_centrality_online.update', '/usr/lib/memgraph/query_modules/betweenness_centrality_online.so', 'betweenness_centrality_online.update(created_vertices = [] :: LIST OF NODE, created_edges = [] :: LIST OF RELATIONSHIP, deleted_vertices = [] :: LIST OF NODE, deleted_edges = [] :: LIST OF RELATIONSHIP, normalize = true :: BOOLEAN, threads = 8 :: INTEGER) :: (betweenness_centrality :: FLOAT, node :: NODE)')
# (True, False, 'biconnected_components.get', '/usr/lib/memgraph/query_modules/biconnected_components.so', 'biconnected_components.get() :: (bcc_id :: INTEGER, node_from :: NODE, node_to :: NODE)')
# (True, False, 'bipartite_matching.max', '/usr/lib/memgraph/query_modules/bipartite_matching.so', 'bipartite_matching.max() :: (maximum_bipartite_matching :: INTEGER)')
# (True, False, 'bridges.get', '/usr/lib/memgraph/query_modules/bridges.so', 'bridges.get() :: (node_from :: NODE, node_to :: NODE)')
# (True, False, 'collections.partition', '/usr/lib/memgraph/query_modules/collections.so', 'collections.partition(list :: LIST OF ANY, partition_size :: INTEGER) :: (result :: LIST OF ANY)')
# (True, False, 'collections.split', '/usr/lib/memgraph/query_modules/collections.so', 'collections.split(coll :: LIST OF ANY, delimiter :: ANY) :: (splitted :: LIST OF ANY)')
# (True, False, 'community_detection.get', '/usr/lib/memgraph/query_modules/community_detection.so', 'community_detection.get(weight = "weight" :: STRING, coloring = false :: BOOLEAN, min_graph_shrink = 100000 :: INTEGER, community_alg_threshold = 1e-06 :: FLOAT, coloring_alg_threshold = 0.01 :: FLOAT) :: (community_id :: INTEGER, node :: NODE)')
# (True, False, 'community_detection.get_subgraph', '/usr/lib/memgraph/query_modules/community_detection.so', 'community_detection.get_subgraph(subgraph_nodes :: LIST OF NODE, subgraph_relationships :: LIST OF RELATIONSHIP, weight = "weight" :: STRING, coloring = false :: BOOLEAN, min_graph_shrink = 100000 :: INTEGER, community_alg_threshold = 1e-06 :: FLOAT, coloring_alg_threshold = 0.01 :: FLOAT) :: (community_id :: INTEGER, node :: NODE)')
# (True, False, 'community_detection_online.get', '/usr/lib/memgraph/query_modules/community_detection_online.so', 'community_detection_online.get() :: (community_id :: INTEGER, node :: NODE)')
# (True, False, 'community_detection_online.reset', '/usr/lib/memgraph/query_modules/community_detection_online.so', 'community_detection_online.reset() :: (message :: STRING)')
# (True, False, 'community_detection_online.set', '/usr/lib/memgraph/query_modules/community_detection_online.so', 'community_detection_online.set(directed = false :: BOOLEAN, weighted = false :: BOOLEAN, similarity_threshold = 0.7 :: FLOAT, exponent = 4 :: FLOAT, min_value = 0.1 :: FLOAT, weight_property = "weight" :: STRING, w_selfloop = 1 :: FLOAT, max_iterations = 5 :: INTEGER, max_updates = 100 :: INTEGER) :: (community_id :: INTEGER, node :: NODE)')
# (True, False, 'community_detection_online.update', '/usr/lib/memgraph/query_modules/community_detection_online.so', 'community_detection_online.update(createdVertices = [] :: LIST OF NODE, createdEdges = [] :: LIST OF RELATIONSHIP, updatedVertices = [] :: LIST OF NODE, updatedEdges = [] :: LIST OF RELATIONSHIP, deletedVertices = [] :: LIST OF NODE, deletedEdges = [] :: LIST OF RELATIONSHIP) :: (community_id :: INTEGER, node :: NODE)')
# (True, True, 'create.node', '/usr/lib/memgraph/query_modules/create.so', 'create.node(label :: LIST OF STRING, props :: MAP) :: (node :: NODE)')
# (True, True, 'create.nodes', '/usr/lib/memgraph/query_modules/create.so', 'create.nodes(label :: LIST OF STRING, props :: LIST OF MAP) :: (node :: NODE)')
# (True, True, 'create.relationship', '/usr/lib/memgraph/query_modules/create.so', 'create.relationship(from :: NODE, relationshipType :: STRING, properties :: MAP, to :: NODE) :: (relationship :: RELATIONSHIP)')
# (True, True, 'create.remove_labels', '/usr/lib/memgraph/query_modules/create.so', 'create.remove_labels(nodes :: ANY, label :: LIST OF STRING) :: (node :: NODE)')
# (True, True, 'create.remove_properties', '/usr/lib/memgraph/query_modules/create.so', 'create.remove_properties(nodes :: ANY, keys :: LIST OF STRING) :: (node :: NODE)')
# (True, True, 'create.remove_rel_properties', '/usr/lib/memgraph/query_modules/create.so', 'create.remove_rel_properties(relationships :: ANY, keys :: LIST OF STRING) :: (relationship :: RELATIONSHIP)')
# (True, True, 'create.set_properties', '/usr/lib/memgraph/query_modules/create.so', 'create.set_properties(input_nodes :: ANY, input_keys :: LIST OF STRING, input_values :: LIST OF ANY) :: (node :: NODE)')
# (True, True, 'create.set_property', '/usr/lib/memgraph/query_modules/create.so', 'create.set_property(nodes :: ANY, key :: STRING, value :: ANY) :: (node :: NODE)')
# (True, True, 'create.set_rel_properties', '/usr/lib/memgraph/query_modules/create.so', 'create.set_rel_properties(relationships :: ANY, keys :: LIST OF STRING, values :: LIST OF ANY) :: (relationship :: RELATIONSHIP)')
# (True, True, 'create.set_rel_property', '/usr/lib/memgraph/query_modules/create.so', 'create.set_rel_property(input_rel :: ANY, input_key :: STRING, input_value :: ANY) :: (relationship :: RELATIONSHIP)')
# (True, False, 'csv_utils.create_csv_file', '/usr/lib/memgraph/query_modules/csv_utils.so', 'csv_utils.create_csv_file(filepath :: STRING, content :: STRING, is_append = false :: BOOLEAN) :: (filepath :: STRING)')
# (True, False, 'csv_utils.delete_csv_file', '/usr/lib/memgraph/query_modules/csv_utils.so', 'csv_utils.delete_csv_file(filepath :: STRING) :: ()')
# (True, False, 'cycles.get', '/usr/lib/memgraph/query_modules/cycles.so', 'cycles.get() :: (cycle_id :: INTEGER, node :: NODE)')
# (True, False, 'date.format', '/usr/lib/memgraph/query_modules/date.py', 'date.format(time :: INTEGER, unit = "ms" :: STRING, format = "%Y-%m-%d %H:%M:%S %Z" :: STRING, timezone = "UTC" :: STRING) :: (formatted :: STRING)')
# (True, False, 'date.parse', '/usr/lib/memgraph/query_modules/date.py', 'date.parse(time :: STRING, unit = "ms" :: STRING, format = "%Y-%m-%d %H:%M:%S" :: STRING, timezone = "UTC" :: STRING) :: (parsed :: INTEGER)')
# (True, False, 'degree_centrality.get', '/usr/lib/memgraph/query_modules/degree_centrality.so', 'degree_centrality.get(type = Null :: STRING?) :: (degree :: FLOAT, node :: NODE)')
# (True, False, 'degree_centrality.get_subgraph', '/usr/lib/memgraph/query_modules/degree_centrality.so', 'degree_centrality.get_subgraph(subgraph_nodes :: LIST OF NODE, subgraph_relationships :: LIST OF RELATIONSHIP, type = Null :: STRING?) :: (degree :: FLOAT, node :: NODE)')
# (True, False, 'distance_calculator.multiple', '/usr/lib/memgraph/query_modules/distance_calculator.so', 'distance_calculator.multiple(start :: LIST OF NODE, end :: LIST OF NODE, metrics = "m" :: STRING, decimals = 2 :: INTEGER) :: (distances :: LIST OF FLOAT)')
# (True, False, 'distance_calculator.single', '/usr/lib/memgraph/query_modules/distance_calculator.so', 'distance_calculator.single(start_point :: NODE, end_point :: NODE, metrics = "m" :: STRING, decimals = 2 :: INTEGER) :: (distance :: FLOAT)')
# (True, False, 'do.case', '/usr/lib/memgraph/query_modules/do.so', 'do.case(conditionals :: LIST OF ANY, else_query :: STRING, params = {} :: MAP) :: (value :: MAP)')
# (True, False, 'do.when', '/usr/lib/memgraph/query_modules/do.so', 'do.when(condition :: BOOLEAN, if_query :: STRING, else_query :: STRING, params = {} :: MAP) :: (value :: MAP)')
# (True, False, 'elastic_search_serialization.connect', '/usr/lib/memgraph/query_modules/elastic_search_serialization.py', 'elastic_search_serialization.connect(elastic_url :: STRING, ca_certs :: STRING, elastic_user :: STRING, elastic_password :: ANY?) :: (connection_status :: MAP)')
# (True, False, 'elastic_search_serialization.create_index', '/usr/lib/memgraph/query_modules/elastic_search_serialization.py', 'elastic_search_serialization.create_index(index_name :: STRING, schema_path :: STRING, schema_parameters :: MAP) :: (response :: MAP)')
# (True, False, 'elastic_search_serialization.index', '/usr/lib/memgraph/query_modules/elastic_search_serialization.py', 'elastic_search_serialization.index(createdObjects :: LIST OF MAP, node_index :: STRING, edge_index :: STRING, thread_count = 1 :: INTEGER, chunk_size = 500 :: INTEGER, max_chunk_bytes = 104857600 :: INTEGER, raise_on_error = true :: BOOLEAN, raise_on_exception = true :: BOOLEAN, max_retries = 0 :: INTEGER, initial_backoff = 2 :: FLOAT, max_backoff = 600 :: FLOAT, yield_ok = true :: BOOLEAN, queue_size = 4 :: INTEGER) :: (edges :: INTEGER, nodes :: INTEGER)')
# (True, False, 'elastic_search_serialization.index_db', '/usr/lib/memgraph/query_modules/elastic_search_serialization.py', 'elastic_search_serialization.index_db(node_index :: STRING, edge_index :: STRING, thread_count = 1 :: INTEGER, chunk_size = 500 :: INTEGER, max_chunk_bytes = 104857600 :: INTEGER, raise_on_error = true :: BOOLEAN, raise_on_exception = true :: BOOLEAN, max_retries = 0 :: INTEGER, initial_backoff = 2 :: FLOAT, max_backoff = 600 :: FLOAT, yield_ok = true :: BOOLEAN, queue_size = 4 :: INTEGER) :: (edges :: INTEGER, nodes :: INTEGER)')
# (True, False, 'elastic_search_serialization.reindex', '/usr/lib/memgraph/query_modules/elastic_search_serialization.py', 'elastic_search_serialization.reindex(source_index :: ANY, target_index :: STRING, query :: STRING, chunk_size = 500 :: INTEGER, scroll = "5m" :: STRING, op_type = Null :: STRING?) :: (response :: STRING)')
# (True, False, 'elastic_search_serialization.scan', '/usr/lib/memgraph/query_modules/elastic_search_serialization.py', 'elastic_search_serialization.scan(index_name :: STRING, query :: STRING, scroll = "5m" :: STRING, raise_on_error = true :: BOOLEAN, preserve_order = false :: BOOLEAN, size = 1000 :: INTEGER, from_ = 0 :: INTEGER, request_timeout = Null :: FLOAT?, clear_scroll = false :: BOOLEAN) :: (items :: LIST OF MAP)')
# (True, False, 'elastic_search_serialization.search', '/usr/lib/memgraph/query_modules/elastic_search_serialization.py', 'elastic_search_serialization.search(index_name :: STRING, query :: STRING, size = 1000 :: INTEGER, from_ = 0 :: INTEGER, aggregations = Null :: MAP?, aggs = Null :: MAP?) :: (result :: MAP)')
# (True, False, 'example_c.procedure', '/usr/lib/memgraph/query_modules/example_c.so', 'example_c.procedure(required_arg :: ANY?, optional_arg = Null :: ANY?) :: (args :: LIST OF ANY?, result :: STRING)')
# (True, True, 'example_c.write_procedure', '/usr/lib/memgraph/query_modules/example_c.so', 'example_c.write_procedure(required_arg :: STRING) :: (created_vertex :: NODE)')
# (True, False, 'export_util.csv_graph', '/usr/lib/memgraph/query_modules/export_util.py', 'export_util.csv_graph(nodes_list :: LIST OF NODE, relationships_list :: LIST OF RELATIONSHIP, path = "" :: STRING, config = {} :: MAP) :: (data :: STRING, path :: STRING)')
# (True, False, 'export_util.csv_query', '/usr/lib/memgraph/query_modules/export_util.py', 'export_util.csv_query(query :: STRING, file_path = "" :: STRING, stream = false :: BOOLEAN) :: (data :: STRING, file_path :: STRING)')
# (True, False, 'export_util.cypher_all', '/usr/lib/memgraph/query_modules/export_util.py', 'export_util.cypher_all(path = "" :: STRING, config = {} :: MAP) :: (data :: STRING, path :: STRING)')
# (True, False, 'export_util.graphml', '/usr/lib/memgraph/query_modules/export_util.py', 'export_util.graphml(path = "" :: STRING, config = Null :: MAP?) :: (status :: STRING)')
# (True, False, 'export_util.json', '/usr/lib/memgraph/query_modules/export_util.py', 'export_util.json(path = "" :: STRING, config = {} :: MAP) :: (data :: STRING, path :: STRING)')
# (True, False, 'export_util.json_graph', '/usr/lib/memgraph/query_modules/export_util.py', 'export_util.json_graph(nodes :: LIST OF ANY?, relationships :: LIST OF ANY?, path = "" :: STRING, config = {} :: MAP) :: (data :: STRING, path :: STRING)')
# (True, False, 'graph_analyzer.analyze', '/usr/lib/memgraph/query_modules/graph_analyzer.py', 'graph_analyzer.analyze(analyses = Null :: LIST? OF STRING) :: (name :: STRING, value :: STRING)')
# (True, False, 'graph_analyzer.analyze_subgraph', '/usr/lib/memgraph/query_modules/graph_analyzer.py', 'graph_analyzer.analyze_subgraph(vertices :: LIST OF NODE, edges :: LIST OF RELATIONSHIP, analyses = Null :: LIST? OF STRING) :: (name :: STRING, value :: STRING)')
# (True, False, 'graph_analyzer.help', '/usr/lib/memgraph/query_modules/graph_analyzer.py', 'graph_analyzer.help() :: (name :: STRING, value :: STRING)')
# (True, False, 'graph_coloring.color_graph', '/usr/lib/memgraph/query_modules/graph_coloring.py', 'graph_coloring.color_graph(parameters = {} :: MAP, edge_property = "weight" :: STRING) :: (color :: INTEGER, node :: NODE)')
# (True, False, 'graph_coloring.color_subgraph', '/usr/lib/memgraph/query_modules/graph_coloring.py', 'graph_coloring.color_subgraph(vertices :: LIST OF NODE, edges :: LIST OF RELATIONSHIP, parameters = {} :: MAP, edge_property = "weight" :: STRING) :: (color :: INTEGER, node :: NODE)')
# (True, False, 'graph_util.ancestors', '/usr/lib/memgraph/query_modules/graph_util.so', 'graph_util.ancestors(node :: NODE) :: (ancestors :: LIST OF NODE)')
# (True, True, 'graph_util.chain_nodes', '/usr/lib/memgraph/query_modules/graph_util.so', 'graph_util.chain_nodes(nodes :: LIST OF NODE, edge_type :: STRING) :: (connections :: LIST OF RELATIONSHIP)')
# (True, False, 'graph_util.connect_nodes', '/usr/lib/memgraph/query_modules/graph_util.so', 'graph_util.connect_nodes(nodes :: LIST OF NODE) :: (connections :: LIST OF RELATIONSHIP)')
# (True, False, 'graph_util.descendants', '/usr/lib/memgraph/query_modules/graph_util.so', 'graph_util.descendants(node :: NODE) :: (descendants :: LIST OF NODE)')
# (True, False, 'graph_util.topological_sort', '/usr/lib/memgraph/query_modules/graph_util.so', 'graph_util.topological_sort() :: (sorted_nodes :: LIST OF NODE)')
# (True, False, 'igraphalg.all_shortest_path_lengths', '/usr/lib/memgraph/query_modules/igraphalg.py', 'igraphalg.all_shortest_path_lengths(weights = Null :: STRING?, directed = false :: BOOLEAN) :: (dest_node :: NODE, length :: FLOAT, src_node :: NODE)')
# (True, False, 'igraphalg.community_leiden', '/usr/lib/memgraph/query_modules/igraphalg.py', 'igraphalg.community_leiden(objective_function = "CPM" :: STRING, weights = Null :: STRING?, resolution_parameter = 1 :: FLOAT, beta = 0.01 :: FLOAT, initial_membership = Null :: LIST? OF INTEGER?, n_iterations = 2 :: INTEGER, node_weights = Null :: LIST? OF FLOAT?) :: (community_id :: INTEGER, node :: NODE)')
# (True, False, 'igraphalg.get_all_simple_paths', '/usr/lib/memgraph/query_modules/igraphalg.py', 'igraphalg.get_all_simple_paths(v :: NODE, to :: NODE, cutoff = -1 :: INTEGER) :: (path :: LIST OF NODE)')
# (True, False, 'igraphalg.get_shortest_path', '/usr/lib/memgraph/query_modules/igraphalg.py', 'igraphalg.get_shortest_path(source :: NODE, target :: NODE, weights = Null :: STRING?, directed = true :: BOOLEAN) :: (path :: LIST OF NODE)')
# (True, False, 'igraphalg.maxflow', '/usr/lib/memgraph/query_modules/igraphalg.py', 'igraphalg.maxflow(source :: NODE, target :: NODE, capacity = "weight" :: STRING) :: (max_flow :: NUMBER)')
# (True, False, 'igraphalg.mincut', '/usr/lib/memgraph/query_modules/igraphalg.py', 'igraphalg.mincut(source :: NODE, target :: NODE, capacity = Null :: STRING?, directed = true :: BOOLEAN) :: (node :: NODE, partition_id :: INTEGER)')
# (True, False, 'igraphalg.pagerank', '/usr/lib/memgraph/query_modules/igraphalg.py', 'igraphalg.pagerank(damping = 0.85 :: NUMBER, weights = Null :: STRING?, directed = true :: BOOLEAN, implementation = "prpack" :: STRING) :: (node :: NODE, rank :: FLOAT)')
# (True, False, 'igraphalg.shortest_path_length', '/usr/lib/memgraph/query_modules/igraphalg.py', 'igraphalg.shortest_path_length(source :: NODE, target :: NODE, weights = Null :: STRING?, directed = true :: BOOLEAN) :: (length :: FLOAT)')
# (True, False, 'igraphalg.spanning_tree', '/usr/lib/memgraph/query_modules/igraphalg.py', 'igraphalg.spanning_tree(weights = Null :: STRING?, directed = false :: BOOLEAN) :: (tree :: LIST OF LIST OF NODE)')
# (True, False, 'igraphalg.topological_sort', '/usr/lib/memgraph/query_modules/igraphalg.py', 'igraphalg.topological_sort(mode = "out" :: STRING) :: (nodes :: LIST OF NODE)')
# (True, True, 'import_util.cypher', '/usr/lib/memgraph/query_modules/import_util.py', 'import_util.cypher(path :: STRING) :: ()')
# (True, True, 'import_util.graphml', '/usr/lib/memgraph/query_modules/import_util.py', 'import_util.graphml(path = "" :: STRING, config = Null :: MAP?) :: (status :: STRING)')
# (True, True, 'import_util.json', '/usr/lib/memgraph/query_modules/import_util.py', 'import_util.json(path :: STRING) :: ()')
# (True, False, 'json_util.load_from_path', '/usr/lib/memgraph/query_modules/json_util.py', 'json_util.load_from_path(path :: STRING) :: (objects :: LIST OF ANY?)')
# (True, False, 'json_util.load_from_url', '/usr/lib/memgraph/query_modules/json_util.py', 'json_util.load_from_url(url :: STRING) :: (objects :: LIST OF ANY?)')
# (True, False, 'katz_centrality.get', '/usr/lib/memgraph/query_modules/katz_centrality.so', 'katz_centrality.get(alpha = 0.2 :: FLOAT, epsilon = 0.01 :: FLOAT) :: (node :: NODE, rank :: FLOAT)')
# (True, False, 'katz_centrality_online.get', '/usr/lib/memgraph/query_modules/katz_centrality_online.so', 'katz_centrality_online.get() :: (node :: NODE, rank :: FLOAT)')
# (True, False, 'katz_centrality_online.reset', '/usr/lib/memgraph/query_modules/katz_centrality_online.so', 'katz_centrality_online.reset() :: (message :: STRING)')
# (True, False, 'katz_centrality_online.set', '/usr/lib/memgraph/query_modules/katz_centrality_online.so', 'katz_centrality_online.set(alpha = 0.2 :: FLOAT, epsilon = 0.01 :: FLOAT) :: (node :: NODE, rank :: FLOAT)')
# (True, False, 'katz_centrality_online.update', '/usr/lib/memgraph/query_modules/katz_centrality_online.so', 'katz_centrality_online.update(created_vertices = [] :: LIST? OF NODE, created_edges = [] :: LIST? OF RELATIONSHIP, deleted_vertices = [] :: LIST? OF NODE, deleted_edges = [] :: LIST? OF RELATIONSHIP) :: (node :: NODE, rank :: FLOAT)')
# (True, False, 'kmeans.get_clusters', '/usr/lib/memgraph/query_modules/kmeans.py', 'kmeans.get_clusters(n_clusters :: NUMBER, embedding_property = "embedding" :: STRING, init = "k-means++" :: STRING, n_init = 10 :: NUMBER, max_iter = 10 :: NUMBER, tol = 0.0001 :: NUMBER, algorithm = "auto" :: STRING, random_state = 1998 :: INTEGER) :: (cluster_id :: NUMBER, node :: NODE)')
# (True, True, 'kmeans.set_clusters', '/usr/lib/memgraph/query_modules/kmeans.py', 'kmeans.set_clusters(n_clusters :: NUMBER, embedding_property = "embedding" :: STRING, cluster_property = "cluster_id" :: ANY?, init = "k-means++" :: STRING, n_init = 10 :: NUMBER, max_iter = 10 :: NUMBER, tol = 0.0001 :: NUMBER, algorithm = "auto" :: STRING, random_state = 1998 :: ANY?) :: (cluster_id :: NUMBER, node :: NODE)')
# (True, False, 'link_prediction.get_training_results', '/usr/lib/memgraph/query_modules/link_prediction.py', 'link_prediction.get_training_results() :: (training_results :: ANY, validation_results :: ANY)')
# (True, False, 'link_prediction.load_model', '/usr/lib/memgraph/query_modules/link_prediction.py', 'link_prediction.load_model(path = "/tmp/" :: STRING) :: (status :: ANY)')
# (True, False, 'link_prediction.predict', '/usr/lib/memgraph/query_modules/link_prediction.py', 'link_prediction.predict(src_vertex :: NODE, dest_vertex :: NODE) :: (score :: NUMBER)')
# (True, False, 'link_prediction.recommended_vertex', '/usr/lib/memgraph/query_modules/link_prediction.py', 'link_prediction.recommended_vertex(src_vertex :: NODE, dest_vertices :: LIST OF NODE, k :: INTEGER) :: (recommendation :: NODE, score :: NUMBER)')
# (True, False, 'link_prediction.reset_parameters', '/usr/lib/memgraph/query_modules/link_prediction.py', 'link_prediction.reset_parameters() :: (status :: ANY)')
# (True, False, 'link_prediction.set_model_parameters', '/usr/lib/memgraph/query_modules/link_prediction.py', 'link_prediction.set_model_parameters(parameters :: MAP) :: (message :: STRING, status :: BOOLEAN)')
# (True, False, 'link_prediction.train', '/usr/lib/memgraph/query_modules/link_prediction.py', 'link_prediction.train() :: (training_results :: ANY, validation_results :: ANY)')
# (True, False, 'llm_util.schema', '/usr/lib/memgraph/query_modules/llm_util.py', 'llm_util.schema(output_type = "prompt_ready" :: STRING) :: (schema :: ANY)')
# (True, False, 'map.from_nodes', '/usr/lib/memgraph/query_modules/map.so', 'map.from_nodes(label :: STRING, property :: STRING) :: (map :: MAP)')
# (True, False, 'max_flow.get_flow', '/usr/lib/memgraph/query_modules/max_flow.py', 'max_flow.get_flow(start_v :: NODE, end_v :: NODE, edge_property = "weight" :: STRING) :: (max_flow :: NUMBER)')
# (True, False, 'max_flow.get_paths', '/usr/lib/memgraph/query_modules/max_flow.py', 'max_flow.get_paths(start_v :: NODE, end_v :: NODE, edge_property = "weight" :: STRING) :: (flow :: NUMBER, path :: PATH)')
# (True, True, 'merge.node', '/usr/lib/memgraph/query_modules/merge.so', 'merge.node(labels :: LIST OF STRING, identProps :: MAP, createProps :: MAP, matchProps :: MAP) :: (node :: NODE)')
# (True, True, 'merge.relationship', '/usr/lib/memgraph/query_modules/merge.so', 'merge.relationship(startNode :: NODE, relationshipType :: STRING, identProps :: MAP, createProps :: MAP, endNode :: NODE, matchProps :: MAP) :: (rel :: RELATIONSHIP)')
# (True, False, 'meta.reset', '/usr/lib/memgraph/query_modules/meta.so', 'meta.reset() :: ()')
# (True, False, 'meta.stats_offline', '/usr/lib/memgraph/query_modules/meta.so', 'meta.stats_offline() :: (labelCount :: INTEGER, labels :: MAP, nodeCount :: INTEGER, propertyKeyCount :: INTEGER, relationshipCount :: INTEGER, relationshipTypeCount :: INTEGER, relationshipTypes :: MAP, relationshipTypesCount :: MAP, stats :: MAP)')
# (True, False, 'meta.stats_online', '/usr/lib/memgraph/query_modules/meta.so', 'meta.stats_online(update_stats = false :: BOOLEAN) :: (labelCount :: INTEGER, labels :: MAP, nodeCount :: INTEGER, propertyKeyCount :: INTEGER, relationshipCount :: INTEGER, relationshipTypeCount :: INTEGER, relationshipTypes :: MAP, relationshipTypesCount :: MAP, stats :: MAP)')
# (True, False, 'meta.update', '/usr/lib/memgraph/query_modules/meta.so', 'meta.update(createdObjects :: LIST OF MAP, deletedObjects :: LIST OF MAP, removedVertexProperties :: LIST OF MAP, removedEdgeProperties :: LIST OF MAP, setVertexLabels :: LIST OF MAP, removedVertexLabels :: LIST OF MAP) :: ()')
# (True, False, 'meta_util.schema', '/usr/lib/memgraph/query_modules/meta_util.py', 'meta_util.schema(include_properties = false :: BOOLEAN) :: (nodes :: LIST OF MAP, relationships :: LIST OF MAP)')
# (False, False, 'mg.create_module_file', 'builtin', 'mg.create_module_file(filename :: STRING, content :: STRING) :: (path :: STRING)')
# (False, False, 'mg.delete_module_file', 'builtin', 'mg.delete_module_file(path :: STRING) :: ()')
# (False, False, 'mg.functions', 'builtin', 'mg.functions() :: (is_editable :: BOOLEAN, name :: STRING, path :: STRING, signature :: STRING)')
# (False, False, 'mg.get_module_file', 'builtin', 'mg.get_module_file(path :: STRING) :: (content :: STRING)')
# (False, False, 'mg.get_module_files', 'builtin', 'mg.get_module_files() :: (is_editable :: BOOLEAN, path :: STRING)')
# (False, False, 'mg.kafka_set_stream_offset', 'builtin', 'mg.kafka_set_stream_offset(stream_name :: STRING, offset :: INTEGER) :: ()')
# (False, False, 'mg.kafka_stream_info', 'builtin', 'mg.kafka_stream_info(stream_name :: STRING) :: (bootstrap_servers :: STRING, configs :: MAP, consumer_group :: STRING, credentials :: MAP, topics :: LIST OF STRING)')
# (False, False, 'mg.load', 'builtin', 'mg.load(module_name :: STRING) :: ()')
# (False, False, 'mg.load_all', 'builtin', 'mg.load_all() :: ()')
# (False, False, 'mg.procedures', 'builtin', 'mg.procedures() :: (is_editable :: BOOLEAN, is_write :: BOOLEAN, name :: STRING, path :: STRING, signature :: STRING)')
# (False, False, 'mg.pulsar_stream_info', 'builtin', 'mg.pulsar_stream_info(stream_name :: STRING) :: (service_url :: STRING, topics :: LIST OF STRING)')
# (False, False, 'mg.transformations', 'builtin', 'mg.transformations() :: (is_editable :: BOOLEAN, name :: STRING, path :: STRING)')
# (False, False, 'mg.update_module_file', 'builtin', 'mg.update_module_file(path :: STRING, content :: STRING) :: ()')
# (True, False, 'mgps.components', '/usr/lib/memgraph/query_modules/mgps.py', 'mgps.components() :: (edition :: STRING, name :: STRING, versions :: LIST OF ANY?)')
# (True, False, 'migrate.mysql', '/usr/lib/memgraph/query_modules/migrate.py', 'migrate.mysql(table_or_sql :: STRING, config :: MAP, config_path = "" :: STRING, params = Null :: ANY?) :: (row :: MAP)')
# (True, False, 'migrate.oracle_db', '/usr/lib/memgraph/query_modules/migrate.py', 'migrate.oracle_db(table_or_sql :: STRING, config :: MAP, config_path = "" :: STRING, params = Null :: ANY?) :: (row :: MAP)')
# (True, False, 'migrate.sql_server', '/usr/lib/memgraph/query_modules/migrate.py', 'migrate.sql_server(table_or_sql :: STRING, config :: MAP, config_path = "" :: STRING, params = Null :: ANY?) :: (row :: MAP)')
# (True, False, 'neighbors.at_hop', '/usr/lib/memgraph/query_modules/neighbors.so', 'neighbors.at_hop(node :: NODE, rel_type :: LIST OF STRING, distance :: INTEGER) :: (nodes :: NODE)')
# (True, False, 'neighbors.by_hop', '/usr/lib/memgraph/query_modules/neighbors.so', 'neighbors.by_hop(node :: NODE, rel_type :: LIST OF STRING, distance :: INTEGER) :: (nodes :: LIST OF NODE)')
# (True, False, 'node.relationship_exists', '/usr/lib/memgraph/query_modules/node.so', 'node.relationship_exists(node :: NODE, pattern = [] :: LIST OF STRING) :: (exists :: BOOLEAN)')
# (True, False, 'node.relationship_types', '/usr/lib/memgraph/query_modules/node.so', 'node.relationship_types(node :: NODE, types = [] :: LIST OF STRING) :: (relationship_types :: LIST OF STRING)')
# (True, False, 'node.relationships_exist', '/usr/lib/memgraph/query_modules/node.so', 'node.relationships_exist(node :: NODE, relationships :: LIST OF STRING) :: (result :: MAP)')
# (True, False, 'node2vec.get_embeddings', '/usr/lib/memgraph/query_modules/node2vec.py', 'node2vec.get_embeddings(is_directed = false :: BOOLEAN, p = 2 :: ANY?, q = 0.5 :: ANY?, num_walks = 4 :: ANY?, walk_length = 5 :: ANY?, vector_size = 100 :: ANY?, alpha = 0.025 :: ANY?, window = 5 :: ANY?, min_count = 1 :: ANY?, seed = 1 :: ANY?, workers = 1 :: ANY?, min_alpha = 0.0001 :: ANY?, sg = 1 :: ANY?, hs = 0 :: ANY?, negative = 5 :: ANY?, epochs = 5 :: ANY?, edge_weight_property = "weight" :: ANY?) :: (embeddings :: LIST OF LIST OF NUMBER, nodes :: LIST OF NODE)')
# (True, False, 'node2vec.help', '/usr/lib/memgraph/query_modules/node2vec.py', 'node2vec.help() :: (name :: STRING, value :: STRING)')
# (True, True, 'node2vec.set_embeddings', '/usr/lib/memgraph/query_modules/node2vec.py', 'node2vec.set_embeddings(is_directed = false :: BOOLEAN, p = 2 :: ANY?, q = 0.5 :: ANY?, num_walks = 4 :: ANY?, walk_length = 5 :: ANY?, vector_size = 100 :: ANY?, alpha = 0.025 :: ANY?, window = 5 :: ANY?, min_count = 1 :: ANY?, seed = 1 :: ANY?, workers = 1 :: ANY?, min_alpha = 0.0001 :: ANY?, sg = 1 :: ANY?, hs = 0 :: ANY?, negative = 5 :: ANY?, epochs = 5 :: ANY?, edge_weight_property = "weight" :: ANY?) :: (embeddings :: LIST OF LIST OF NUMBER, nodes :: LIST OF NODE)')
# (True, False, 'node2vec_online.get', '/usr/lib/memgraph/query_modules/node2vec_online.py', 'node2vec_online.get() :: (embedding :: LIST OF NUMBER, node :: NODE)')
# (True, False, 'node2vec_online.help', '/usr/lib/memgraph/query_modules/node2vec_online.py', 'node2vec_online.help() :: (name :: STRING, value :: STRING)')
# (True, False, 'node2vec_online.reset', '/usr/lib/memgraph/query_modules/node2vec_online.py', 'node2vec_online.reset() :: (message :: STRING)')
# (True, False, 'node2vec_online.set_streamwalk_updater', '/usr/lib/memgraph/query_modules/node2vec_online.py', 'node2vec_online.set_streamwalk_updater(half_life = 7200 :: INTEGER, max_length = 3 :: INTEGER, beta = 0.9 :: NUMBER, cutoff = 604800 :: INTEGER, sampled_walks = 4 :: INTEGER, full_walks = false :: BOOLEAN) :: (message :: STRING)')
# (True, False, 'node2vec_online.set_word2vec_learner', '/usr/lib/memgraph/query_modules/node2vec_online.py', 'node2vec_online.set_word2vec_learner(embedding_dimension = 128 :: INTEGER, learning_rate = 0.01 :: NUMBER, skip_gram = true :: BOOLEAN, negative_rate = 10 :: NUMBER, threads = Null :: INTEGER?) :: (message :: STRING)')
# (True, False, 'node2vec_online.update', '/usr/lib/memgraph/query_modules/node2vec_online.py', 'node2vec_online.update(edges :: LIST OF RELATIONSHIP) :: ()')
# (True, False, 'node_classification.get_training_data', '/usr/lib/memgraph/query_modules/node_classification.py', 'node_classification.get_training_data() :: (epoch :: INTEGER, loss :: FLOAT, train_log :: ANY, val_log :: ANY, val_loss :: FLOAT)')
# (True, False, 'node_classification.load_model', '/usr/lib/memgraph/query_modules/node_classification.py', 'node_classification.load_model(num = 0 :: INTEGER) :: (path :: STRING, status :: STRING)')
# (True, False, 'node_classification.predict', '/usr/lib/memgraph/query_modules/node_classification.py', 'node_classification.predict(vertex :: NODE) :: (predicted_class :: INTEGER, status :: STRING)')
# (True, False, 'node_classification.reset', '/usr/lib/memgraph/query_modules/node_classification.py', 'node_classification.reset() :: (status :: STRING)')
# (True, False, 'node_classification.save_model', '/usr/lib/memgraph/query_modules/node_classification.py', 'node_classification.save_model() :: (path :: STRING, status :: STRING)')
# (True, False, 'node_classification.set_model_parameters', '/usr/lib/memgraph/query_modules/node_classification.py', 'node_classification.set_model_parameters(params = {} :: ANY) :: (aggregator :: STRING, checkpoint_freq :: INTEGER, console_log_freq :: INTEGER, device_type :: STRING, hidden_features_size :: LIST OF ANY?, layer_type :: STRING, learning_rate :: FLOAT, metrics :: ANY, node_id_property :: STRING, num_epochs :: INTEGER, path_to_model :: STRING, split_ratio :: FLOAT, weight_decay :: FLOAT)')
# (True, False, 'node_classification.train', '/usr/lib/memgraph/query_modules/node_classification.py', 'node_classification.train(num_epochs = 100 :: INTEGER) :: (epoch :: INTEGER, loss :: FLOAT, train_log :: ANY, val_log :: ANY, val_loss :: FLOAT)')
# (True, False, 'node_similarity.cosine', '/usr/lib/memgraph/query_modules/node_similarity.so', 'node_similarity.cosine(property :: STRING) :: (node1 :: NODE, node2 :: NODE, similarity :: FLOAT)')
# (True, False, 'node_similarity.cosine_pairwise', '/usr/lib/memgraph/query_modules/node_similarity.so', 'node_similarity.cosine_pairwise(property :: STRING, src_nodes :: LIST OF NODE, dst_nodes :: LIST OF NODE) :: (node1 :: NODE, node2 :: NODE, similarity :: FLOAT)')
# (True, False, 'node_similarity.jaccard', '/usr/lib/memgraph/query_modules/node_similarity.so', 'node_similarity.jaccard() :: (node1 :: NODE, node2 :: NODE, similarity :: FLOAT)')
# (True, False, 'node_similarity.jaccard_pairwise', '/usr/lib/memgraph/query_modules/node_similarity.so', 'node_similarity.jaccard_pairwise(src_nodes :: LIST OF NODE, dst_nodes :: LIST OF NODE) :: (node1 :: NODE, node2 :: NODE, similarity :: FLOAT)')
# (True, False, 'node_similarity.overlap', '/usr/lib/memgraph/query_modules/node_similarity.so', 'node_similarity.overlap() :: (node1 :: NODE, node2 :: NODE, similarity :: FLOAT)')
# (True, False, 'node_similarity.overlap_pairwise', '/usr/lib/memgraph/query_modules/node_similarity.so', 'node_similarity.overlap_pairwise(src_nodes :: LIST OF NODE, dst_nodes :: LIST OF NODE) :: (node1 :: NODE, node2 :: NODE, similarity :: FLOAT)')
# (True, True, 'nodes.delete', '/usr/lib/memgraph/query_modules/nodes.so', 'nodes.delete(nodes :: ANY) :: ()')
# (True, True, 'nodes.link', '/usr/lib/memgraph/query_modules/nodes.so', 'nodes.link(nodes :: LIST OF NODE, type :: STRING) :: ()')
# (True, False, 'nodes.relationship_types', '/usr/lib/memgraph/query_modules/nodes.so', 'nodes.relationship_types(nodes :: ANY, types = [] :: LIST OF STRING) :: (relationship_types :: LIST OF MAP)')
# (True, False, 'nodes.relationships_exist', '/usr/lib/memgraph/query_modules/nodes.so', 'nodes.relationships_exist(nodes :: LIST OF ANY, relationships :: LIST OF STRING) :: (result :: MAP)')
# (True, False, 'nxalg.all_shortest_paths', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.all_shortest_paths(source :: NODE, target :: NODE, weight = Null :: STRING?, method = "dijkstra" :: STRING) :: (paths :: LIST OF LIST OF NODE)')
# (True, False, 'nxalg.all_simple_paths', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.all_simple_paths(source :: NODE, target :: NODE, cutoff = Null :: INTEGER?) :: (paths :: LIST OF LIST OF NODE)')
# (True, False, 'nxalg.ancestors', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.ancestors(source :: NODE) :: (ancestors :: LIST OF NODE)')
# (True, False, 'nxalg.betweenness_centrality', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.betweenness_centrality(k = Null :: INTEGER?, normalized = true :: BOOLEAN, weight = Null :: STRING?, endpoints = false :: BOOLEAN, seed = Null :: INTEGER?) :: (betweenness :: NUMBER, node :: NODE)')
# (True, False, 'nxalg.bfs_edges', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.bfs_edges(source :: NODE, reverse = false :: BOOLEAN, depth_limit = Null :: INTEGER?) :: (edges :: LIST OF RELATIONSHIP)')
# (True, False, 'nxalg.bfs_predecessors', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.bfs_predecessors(source :: NODE, depth_limit = Null :: INTEGER?) :: (node :: NODE, predecessor :: NODE)')
# (True, False, 'nxalg.bfs_successors', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.bfs_successors(source :: NODE, depth_limit = Null :: INTEGER?) :: (node :: NODE, successors :: LIST OF NODE)')
# (True, False, 'nxalg.bfs_tree', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.bfs_tree(source :: NODE, reverse = false :: BOOLEAN, depth_limit = Null :: INTEGER?) :: (tree :: LIST OF NODE)')
# (True, False, 'nxalg.biconnected_components', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.biconnected_components() :: (components :: LIST OF LIST OF NODE)')
# (True, False, 'nxalg.bridges', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.bridges(root = Null :: NODE?) :: (bridges :: LIST OF RELATIONSHIP)')
# (True, False, 'nxalg.center', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.center() :: (center :: LIST OF NODE)')
# (True, False, 'nxalg.chain_decomposition', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.chain_decomposition(root = Null :: NODE?) :: (chains :: LIST OF LIST OF RELATIONSHIP)')
# (True, False, 'nxalg.check_planarity', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.check_planarity() :: (is_planar :: BOOLEAN)')
# (True, False, 'nxalg.clustering', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.clustering(nodes = Null :: LIST? OF NODE, weight = Null :: STRING?) :: (clustering :: NUMBER, node :: NODE)')
# (True, False, 'nxalg.communicability', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.communicability() :: (communicability :: NUMBER, node1 :: NODE, node2 :: NODE)')
# (True, False, 'nxalg.core_number', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.core_number() :: (core :: NUMBER, node :: NODE)')
# (True, False, 'nxalg.degree_assortativity_coefficient', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.degree_assortativity_coefficient(x = "out" :: STRING, y = "in" :: STRING, weight = Null :: STRING?, nodes = Null :: LIST? OF NODE) :: (assortativity :: FLOAT)')
# (True, False, 'nxalg.descendants', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.descendants(source :: NODE) :: (descendants :: LIST OF NODE)')
# (True, False, 'nxalg.dfs_postorder_nodes', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.dfs_postorder_nodes(source :: NODE, depth_limit = Null :: INTEGER?) :: (nodes :: LIST OF NODE)')
# (True, False, 'nxalg.dfs_predecessors', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.dfs_predecessors(source :: NODE, depth_limit = Null :: INTEGER?) :: (node :: NODE, predecessor :: NODE)')
# (True, False, 'nxalg.dfs_preorder_nodes', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.dfs_preorder_nodes(source :: NODE, depth_limit = Null :: INTEGER?) :: (nodes :: LIST OF NODE)')
# (True, False, 'nxalg.dfs_successors', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.dfs_successors(source :: NODE, depth_limit = Null :: INTEGER?) :: (node :: NODE, successors :: LIST OF NODE)')
# (True, False, 'nxalg.dfs_tree', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.dfs_tree(source :: NODE, depth_limit = Null :: INTEGER?) :: (tree :: LIST OF NODE)')
# (True, False, 'nxalg.diameter', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.diameter() :: (diameter :: INTEGER)')
# (True, False, 'nxalg.dominance_frontiers', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.dominance_frontiers(start :: NODE) :: (frontier :: LIST OF NODE, node :: NODE)')
# (True, False, 'nxalg.dominating_set', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.dominating_set(start :: NODE) :: (dominating_set :: LIST OF NODE)')
# (True, False, 'nxalg.edge_bfs', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.edge_bfs(source = Null :: NODE?, orientation = Null :: STRING?) :: (edges :: LIST OF RELATIONSHIP)')
# (True, False, 'nxalg.edge_dfs', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.edge_dfs(source = Null :: NODE?, orientation = Null :: STRING?) :: (edges :: LIST OF RELATIONSHIP)')
# (True, False, 'nxalg.find_cliques', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.find_cliques() :: (cliques :: LIST OF LIST OF NODE)')
# (True, False, 'nxalg.find_cycle', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.find_cycle(source = Null :: LIST? OF NODE, orientation = Null :: STRING?) :: (cycle :: LIST? OF RELATIONSHIP)')
# (True, False, 'nxalg.flow_hierarchy', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.flow_hierarchy(weight = Null :: STRING?) :: (flow_hierarchy :: FLOAT)')
# (True, False, 'nxalg.global_efficiency', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.global_efficiency() :: (global_efficiency :: FLOAT)')
# (True, False, 'nxalg.greedy_color', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.greedy_color(strategy = "largest_first" :: STRING, interchange = false :: BOOLEAN) :: (color :: INTEGER, node :: NODE)')
# (True, False, 'nxalg.has_eulerian_path', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.has_eulerian_path() :: (has_eulerian_path :: BOOLEAN)')
# (True, False, 'nxalg.has_path', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.has_path(source :: NODE, target :: NODE) :: (has_path :: BOOLEAN)')
# (True, False, 'nxalg.immediate_dominators', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.immediate_dominators(start :: NODE) :: (dominator :: NODE, node :: NODE)')
# (True, False, 'nxalg.is_arborescence', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_arborescence() :: (is_arborescence :: BOOLEAN)')
# (True, False, 'nxalg.is_at_free', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_at_free() :: (is_at_free :: BOOLEAN)')
# (True, False, 'nxalg.is_bipartite', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_bipartite() :: (is_bipartite :: BOOLEAN)')
# (True, False, 'nxalg.is_branching', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_branching() :: (is_branching :: BOOLEAN)')
# (True, False, 'nxalg.is_chordal', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_chordal() :: (is_chordal :: BOOLEAN)')
# (True, False, 'nxalg.is_distance_regular', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_distance_regular() :: (is_distance_regular :: BOOLEAN)')
# (True, False, 'nxalg.is_edge_cover', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_edge_cover(cover :: LIST OF RELATIONSHIP) :: (is_edge_cover :: BOOLEAN)')
# (True, False, 'nxalg.is_eulerian', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_eulerian() :: (is_eulerian :: BOOLEAN)')
# (True, False, 'nxalg.is_forest', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_forest() :: (is_forest :: BOOLEAN)')
# (True, False, 'nxalg.is_isolate', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_isolate(n :: NODE) :: (is_isolate :: BOOLEAN)')
# (True, False, 'nxalg.is_isomorphic', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_isomorphic(nodes1 :: LIST OF NODE, edges1 :: LIST OF RELATIONSHIP, nodes2 :: LIST OF NODE, edges2 :: LIST OF RELATIONSHIP) :: (is_isomorphic :: BOOLEAN)')
# (True, False, 'nxalg.is_semieulerian', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_semieulerian() :: (is_semieulerian :: BOOLEAN)')
# (True, False, 'nxalg.is_simple_path', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_simple_path(nodes :: LIST OF NODE) :: (is_simple_path :: BOOLEAN)')
# (True, False, 'nxalg.is_strongly_regular', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_strongly_regular() :: (is_strongly_regular :: BOOLEAN)')
# (True, False, 'nxalg.is_tournament', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_tournament() :: (is_tournament :: BOOLEAN)')
# (True, False, 'nxalg.is_tree', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.is_tree() :: (is_tree :: BOOLEAN)')
# (True, False, 'nxalg.isolates', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.isolates() :: (isolates :: LIST OF NODE)')
# (True, False, 'nxalg.jaccard_coefficient', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.jaccard_coefficient(ebunch = Null :: LIST? OF LIST OF NODE) :: (coef :: FLOAT, u :: NODE, v :: NODE)')
# (True, False, 'nxalg.k_clique_communities', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.k_clique_communities(k :: INTEGER, cliques = Null :: LIST? OF LIST OF NODE) :: (communities :: LIST OF LIST OF NODE)')
# (True, False, 'nxalg.k_components', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.k_components(density = 0.95 :: NUMBER) :: (components :: LIST OF LIST OF NODE, k :: INTEGER)')
# (True, False, 'nxalg.k_edge_components', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.k_edge_components(k :: INTEGER) :: (components :: LIST OF LIST OF NODE)')
# (True, False, 'nxalg.local_efficiency', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.local_efficiency() :: (local_efficiency :: FLOAT)')
# (True, False, 'nxalg.lowest_common_ancestor', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.lowest_common_ancestor(node1 :: NODE, node2 :: NODE) :: (ancestor :: NODE?)')
# (True, False, 'nxalg.maximal_matching', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.maximal_matching() :: (edges :: LIST OF RELATIONSHIP)')
# (True, False, 'nxalg.minimum_spanning_tree', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.minimum_spanning_tree(weight = "weight" :: STRING, algorithm = "kruskal" :: STRING, ignore_nan = false :: BOOLEAN) :: (edges :: LIST OF RELATIONSHIP, nodes :: LIST OF NODE)')
# (True, False, 'nxalg.multi_source_dijkstra_path', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.multi_source_dijkstra_path(sources :: LIST OF NODE, cutoff = Null :: INTEGER?, weight = "weight" :: STRING) :: (path :: LIST OF NODE, target :: NODE)')
# (True, False, 'nxalg.multi_source_dijkstra_path_length', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.multi_source_dijkstra_path_length(sources :: LIST OF NODE, cutoff = Null :: INTEGER?, weight = "weight" :: STRING) :: (length :: NUMBER, target :: NODE)')
# (True, False, 'nxalg.node_boundary', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.node_boundary(nbunch1 :: LIST OF NODE, nbunch2 = Null :: LIST? OF NODE) :: (boundary :: LIST OF NODE)')
# (True, False, 'nxalg.node_connectivity', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.node_connectivity(source = Null :: NODE?, target = Null :: NODE?) :: (connectivity :: INTEGER)')
# (True, False, 'nxalg.node_expansion', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.node_expansion(s :: LIST OF NODE) :: (node_expansion :: NUMBER)')
# (True, False, 'nxalg.non_randomness', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.non_randomness(k = Null :: INTEGER?) :: (non_randomness :: FLOAT, relative_non_randomness :: FLOAT)')
# (True, False, 'nxalg.pagerank', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.pagerank(alpha = 0.85 :: NUMBER, personalization = Null :: STRING?, max_iter = 100 :: INTEGER, tol = 1e-06 :: NUMBER, nstart = Null :: STRING?, weight = "weight" :: STRING?, dangling = Null :: STRING?) :: (node :: NODE, rank :: FLOAT)')
# (True, False, 'nxalg.reciprocity', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.reciprocity(nodes = Null :: LIST? OF NODE) :: (node :: NODE?, reciprocity :: FLOAT?)')
# (True, False, 'nxalg.shortest_path', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.shortest_path(source = Null :: NODE?, target = Null :: NODE?, weight = Null :: STRING?, method = "dijkstra" :: STRING) :: (path :: LIST OF NODE, source :: NODE, target :: NODE)')
# (True, False, 'nxalg.shortest_path_length', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.shortest_path_length(source = Null :: NODE?, target = Null :: NODE?, weight = Null :: STRING?, method = "dijkstra" :: STRING) :: (length :: NUMBER, source :: NODE, target :: NODE)')
# (True, False, 'nxalg.simple_cycles', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.simple_cycles() :: (cycles :: LIST OF LIST OF NODE)')
# (True, False, 'nxalg.strongly_connected_components', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.strongly_connected_components() :: (components :: LIST OF LIST OF NODE)')
# (True, False, 'nxalg.topological_sort', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.topological_sort() :: (nodes :: LIST? OF NODE)')
# (True, False, 'nxalg.triadic_census', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.triadic_census() :: (count :: INTEGER, triad :: STRING)')
# (True, False, 'nxalg.voronoi_cells', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.voronoi_cells(center_nodes :: LIST OF NODE, weight = "weight" :: STRING) :: (cell :: LIST OF NODE, center :: NODE)')
# (True, False, 'nxalg.wiener_index', '/usr/lib/memgraph/query_modules/nxalg.py', 'nxalg.wiener_index(weight = Null :: STRING?) :: (wiener_index :: NUMBER)')
# (True, False, 'pagerank.get', '/usr/lib/memgraph/query_modules/pagerank.so', 'pagerank.get(max_iterations = 100 :: INTEGER, damping_factor = 0.85 :: FLOAT, stop_epsilon = 1e-05 :: FLOAT) :: (node :: NODE, rank :: FLOAT)')
# (True, False, 'pagerank_online.get', '/usr/lib/memgraph/query_modules/pagerank_online.so', 'pagerank_online.get() :: (node :: NODE, rank :: FLOAT)')
# (True, False, 'pagerank_online.reset', '/usr/lib/memgraph/query_modules/pagerank_online.so', 'pagerank_online.reset() :: (message :: STRING)')
# (True, False, 'pagerank_online.set', '/usr/lib/memgraph/query_modules/pagerank_online.so', 'pagerank_online.set(walks_per_node = 10 :: INTEGER, walk_stop_epsilon = 0.1 :: FLOAT) :: (node :: NODE, rank :: FLOAT)')
# (True, False, 'pagerank_online.update', '/usr/lib/memgraph/query_modules/pagerank_online.so', 'pagerank_online.update(created_vertices = [] :: LIST? OF NODE, created_edges = [] :: LIST? OF RELATIONSHIP, deleted_vertices = [] :: LIST? OF NODE, deleted_edges = [] :: LIST? OF RELATIONSHIP) :: (node :: NODE, rank :: FLOAT)')
# (True, False, 'path.create', '/usr/lib/memgraph/query_modules/path.so', 'path.create(start_node :: NODE, relationships = {key: []} :: MAP) :: (path :: PATH)')
# (True, False, 'path.expand', '/usr/lib/memgraph/query_modules/path.so', 'path.expand(start :: ANY, relationships :: LIST OF STRING, labels :: LIST OF STRING, min_hops :: INTEGER, max_hops :: INTEGER) :: (result :: PATH)')
# (True, False, 'path.subgraph_all', '/usr/lib/memgraph/query_modules/path.so', 'path.subgraph_all(start_node :: ANY, config :: MAP) :: (nodes :: LIST OF NODE, rels :: LIST OF RELATIONSHIP)')
# (True, False, 'path.subgraph_nodes', '/usr/lib/memgraph/query_modules/path.so', 'path.subgraph_nodes(start_node :: ANY, config :: MAP) :: (nodes :: NODE)')
# (True, False, 'periodic.iterate', '/usr/lib/memgraph/query_modules/periodic.so', 'periodic.iterate(input_query :: STRING, running_query :: STRING, config :: MAP) :: (number_of_executed_batches :: INTEGER, success :: BOOLEAN)')
# (True, False, 'py_example.procedure', '/usr/lib/memgraph/query_modules/py_example.py', 'py_example.procedure(required_arg :: ANY?, optional_arg = Null :: ANY?) :: (args :: LIST OF ANY?, avg_degree :: NUMBER, props :: MAP?, vertex_count :: INTEGER)')
# (True, True, 'py_example.write_procedure', '/usr/lib/memgraph/query_modules/py_example.py', 'py_example.write_procedure(property_name :: STRING, property_value :: ANY?) :: (created_vertex :: NODE)')
# (True, True, 'refactor.categorize', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.categorize(original_prop_key :: STRING, rel_type :: STRING, is_outgoing :: BOOLEAN, new_label :: STRING, new_prop_name_key :: STRING, copy_props_list = [] :: LIST OF STRING) :: (status :: STRING)')
# (True, True, 'refactor.clone_nodes', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.clone_nodes(nodes :: LIST OF NODE, withRelationships = false :: BOOLEAN, skipProperties = [] :: LIST OF STRING) :: (error :: STRING, input :: INTEGER, output :: NODE)')
# (True, True, 'refactor.clone_subgraph', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.clone_subgraph(nodes :: LIST OF NODE, rels = [] :: LIST OF RELATIONSHIP, config = {} :: MAP) :: (error :: STRING, input :: INTEGER, output :: NODE)')
# (True, True, 'refactor.clone_subgraph_from_paths', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.clone_subgraph_from_paths(paths :: LIST OF PATH, config = {} :: MAP) :: (error :: STRING, input :: INTEGER, output :: NODE)')
# (True, True, 'refactor.collapse_node', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.collapse_node(nodes :: ANY, type :: STRING) :: (id_collapsed :: INTEGER, new_relationship :: RELATIONSHIP)')
# (True, True, 'refactor.delete_and_reconnect', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.delete_and_reconnect(path :: PATH, nodes :: LIST OF NODE, config = {} :: MAP) :: (nodes :: LIST OF NODE, relationships :: LIST OF RELATIONSHIP)')
# (True, True, 'refactor.extract_node', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.extract_node(relationships :: ANY, labels :: LIST OF STRING, outType :: STRING, inType :: STRING) :: (error :: STRING, input :: INTEGER, output :: NODE)')
# (True, True, 'refactor.from', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.from(relationship :: RELATIONSHIP, new_from :: NODE) :: (relationship :: RELATIONSHIP)')
# (True, True, 'refactor.invert', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.invert(relationship :: ANY) :: (error :: STRING, input :: INTEGER, output :: RELATIONSHIP)')
# (True, True, 'refactor.normalize_as_boolean', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.normalize_as_boolean(entity :: ANY, property_key :: STRING, true_values :: LIST OF ANY, false_values :: LIST OF ANY) :: ()')
# (True, True, 'refactor.rename_label', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.rename_label(old_label :: STRING, new_label :: STRING, nodes :: LIST OF NODE) :: (nodes_changed :: INTEGER)')
# (True, True, 'refactor.rename_node_property', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.rename_node_property(old_property :: STRING, new_property :: STRING, nodes :: LIST OF NODE) :: (nodes_changed :: INTEGER)')
# (True, True, 'refactor.rename_type', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.rename_type(oldType :: STRING, newType :: STRING, rels :: LIST OF RELATIONSHIP) :: (relationships_changed :: INTEGER)')
# (True, True, 'refactor.rename_type_property', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.rename_type_property(old_property :: STRING, new_property :: STRING, rels :: LIST OF RELATIONSHIP) :: (relationships_changed :: INTEGER)')
# (True, True, 'refactor.to', '/usr/lib/memgraph/query_modules/refactor.so', 'refactor.to(relationship :: RELATIONSHIP, new_to :: NODE) :: (relationship :: RELATIONSHIP)')
# (True, False, 'rust_example.basic', '/usr/lib/memgraph/query_modules/rust_example.so', 'rust_example.basic(input_string :: STRING, optional_input_int = 0 :: INTEGER) :: (output_int :: INTEGER, output_string :: STRING)')
# (True, False, 'rust_example.test_procedure', '/usr/lib/memgraph/query_modules/rust_example.so', 'rust_example.test_procedure() :: (first_edge_type :: STRING, first_label :: STRING, has_L3_label :: BOOLEAN, labels_count :: INTEGER, list :: LIST OF INTEGER, name_property :: STRING, properties_string :: STRING)')
# (True, False, 'set_cover.cp_solve', '/usr/lib/memgraph/query_modules/set_cover.py', 'set_cover.cp_solve(element_vertexes :: LIST OF NODE, set_vertexes :: LIST OF NODE) :: (containing_set :: NODE)')
# (True, False, 'set_cover.greedy', '/usr/lib/memgraph/query_modules/set_cover.py', 'set_cover.greedy(element_vertexes :: LIST OF NODE, set_vertexes :: LIST OF NODE) :: (containing_set :: NODE)')
# (True, False, 'temporal.format', '/usr/lib/memgraph/query_modules/temporal.py', 'temporal.format(temporal :: ANY, format = "ISO" :: STRING) :: (formatted :: STRING)')
# (True, False, 'text.join', '/usr/lib/memgraph/query_modules/text.so', 'text.join(strings :: LIST OF STRING, delimiter :: STRING) :: (string :: STRING)')
# (True, False, 'tgn.get', '/usr/lib/memgraph/query_modules/tgn.py', 'tgn.get() :: (embedding :: LIST OF FLOAT, node :: NODE)')
# (True, False, 'tgn.get_results', '/usr/lib/memgraph/query_modules/tgn.py', 'tgn.get_results() :: (batch_num :: NUMBER, batch_process_time :: NUMBER, batch_type :: STRING, epoch_num :: NUMBER, precision :: NUMBER)')
# (True, False, 'tgn.predict_link_score', '/usr/lib/memgraph/query_modules/tgn.py', 'tgn.predict_link_score(src :: NODE, dest :: NODE) :: (prediction :: NUMBER)')
# (True, False, 'tgn.reset', '/usr/lib/memgraph/query_modules/tgn.py', 'tgn.reset() :: (message :: STRING)')
# (True, False, 'tgn.revert_from_database', '/usr/lib/memgraph/query_modules/tgn.py', 'tgn.revert_from_database() :: ()')
# (True, False, 'tgn.save_tgn_params', '/usr/lib/memgraph/query_modules/tgn.py', 'tgn.save_tgn_params() :: ()')
# (True, False, 'tgn.set_eval', '/usr/lib/memgraph/query_modules/tgn.py', 'tgn.set_eval() :: (message :: STRING)')
# (True, False, 'tgn.set_params', '/usr/lib/memgraph/query_modules/tgn.py', 'tgn.set_params(params :: MAP) :: ()')
# (True, False, 'tgn.train_and_eval', '/usr/lib/memgraph/query_modules/tgn.py', 'tgn.train_and_eval(num_epochs :: INTEGER) :: (batch_num :: NUMBER, batch_process_time :: NUMBER, batch_type :: STRING, epoch_num :: NUMBER, precision :: NUMBER)')
# (True, False, 'tgn.update', '/usr/lib/memgraph/query_modules/tgn.py', 'tgn.update(edges :: LIST OF RELATIONSHIP) :: ()')
# (True, False, 'tsp.solve', '/usr/lib/memgraph/query_modules/tsp.py', 'tsp.solve(points :: LIST OF NODE, method = "1.5_approx" :: STRING) :: (destinations :: LIST OF NODE, sources :: LIST OF NODE)')
# (True, False, 'union_find.connected', '/usr/lib/memgraph/query_modules/union_find.py', 'union_find.connected(nodes1 :: ANY?, nodes2 :: ANY?, mode = "pairwise" :: STRING, update = true :: BOOLEAN) :: (connected :: BOOLEAN, node1 :: NODE, node2 :: NODE)')
# (True, True, 'util_module.md5', '/usr/lib/memgraph/query_modules/util_module.so', 'util_module.md5(values :: LIST OF ANY) :: (result :: STRING)')
# (True, False, 'uuid_generator.get', '/usr/lib/memgraph/query_modules/uuid_generator.so', 'uuid_generator.get() :: (uuid :: STRING)')
# (True, False, 'vrp.route', '/usr/lib/memgraph/query_modules/vrp.py', 'vrp.route(depot_node :: NODE, number_of_vehicles = Null :: INTEGER?) :: (from_vertex :: NODE, to_vertex :: NODE)')
# (True, False, 'wcc.get_components', '/usr/lib/memgraph/query_modules/wcc.py', 'wcc.get_components(vertices :: LIST OF NODE, edges :: LIST OF RELATIONSHIP) :: (components :: LIST OF LIST OF NODE, n_components :: INTEGER)')
# (True, False, 'weakly_connected_components.get', '/usr/lib/memgraph/query_modules/weakly_connected_components.so', 'weakly_connected_components.get() :: (component_id :: INTEGER, node :: NODE)')
# (True, False, 'xml_module.load', '/usr/lib/memgraph/query_modules/xml_module.py', 'xml_module.load(xml_url :: STRING, simple = false :: BOOLEAN, path = "" :: STRING, xpath = "" :: STRING, headers = {} :: MAP) :: (output_map :: MAP)')

# %% [markdown]
# Find a node pair with least relationship count

# %%
# Define the Cypher query
query = """
MATCH (n)-[r]->(m)
WITH n, m, COUNT(r) AS relationship_count
ORDER BY relationship_count ASC
LIMIT 1
RETURN n, m, relationship_count
"""

# Execute the query
cursor.execute(query)

# Fetch and display the results
result = cursor.fetchone()
if result:
    node1, node2, relationship_count = result
    print(f"Node 1: {node1}, Node 2: {node2}, Number of Relationships: {relationship_count}")
else:
    print("No nodes found.")
# Out:
# Node 1: (:Entity {'name': 'LifeStage'}), Node 2: (:Entity {'name': 'Cell'}), Number of Relationships: 1

# %%
def random_relations():
    # Define the Cypher query
    query = """
    MATCH (n)-[r]->(m)
    WITH n, m, COUNT(r) AS relationship_count
    ORDER BY rand()
    LIMIT 1
    RETURN n, m, relationship_count
    """

    # Execute the query
    cursor.execute(query)

    # Fetch and display the results
    result = cursor.fetchone()
    if result:
        node1, node2, relationship_count = result
        print(f"Node 1: {node1}, Node 2: {node2}, Number of Relationships: {relationship_count}")
    else:
        print("No nodes found.")

# %%
random_relations()
# Out:
# Node 1: (:Entity {'name': 'AnatomiMolecularMixturecalEntity'}), Node 2: (:Entity {'name': 'ProteinFamily'}), Number of Relationships: 5

# %% [markdown]
# random_rel

# %%
def count_nodes(cursor):
    # Query to count the total number of nodes
    cursor.execute("MATCH (n) RETURN count(n)")
    # print(f"Total number of nodes in the database: {cursor.fetchone()[0]}")
    return cursor.fetchone()[0]

def count_relationships(cursor):
    # Query to count the total number of relationships
    cursor.execute("MATCH ()-[r]->() RETURN count(r)")
    total_relationships = cursor.fetchone()[0]
    # print(f"Total number of relationships in the database: {total_relationships}")
    return total_relationships

def show_storage_info():
    # Execute the SHOW STORAGE INFO commandytre
    cursor.execute("SHOW STORAGE INFO;")

    # Fetch and display the results
    results = cursor.fetchall()
    for result in results:
        print(result)

# %% [markdown]
# #### Build memgraph database -- with `MetaKG` Index

# %% [markdown]
# Build the `memgraph` db from the `Metakg` index.
# Should be run once -- similar to `admin.consolidate_metakg()`

# %% [markdown]
# First, lets view the data from the index

# %%
# # # Delete all nodes and relationships
# cursor.execute("MATCH (n) DETACH DELETE n")

# %% [markdown]
# #### Build the Database

# %% [markdown]
# ```
# query = """
# MERGE (s:Entity {name: $subject})
# MERGE (o:Entity {name: $object})
# MERGE (s)-[r:RELATED_TO {id: $unique_id}]->(o)
# SET r.predicate = $predicate, r.api = $api_data
# """
# ```

# %%
index = ConsolidatedMetaKGDoc.Index.name

# %%
# Cypher query to create an index on the 'name' property of 'Entity' nodes
create_index_query = """
CREATE INDEX ON :Entity(name);
"""

# Execute the index creation query
cursor.execute(create_index_query)

# %%
for edge in MetaKG.get_all_via_scan(size=1000, index=index):
    subject = edge['_source']['subject']
    object = edge['_source']['object']
    predicate = edge['_source']['predicate']
    api_data = edge['_source']['api']  # Additional data as properties

    # Construct a unique identifier for each relationship
    # This is just an example - modify it according to your data structure
    unique_id = f"{subject}-{predicate}-{object}"
    
    # Cypher query to create nodes with a static relationship
    query = """
    MERGE (s:Entity {name: $subject})
    MERGE (o:Entity {name: $object})
    MERGE (s)-[r:RELATED_TO {id: $unique_id}]->(o)
    SET r.predicate = $predicate, r.api = $api_data
    """
    params = {'subject': subject, 'object': object, 'unique_id': unique_id, 'predicate': predicate, 'api_data': api_data}
    cursor.execute(query, params)

# %% [markdown]
# #### Inspect Database

# %%
show_storage_info()
# Out:
# ('name', 'memgraph')
# ('vertex_count', 113)
# ('edge_count', 167827)
# ('average_degree', 2970.3893805309735)
# ('memory_usage', '645.79MiB')
# ('disk_usage', '885.86MiB')
# ('memory_allocated', '367.05MiB')
# ('allocation_limit', '59.06GiB')
# ('global_isolation_level', 'SNAPSHOT_ISOLATION')
# ('session_isolation_level', '')
# ('next_session_isolation_level', '')
# ('storage_mode', 'IN_MEMORY_TRANSACTIONAL')

# %%
count_nodes(cursor), count_relationships(cursor)
# Out:
# (113, 167827)

# %% [markdown]
# View the most recently created nodes:

# %%
# Fetch the most recent nodes
query = "MATCH (n) RETURN n ORDER BY n.creationTime DESC LIMIT 5"
cursor.execute(query)

# Display the results
results = cursor.fetchall()
for node in results:
    print(node)
# Out:
# (<mgclient.Node(id=70, labels={'Entity'}, properties={'name': 'GeneticInheritance'}) at 0x110556670>,)
# (<mgclient.Node(id=84, labels={'Entity'}, properties={'name': 'ActivityAndBehavior'}) at 0x110554d80>,)
# (<mgclient.Node(id=83, labels={'Entity'}, properties={'name': 'BiologicalProcessOrActivity'}) at 0x110555230>,)
# (<mgclient.Node(id=82, labels={'Entity'}, properties={'name': 'LifeStage'}) at 0x11072f7b0>,)
# (<mgclient.Node(id=81, labels={'Entity'}, properties={'name': 'MacromolecularMachineMixin'}) at 0x11072dd70>,)

# %% [markdown]
# #### Run Queries

# %% [markdown]
# Set sample query params

# %%
subject = 'Gene'
object = 'PhysiologicalProcess'

# %% [markdown]
# Query for a random document - This query matches all nodes (n) in the database, orders them randomly using the RAND() function, and limits the result to just one node.

# %%
query = "MATCH (n) RETURN n ORDER BY RAND() LIMIT 1"
cursor.execute(query)

# Fetch and display the result
result = cursor.fetchone()
if result:
    random_node = result[0]
    print(f"Random Node Properties: {random_node.properties}")
else:
    print("No nodes found in the database.")
# Out:
# Random Node Properties: {'name': 'ChemicalMixture'}

# %% [markdown]
# Return just 1 document - This query matches all nodes (n) in the database and limits the result to just one node.

# %%
query = "MATCH (n) RETURN n LIMIT 1"
cursor.execute(query)

# Fetch and display the result
result = cursor.fetchone()
if result:
    node = result[0]
    print(f"Node Properties: {node.properties}")
else:
    print("No nodes found in the database.")
# Out:
# Node Properties: {'name': 'SmallMolecule'}

# %% [markdown]
# Query that matches all relationships between nodes -

# %%
query = """
MATCH (a:Entity {name: $subject})-[r]->(b:Entity {name: $object})
RETURN r
"""

cursor.execute(query, {'subject': subject, 'object': object})

# Fetch and display the results
results = cursor.fetchall()
for result in results:
    relationship = result[0]
    print(f"Relationship Properties: {relationship.properties}")
# Out:
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6bb25982762d', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-icees-kg/1.3.0', 'ui': 'https://smart-api.info/ui/44e7a1147ca8657f50af6bb25982762d'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Exposures Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Exploring Agent']}}], 'id': 'Gene-correlated_with-PhysiologicalProcess', 'predicate': 'correlated_with'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1/team/Service%20Provider', 'support_batch': True}}, 'name': 'Service Provider TRAPI', 'smartapi': {'id': '36f82f05705c317bac17ddae3a0ea2f0', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/service-provider-trapi.yaml', 'ui': 'https://smart-api.info/ui/36f82f05705c317bac17ddae3a0ea2f0'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Service Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Exploring Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'method': 'post', 'params': {'fields': 'object.umls,predication.pmid,pmid_count,predication_count,subject.umls,subject.name,predicate,object.name', 'size': 1000}, 'path': '/query', 'request_body': {'body': '{"q": {{ queryInputs | replPrefix(\'predicate:AFFECTS AND object.semantic_type_abbreviation:celf AND pmid_count:>5 AND subject.umls\')| dump }}, "scopes": []}'}, 'server': 'https://biothings.ncats.io/semmeddb2', 'support_ ...
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1/team/Service%20Provider', 'support_batch': True}}, 'name': 'Service Provider TRAPI', 'smartapi': {'id': '36f82f05705c317bac17ddae3a0ea2f0', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/service-provider-trapi.yaml', 'ui': 'https://smart-api.info/ui/36f82f05705c317bac17ddae3a0ea2f0'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Service Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Exploring Agent']}}, {'bte': {'query_operation': {'method': 'post', 'params': {'fields': 'object.umls,predication.pmid,pmid_count,predication_count,subject.umls,subject.name,predicate,object.name', 'size': 1000}, 'path': '/query', 'request_body': {'body': '{"q": {{ queryInputs | replPrefix(\'predicate:AFFECTS AND subject.semantic_type_abbreviation:celf AND pmid_count:>5 AND object.umls\')| dump }}, "scopes": []}'}, 'server': 'https://biothings.ncats.io/semmeddb2', 'support_batch': True}, 'response_mapping': {'affected_by': {'UMLS': 'subject.umls', 'biolink:original_object': 'object.umls', 'biolink:original_predicate': 'predicate', 'biolink:original_subject': 'subject.umls', 'original_object_name': 'object.name', 'original_subject_name': 'subject.name', 'pmid_count': 'pmid_count', 'predication_count': 'predication_count', 'pubmed': 'predication.pmid'}}}, 'name': 'BioThings SEMMEDDB v2 API', 'provided_by': 'infores:semmeddb', 'smartapi': {'id': '5634bdb9a1315f85f595979eaf90a504', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmeddb/semmeddb2_specific/semmeddb2_smartapi.yaml', 'ui': 'https://smart-api.info/ui/5634bdb9a1315f85f595979eaf90a504'}, 'tags': ['disease', 'phenotype', 'gene', 'chemical', 'association', 'query', 'translator', 'biothings'], 'x-translator': {'component': 'KP', 'team': ['Service Provider']}}, {'bte': {'query_operation': {'method': 'post', 'params': {'fields': 'subject.umls,pmid,subject.name,predicate,object.umls,object.name', 'size': 1000}, 'path': '/query', 'request_body': {'body': '{"q": [ {{ queryInputs | wrap( \'["\', \'","AFFECTS","celf",1,1]\' )}}], "scopes": ["object.umls", "predicate", "subject.semantic_type_abbreviation", "subject.novelty", "object.novelty"]}'}, 'server': 'https://biothings.ncats.io/semmeddb', 'support_batch': True}, 'response_mapping': {'affected_by': {'UMLS': 'subject.uml ...
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1/team/Service%20Provider', 'support_batch': True}}, 'name': 'Service Provider TRAPI', 'smartapi': {'id': '36f82f05705c317bac17ddae3a0ea2f0', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/service-provider-trapi.yaml', 'ui': 'https://smart-api.info/ui/36f82f05705c317bac17ddae3a0ea2f0'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Service Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Exploring Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'method': 'post', 'params': {'fields': 'object.umls,predication.pmid,pmid_count,predication_count,subject.umls,subject.name,predicate,object.name', 'size': 1000}, 'path': '/query', 'request_body': {'body': '{"q": {{ queryInputs | replPrefix(\'predicate:DISRUPTS AND object.semantic_type_abbreviation:celf AND pmid_count:>5 AND subject.umls\')| dump }}, "scopes": []}'}, 'server': 'https://biothings.ncats.io/semmeddb2', 'support ...
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-entity_positively_regulates_entity-PhysiologicalProcess', 'predicate': 'entity_positively_regulates_entity'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1/team/Service%20Provider', 'support_batch': True}}, 'name': 'Service Provider TRAPI', 'smartapi': {'id': '36f82f05705c317bac17ddae3a0ea2f0', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/service-provider-trapi.yaml', 'ui': 'https://smart-api.info/ui/36f82f05705c317bac17ddae3a0ea2f0'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Service Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Exploring Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'method': 'post', 'params': {'fields': 'object.umls,predication.pmid,pmid_count,predication_count,subject.umls,subject.name,predicate,object.name', 'size': 1000}, 'path': '/query', 'request_body': {'body': '{"q": {{ queryInputs | replPrefix(\'predicate:CAUSES AND object.semantic_type_abbreviation:celf AND pmid_count:>5 AND subject.umls\')| dump }}, "scopes": []}'}, 'server': 'https://biothings.ncats.io/semmeddb2', 'support_b ...
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/pharos/1.3', 'support_batch': True}}, 'name': 'Automat-pharos(Trapi v1.3.0)', 'smartapi': {'id': '0295640b4d060133e4296dda4c31da47', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-pharos/1.3.0', 'ui': 'https://smart-api.info/ui/0295640b4d060133e4296dda4c31da47'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Ranking Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/robokopkg/1.3', 'support_batch': True}}, 'name': 'Automat-robokop(Trapi v1.3.0)', 'smartapi': {'id': '123ee14a757d01213707e1f90b01736a', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-robokop/1.3.0', 'ui': 'https://smart-api.info/ui/123ee14a757d01213707e1f90b01736a'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Ranking Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Exploring Agent']}}], 'id': 'Gene-genetic_association-PhysiologicalProcess', 'predicate': 'genetic_association'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-composed_primarily_of-PhysiologicalProcess', 'predicate': 'composed_primarily_of'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-treated_by-PhysiologicalProcess', 'predicate': 'treated_by'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-gene_associated_with_condition-PhysiologicalProcess', 'predicate': 'gene_associated_with_condition'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-associated_with_sensitivity_to-PhysiologicalProcess', 'predicate': 'associated_with_sensitivity_to'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-increases_response_to-PhysiologicalProcess', 'predicate': 'increases_response_to'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-response_decreased_by-PhysiologicalProcess', 'predicate': 'response_decreased_by'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-resistance_associated_with-PhysiologicalProcess', 'predicate': 'resistance_associated_with'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-produced_by-PhysiologicalProcess', 'predicate': 'produced_by'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-interacts_with-PhysiologicalProcess', 'predicate': 'interacts_with'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-treats-PhysiologicalProcess', 'predicate': 'treats'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-condition_associated_with_gene-PhysiologicalProcess', 'predicate': 'condition_associated_with_gene'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-is_ameliorated_by-PhysiologicalProcess', 'predicate': 'is_ameliorated_by'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-regulates-PhysiologicalProcess', 'predicate': 'regulates'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-response_increased_by-PhysiologicalProcess', 'predicate': 'response_increased_by'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-sensitivity_associated_with-PhysiologicalProcess', 'predicate': 'sensitivity_associated_with'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-has_biomarker-PhysiologicalProcess', 'predicate': 'has_biomarker'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-participates_in-PhysiologicalProcess', 'predicate': 'participates_in'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-decreased_likelihood_associated_with-PhysiologicalProcess', 'predicate': 'decreased_likelihood_associated_with'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-contributes_to-PhysiologicalProcess', 'predicate': 'contributes_to'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://explanatory-agent.transltr.io/v1.3/', 'support_batch': True}}, 'name': 'Explanatory Agent API', 'smartapi': {'id': '95b8a4ac17ea779165a709185ac07f23', 'metadata': 'https://raw.githubusercontent.com/NCATSTranslator/Explanatory-Agent/master/Agent/smart-api-1.2.0.yaml', 'ui': 'https://smart-api.info/ui/95b8a4ac17ea779165a709185ac07f23'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', '1.3.0', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Explanatory Agent']}}], 'id': 'Gene-caused_by-PhysiologicalProcess', 'predicate': 'caused_by'}
# ...
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-close_match-PhysiologicalProcess', 'predicate': 'close_match'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-subclass_of-PhysiologicalProcess', 'predicate': 'subclass_of'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-prevents-PhysiologicalProcess', 'predicate': 'prevents'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-enables-PhysiologicalProcess', 'predicate': 'enables'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-has_input-PhysiologicalProcess', 'predicate': 'has_input'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-coexists_with-PhysiologicalProcess', 'predicate': 'coexists_with'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Gene-manifestation_of-PhysiologicalProcess', 'predicate': 'manifestation_of'}
# Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}], 'id': 'Gene-produces-PhysiologicalProcess', 'predicate': 'produces'}

# %% [markdown]
# Get the total count of the relationships

# %%
query = """
MATCH (a:Entity {name: $subject})-[r]->(b:Entity {name: $object})
RETURN COUNT(r) as relationship_count
"""

cursor.execute(query, {'subject': subject, 'object': object})

# Fetch and display the result
result = cursor.fetchone()
if result:
    print(f"Number of relationships between '{subject}' and '{object}': {result[0]}")
else:
    print("No relationships found.")
# Out:
# Number of relationships between 'Gene' and 'PhysiologicalProcess': 67

# %% [markdown]
# Print only the relation(predicate) name

# %%
list_query = """
MATCH (a:Entity {name: $subject})-[r]->(b:Entity {name: $object})
RETURN DISTINCT r.predicate as predicate
"""

# Execute the list query
cursor.execute(list_query, {'subject': subject, 'object': object})
list_results = cursor.fetchall()
pp.pprint(f"Predicates: {list_results}")
# Out:
# ("Predicates: [('correlated_with',), ('affects',), ('affected_by',), "
#  "('disrupts',), ('entity_positively_regulates_entity',), ('causes',), "
#  "('genetic_association',), ('composed_primarily_of',), ('treated_by',), "
#  "('gene_associated_with_condition',), ('associated_with_sensitivity_to',), "
#  "('increases_response_to',), ('response_decreased_by',), "
#  "('resistance_associated_with',), ('produced_by',), ('interacts_with',), "
#  "('treats',), ('condition_associated_with_gene',), ('is_ameliorated_by',), "
#  "('regulates',), ('response_increased_by',), "
#  "('sensitivity_associated_with',), ('has_biomarker',), ('participates_in',), "
#  "('decreased_likelihood_associated_with',), ('contributes_to',), "
#  "('caused_by',), ('associated_with_increased_likelihood_of',), "
#  "('has_participant',), ('entity_negatively_regulates_entity',), "
#  "('decreases_response_to',), ('associated_with',), ('is_exacerbated_by',), "
#  "('ameliorates',), ('positively_correlated_with',), ('disrupted_by',), "
#  "('increased_likelihood_associated_with',), "
#  "('associated_with_decreased_likelihood_of',), "
#  "('occurs_together_in_literature_with',), ('has_upstream_actor',), "
#  "('exacerbates',), ('primarily_composed_of',), ('regulated_by',), "
#  "('associated_with_resistance_to',), ('response_affected_by',), "
#  "('coexpressed_with',), ('negatively_correlated_with',), ('similar_to',), "
#  "('related_to',), ('overlaps',), ('biomarker_for',), "
#  "('affects_response_to',), ('capable_of',), ('located_in',), "
#  "('contraindicated_for',), ('expressed_in',), ('predisposes',), "
#  "('precedes',), ('actively_involved_in',), ('close_match',), "
#  "('subclass_of',), ('prevents',), ('enables',), ('has_input',), "
#  "('coexists_with',), ('manifestation_of',), ('produces',)]")

# %%
query = """
MATCH (a:Entity {name: $subject})-[r]->(b:Entity {name: $object})
RETURN a.name, r.predicate, b.name
"""

cursor.execute(query, {'subject': subject, 'object': object})

# Fetch and display the results
results = cursor.fetchall()
for result in results:
    print(f"Subject: {result[0]}, Predicate: {result[1]}, Object: {result[2]}")
# Out:
# Subject: Gene, Predicate: correlated_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: affects, Object: PhysiologicalProcess
# Subject: Gene, Predicate: affected_by, Object: PhysiologicalProcess
# Subject: Gene, Predicate: disrupts, Object: PhysiologicalProcess
# Subject: Gene, Predicate: entity_positively_regulates_entity, Object: PhysiologicalProcess
# Subject: Gene, Predicate: causes, Object: PhysiologicalProcess
# Subject: Gene, Predicate: genetic_association, Object: PhysiologicalProcess
# Subject: Gene, Predicate: composed_primarily_of, Object: PhysiologicalProcess
# Subject: Gene, Predicate: treated_by, Object: PhysiologicalProcess
# Subject: Gene, Predicate: gene_associated_with_condition, Object: PhysiologicalProcess
# Subject: Gene, Predicate: associated_with_sensitivity_to, Object: PhysiologicalProcess
# Subject: Gene, Predicate: increases_response_to, Object: PhysiologicalProcess
# Subject: Gene, Predicate: response_decreased_by, Object: PhysiologicalProcess
# Subject: Gene, Predicate: resistance_associated_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: produced_by, Object: PhysiologicalProcess
# Subject: Gene, Predicate: interacts_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: treats, Object: PhysiologicalProcess
# Subject: Gene, Predicate: condition_associated_with_gene, Object: PhysiologicalProcess
# Subject: Gene, Predicate: is_ameliorated_by, Object: PhysiologicalProcess
# Subject: Gene, Predicate: regulates, Object: PhysiologicalProcess
# Subject: Gene, Predicate: response_increased_by, Object: PhysiologicalProcess
# Subject: Gene, Predicate: sensitivity_associated_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: has_biomarker, Object: PhysiologicalProcess
# Subject: Gene, Predicate: participates_in, Object: PhysiologicalProcess
# Subject: Gene, Predicate: decreased_likelihood_associated_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: contributes_to, Object: PhysiologicalProcess
# Subject: Gene, Predicate: caused_by, Object: PhysiologicalProcess
# Subject: Gene, Predicate: associated_with_increased_likelihood_of, Object: PhysiologicalProcess
# Subject: Gene, Predicate: has_participant, Object: PhysiologicalProcess
# Subject: Gene, Predicate: entity_negatively_regulates_entity, Object: PhysiologicalProcess
# Subject: Gene, Predicate: decreases_response_to, Object: PhysiologicalProcess
# Subject: Gene, Predicate: associated_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: is_exacerbated_by, Object: PhysiologicalProcess
# Subject: Gene, Predicate: ameliorates, Object: PhysiologicalProcess
# Subject: Gene, Predicate: positively_correlated_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: disrupted_by, Object: PhysiologicalProcess
# Subject: Gene, Predicate: increased_likelihood_associated_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: associated_with_decreased_likelihood_of, Object: PhysiologicalProcess
# Subject: Gene, Predicate: occurs_together_in_literature_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: has_upstream_actor, Object: PhysiologicalProcess
# Subject: Gene, Predicate: exacerbates, Object: PhysiologicalProcess
# Subject: Gene, Predicate: primarily_composed_of, Object: PhysiologicalProcess
# Subject: Gene, Predicate: regulated_by, Object: PhysiologicalProcess
# Subject: Gene, Predicate: associated_with_resistance_to, Object: PhysiologicalProcess
# Subject: Gene, Predicate: response_affected_by, Object: PhysiologicalProcess
# Subject: Gene, Predicate: coexpressed_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: negatively_correlated_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: similar_to, Object: PhysiologicalProcess
# Subject: Gene, Predicate: related_to, Object: PhysiologicalProcess
# Subject: Gene, Predicate: overlaps, Object: PhysiologicalProcess
# Subject: Gene, Predicate: biomarker_for, Object: PhysiologicalProcess
# Subject: Gene, Predicate: affects_response_to, Object: PhysiologicalProcess
# Subject: Gene, Predicate: capable_of, Object: PhysiologicalProcess
# Subject: Gene, Predicate: located_in, Object: PhysiologicalProcess
# Subject: Gene, Predicate: contraindicated_for, Object: PhysiologicalProcess
# Subject: Gene, Predicate: expressed_in, Object: PhysiologicalProcess
# Subject: Gene, Predicate: predisposes, Object: PhysiologicalProcess
# Subject: Gene, Predicate: precedes, Object: PhysiologicalProcess
# Subject: Gene, Predicate: actively_involved_in, Object: PhysiologicalProcess
# Subject: Gene, Predicate: close_match, Object: PhysiologicalProcess
# Subject: Gene, Predicate: subclass_of, Object: PhysiologicalProcess
# Subject: Gene, Predicate: prevents, Object: PhysiologicalProcess
# Subject: Gene, Predicate: enables, Object: PhysiologicalProcess
# Subject: Gene, Predicate: has_input, Object: PhysiologicalProcess
# Subject: Gene, Predicate: coexists_with, Object: PhysiologicalProcess
# Subject: Gene, Predicate: manifestation_of, Object: PhysiologicalProcess
# Subject: Gene, Predicate: produces, Object: PhysiologicalProcess

# %%
# Methods
def count_relationships_between_nodes(cursor, subject, object):
    query = """
    MATCH (a:Entity {name: $subject})-[r]->(b:Entity {name: $object})
    RETURN COUNT(r) as relationship_count
    """

    cursor.execute(query, {'subject': subject, 'object': object})

    # Fetch and display the result
    result = cursor.fetchone()
    if result:
        print(f"Number of relationships between '{subject}' and '{object}': {result[0]}")
    else:
        print("No relationships found.")

# %%
count_relationships_between_nodes(cursor, 'ChemicalMixture', 'SmallMolecule')
# Out:
# Number of relationships between 'ChemicalMixture' and 'SmallMolecule': 61

# %% [markdown]
# Get the paths

# %% [markdown]
# ## Subgraphs

# %%
# # this pair of nodes have 1 relationship between them, easy to test
# subject = 'InformationResource'
# object = 'Publication'

# this pair has 5 relationships between them, more complex to test
subject='AnatomiMolecularMixturecalEntity'
object='ProteinFamily'

# %%
query="""
MATCH p=(n:Entity {name: $start_name})-[r:RELATED_TO]->(m:Entity {name: $end_name})
WITH project(p) AS subgraph
RETURN subgraph;
"""

cursor.execute(query, {'start_name': subject, 'end_name': object})
results = cursor.fetchall()

# %% [markdown]
# **Inspect Subgraph**

# %%
# results

# %% [markdown]
# 1. **Node and Relationship Attributes:** Retrieve attributes of the nodes and relationships in the subgraph. For example, you can get their labels, properties, or counts.

# %%
query = """
MATCH p=(n:Entity {name: $start_name})-[r:RELATED_TO]->(m:Entity {name: $end_name})
RETURN n as StartNode, labels(n) as StartLabels, properties(n) as StartProperties,
       m as EndNode, labels(m) as EndLabels, properties(m) as EndProperties,
       type(r) as RelationshipType, properties(r) as RelationshipProperties
"""

cursor.execute(query, {'start_name': subject, 'end_name': object})
results = cursor.fetchall()

for result in results:
    # Accessing tuple elements by index
    start_node, start_labels, start_properties, end_node, end_labels, end_properties, relationship_type, relationship_properties = result
    
    print(f"Start Node: {start_node}, Start Node Labels: {start_labels}, Start Node Properties: {start_properties}")
    print(f"End Node: {end_node}, End Node Labels: {end_labels}, End Node Properties: {end_properties}")
    print(f"Relationship Type: {relationship_type}, Relationship Properties: {relationship_properties}")
# Out:
# Start Node: (:Entity {'name': 'InformationResource'}), Start Node Labels: ['Entity'], Start Node Properties: {'name': 'InformationResource'}
# End Node: (:Entity {'name': 'Publication'}), End Node Labels: ['Entity'], End Node Properties: {'name': 'Publication'}
# Relationship Type: RELATED_TO, Relationship Properties: {'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-subclass_of-Publication', 'predicate': 'subclass_of'}

# %% [markdown]
# 2. **Subgraph Structure:** If you're interested in the overall structure of the subgraph, such as how many nodes and relationships it contains, or specific patterns within it, you can modify the query to summarize this information.

# %%
query = """
MATCH p=(n:Entity {name: $start_name})-[r:RELATED_TO]->(m:Entity {name: $end_name})
WITH n, m, r
RETURN count(distinct n) as NodeCount, count(distinct m) as EndNodeCount, count(r) as RelationshipCount
"""

cursor.execute(query, {'start_name': subject, 'end_name': object})
results = cursor.fetchall()

for result in results:
    # Accessing elements by their index
    node_count, end_node_count, relationship_count = result
    print(f"Number of Start Nodes: {node_count}, Number of End Nodes: {end_node_count}, Number of Relationships: {relationship_count}")
# Out:
# Number of Start Nodes: 1, Number of End Nodes: 1, Number of Relationships: 1

# %% [markdown]
# 3. **Explore Connected Nodes:** To explore further from the start and end nodes, you can extend the query to fetch nodes connected to them.

# %%
query = """
MATCH (start:Entity {name: $start_name})-[r1:RELATED_TO]->(m:Entity),
      (m)-[r2:RELATED_TO]->(end:Entity {name: $end_name})
RETURN start, m, end, r1, r2
"""

cursor.execute(query, {'start_name': subject, 'end_name': object})
results = cursor.fetchall()
for result in results:
    print(result)
# Out:
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118ebf330>, <mgclient.Node(id=14, labels={'Entity'}, properties={'name': 'Disease'}) at 0x118ebf960>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebe5b0>, <mgclient.Relationship(start_id=113, end_id=14, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-Disease', 'predicate': 'associated_with'}) at 0x11931ea30>, <mgclient.Relationship(start_id=14, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6bb25982762d', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-icees-kg/1.3.0', 'ui': 'https://smart-api.info/ui/44e7a1147ca8657f50af6bb25982762d'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Exposures Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118ebdd70>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebfde0>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebfb70>, <mgclient.Relationship(start_id=113, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-subclass_of-Publication', 'predicate': 'subclass_of'}) at 0x11932a3b0>, <mgclient.Relationship(start_id=8, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6bb25982762d', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-icees-kg/1.3.0', 'ui': 'https://smart-api.info/ui/44e7a1147ca8657f50af6bb25982762d'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Exposures Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'biothings', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Exploring Agent']}}], 'id': 'Publication-correlated_with-Publication', 'predicate': 'correlated_with'}) at 0x119310cf0>)
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118ebf4b0>, <mgclient.Node(id=19, labels={'Entity'}, properties={'name': 'InformationContentEntity'}) at 0x118ebf870>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebffc0>, <mgclient.Relationship(start_id=113, end_id=19, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-subclass_of-InformationContentEntity', 'predicate': 'subclass_of'}) at 0x1193136b0>, <mgclient.Relationship(start_id=19, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6bb25982762d', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-icees-kg/1.3.0', 'ui': 'https://smart-api.info/ui/44e7a1147ca8657f50af6bb25982762d'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Exposures Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi',  ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118ebf390>, <mgclient.Node(id=19, labels={'Entity'}, properties={'name': 'InformationContentEntity'}) at 0x118ebf180>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebed90>, <mgclient.Relationship(start_id=113, end_id=19, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-related_to-InformationContentEntity', 'predicate': 'related_to'}) at 0x11932f5f0>, <mgclient.Relationship(start_id=19, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6bb25982762d', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-icees-kg/1.3.0', 'ui': 'https://smart-api.info/ui/44e7a1147ca8657f50af6bb25982762d'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Exposures Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'b ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118ebf8d0>, <mgclient.Node(id=19, labels={'Entity'}, properties={'name': 'InformationContentEntity'}) at 0x118ebe760>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebe820>, <mgclient.Relationship(start_id=113, end_id=19, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-subclass_of-InformationContentEntity', 'predicate': 'subclass_of'}) at 0x119336a70>, <mgclient.Relationship(start_id=19, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://ontology-kp.apps.renci.org', 'support_batch': True}}, 'name': 'Ontology-KP API', 'smartapi': {'id': '2ca2daadd989387f1e8f7121fa214eda', 'metadata': 'https://ontology-kp.apps.renci.org/docs/docs.yaml', 'ui': 'https://smart-api.info/ui/2ca2daadd989387f1e8f7121fa214eda'}, 'tags': ['translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Standards Reference Implementation Team']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', ' ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118ebf120>, <mgclient.Node(id=19, labels={'Entity'}, properties={'name': 'InformationContentEntity'}) at 0x118ebff00>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebebe0>, <mgclient.Relationship(start_id=113, end_id=19, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-related_to-InformationContentEntity', 'predicate': 'related_to'}) at 0x11933b8f0>, <mgclient.Relationship(start_id=19, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://ontology-kp.apps.renci.org', 'support_batch': True}}, 'name': 'Ontology-KP API', 'smartapi': {'id': '2ca2daadd989387f1e8f7121fa214eda', 'metadata': 'https://ontology-kp.apps.renci.org/docs/docs.yaml', 'ui': 'https://smart-api.info/ui/2ca2daadd989387f1e8f7121fa214eda'}, 'tags': ['translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Standards Reference Implementation Team']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bt ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118ebfd80>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebf840>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebe6d0>, <mgclient.Relationship(start_id=113, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-subclass_of-Publication', 'predicate': 'subclass_of'}) at 0x11933f970>, <mgclient.Relationship(start_id=8, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://ontology-kp.apps.renci.org', 'support_batch': True}}, 'name': 'Ontology-KP API', 'smartapi': {'id': '2ca2daadd989387f1e8f7121fa214eda', 'metadata': 'https://ontology-kp.apps.renci.org/docs/docs.yaml', 'ui': 'https://smart-api.info/ui/2ca2daadd989387f1e8f7121fa214eda'}, 'tags': ['translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Standards Reference Implementation Team']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator':  ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118ebe970>, <mgclient.Node(id=40, labels={'Entity'}, properties={'name': 'NamedThing'}) at 0x118ebef70>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebf3f0>, <mgclient.Relationship(start_id=113, end_id=40, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-NamedThing', 'predicate': 'associated_with'}) at 0x119347930>, <mgclient.Relationship(start_id=40, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://ontology-kp.apps.renci.org', 'support_batch': True}}, 'name': 'Ontology-KP API', 'smartapi': {'id': '2ca2daadd989387f1e8f7121fa214eda', 'metadata': 'https://ontology-kp.apps.renci.org/docs/docs.yaml', 'ui': 'https://smart-api.info/ui/2ca2daadd989387f1e8f7121fa214eda'}, 'tags': ['translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Standards Reference Implementation Team']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-tran ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118ebff30>, <mgclient.Node(id=40, labels={'Entity'}, properties={'name': 'NamedThing'}) at 0x118ebe9d0>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebfc30>, <mgclient.Relationship(start_id=113, end_id=40, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-subclass_of-NamedThing', 'predicate': 'subclass_of'}) at 0x11934b8f0>, <mgclient.Relationship(start_id=40, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://ontology-kp.apps.renci.org', 'support_batch': True}}, 'name': 'Ontology-KP API', 'smartapi': {'id': '2ca2daadd989387f1e8f7121fa214eda', 'metadata': 'https://ontology-kp.apps.renci.org/docs/docs.yaml', 'ui': 'https://smart-api.info/ui/2ca2daadd989387f1e8f7121fa214eda'}, 'tags': ['translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Standards Reference Implementation Team']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118ebfd20>, <mgclient.Node(id=15, labels={'Entity'}, properties={'name': 'PhenotypicFeature'}) at 0x118ebf810>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebfe10>, <mgclient.Relationship(start_id=113, end_id=15, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-PhenotypicFeature', 'predicate': 'associated_with'}) at 0x1193541f0>, <mgclient.Relationship(start_id=15, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://automat.transltr.io/icees-kg/1.3', 'support_batch': True}}, 'name': 'Automat-icees-kg(Trapi v1.3.0)', 'smartapi': {'id': '44e7a1147ca8657f50af6bb25982762d', 'metadata': 'https://trapi-openapi.apps.renci.org/trapi/infores:automat-icees-kg/1.3.0', 'ui': 'https://smart-api.info/ui/44e7a1147ca8657f50af6bb25982762d'}, 'tags': ['translator', 'automat', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Exposures Provider']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://bte.transltr.io/v1', 'support_batch': True}}, 'name': 'BioThings Explorer (BTE) TRAPI', 'smartapi': {'id': 'dc91716f44207d2e1287c727f281d339', 'metadata': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_explorer/smartapi.yaml', 'ui': 'https://smart-api.info/ui/dc91716f44207d2e1287c727f281d339'}, 'tags': ['1.3.0', 'meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'bioth ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x10fc0f570>, <mgclient.Node(id=19, labels={'Entity'}, properties={'name': 'InformationContentEntity'}) at 0x118ebea30>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebea60>, <mgclient.Relationship(start_id=113, end_id=19, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-subclass_of-InformationContentEntity', 'predicate': 'subclass_of'}) at 0x119356470>, <mgclient.Relationship(start_id=19, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://ontology-kp.apps.renci.org', 'support_batch': True}}, 'name': 'Ontology-KP API', 'smartapi': {'id': '2ca2daadd989387f1e8f7121fa214eda', 'metadata': 'https://ontology-kp.apps.renci.org/docs/docs.yaml', 'ui': 'https://smart-api.info/ui/2ca2daadd989387f1e8f7121fa214eda'}, 'tags': ['translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Standards Reference Implementation Team']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', ' ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118ebefd0>, <mgclient.Node(id=19, labels={'Entity'}, properties={'name': 'InformationContentEntity'}) at 0x118ebf270>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118ebe880>, <mgclient.Relationship(start_id=113, end_id=19, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-related_to-InformationContentEntity', 'predicate': 'related_to'}) at 0x11935ed70>, <mgclient.Relationship(start_id=19, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://ontology-kp.apps.renci.org', 'support_batch': True}}, 'name': 'Ontology-KP API', 'smartapi': {'id': '2ca2daadd989387f1e8f7121fa214eda', 'metadata': 'https://ontology-kp.apps.renci.org/docs/docs.yaml', 'ui': 'https://smart-api.info/ui/2ca2daadd989387f1e8f7121fa214eda'}, 'tags': ['translator', 'trapi', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Standards Reference Implementation Team']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bt ...
# ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118deeee0>, <mgclient.Node(id=15, labels={'Entity'}, properties={'name': 'PhenotypicFeature'}) at 0x118deea60>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118dee790>, <mgclient.Relationship(start_id=113, end_id=15, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cbece11a'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'asyncquery_status', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-PhenotypicFeature', 'predicate': 'associated_with'}) at 0x119823af0>, <mgclient.Relationship(start_id=15, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.ncats.io/api/rtxkg2/v1.4', 'support_batch': True}}, 'name': 'RTX KG2', 'smartapi': {'id': 'd6ea093bcb5476331d309623cbece11a', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/NewFmt/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/d6ea093bcb5476331d309623cb ...
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118dee9a0>, <mgclient.Node(id=39, labels={'Entity'}, properties={'name': 'Pathway'}) at 0x118deeb50>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118deeb80>, <mgclient.Relationship(start_id=113, end_id=39, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-associated_with-Pathway', 'predicate': 'associated_with'}) at 0x11982b270>, <mgclient.Relationship(start_id=39, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Pathway-has_participant-Publication', 'predicate': 'has_participant'}) at 0x119830830>)
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118dee970>, <mgclient.Node(id=55, labels={'Entity'}, properties={'name': 'Behavior'}) at 0x118dee7f0>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118dee940>, <mgclient.Relationship(start_id=113, end_id=55, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-related_to-Behavior', 'predicate': 'related_to'}) at 0x119832070>, <mgclient.Relationship(start_id=55, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Behavior-coexists_with-Publication', 'predicate': 'coexists_with'}) at 0x1198335f0>)
# (<mgclient.Node(id=113, labels={'Entity'}, properties={'name': 'InformationResource'}) at 0x118deec40>, <mgclient.Node(id=55, labels={'Entity'}, properties={'name': 'Behavior'}) at 0x118deea30>, <mgclient.Node(id=8, labels={'Entity'}, properties={'name': 'Publication'}) at 0x118deea90>, <mgclient.Relationship(start_id=113, end_id=55, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'InformationResource-related_to-Behavior', 'predicate': 'related_to'}) at 0x119834e70>, <mgclient.Relationship(start_id=55, end_id=8, type='RELATED_TO', properties={'api': [{'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://kg2.transltr.io/api/rtxkg2/v1.3', 'support_batch': True}}, 'name': 'RTX KG2 - TRAPI 1.3.0', 'smartapi': {'id': 'ccd4a8bb83de81401e9a27f1d8e7f948', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/KG2/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/ccd4a8bb83de81401e9a27f1d8e7f948'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'entity', 'status', 'bte-trapi'], 'x-translator': {'component': 'KP', 'team': ['Expander Agent']}}, {'bte': {'query_operation': {'input_separator': ',', 'method': 'post', 'params': None, 'path': '/query', 'path_params': None, 'request_body': None, 'server': 'https://arax.transltr.io/api/arax/v1.3', 'support_batch': True}}, 'name': 'ARAX Translator Reasoner - TRAPI 1.3.0', 'smartapi': {'id': 'e248aefca0f469229e82cca80fbabc89', 'metadata': 'https://raw.githubusercontent.com/RTXteam/RTX/production/code/UI/OpenAPI/python-flask-server/openapi_server/openapi/openapi.yaml', 'ui': 'https://smart-api.info/ui/e248aefca0f469229e82cca80fbabc89'}, 'tags': ['meta_knowledge_graph', 'query', 'asyncquery', 'translator', 'trapi', 'response', 'translate', 'entity', 'exampleQuestions', 'PubmedMeshNgd', 'status', 'bte-trapi'], 'x-translator': {'component': 'ARA', 'team': ['Expander Agent']}}], 'id': 'Behavior-close_match-Publication', 'predicate': 'close_match'}) at 0x1198363f0>)

# %% [markdown]
# ### Get all simple paths

# %% [markdown]
# Run `nxalg` method -- networkx extension

# %%
# # # this pair of nodes have 1 relationship between them, easy to test
# subject = 'InformationResource'
# object = 'Publication'
# this pair has 5 relationships between them, more complex to test
subject='AnatomiMolecularMixturecalEntity'
object='ProteinFamily'

# %%
cursor.execute("CALL mg.load('nxalg');")
# Out:
# mg_raw_transport_recv: connection closed by server
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/setup_memgraph_metakg_db.ipynb Cell 58 line 1
# ----> <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/setup_memgraph_metakg_db.ipynb#Y111sZmlsZQ%3D%3D?line=0'>1</a> cursor.execute("CALL mg.load('nxalg');")
#
# DatabaseError: failed to receive chunk size
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
subgraph_query = """
MATCH p=(start:Entity {name: $start_name})-[r:RELATED_TO]->(end:Entity {name: $end_name})
WITH project(p) AS subgraph
RETURN subgraph;
"""
cursor.execute(subgraph_query, {'start_name': subject, 'end_name': object})
subgraph_result = cursor.fetchone()
subgraph = subgraph_result[0] if subgraph_result else None

# %%
projection_query = """
MATCH p=(start:Entity {name: $start_name})-[r:RELATED_TO]->(end:Entity {name: $end_name})
WITH project(p) AS subgraph
RETURN subgraph;
"""
cursor.execute(projection_query, {'start_name': subject, 'end_name': object})
subgraph_result = cursor.fetchone()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/setup_memgraph_metakg_db.ipynb Cell 59 line 6
#       <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/setup_memgraph_metakg_db.ipynb#Y130sZmlsZQ%3D%3D?line=0'>1</a> projection_query = """
#       <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/setup_memgraph_metakg_db.ipynb#Y130sZmlsZQ%3D%3D?line=1'>2</a> MATCH p=(start:Entity {name: $start_name})-[r:RELATED_TO]->(end:Entity {name: $end_name})
#       <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/setup_memgraph_metakg_db.ipynb#Y130sZmlsZQ%3D%3D?line=2'>3</a> WITH project(p) AS subgraph
#       <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/setup_memgraph_metakg_db.ipynb#Y130sZmlsZQ%3D%3D?line=3'>4</a> RETURN subgraph;
#       <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/setup_memgraph_metakg_db.ipynb#Y130sZmlsZQ%3D%3D?line=4'>5</a> """
# ----> <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/setup_memgraph_metakg_db.ipynb#Y130sZmlsZQ%3D%3D?line=5'>6</a> cursor.execute(projection_query, {'start_name': subject, 'end_name': object})
#       <a href='vscode-notebook-cell:/Users/nacosta/Documents/smartAPI/path_finder2.0/smartAPI/src/setup_memgraph_metakg_db.ipynb#Y130sZmlsZQ%3D%3D?line=6'>7</a> subgraph_result = cursor.fetchone()
#
# NameError: name 'subject' is not defined

# %%
algorithm_query = """
MATCH (start:Entity {name: $start_name}), (end:Entity {name: $end_name})
WHERE id(start) < id(end)  // Ensures each pair is processed once
MATCH p=(start)-[r:RELATED_TO]->(end)
CALL nxalg.all_simple_paths(start, end, 3) 
YIELD path
RETURN path;
"""

cursor.execute(algorithm_query, {'start_name': subject, 'end_name': object})
results = cursor.fetchall()
for result in results:
    path = result[0]
    print(here)
    print(f"Path: {path}")

# %% [markdown]
# Run `algo` methods to test package

# %%
projection_query = """
MATCH p=(n:Entity {name: $start_name})-[r:RELATED_TO]->(m:Entity {name: $end_name})
WITH project(p) AS subgraph
RETURN subgraph;
"""
cursor.execute(projection_query, {'start_name': subject, 'end_name': object})
projection_result = cursor.fetchone()  # Assuming this returns the subgraph projection
subgraph = projection_result[0]

# %%
# Define the Cypher query
query = """
MATCH (n:Label), (m:Label)
CALL nxalg.all_simple_paths(n, m, 5) YIELD paths
RETURN paths
"""

# Execute the query
cursor.execute(query)

# Fetch and display the results
results = cursor.fetchall()
for result in results:
    paths = result[0]
    print(f"Paths: {paths}")

# %%
MATCH (start:Entity {name: 'AnatomiMolecularMixturecalEntity' }), (end:Entity {name: 'ProteinFamily' })
WHERE id(start) < id(end)  // Ensures each pair is processed once
MATCH p=(start)-[r:RELATED_TO]->(end)
CALL nxalg.all_simple_paths(start, end, 3) 
YIELD path
RETURN path;

# %% [markdown]
# ---
